# %% [markdown]
# # Investigating parameters effects on Sensitivity of the OGGM Mass Balance and Runoff Models

# %% [markdown]
# In this notebook we will explore the sensitivity of OGGM's mass-balance and runoff models using SAFE. We will focus on the three parameters: melt factor, precipitation factor and temperature bias.
#
# We will start by applying one-at-a-time sensitivity analysis to get a feel for how much each parameter affects the model and output. We will then consider the uncertainty of these sensitivities and work to quantify them.

# %% [markdown]
# ## Sensitivity Analysis with the OGGM Mass Balance Model

# %% [markdown]
# We will apply sensitivity analysis in the following order to investigate our model behaviour:
#
# 1. **One-at-a-time**: We will apply one-at-a-time analysis , in which we change one parameter at a time and see how the mass balance changes in accordance. To show this, we will plot an interactive mass balance time series with toggles, where the parameter values can be changed within their default boundaries.
# 2. **Global sensitivity analysis**: Here we will use AAT sampling to randomly sample a combination of the 3 parameters and investigate the sensitivity in the following ways
#     a. Qualitative - scatter plots
#     b. Quantitative - RSA and bootstrapping
#
# This will be applied first to the mass balance model in the OGGM, and then to the runoff model in the OGGM.

# %% [markdown]
# First we install the packages we require from both OGGM and SAFE.

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import scipy.stats as st

import oggm
from oggm import cfg, utils, workflow
from oggm.core import massbalance
from oggm.utils._funcs import rmsd
from oggm import tasks

# Install python package for interactive visualisation and import required functions:
# %pip install -q ipywidgets
from ipywidgets import interact, fixed

# Install SAFE package and import required functions
# %pip install SAFEpython

import xarray as xr
import safepython.PAWN as PAWN # Module to calculate PAWN sensitivity indices
import safepython.RSA_thres as RSA_tr # Module that implements RSA
from safepython.model_execution import model_execution # Module to execute the model
from safepython.sampling import AAT_sampling # Functions to perform the input sampling
from safepython.util import aggregate_boot # Functions to perform bootstrapping
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: SAFEpython in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: matplotlib>=2.2.3 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (3.10.6)
# Requirement already satisfied: numpy>=1.19.2 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (1.26.4)
# Requirement already satisfied: scipy>=1.3.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (25.0)
# Requirement already satisfied: pillow>=8 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->SAFEpython) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now prepare to load the glacier dierectories from the OGGM.

# %%
cfg.initialize(logging_level='WARNING')
cfg.PATHS['working_dir'] = utils.gettempdir(dirname='OGGM-calib-ro', reset=True)
cfg.PARAMS['border'] = 10
cfg.PARAMS['store_model_geometry'] = True
oggm.cfg.PARAMS['min_ice_thick_for_length'] = 1  # a glacier is when ice thicker than 1m
# Out:
# 2026-01-19 14:22:49: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2026-01-19 14:22:49: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2026-01-19 14:22:49: oggm.cfg: Multiprocessing: using all available processors (N=22)
# 2026-01-19 14:22:51: oggm.cfg: PARAMS['border'] changed from `80` to `10`.
# 2026-01-19 14:22:51: oggm.cfg: PARAMS['store_model_geometry'] changed from `False` to `True`.
# 2026-01-19 14:22:51: oggm.cfg: PARAMS['min_ice_thick_for_length'] changed from `0.0` to `1`.

# %% [markdown]
# We start from a well known glacier in the Austrian Alps, Hintereisferner. But you can choose any other glacier, e.g. from [this list](https://github.com/OGGM/oggm-sample-data/blob/master/wgms/rgi_wgms_links_20220112.csv)

# %%
# Hintereisferner
rgi_id = 'RGI60-11.00897'

# We pick the elevation-bands glaciers because they run a bit faster - but they create more step changes in the area outputs
base_url = 'https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/L3-L5_files/2023.3/elev_bands/W5E5_spinup'
gdir_hef = workflow.init_glacier_directories([rgi_id], from_prepro_level=4, prepro_border=160, prepro_base_url=base_url)[0]
# Out:
# 2026-01-19 14:22:53: oggm.workflow: init_glacier_directories from prepro level 4 on 1 glaciers.
# 2026-01-19 14:22:53: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers

# %%
# Get the observed mass balance and set up dataframe
mbdf = gdir_hef.get_ref_mb_data().loc[2000:2019] # WGMS data for HEF
mbdf['in_situ_mb'] = gdir_hef.get_ref_mb_data().loc[2000:2019]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

# %% [markdown]
# # 1 - One-at-a-time Sensitivity Analysis

# %% [markdown]
# We have loaded all required packages, so now we need to create a runner for the OGGM. To do this, we will set the 3 mass balance parameters to some tentative values, run the model and plot the resulting runoff timeseries. We can then change the parameter values one-at-a-time and look at how this changes the model predictions.
#
# Since we have WGMS observed data here, we will use some fit-to-data metrics to compare the difference in mean, standard deviation and RMSD between the simulated and observed mass balance values.

# %%
def oggm_sim(sample_row, gdir, run_with_hydro=False, years=range(2000,2020)): # set years here for example
    '''
    Reads in the parameters (melt_f, prcp_fac and temp_bias) set in the inputs, and runs the OGGM processes to 
    produce either a time series for the annual specific mass balance, or for the annual runoff.

    Parameters:
    -------------
    sample_row: Tuple
        The parameters we are feeding in (likely from our randomly generated samples). This is a tuple of
        (melt_f, prcp_fac, temp_bias).
    gdir: GlacierDirectory
        The glacier directory.
    run_with_hydro=False: bool
        A flag to indicate if the user wishes to produce a regular mass balance timeseries, or requires to execute the
        OGGM task, run_with_hydro, which produces a timeseries of the runoff.
    years: range(int,int)
        The years we wish to produce a timeseries for.

    Returns:
    -------------
    np.ndarray
        Specific mass balance (units: mm w.e. yr-1).
        OR Runoff (units: Mt w.e. yr-1).

    '''

    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    
    # Set the parameter values
    melt_f, prcp_fac, temp_bias = sample_row
    cfg.PARAMS['melt_f'] = float(melt_f)
    cfg.PARAMS['prcp_fac'] = float(prcp_fac)
    cfg.PARAMS['temp_bias'] = float(temp_bias)

    if run_with_hydro == False:
        # Running the model with the given parameters (without calibration which would alter them again)
        mbmod = massbalance.MonthlyTIModel(gdir, melt_f=melt_f, prcp_fac=prcp_fac, temp_bias=temp_bias)
        fls = gdir.read_pickle('inversion_flowlines') # Read flowlines
        mbdf['mod_mb'] = mbmod.get_specific_mb(fls=fls, year=mbdf.index) # Compute modelled mass balance  

        return np.array(mbdf['mod_mb'])

    else: # If the run_with_hydro flag is set to true, generate the hydrological data and calculate the runoff
        gdir.settings['error_when_glacier_reaches_boundaries'] = False # TODO- When more realistic, I assume we will not need this?
        
        # Setting the parameters in the glacier directory settings, run_with_hydro is a higher level function that reads them from there
        gdir.settings['melt_f'] = float(melt_f) 
        gdir.settings['prcp_fac'] = float(prcp_fac)
        gdir.settings['temp_bias'] = float(temp_bias)
    
        # file identifier where the model output is saved
        # Create unique file identifier based on parameters
        file_id = f'_hydro_mf{melt_f:.2f}_pf{prcp_fac:.2f}_tb{temp_bias:.2f}'
    
        # Delete old file if it exists to force recomputation
        old_file = gdir.get_filepath('model_diagnostics', filesuffix=file_id)
        if os.path.exists(old_file):
            os.remove(old_file)
    
        # We are using the task run_with_hydro to store hydrological outputs along with the usual glaciological outputs
        tasks.run_with_hydro(gdir,  # Run on the selected glacier
                         run_task=tasks.run_from_climate_data,  # which climate scenario? See following notebook for other examples
                         ys=years[0],  # Period which we will average and constantly repeat
                         init_model_filesuffix='_spinup_historical',  # use the previous run as initial state
                         init_model_yr=years[0],  # Start from spinup year 2000
                         store_monthly_hydro=True,  # Monthly ouptuts provide additional information
                         output_filesuffix=file_id);  # an identifier for the output file, to read it later
    
        with xr.open_dataset(gdir.get_filepath('model_diagnostics', filesuffix=file_id)) as ds:
            # The last step of hydrological output is NaN (we can't compute it for this year)
            ds = ds.isel(time=slice(0, -1)).load()
    
        sel_vars = [v for v in ds.variables if 'month_2d' not in ds[v].dims]
        df_annual = ds[sel_vars].to_dataframe()
    
        # These summed variabels give the total runoff from the glacier
        runoff_vars = ['melt_off_glacier', 'melt_on_glacier','liq_prcp_off_glacier', 'liq_prcp_on_glacier']
    
        # Convert them to megatonnes (instead of kg)
        df_runoff = df_annual[runoff_vars] * 1e-9
    
        # Sum all runoff components to get total runoff
        runoff = np.array(df_runoff.sum(axis=1))
    
        return runoff

# %%
def output_metric_calculator(sim, gdir, years=range(2000,2020)):
    '''
    Calculates the fit-to-data metrics from the Mass Balance data, on which we can run the sensitivity analysis.
    This is only used for the mass balance, where we can access a sufficient amount of data to calculate these metrics.

    Parameters:
    ------------

    sim: np.array
        The mass balance time series generated from the oggm_sim method, when the output is the mass balance time series.

    gdir: GlacierDirectory
        The glacier directory.

    years: range(int,int)
        The years we are using data from.

    Return:
    ------------

    YY: np.array
        An array containing the values of:
            - The difference in mass balance between the observed and simulated means.
            - The difference in mass balance between the observed and simulated standard deviations.
            - The RMSD between the simulated mass balance and the observed mass balance annual values.
    '''
    
    # Get the observed mass balance and set up dataframe
    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    mbdf['in_situ_mb'] = gdir.get_ref_mb_data().loc[years]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

    # Calculates the goodness-of-fit metrics for all model simulations compared to the in-situ mass balance
    YY = np.zeros((sim.shape[0], 3))

    for i in range(sim.shape[0]):
        # Calculate the goodness-of-fit metrics from the simulated mass balance and the in-situ mass balance
        YY[i, 0] = np.array(sim[i].mean() - mbdf['in_situ_mb'].mean()) # Calculate mean difference
        YY[i, 1] = np.array(sim[i].std() - mbdf['in_situ_mb'].std()) # Calculate standard deviation difference
        YY[i, 2] = np.array(rmsd(sim[i], mbdf['in_situ_mb'])) # Calculate RMSD

    return YY

# %% [markdown]
# We will now plot our results, the parameter values can be changed one-at-a-time via a toggle on the graph below.

# %%
# Define interactive visualisation function to set the parameters to some tentative values, 
# run the model and plot the resulting runoff time series
def oat_function(gdir, years, melt_f = 5.0, prcp_fac = 3.4, temp_bias = 0.0):
    '''  
    Calls the oggm_sim function and plots each mass balance time series with an interactive plot.

    Parameters:
    ------------
    gdir: GlacierDirectory
        The glacier directory.
    years: range
        The years we are investigating.
    melt_f = 5.0: float
        The value of the melt factor you want to use, here the unit
        is kg m-2 day-1 K-1. Defaults to the default value.
    prcp_fac = 3.4: float
        The value of the precipitation factor. Defaults to the
        default value.
    temp_bias : float
        The value of the temperature bias. Defaults to the
        default value.


    Returns:
    ------------
    An interactive plot displaying the mass balance time series of the glacier with the given parameters.
    '''
    # Create parameter array
    param = np.array([melt_f, prcp_fac, temp_bias])
    
    # Get the observed mass balance and set up dataframe
    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    mbdf['in_situ_mb'] = gdir.get_ref_mb_data().loc[years]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

    # Run the model with the given parameters, here we are interested in the modelled mass balance time series
    mb = oggm_sim(param, gdir)

    # Plot the results
    plt.figure(figsize=[15,3])
    plt.plot(mbdf['in_situ_mb'].index, mb, label='sim', color='k')
    mbdf['in_situ_mb'] = gdir_hef.get_ref_mb_data().loc[years]['ANNUAL_BALANCE']
    plt.plot(mbdf['in_situ_mb'], color=[0.7,0.7,0.7], label='obs')
    plt.ylabel('Specific mass balance (mm w.e.)')
    plt.xlabel('Year')
    plt.legend()
    plt.show();

# Create interactive plot, the toggles will change the parameter values 
interact(oat_function,
         gdir = fixed(gdir_hef),
         years = fixed(range(2000,2020)),
         melt_f = (1.5, 17.0, 0.1),
         prcp_fac = (0.1, 10.0, 0.1),
         temp_bias = (-15.0, 15.0, 0.1));
# Out:
# interactive(children=(FloatSlider(value=5.0, description='melt_f', max=17.0, min=1.5), FloatSlider(value=3.4, …

# %% [markdown]
# The above graph shows the effects that moving each of the parameters has to the mass balance time series.

# %% [markdown]
# # GSA - Global Sensitvity Analysis

# %% [markdown]
# For our Global Sensitivity Analysis here we will be initially using Regional Sensitivity Analysis (RSA) and exploring PAWN in the SAFE Toolbox later on. More information on the RSA method can be seen in [Pianosi et al., 2016](https://www.sciencedirect.com/science/article/pii/S1364815216300287?fr=RR-2&ref=pdf_download&rr=9c07930109fe6535#bib67).
#
# RSA is also called Monte Carlo filtering, here we split input samples depending on whether the associated output is above or below a prescribed threshold. Then the two input sets are compared to gain insight on the model behaviour and mapping.
#
# RSA has been widely used in applications where the model output is an objective function (i.e. a measure of the model accuracy against observations) and splitting the criterion reflects the acheivement of a minimum requirement of model performance. This works well for our Mass-Balance sensitivity in the OGGM since we have access to WGMS data from observations of the Mass-Balance. We will be comparing the fit-to-data metrics of: the difference in mean values, the difference in standard deviation values and the RMSD. In an ideal scenario, we will be aiming to get this as close to 0 as possible and so we can use this as our RSA threshold.
#
# We will be using AAT Sampling from SAFE to perform global sampling. This method will be creating Monte Carlo Simulations, we will start by plotting the mass balance time series resulting from the Monte Carlo simulations and analyse the results.

# %% [markdown]
# ### Running Monte Carlo Simulations

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)

distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 0.1, -15.0]) # Minimum values for each parameter
x_max = np.array([17.0, 10.0, 15.0]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
    
samp_strat = 'lhs' 

N = 2000 # Number of samples
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

sim = model_execution(oggm_sim, X, gdir_hef, ExtraArgOut=True) # Execute the model for all samples
# Out:
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `5.0` to `10.512516258737463`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `3.400000000000001` to `7.917786608782521`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `0.0` to `-1.0727055956282747`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `10.512516258737463` to `15.465221487639994`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `7.917786608782521` to `1.4835107765912183`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `-1.0727055956282747` to `-14.634451509917984`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `15.465221487639994` to `15.086764696441458`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4835107765912183` to `6.0391461564804345`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `-14.634451509917984` to `12.189627928641006`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `15.086764696441458` to `15.990058260167242`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `6.0391461564804345` to `2.0952062277895767`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `12.189627928641006` to `-5.350965605954162`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `15.990058260167242` to `6.288222489291435`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0952062277895767` to `9.424344640217425`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `-5.350965605954162` to `12.565756413862427`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `6.288222489291435` to `5.050969345806118`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `9.424344640217425` to `1.7707177573673012`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `12.565756413862427` to `-11.64236176708977`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `5.050969345806118` to `6.095133155699524`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7707177573673012` to `8.812629910574275`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `-11.64236176708977` to `11.346869712702219`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `6.095133155699524` to `15.888630456349205`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `8.812629910574275` to `6.531005944605457`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `11.346869712702219` to `14.210737698432272`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['melt_f'] changed from `15.888630456349205` to `4.9110969092336125`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['prcp_fac'] changed from `6.531005944605457` to `0.6805214412327887`.
# 2026-01-19 14:34:31: oggm.cfg: PARAMS['temp_bias'] changed from `14.210737698432272` to `-4.927104186639971`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `4.9110969092336125` to `16.257610598401225`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6805214412327887` to `9.370615875123729`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-4.927104186639971` to `-7.622800927530103`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `16.257610598401225` to `16.1583843439829`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `9.370615875123729` to `1.8354463351119708`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-7.622800927530103` to `14.690036238883138`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `16.1583843439829` to `2.272834303439625`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8354463351119708` to `7.103837037116146`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `14.690036238883138` to `-14.615275424587454`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `2.272834303439625` to `6.383007112569745`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `7.103837037116146` to `6.154452992941879`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-14.615275424587454` to `-10.997832992873748`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `6.383007112569745` to `7.618015570325471`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `6.154452992941879` to `2.4557449229041715`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-10.997832992873748` to `8.348386527178874`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `7.618015570325471` to `16.334679964213883`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `2.4557449229041715` to `2.0020321327403767`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `8.348386527178874` to `11.707334625526833`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `16.334679964213883` to `2.7949697451848388`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0020321327403767` to `7.119839829264339`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `11.707334625526833` to `11.110284915638914`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `2.7949697451848388` to `16.72307363682191`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `7.119839829264339` to `2.7539162808181143`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `11.110284915638914` to `-13.170461718299679`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `16.72307363682191` to `16.180370529236257`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `2.7539162808181143` to `2.84929043181692`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-13.170461718299679` to `11.977367330709964`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `16.180370529236257` to `7.081380274585576`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `2.84929043181692` to `9.108377424937865`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `11.977367330709964` to `2.929101557531986`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `7.081380274585576` to `15.559541608374657`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `9.108377424937865` to `5.900038822450278`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `2.929101557531986` to `-9.251331682704812`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `15.559541608374657` to `12.13744998892455`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `5.900038822450278` to `4.321431179015613`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-9.251331682704812` to `-12.18114060845793`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `12.13744998892455` to `11.31092897736684`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `4.321431179015613` to `8.840096587682194`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-12.18114060845793` to `-6.160491752370762`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `11.31092897736684` to `13.84266328902476`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `8.840096587682194` to `1.5204419989712707`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-6.160491752370762` to `6.296235795537779`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `13.84266328902476` to `14.376397614257685`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `1.5204419989712707` to `6.380396670457943`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `6.296235795537779` to `7.497458826269451`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `14.376397614257685` to `1.9595823033380495`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `6.380396670457943` to `0.5132949708009287`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `7.497458826269451` to `-7.9850011377836045`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `1.9595823033380495` to `11.051892581895608`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5132949708009287` to `9.129187124328642`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-7.9850011377836045` to `3.197532203820245`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `11.051892581895608` to `5.667063545375135`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `9.129187124328642` to `3.6003848776376763`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `3.197532203820245` to `-14.757920499501436`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `5.667063545375135` to `8.337310158013045`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6003848776376763` to `5.582424709445744`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-14.757920499501436` to `-3.71136783281934`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `8.337310158013045` to `6.332194205043615`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `5.582424709445744` to `4.081146203017919`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `-3.71136783281934` to `2.100327493404052`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `6.332194205043615` to `15.201640822902327`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `4.081146203017919` to `8.354449325612594`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `2.100327493404052` to `0.8775431380216485`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `15.201640822902327` to `5.877403204406653`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `8.354449325612594` to `7.160624932916272`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `0.8775431380216485` to `0.34608621435012665`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['melt_f'] changed from `5.877403204406653` to `1.599423682198558`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['prcp_fac'] changed from `7.160624932916272` to `1.409280951148302`.
# 2026-01-19 14:34:32: oggm.cfg: PARAMS['temp_bias'] changed from `0.34608621435012665` to `-13.271621659013597`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `1.599423682198558` to `7.9569411920775215`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `1.409280951148302` to `9.576759579071487`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-13.271621659013597` to `-3.8451664407948485`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `7.9569411920775215` to `15.444483828340896`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `9.576759579071487` to `5.918425674672246`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-3.8451664407948485` to `1.7508079564865753`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `15.444483828340896` to `11.980212823211136`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `5.918425674672246` to `0.6734214520179459`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `1.7508079564865753` to `-14.600843002490711`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `11.980212823211136` to `8.056906029077563`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6734214520179459` to `4.663371089830118`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-14.600843002490711` to `-14.947647693317133`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `8.056906029077563` to `10.166999220452428`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `4.663371089830118` to `8.138764779807268`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-14.947647693317133` to `-6.255829588788476`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `10.166999220452428` to `15.098867661732886`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `8.138764779807268` to `0.9217569461904502`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-6.255829588788476` to `-11.965596505137846`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `15.098867661732886` to `12.349288140367454`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9217569461904502` to `8.302214685754379`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-11.965596505137846` to `7.889176899076734`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `12.349288140367454` to `11.831675548051479`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `8.302214685754379` to `1.2498306905419603`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `7.889176899076734` to `2.343231227847191`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `11.831675548051479` to `8.369138970800243`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2498306905419603` to `7.131917851497503`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `2.343231227847191` to `-8.789519501666264`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `8.369138970800243` to `10.0675025719604`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `7.131917851497503` to `0.502776402243757`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-8.789519501666264` to `-9.98249828714227`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `10.0675025719604` to `6.140675531501133`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `0.502776402243757` to `7.807295532827441`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-9.98249828714227` to `1.1561654264591823`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `6.140675531501133` to `13.694761505129406`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `7.807295532827441` to `4.614650197081084`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `1.1561654264591823` to `11.033296368881448`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `13.694761505129406` to `16.813737612553638`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `4.614650197081084` to `0.555577051098741`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `11.033296368881448` to `7.044395917345206`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `16.813737612553638` to `6.267674869604616`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `0.555577051098741` to `0.7852437781071607`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `7.044395917345206` to `-13.025995802440846`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `6.267674869604616` to `11.201078077583928`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7852437781071607` to `9.84693890256693`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-13.025995802440846` to `-2.7599873097996035`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `11.201078077583928` to `4.976943963599829`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `9.84693890256693` to `7.789377822606281`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-2.7599873097996035` to `6.175873991419934`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `4.976943963599829` to `4.1628055082792095`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `7.789377822606281` to `2.6660310833152177`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `6.175873991419934` to `-2.560767088683738`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `4.1628055082792095` to `15.103990296761813`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `2.6660310833152177` to `5.5305077564541545`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-2.560767088683738` to `12.794477776850105`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `15.103990296761813` to `14.688449760076136`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `5.5305077564541545` to `5.267479553900133`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `12.794477776850105` to `14.123706983006034`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `14.688449760076136` to `10.961904995276104`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `5.267479553900133` to `6.592752651716872`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `14.123706983006034` to `-5.099811842149245`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `10.961904995276104` to `8.936802871174518`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `6.592752651716872` to `2.8611831053951846`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-5.099811842149245` to `-10.679684285945683`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `8.936802871174518` to `3.6618109126447678`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `2.8611831053951846` to `8.996594719354452`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `-10.679684285945683` to `8.767198823792192`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `3.6618109126447678` to `10.65494301323313`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `8.996594719354452` to `8.94727097337139`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `8.767198823792192` to `4.518777395349428`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['melt_f'] changed from `10.65494301323313` to `4.918161732404303`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['prcp_fac'] changed from `8.94727097337139` to `3.451425118849772`.
# 2026-01-19 14:34:33: oggm.cfg: PARAMS['temp_bias'] changed from `4.518777395349428` to `-14.046315457500405`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `4.918161732404303` to `11.131199427380794`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `3.451425118849772` to `4.544920701259491`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-14.046315457500405` to `-13.945289783099284`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `11.131199427380794` to `16.815358347255664`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `4.544920701259491` to `9.01073714823036`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-13.945289783099284` to `-13.774925808644666`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `16.815358347255664` to `14.407075732278825`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `9.01073714823036` to `4.777078491031432`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-13.774925808644666` to `-9.29718283368619`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `14.407075732278825` to `11.037645720007031`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `4.777078491031432` to `3.867459168026588`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-9.29718283368619` to `6.764841246310276`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `11.037645720007031` to `9.552087715857063`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `3.867459168026588` to `3.3816035589102773`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `6.764841246310276` to `13.969551661157784`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `9.552087715857063` to `16.628718325707986`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `3.3816035589102773` to `9.337482543651294`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `13.969551661157784` to `-0.24908556664848014`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `16.628718325707986` to `9.29656949063284`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `9.337482543651294` to `7.061053790385742`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-0.24908556664848014` to `-1.9825620686018137`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `9.29656949063284` to `2.610703974860576`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `7.061053790385742` to `0.6596090661181826`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-1.9825620686018137` to `-6.5360262835602025`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `2.610703974860576` to `16.76395740632276`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6596090661181826` to `5.141284427582246`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-6.5360262835602025` to `13.66946832077969`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `16.76395740632276` to `12.861360387209897`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `5.141284427582246` to `9.300175250932902`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `13.66946832077969` to `-12.689503381393074`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `12.861360387209897` to `12.434186172325424`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `9.300175250932902` to `9.073590483751778`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-12.689503381393074` to `-11.425859378610602`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `12.434186172325424` to `6.190783536980048`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `9.073590483751778` to `2.210510800698068`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-11.425859378610602` to `12.669425361277941`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `6.190783536980048` to `9.441871375174562`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `2.210510800698068` to `3.5873084192519595`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `12.669425361277941` to `5.993252741221205`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `9.441871375174562` to `15.531865732192134`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `3.5873084192519595` to `5.943652308190329`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `5.993252741221205` to `-7.278266672156058`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `15.531865732192134` to `15.541693178876152`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `5.943652308190329` to `4.713588959819483`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-7.278266672156058` to `-0.9764495745819666`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `15.541693178876152` to `10.32794687177881`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `4.713588959819483` to `8.39362638795171`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-0.9764495745819666` to `12.430076438524633`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `10.32794687177881` to `9.058989181521731`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `8.39362638795171` to `7.4626992930199645`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `12.430076438524633` to `-4.361214282103139`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `9.058989181521731` to `12.725439189515464`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `7.4626992930199645` to `9.489381130035214`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-4.361214282103139` to `13.987466183213972`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `12.725439189515464` to `6.713960423151708`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `9.489381130035214` to `1.1466182188875729`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `13.987466183213972` to `2.8152701272556797`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `6.713960423151708` to `8.022459568910909`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1466182188875729` to `0.38101848545115313`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `2.8152701272556797` to `-4.716354685479034`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `8.022459568910909` to `4.8929803747228755`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `0.38101848545115313` to `6.695844716944575`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-4.716354685479034` to `-9.31621583157089`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['melt_f'] changed from `4.8929803747228755` to `13.957746103364931`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['prcp_fac'] changed from `6.695844716944575` to `6.979255316968806`.
# 2026-01-19 14:34:34: oggm.cfg: PARAMS['temp_bias'] changed from `-9.31621583157089` to `-6.509721868404489`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `13.957746103364931` to `6.31685015788742`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `6.979255316968806` to `8.599448995970636`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-6.509721868404489` to `13.471382384920634`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `6.31685015788742` to `14.353635358422144`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `8.599448995970636` to `7.177489389694288`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `13.471382384920634` to `-6.756053219296833`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `14.353635358422144` to `10.812766476202038`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `7.177489389694288` to `6.804406607797733`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-6.756053219296833` to `12.105034133493042`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `10.812766476202038` to `11.071109856385029`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `6.804406607797733` to `6.624450397079268`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `12.105034133493042` to `1.7025484331910512`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `11.071109856385029` to `15.11908511480484`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `6.624450397079268` to `1.7576255659749902`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `1.7025484331910512` to `11.372360127415863`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `15.11908511480484` to `8.225610286448482`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7576255659749902` to `4.681820832311827`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `11.372360127415863` to `4.804300367898648`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `8.225610286448482` to `7.5698877871382875`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `4.681820832311827` to `1.4219059855893323`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `4.804300367898648` to `-1.610683855786533`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `7.5698877871382875` to `6.651597869483521`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4219059855893323` to `4.904148521167882`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-1.610683855786533` to `11.459334021336268`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `6.651597869483521` to `13.525972392705816`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `4.904148521167882` to `4.224052698448416`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `11.459334021336268` to `-2.1371908262553525`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `13.525972392705816` to `3.0593112564830234`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `4.224052698448416` to `9.831453596851622`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-2.1371908262553525` to `12.021158730863068`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `3.0593112564830234` to `3.816685704998461`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `9.831453596851622` to `3.376244874459548`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `12.021158730863068` to `11.288762758011728`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `3.816685704998461` to `8.512210273037432`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `3.376244874459548` to `5.713011967237074`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `11.288762758011728` to `5.957874656134447`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `8.512210273037432` to `9.982595933717306`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `5.713011967237074` to `6.471299207745662`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `5.957874656134447` to `8.723281552270628`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `9.982595933717306` to `13.600270669674707`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `6.471299207745662` to `8.841908782711599`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `8.723281552270628` to `-6.478051217463868`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `13.600270669674707` to `5.474417890154457`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `8.841908782711599` to `8.165378299313225`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-6.478051217463868` to `0.9465116848781641`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `5.474417890154457` to `2.51604467922719`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `8.165378299313225` to `7.6660212321294`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `0.9465116848781641` to `-6.908847977908474`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `2.51604467922719` to `14.658076605145151`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `7.6660212321294` to `7.431244431374296`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-6.908847977908474` to `-14.06499578415115`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `14.658076605145151` to `7.673802763544659`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `7.431244431374296` to `0.7308164714462465`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-14.06499578415115` to `-0.04456787930422479`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `7.673802763544659` to `2.181367781757534`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7308164714462465` to `0.763388507027173`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-0.04456787930422479` to `-6.593703243892081`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `2.181367781757534` to `12.00041580702372`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `0.763388507027173` to `0.7906262609990627`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-6.593703243892081` to `-7.587471877930416`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `12.00041580702372` to `13.189409010868681`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7906262609990627` to `4.67622148102005`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-7.587471877930416` to `-5.038827434467178`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `13.189409010868681` to `8.637756706740328`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `4.67622148102005` to `9.697764922389261`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `-5.038827434467178` to `11.252971080903741`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['melt_f'] changed from `8.637756706740328` to `16.089141881644558`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['prcp_fac'] changed from `9.697764922389261` to `3.79733053321781`.
# 2026-01-19 14:34:35: oggm.cfg: PARAMS['temp_bias'] changed from `11.252971080903741` to `-10.355072132827098`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `16.089141881644558` to `2.960188781495981`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `3.79733053321781` to `4.372548912663355`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-10.355072132827098` to `-4.326942338643281`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `2.960188781495981` to `6.8643076497876585`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `4.372548912663355` to `0.4416463289581771`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-4.326942338643281` to `14.924800492415898`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `6.8643076497876585` to `11.972068330968808`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4416463289581771` to `5.867399488583872`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `14.924800492415898` to `4.673185955084339`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `11.972068330968808` to `11.601184683129397`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `5.867399488583872` to `5.136329583406029`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `4.673185955084339` to `14.492828117019624`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `11.601184683129397` to `10.159259543364081`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `5.136329583406029` to `0.9829145092560698`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `14.492828117019624` to `-0.3030762175539028`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `10.159259543364081` to `12.963987878882572`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9829145092560698` to `8.004967131306161`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-0.3030762175539028` to `-2.1529390509960873`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `12.963987878882572` to `7.332581180363938`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `8.004967131306161` to `0.4506763334382501`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-2.1529390509960873` to `-9.68009520311245`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `7.332581180363938` to `7.536152643149271`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4506763334382501` to `4.705135797194858`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-9.68009520311245` to `7.705207082408137`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `7.536152643149271` to `4.790793186804844`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `4.705135797194858` to `6.526549670711383`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `7.705207082408137` to `12.382668750417814`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `4.790793186804844` to `15.307057975961152`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `6.526549670711383` to `2.404334504815676`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `12.382668750417814` to `8.631374644607895`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `15.307057975961152` to `8.275779440748405`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `2.404334504815676` to `2.623808342190708`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `8.631374644607895` to `6.086770379907591`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `8.275779440748405` to `7.981967916425956`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `2.623808342190708` to `0.7253145121161315`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `6.086770379907591` to `-8.03457838919441`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `7.981967916425956` to `6.832133521395339`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7253145121161315` to `9.420561573559631`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-8.03457838919441` to `-9.256978841458068`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `6.832133521395339` to `3.550196146446216`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `9.420561573559631` to `2.834002619816559`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-9.256978841458068` to `-11.630965669425702`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `3.550196146446216` to `14.988027929249153`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `2.834002619816559` to `6.571871022995784`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-11.630965669425702` to `-13.462500494029014`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `14.988027929249153` to `15.845328167893099`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `6.571871022995784` to `6.6718866527740674`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-13.462500494029014` to `-0.6563913256040603`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['melt_f'] changed from `15.845328167893099` to `2.64688057250164`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['prcp_fac'] changed from `6.6718866527740674` to `2.8895200117176065`.
# 2026-01-19 14:34:36: oggm.cfg: PARAMS['temp_bias'] changed from `-0.6563913256040603` to `-12.710227848657121`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `2.64688057250164` to `2.421819879222958`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `2.8895200117176065` to `9.716743300282754`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-12.710227848657121` to `4.849267481888006`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `2.421819879222958` to `7.59225351325005`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `9.716743300282754` to `7.167501534817582`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `4.849267481888006` to `-14.376686733465071`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `7.59225351325005` to `1.7758309485810482`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `7.167501534817582` to `6.88493992863632`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-14.376686733465071` to `-6.441442891269306`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `1.7758309485810482` to `9.328484728785183`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `6.88493992863632` to `7.495346655810829`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-6.441442891269306` to `1.5105041261456442`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `9.328484728785183` to `12.574574645939766`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `7.495346655810829` to `5.008635584451389`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `1.5105041261456442` to `-5.725985392306416`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `12.574574645939766` to `11.660537249670996`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `5.008635584451389` to `5.311020706988069`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-5.725985392306416` to `10.782470723104979`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `11.660537249670996` to `7.231272216306686`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `5.311020706988069` to `4.698652740368751`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `10.782470723104979` to `9.83330643216178`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `7.231272216306686` to `3.6334093985701004`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `4.698652740368751` to `1.194810045401915`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `9.83330643216178` to `-0.49615173122868583`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `3.6334093985701004` to `4.729279735998256`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `1.194810045401915` to `9.970977064201648`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-0.49615173122868583` to `7.332354921173593`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `4.729279735998256` to `3.545528315612161`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `9.970977064201648` to `4.155267268707624`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `7.332354921173593` to `-13.134784726416344`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `3.545528315612161` to `6.689020270809778`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `4.155267268707624` to `3.517707530018915`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-13.134784726416344` to `-4.453109076283923`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `6.689020270809778` to `4.249874386352734`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `3.517707530018915` to `8.66719489927494`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-4.453109076283923` to `-14.476703775038256`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `4.249874386352734` to `13.086072642571777`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `8.66719489927494` to `5.560076356434685`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-14.476703775038256` to `-5.492509524875`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `13.086072642571777` to `2.205214599335552`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `5.560076356434685` to `6.999661100285082`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-5.492509524875` to `-1.0535224563558696`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `2.205214599335552` to `4.801143280526077`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `6.999661100285082` to `3.2664315047366954`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-1.0535224563558696` to `-4.770842761312855`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `4.801143280526077` to `13.78914624830843`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `3.2664315047366954` to `0.877342657413747`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-4.770842761312855` to `3.7602549106092162`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `13.78914624830843` to `6.06255951830048`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `0.877342657413747` to `0.6942081459349021`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `3.7602549106092162` to `0.7783772059092353`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `6.06255951830048` to `10.49148015569061`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6942081459349021` to `4.5671172118563`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `0.7783772059092353` to `-10.303129606098722`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['melt_f'] changed from `10.49148015569061` to `5.017360990555607`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['prcp_fac'] changed from `4.5671172118563` to `1.3764608968653333`.
# 2026-01-19 14:34:37: oggm.cfg: PARAMS['temp_bias'] changed from `-10.303129606098722` to `10.019651147499463`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `5.017360990555607` to `7.177539079030277`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3764608968653333` to `8.37611888482386`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `10.019651147499463` to `9.754031020731144`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `7.177539079030277` to `13.893374469316853`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `8.37611888482386` to `7.83227588803223`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `9.754031020731144` to `2.4868699362168023`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `13.893374469316853` to `10.99306504608487`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `7.83227588803223` to `9.878525101753272`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `2.4868699362168023` to `-2.0740955270705683`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `10.99306504608487` to `10.607657286531653`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `9.878525101753272` to `9.78656842359695`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `-2.0740955270705683` to `-8.397666921895782`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `10.607657286531653` to `5.647020705494841`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `9.78656842359695` to `1.1512481977310327`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `-8.397666921895782` to `-13.633490635545854`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `5.647020705494841` to `8.85981779273374`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1512481977310327` to `4.463673565932371`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `-13.633490635545854` to `11.500537238847038`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `8.85981779273374` to `12.396874225362357`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `4.463673565932371` to `0.7044649754620145`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `11.500537238847038` to `-8.656225813142179`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `12.396874225362357` to `9.886881628090107`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7044649754620145` to `2.5562884636565246`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `-8.656225813142179` to `-13.970412994497847`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `9.886881628090107` to `4.093140627116055`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5562884636565246` to `1.0730401692157474`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `-13.970412994497847` to `6.925000987944632`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `4.093140627116055` to `7.514435069065948`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0730401692157474` to `4.396215115572416`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `6.925000987944632` to `-1.197131578086422`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `7.514435069065948` to `9.189940699670316`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['prcp_fac'] changed from `4.396215115572416` to `4.915947080155278`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['temp_bias'] changed from `-1.197131578086422` to `10.872889706179052`.
# 2026-01-19 14:34:38: oggm.cfg: PARAMS['melt_f'] changed from `9.189940699670316` to `1.6009028054373577`.
# ...
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['temp_bias'] changed from `4.100921215539003` to `13.454189318081106`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['melt_f'] changed from `15.323032387110304` to `2.1672101856421264`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['prcp_fac'] changed from `2.288566283065225` to `1.6550823564015185`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['temp_bias'] changed from `13.454189318081106` to `13.600897669743677`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['melt_f'] changed from `2.1672101856421264` to `6.636286727474185`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['prcp_fac'] changed from `1.6550823564015185` to `0.4549700738370104`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['temp_bias'] changed from `13.600897669743677` to `-6.186462099860567`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['melt_f'] changed from `6.636286727474185` to `7.200904756912468`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4549700738370104` to `5.184357764674522`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['temp_bias'] changed from `-6.186462099860567` to `-13.072964386853572`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['melt_f'] changed from `7.200904756912468` to `9.84931634001363`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['prcp_fac'] changed from `5.184357764674522` to `1.1851451489989704`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['temp_bias'] changed from `-13.072964386853572` to `0.799940492967238`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['melt_f'] changed from `9.84931634001363` to `5.461286087653079`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1851451489989704` to `7.634941674798193`.
# 2026-01-19 14:36:01: oggm.cfg: PARAMS['temp_bias'] changed from `0.799940492967238` to `5.368293301263961`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `5.461286087653079` to `1.8231758955100665`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `7.634941674798193` to `4.193315456017353`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `5.368293301263961` to `-12.507756629800774`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `1.8231758955100665` to `10.926635709612809`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `4.193315456017353` to `2.6579858809991594`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-12.507756629800774` to `-1.9238286048487208`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `10.926635709612809` to `6.537241798130365`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `2.6579858809991594` to `3.9075343443531`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-1.9238286048487208` to `-5.711369734753738`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `6.537241798130365` to `10.721654875445225`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `3.9075343443531` to `0.5852867407270566`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-5.711369734753738` to `10.328705033693332`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `10.721654875445225` to `13.722829507443057`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5852867407270566` to `1.7986562436076456`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `10.328705033693332` to `0.14060794329449422`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `13.722829507443057` to `3.1250462294518027`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7986562436076456` to `2.240397645911829`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `0.14060794329449422` to `-14.12463791239465`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `3.1250462294518027` to `14.005388577606396`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `2.240397645911829` to `3.6358420953764843`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-14.12463791239465` to `13.581503978333696`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `14.005388577606396` to `9.00189619736613`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6358420953764843` to `5.757923451812935`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `13.581503978333696` to `-12.398212353442357`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `9.00189619736613` to `4.604067809139389`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `5.757923451812935` to `4.2069158406347285`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-12.398212353442357` to `-10.514895134753804`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `4.604067809139389` to `15.429484142222003`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `4.2069158406347285` to `5.96315679311383`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-10.514895134753804` to `8.953280723232346`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `15.429484142222003` to `16.168884711597535`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `5.96315679311383` to `0.212631115891266`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `8.953280723232346` to `7.600310173126601`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `16.168884711597535` to `8.138118891900053`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `0.212631115891266` to `5.9564602750061475`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `7.600310173126601` to `-7.302355806235397`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `8.138118891900053` to `8.689978994929481`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `5.9564602750061475` to `8.10174399925819`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-7.302355806235397` to `-11.38329529333097`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `8.689978994929481` to `14.838119754325291`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `8.10174399925819` to `0.8883528394351113`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-11.38329529333097` to `-5.698759260160877`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `14.838119754325291` to `10.155858369571963`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8883528394351113` to `2.5058215367477232`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-5.698759260160877` to `-13.251081736081463`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `10.155858369571963` to `13.53071470881616`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5058215367477232` to `2.948524553711997`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-13.251081736081463` to `13.171912626774407`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `13.53071470881616` to `14.60954075578851`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `2.948524553711997` to `1.8502888557501562`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `13.171912626774407` to `-4.9963873201273135`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `14.60954075578851` to `9.03907733575426`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8502888557501562` to `6.511637481824753`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-4.9963873201273135` to `3.301240039897838`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `9.03907733575426` to `15.796806262062631`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `6.511637481824753` to `9.510404686388485`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `3.301240039897838` to `-4.248113694804884`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `15.796806262062631` to `9.680335494617982`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `9.510404686388485` to `4.718717291936221`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-4.248113694804884` to `9.644290791420389`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `9.680335494617982` to `3.2141102877521304`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `4.718717291936221` to `0.16507347963878924`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `9.644290791420389` to `0.7939746795236573`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `3.2141102877521304` to `7.007002820018921`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `0.16507347963878924` to `8.223538018505932`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `0.7939746795236573` to `-2.4855358903973706`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `7.007002820018921` to `2.125766043006587`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `8.223538018505932` to `6.830781419279408`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-2.4855358903973706` to `-9.013023007835162`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['melt_f'] changed from `2.125766043006587` to `13.313210988598327`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['prcp_fac'] changed from `6.830781419279408` to `6.935508181787084`.
# 2026-01-19 14:36:02: oggm.cfg: PARAMS['temp_bias'] changed from `-9.013023007835162` to `-10.730649950928925`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `13.313210988598327` to `10.724983336613262`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `6.935508181787084` to `9.143889759082283`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `-10.730649950928925` to `-5.366068929384953`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `10.724983336613262` to `14.108644405386716`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `9.143889759082283` to `7.202985271266294`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `-5.366068929384953` to `2.6759407690589683`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `14.108644405386716` to `5.573357947660098`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `7.202985271266294` to `3.5532867406024278`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `2.6759407690589683` to `3.5005394415124975`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `5.573357947660098` to `9.786851647219953`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `3.5532867406024278` to `1.709228502795004`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `3.5005394415124975` to `-11.341649611084527`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `9.786851647219953` to `13.49790355518238`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `1.709228502795004` to `6.017005473600075`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `-11.341649611084527` to `6.478254723995601`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `13.49790355518238` to `6.571852337775383`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `6.017005473600075` to `7.743871468471553`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `6.478254723995601` to `4.877971212066498`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `6.571852337775383` to `11.364844966014415`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `7.743871468471553` to `3.7418548365101247`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `4.877971212066498` to `-0.38692089501447136`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `11.364844966014415` to `6.029519711217038`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `3.7418548365101247` to `2.7372237643957984`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `-0.38692089501447136` to `5.306298378274342`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `6.029519711217038` to `5.925864940889475`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `2.7372237643957984` to `0.1704539518051975`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `5.306298378274342` to `7.1106261563915645`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `5.925864940889475` to `16.428279384169002`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `0.1704539518051975` to `6.101012688260413`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `7.1106261563915645` to `8.666518341104577`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `16.428279384169002` to `6.809456559633368`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `6.101012688260413` to `5.6484648886504285`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `8.666518341104577` to `6.4494123544689295`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `6.809456559633368` to `10.285111483130626`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `5.6484648886504285` to `5.808717634300296`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `6.4494123544689295` to `-5.57392590612703`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `10.285111483130626` to `7.126682350601298`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `5.808717634300296` to `3.5698945767729193`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `-5.57392590612703` to `-1.0944706907071247`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `7.126682350601298` to `6.582732514016324`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `3.5698945767729193` to `2.1875844867191923`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `-1.0944706907071247` to `-11.932884361481356`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `6.582732514016324` to `2.887347059494639`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `2.1875844867191923` to `7.97975954863615`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `-11.932884361481356` to `5.107516120506304`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `2.887347059494639` to `1.5101867741869899`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `7.97975954863615` to `3.1154051917526893`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `5.107516120506304` to `-0.5749183156228899`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `1.5101867741869899` to `11.646791410175561`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1154051917526893` to `2.7502076676887444`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `-0.5749183156228899` to `12.374730595491439`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `11.646791410175561` to `3.378257304881686`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `2.7502076676887444` to `8.023466692652443`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `12.374730595491439` to `13.137072563433836`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `3.378257304881686` to `10.574040808444531`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `8.023466692652443` to `7.907127853271936`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `13.137072563433836` to `10.03090980709769`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['melt_f'] changed from `10.574040808444531` to `9.445643436699093`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['prcp_fac'] changed from `7.907127853271936` to `8.608586875753966`.
# 2026-01-19 14:36:03: oggm.cfg: PARAMS['temp_bias'] changed from `10.03090980709769` to `-6.351717833109843`.

# %%
YY = output_metric_calculator(sim, gdir_hef) # Calculate the output metrics for all simulations

# %% [markdown]
# Plotting the Monte Carlo simulation results and comparison with the observed data.

# %%
# Plot Monte Carlo (MC) simulations results and compare with data:
plt.figure(figsize=[15,5])
plt.plot(mbdf['in_situ_mb'].index.values, np.transpose(sim), 'k', linewidth = 0.5)
plt.plot(mbdf['in_situ_mb'], color=[0.7,0.7,0.7], linewidth=2)
plt.ylabel('Mass Balance'); plt.xlabel('Years')
plt.legend(['sim', 'obs'])
plt.title("Number of parameter samples: N = %d" % N, loc='right')
plt.show()

# %% [markdown]
# We can see from the samples that the mass balance is greatly affected by altering the parameters between their given ranges. The lower mass balances seem to be more sparse, with a more significant clustering towards the higher mass-balances. The observed mass-balance is closer towards the higher mass-balance end of the spectrum, towards 0.

# %% [markdown]
# ### Scatter plot of the fit-to-data metrics

# %% [markdown]
# We will now plot a scatter plot of the fit-to-data metrics, this will show us the relationship between the metrics created from our Monte Carlo simulations.

# %%
plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(YY[:,0], YY[:,1], s=5), plt.title('Mean difference vs Std difference'), plt.xlabel('Mean difference (mm w.e.)'), plt.ylabel('Std difference (mm w.e.)'),
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.subplot(1,3,2), plt.scatter(YY[:,0], YY[:,2], s=5), plt.title('Mean difference vs RMSD'), plt.xlabel('Mean difference (mm w.e.)'), plt.ylabel('RMSD (mm w.e.)')
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.subplot(1,3,3), plt.scatter(YY[:,1], YY[:,2], s=5), plt.title('Std difference vs RMSD'), plt.xlabel('Std difference (mm w.e.)'), plt.ylabel('RMSD (mm w.e.)')
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.tight_layout()
plt.show()

# The red lines show the target of having zero differences in the mean, standard deviation and RMSD.
# TODO: Would absolute differences be better than the raw ones?

# %% [markdown]
# The red lines show the target values of our differences, ideally we would want our differences to be 0 and to match the observations as closely as possible.
#
# It can be seen here that all of our fit-to-data metrics are correlated.

# %% [markdown]
# ## Scatter plot for the parameters against the fit-to-data metrics

# %% [markdown]
# Now we can plot the scatter plots for each parameter against each metric, this will help visualise the sensitivities for the mass balance.

# %%
YY_Labels = ['Mean Difference', 'Std Difference', 'RMSD']

def scatter_function(metric='Mean Difference'):
    if metric == 'Mean Difference':
        j = 0
    elif metric == 'Std Difference':
        j = 1  
    elif metric == 'RMSD':
        j = 2
    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(YY_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = YY_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Difference', 'Std Difference', 'RMSD'), va…

# %% [markdown]
# ### Distribution of the model outputs

# %% [markdown]
# Now looking at the distribution of the model outputs, here this is the goodness-of-fit parameters.

# %%
Y_Labels = ['Mean difference (mm w.e.)', 'Std difference (mm w.e.)', 'RMSD (mm w.e.)', 'Mean & Std difference jointly']

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,0], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,1], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[1])

plt.subplot(1,3,3), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,2], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[2])

plt.tight_layout()

# %% [markdown]
# Looking at our distributions of the output samples, the distributions are as follows:
# 1. Mean difference: Skewed distribition with a long tail (negative skew)
# 2. Std difference: Normal distribution
# 3. RMSD: Skewed distribution with a long tail (positive skew)
#
# TODO: Does this mean we can use RSA vs PAWN?

# %% [markdown]
# # Calculating the Sensitivity Indices
#
# Now we use the input-output samples generated in the previous step to calculate sensitivity indices using **Regional Sensitivity Analysis**. Calculating 3 sets of indices, each measuring the relative importance of the 3 input parameters.

# %%
Nboot = 50 # Number of resamples used for bootstrapping

for i in range(3):
    if i==0:
        Y=YY[:,0]
        target=0
    if i==1:
        Y=YY[:,1]
        target=0
    if i==2:
        Y = YY[:,2]
        target = 500 # RMSD cannot be zero here? Minimum working number is around 550, minimum observed value is around 400.

    # plot:
    plt.figure(figsize=[7,2])
    mvd, _, _, idx = RSA_tr.RSA_indices_thres(X, Y, target, Nboot=Nboot)
    mvd_m, mvd_lb, mvd_ub = aggregate_boot(mvd) # shape (M,)
    yerr=np.c_[mvd_m-mvd_lb,mvd_ub-mvd_m].T
    plt.bar(range(len(mvd_m)), mvd_m, color='grey',yerr=yerr)
    plt.title(Y_Labels[i], loc='center'), plt.xticks(range(len(mvd_m)), X_labels), plt.ylabel('Sensitivity')
    plt.show()

# %% [markdown]
# Now lets discuss the outcome of our sensitivity analysis here with the three fit-to-data metrics:
#
# 1. For the first metric: The difference between the observed and the simulated mass balance mean values. The temperature bias is significantly the most impactful here. This would align with what we might expect, the temperature bias increases or decreases the temperature, which will have an impact on the amount of glacier mass we are either losing or retaining due to melting and whether or not the precipitation is liquid or solid. We are also currently using the OGGM's default range which is between -15 and +15 degrees celcius, this is a very large range and therefore this makes sense this is the most impactful for the differences between the mass balance means between the observed and simulated. The temperature bias will create a uniform shift in temperatures which will then shift the mean values.
#
# 2. For the second metric: The difference between the observed and simulated mass balance standard deviation values. The precipitation factor is the most significant in our study. The precipitation factor controls the amount of precipitation for the glacier, therefore controlling accumulation which strongly affects the variability of the mass balance.
#
# 3. Finally, for the third metric: The RMSD, this penalises larger differences and is dominated by larger deviations. The melt factor is the factor that controls how much ablation occurs, this melt will be amplified in high-melt periods and much lower at lower melt periods. Therefore this will affect the RMSD more, due to the large deviations the melt factor can cause throughout difference period of the year.

# %% [markdown]
# ## Extra Investigation: Relationship with temp_bias and other parameters to the fit-to-data outputs

# %% [markdown]
# Now checking, if the relationship with other parameters has been affected by the temp_bias, this is rather dominant in the differences of the mean. We can plot a colour map to check.

# %%
temp_bias_index = 2  # Index of temp_bias in X

YY_Labels = ['Mean Difference', 'Std Difference', 'RMSD']

def scatter_function(metric='Mean Difference'):
    if metric == 'Mean Difference':
        j = 0
    elif metric == 'Std Difference':
        j = 1  
    elif metric == 'RMSD':
        j = 2

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], YY[:, j], c=X[:, temp_bias_index], cmap='coolwarm', edgecolors='grey')
        
        if i == 0:
            plt.ylabel(YY_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Temp Bias (°C)')
    plt.show()

interact(scatter_function, metric=YY_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Difference', 'Std Difference', 'RMSD'), va…

# %% [markdown]
# # Hydrological Response Metrics - Performance Metrics

# %% [markdown]
# Now looking at the hydrological response metrics we have avaliable in the OGGM, mean of runoff and mean of volume.

# %% [markdown]
# ## One-at-a-time Sensitivity Analysis

# %%
# Define interactive visualisation function to set the parameters to some tentative values, 
# run the model and plot the resulting runoff time series

def oat_hydro_function(gdir, melt_f = 5.0, prcp_fac = 3.4, temp_bias = 0.0):
    # Create parameter array
    param = np.array([melt_f, prcp_fac, temp_bias])
    
    # Run the model with the given parameters, here we are interested in the modelled mass balance time series
    runoff = oggm_sim(param, gdir, True)
    # Plot the results
    plt.figure(figsize=[15,3])
    plt.plot(mbdf.index.values, runoff)
    plt.ylabel('Runoff (Mt)')
    plt.xlabel('Year')
    plt.legend()

# Create interactive plot, the toggles will change the parameter values 
interact(oat_hydro_function,
         gdir = fixed(gdir_hef),
         melt_f = (1.5, 17.0, 0.1),
         prcp_fac = (0.1, 10.0, 0.1),
         temp_bias = (-15.0, 15.0, 0.1));
# Out:
# interactive(children=(FloatSlider(value=5.0, description='melt_f', max=17.0, min=1.5), FloatSlider(value=3.4, …

# %% [markdown]
# # GSA - Global Sensitivity Analysis
#
# Now applying RSA to our runoff data to perform a Sensitivity Analysis,
# [Pianosi et al., 2016](https://www.sciencedirect.com/science/article/pii/S1364815216300287?fr=RR-2&ref=pdf_download&rr=9c07930109fe6535#bib67). As discussed with the Mass-Balance timeseries, the RSA typically requires a specified threshold. We currently do not have access to runoff data to provide a threshold and compare our simulated outputs. To work around this issue and apply RSA without specifying thresholds, we can group the ranked output samples into a prescribed number (e.g. 10) and compare the 10 resulting distribution functions of the input factors. (TODO: Is this built into SAFE?) This isn't avaliable in SAFE, so we will be attempting an alternative method which does not require a threshold, PAWN. Which is a novel density-based method.
#
# We will however include the original SAFE implementation of RSA for consistency with the first method, and some arbitrary thresholds. If we do obtain the values of the observed mean runoff and standard deviation of runoff then we can easily change the code to implement the method correctly.

# %% [markdown]
# ### Running Monte Carlo Simulations

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)
distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 0.1, -15.0]) # Minimum values for each parameter
x_max = np.array([17.0, 10.0, 15.0]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
samp_strat = 'lhs' 
N = 1000 # Was 2000, TODO- change back to 2000? 1000 takes around 11 mins to run
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

# %%
runoff  = model_execution(oggm_sim, X, gdir_hef, True) # Execute the model for all samples - note: takes around 5-10 mins with N=1000
# Out:
# 2026-01-19 14:41:02: oggm.cfg: PARAMS['melt_f'] changed from `5.0` to `11.850766752905374`.
# 2026-01-19 14:41:02: oggm.cfg: PARAMS['prcp_fac'] changed from `3.400000000000001` to `6.994073526655448`.
# 2026-01-19 14:41:02: oggm.cfg: PARAMS['temp_bias'] changed from `0.0` to `-6.902726555301882`.
# 2026-01-19 14:41:04: oggm.cfg: PARAMS['melt_f'] changed from `11.850766752905374` to `5.521744893929717`.
# 2026-01-19 14:41:04: oggm.cfg: PARAMS['prcp_fac'] changed from `6.994073526655448` to `3.2695920334673527`.
# 2026-01-19 14:41:04: oggm.cfg: PARAMS['temp_bias'] changed from `-6.902726555301882` to `11.247489193684011`.
# 2026-01-19 14:41:04: oggm.cfg: PARAMS['melt_f'] changed from `5.521744893929717` to `9.332654344786043`.
# 2026-01-19 14:41:04: oggm.cfg: PARAMS['prcp_fac'] changed from `3.2695920334673527` to `0.9669833743780201`.
# 2026-01-19 14:41:04: oggm.cfg: PARAMS['temp_bias'] changed from `11.247489193684011` to `-0.39681624892724265`.
# 2026-01-19 14:41:05: oggm.cfg: PARAMS['melt_f'] changed from `9.332654344786043` to `16.199044908762698`.
# 2026-01-19 14:41:05: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9669833743780201` to `1.9483299559237162`.
# 2026-01-19 14:41:05: oggm.cfg: PARAMS['temp_bias'] changed from `-0.39681624892724265` to `-2.5857139403011615`.
# 2026-01-19 14:41:06: oggm.cfg: PARAMS['melt_f'] changed from `16.199044908762698` to `8.62504222328448`.
# 2026-01-19 14:41:06: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9483299559237162` to `7.81494530724171`.
# 2026-01-19 14:41:06: oggm.cfg: PARAMS['temp_bias'] changed from `-2.5857139403011615` to `-4.894217862884084`.
# 2026-01-19 14:41:07: oggm.cfg: PARAMS['melt_f'] changed from `8.62504222328448` to `11.100847453730147`.
# 2026-01-19 14:41:07: oggm.cfg: PARAMS['prcp_fac'] changed from `7.81494530724171` to `7.035439283175394`.
# 2026-01-19 14:41:07: oggm.cfg: PARAMS['temp_bias'] changed from `-4.894217862884084` to `-3.3183252315727927`.
# 2026-01-19 14:41:08: oggm.cfg: PARAMS['melt_f'] changed from `11.100847453730147` to `2.548469232884619`.
# 2026-01-19 14:41:08: oggm.cfg: PARAMS['prcp_fac'] changed from `7.035439283175394` to `3.004890822810833`.
# 2026-01-19 14:41:08: oggm.cfg: PARAMS['temp_bias'] changed from `-3.3183252315727927` to `-13.396756157967824`.
# 2026-01-19 14:41:08: oggm.cfg: PARAMS['melt_f'] changed from `2.548469232884619` to `8.440285464421978`.
# 2026-01-19 14:41:08: oggm.cfg: PARAMS['prcp_fac'] changed from `3.004890822810833` to `5.715155256290864`.
# 2026-01-19 14:41:08: oggm.cfg: PARAMS['temp_bias'] changed from `-13.396756157967824` to `14.744375311468911`.
# 2026-01-19 14:41:09: oggm.cfg: PARAMS['melt_f'] changed from `8.440285464421978` to `7.159659441801351`.
# 2026-01-19 14:41:09: oggm.cfg: PARAMS['prcp_fac'] changed from `5.715155256290864` to `1.2369384255684934`.
# 2026-01-19 14:41:09: oggm.cfg: PARAMS['temp_bias'] changed from `14.744375311468911` to `-4.617934574646171`.
# 2026-01-19 14:41:10: oggm.cfg: PARAMS['melt_f'] changed from `7.159659441801351` to `9.411766746794054`.
# 2026-01-19 14:41:10: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2369384255684934` to `7.11138738895926`.
# 2026-01-19 14:41:10: oggm.cfg: PARAMS['temp_bias'] changed from `-4.617934574646171` to `-1.0750357994795845`.
# 2026-01-19 14:41:10: oggm.cfg: PARAMS['melt_f'] changed from `9.411766746794054` to `13.420093443201546`.
# 2026-01-19 14:41:10: oggm.cfg: PARAMS['prcp_fac'] changed from `7.11138738895926` to `5.733063090907614`.
# 2026-01-19 14:41:10: oggm.cfg: PARAMS['temp_bias'] changed from `-1.0750357994795845` to `11.161295536256468`.
# 2026-01-19 14:41:11: oggm.cfg: PARAMS['melt_f'] changed from `13.420093443201546` to `11.742516364841824`.
# 2026-01-19 14:41:11: oggm.cfg: PARAMS['prcp_fac'] changed from `5.733063090907614` to `0.8746969316058415`.
# 2026-01-19 14:41:11: oggm.cfg: PARAMS['temp_bias'] changed from `11.161295536256468` to `0.9588624375854877`.
# 2026-01-19 14:41:11: oggm.cfg: PARAMS['melt_f'] changed from `11.742516364841824` to `4.964080961237091`.
# 2026-01-19 14:41:11: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8746969316058415` to `4.391642228684503`.
# 2026-01-19 14:41:11: oggm.cfg: PARAMS['temp_bias'] changed from `0.9588624375854877` to `-0.6110262012919705`.
# 2026-01-19 14:41:12: oggm.cfg: PARAMS['melt_f'] changed from `4.964080961237091` to `13.437881044066314`.
# 2026-01-19 14:41:12: oggm.cfg: PARAMS['prcp_fac'] changed from `4.391642228684503` to `1.1111219777365062`.
# 2026-01-19 14:41:12: oggm.cfg: PARAMS['temp_bias'] changed from `-0.6110262012919705` to `8.27133710987082`.
# 2026-01-19 14:41:13: oggm.cfg: PARAMS['melt_f'] changed from `13.437881044066314` to `15.494227890514415`.
# 2026-01-19 14:41:13: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1111219777365062` to `1.0610288707510422`.
# 2026-01-19 14:41:13: oggm.cfg: PARAMS['temp_bias'] changed from `8.27133710987082` to `14.864079535062011`.
# 2026-01-19 14:41:13: oggm.cfg: PARAMS['melt_f'] changed from `15.494227890514415` to `16.928640773041202`.
# 2026-01-19 14:41:13: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0610288707510422` to `3.9718421182712906`.
# 2026-01-19 14:41:13: oggm.cfg: PARAMS['temp_bias'] changed from `14.864079535062011` to `13.553350527771443`.
# 2026-01-19 14:41:14: oggm.cfg: PARAMS['melt_f'] changed from `16.928640773041202` to `6.800948148153394`.
# 2026-01-19 14:41:14: oggm.cfg: PARAMS['prcp_fac'] changed from `3.9718421182712906` to `5.743823240700852`.
# 2026-01-19 14:41:14: oggm.cfg: PARAMS['temp_bias'] changed from `13.553350527771443` to `7.539881409100374`.
# 2026-01-19 14:41:14: oggm.cfg: PARAMS['melt_f'] changed from `6.800948148153394` to `10.325566811865384`.
# 2026-01-19 14:41:14: oggm.cfg: PARAMS['prcp_fac'] changed from `5.743823240700852` to `4.002341073164273`.
# 2026-01-19 14:41:14: oggm.cfg: PARAMS['temp_bias'] changed from `7.539881409100374` to `0.2090139117845009`.
# 2026-01-19 14:41:15: oggm.cfg: PARAMS['melt_f'] changed from `10.325566811865384` to `3.8798986586770425`.
# 2026-01-19 14:41:15: oggm.cfg: PARAMS['prcp_fac'] changed from `4.002341073164273` to `4.162749260308045`.
# 2026-01-19 14:41:15: oggm.cfg: PARAMS['temp_bias'] changed from `0.2090139117845009` to `14.622294894870763`.
# 2026-01-19 14:41:15: oggm.cfg: PARAMS['melt_f'] changed from `3.8798986586770425` to `1.5621821412728103`.
# 2026-01-19 14:41:15: oggm.cfg: PARAMS['prcp_fac'] changed from `4.162749260308045` to `8.71983034792593`.
# 2026-01-19 14:41:15: oggm.cfg: PARAMS['temp_bias'] changed from `14.622294894870763` to `13.294136069169433`.
# 2026-01-19 14:41:16: oggm.cfg: PARAMS['melt_f'] changed from `1.5621821412728103` to `4.992519821566846`.
# 2026-01-19 14:41:16: oggm.cfg: PARAMS['prcp_fac'] changed from `8.71983034792593` to `1.9660498132740547`.
# 2026-01-19 14:41:16: oggm.cfg: PARAMS['temp_bias'] changed from `13.294136069169433` to `2.1039997386462517`.
# 2026-01-19 14:41:16: oggm.cfg: PARAMS['melt_f'] changed from `4.992519821566846` to `5.7454920283808715`.
# 2026-01-19 14:41:16: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9660498132740547` to `7.578420733568279`.
# 2026-01-19 14:41:16: oggm.cfg: PARAMS['temp_bias'] changed from `2.1039997386462517` to `8.957631575531984`.
# 2026-01-19 14:41:17: oggm.cfg: PARAMS['melt_f'] changed from `5.7454920283808715` to `11.204774182436484`.
# 2026-01-19 14:41:17: oggm.cfg: PARAMS['prcp_fac'] changed from `7.578420733568279` to `2.1791777526074325`.
# 2026-01-19 14:41:17: oggm.cfg: PARAMS['temp_bias'] changed from `8.957631575531984` to `-12.418313331837018`.
# 2026-01-19 14:41:17: oggm.cfg: PARAMS['melt_f'] changed from `11.204774182436484` to `3.830735805839979`.
# 2026-01-19 14:41:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.1791777526074325` to `6.006968101047969`.
# 2026-01-19 14:41:17: oggm.cfg: PARAMS['temp_bias'] changed from `-12.418313331837018` to `-9.165180759873952`.
# 2026-01-19 14:41:18: oggm.cfg: PARAMS['melt_f'] changed from `3.830735805839979` to `5.933508405450134`.
# 2026-01-19 14:41:18: oggm.cfg: PARAMS['prcp_fac'] changed from `6.006968101047969` to `2.196962905671835`.
# 2026-01-19 14:41:18: oggm.cfg: PARAMS['temp_bias'] changed from `-9.165180759873952` to `5.184969979928731`.
# 2026-01-19 14:41:19: oggm.cfg: PARAMS['melt_f'] changed from `5.933508405450134` to `13.101733240771292`.
# 2026-01-19 14:41:19: oggm.cfg: PARAMS['prcp_fac'] changed from `2.196962905671835` to `8.65366637537708`.
# 2026-01-19 14:41:19: oggm.cfg: PARAMS['temp_bias'] changed from `5.184969979928731` to `-4.937718401658394`.
# 2026-01-19 14:41:20: oggm.cfg: PARAMS['melt_f'] changed from `13.101733240771292` to `11.984399548783957`.
# 2026-01-19 14:41:20: oggm.cfg: PARAMS['prcp_fac'] changed from `8.65366637537708` to `3.232924307145727`.
# 2026-01-19 14:41:20: oggm.cfg: PARAMS['temp_bias'] changed from `-4.937718401658394` to `-11.478632165510472`.
# 2026-01-19 14:41:20: oggm.cfg: PARAMS['melt_f'] changed from `11.984399548783957` to `12.5523535808124`.
# 2026-01-19 14:41:20: oggm.cfg: PARAMS['prcp_fac'] changed from `3.232924307145727` to `1.1329977898298065`.
# 2026-01-19 14:41:20: oggm.cfg: PARAMS['temp_bias'] changed from `-11.478632165510472` to `-14.93987578691664`.
# 2026-01-19 14:41:21: oggm.cfg: PARAMS['melt_f'] changed from `12.5523535808124` to `11.472207411898038`.
# 2026-01-19 14:41:21: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1329977898298065` to `9.427232397731744`.
# 2026-01-19 14:41:21: oggm.cfg: PARAMS['temp_bias'] changed from `-14.93987578691664` to `-13.697871594154945`.
# 2026-01-19 14:41:22: oggm.cfg: PARAMS['melt_f'] changed from `11.472207411898038` to `1.5309744173668822`.
# 2026-01-19 14:41:22: oggm.cfg: PARAMS['prcp_fac'] changed from `9.427232397731744` to `3.9580035322915177`.
# 2026-01-19 14:41:22: oggm.cfg: PARAMS['temp_bias'] changed from `-13.697871594154945` to `7.8376117356516275`.
# 2026-01-19 14:41:22: oggm.cfg: PARAMS['melt_f'] changed from `1.5309744173668822` to `11.753725956295014`.
# 2026-01-19 14:41:22: oggm.cfg: PARAMS['prcp_fac'] changed from `3.9580035322915177` to `7.614930965279897`.
# 2026-01-19 14:41:22: oggm.cfg: PARAMS['temp_bias'] changed from `7.8376117356516275` to `-5.492101077281669`.
# 2026-01-19 14:41:23: oggm.cfg: PARAMS['melt_f'] changed from `11.753725956295014` to `14.296139954767886`.
# 2026-01-19 14:41:23: oggm.cfg: PARAMS['prcp_fac'] changed from `7.614930965279897` to `6.944650375292295`.
# 2026-01-19 14:41:23: oggm.cfg: PARAMS['temp_bias'] changed from `-5.492101077281669` to `14.641241183268626`.
# 2026-01-19 14:41:24: oggm.cfg: PARAMS['melt_f'] changed from `14.296139954767886` to `11.2406844951114`.
# 2026-01-19 14:41:24: oggm.cfg: PARAMS['prcp_fac'] changed from `6.944650375292295` to `9.190616230526038`.
# 2026-01-19 14:41:24: oggm.cfg: PARAMS['temp_bias'] changed from `14.641241183268626` to `14.217157826515564`.
# 2026-01-19 14:41:25: oggm.cfg: PARAMS['melt_f'] changed from `11.2406844951114` to `13.80660225890152`.
# 2026-01-19 14:41:25: oggm.cfg: PARAMS['prcp_fac'] changed from `9.190616230526038` to `4.986277624458796`.
# 2026-01-19 14:41:25: oggm.cfg: PARAMS['temp_bias'] changed from `14.217157826515564` to `13.084283286278783`.
# 2026-01-19 14:41:25: oggm.cfg: PARAMS['melt_f'] changed from `13.80660225890152` to `4.866791977884955`.
# 2026-01-19 14:41:25: oggm.cfg: PARAMS['prcp_fac'] changed from `4.986277624458796` to `3.9134376962291615`.
# 2026-01-19 14:41:25: oggm.cfg: PARAMS['temp_bias'] changed from `13.084283286278783` to `-11.15122276280347`.
# 2026-01-19 14:41:26: oggm.cfg: PARAMS['melt_f'] changed from `4.866791977884955` to `3.3909845110195427`.
# 2026-01-19 14:41:26: oggm.cfg: PARAMS['prcp_fac'] changed from `3.9134376962291615` to `5.6754525411036365`.
# 2026-01-19 14:41:26: oggm.cfg: PARAMS['temp_bias'] changed from `-11.15122276280347` to `2.253511882099456`.
# 2026-01-19 14:41:26: oggm.cfg: PARAMS['melt_f'] changed from `3.3909845110195427` to `9.053838323993777`.
# 2026-01-19 14:41:26: oggm.cfg: PARAMS['prcp_fac'] changed from `5.6754525411036365` to `2.7551797512388347`.
# 2026-01-19 14:41:26: oggm.cfg: PARAMS['temp_bias'] changed from `2.253511882099456` to `-9.832102412314661`.
# 2026-01-19 14:41:27: oggm.cfg: PARAMS['melt_f'] changed from `9.053838323993777` to `8.038979911115531`.
# 2026-01-19 14:41:27: oggm.cfg: PARAMS['prcp_fac'] changed from `2.7551797512388347` to `3.506587930617208`.
# 2026-01-19 14:41:27: oggm.cfg: PARAMS['temp_bias'] changed from `-9.832102412314661` to `-8.204524817460722`.
# 2026-01-19 14:41:28: oggm.cfg: PARAMS['melt_f'] changed from `8.038979911115531` to `2.0986686473916913`.
# 2026-01-19 14:41:28: oggm.cfg: PARAMS['prcp_fac'] changed from `3.506587930617208` to `0.8072411122363525`.
# 2026-01-19 14:41:28: oggm.cfg: PARAMS['temp_bias'] changed from `-8.204524817460722` to `11.606968332173107`.
# 2026-01-19 14:41:28: oggm.cfg: PARAMS['melt_f'] changed from `2.0986686473916913` to `15.178145858990485`.
# 2026-01-19 14:41:28: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8072411122363525` to `8.326459467604572`.
# 2026-01-19 14:41:28: oggm.cfg: PARAMS['temp_bias'] changed from `11.606968332173107` to `10.594007726400655`.
# 2026-01-19 14:41:29: oggm.cfg: PARAMS['melt_f'] changed from `15.178145858990485` to `5.339860099610843`.
# 2026-01-19 14:41:29: oggm.cfg: PARAMS['prcp_fac'] changed from `8.326459467604572` to `4.9172320449027564`.
# 2026-01-19 14:41:29: oggm.cfg: PARAMS['temp_bias'] changed from `10.594007726400655` to `-9.677192617993533`.
# 2026-01-19 14:41:29: oggm.cfg: PARAMS['melt_f'] changed from `5.339860099610843` to `10.814301857254558`.
# 2026-01-19 14:41:29: oggm.cfg: PARAMS['prcp_fac'] changed from `4.9172320449027564` to `8.858015478011952`.
# 2026-01-19 14:41:29: oggm.cfg: PARAMS['temp_bias'] changed from `-9.677192617993533` to `-10.35428954703691`.
# 2026-01-19 14:41:30: oggm.cfg: PARAMS['melt_f'] changed from `10.814301857254558` to `3.2412279664069708`.
# 2026-01-19 14:41:30: oggm.cfg: PARAMS['prcp_fac'] changed from `8.858015478011952` to `8.969990272744607`.
# 2026-01-19 14:41:30: oggm.cfg: PARAMS['temp_bias'] changed from `-10.35428954703691` to `5.159489779868867`.
# 2026-01-19 14:41:31: oggm.cfg: PARAMS['melt_f'] changed from `3.2412279664069708` to `3.071326138725338`.
# 2026-01-19 14:41:31: oggm.cfg: PARAMS['prcp_fac'] changed from `8.969990272744607` to `1.5664038459176757`.
# 2026-01-19 14:41:31: oggm.cfg: PARAMS['temp_bias'] changed from `5.159489779868867` to `-5.471513861128553`.
# 2026-01-19 14:41:32: oggm.cfg: PARAMS['melt_f'] changed from `3.071326138725338` to `15.427170678185231`.
# 2026-01-19 14:41:32: oggm.cfg: PARAMS['prcp_fac'] changed from `1.5664038459176757` to `9.238499936056595`.
# 2026-01-19 14:41:32: oggm.cfg: PARAMS['temp_bias'] changed from `-5.471513861128553` to `13.341736370051553`.
# 2026-01-19 14:41:32: oggm.cfg: PARAMS['melt_f'] changed from `15.427170678185231` to `5.466848016637899`.
# 2026-01-19 14:41:32: oggm.cfg: PARAMS['prcp_fac'] changed from `9.238499936056595` to `9.236292349673702`.
# 2026-01-19 14:41:32: oggm.cfg: PARAMS['temp_bias'] changed from `13.341736370051553` to `13.431657034030206`.
# 2026-01-19 14:41:33: oggm.cfg: PARAMS['melt_f'] changed from `5.466848016637899` to `2.173561679303954`.
# 2026-01-19 14:41:33: oggm.cfg: PARAMS['prcp_fac'] changed from `9.236292349673702` to `9.787413423374026`.
# 2026-01-19 14:41:33: oggm.cfg: PARAMS['temp_bias'] changed from `13.431657034030206` to `9.865855807021006`.
# 2026-01-19 14:41:33: oggm.cfg: PARAMS['melt_f'] changed from `2.173561679303954` to `11.677652418098207`.
# 2026-01-19 14:41:33: oggm.cfg: PARAMS['prcp_fac'] changed from `9.787413423374026` to `4.597035197934953`.
# 2026-01-19 14:41:33: oggm.cfg: PARAMS['temp_bias'] changed from `9.865855807021006` to `5.8858625966935065`.
# 2026-01-19 14:41:34: oggm.cfg: PARAMS['melt_f'] changed from `11.677652418098207` to `7.4881886005854605`.
# 2026-01-19 14:41:34: oggm.cfg: PARAMS['prcp_fac'] changed from `4.597035197934953` to `3.8642298634264955`.
# 2026-01-19 14:41:34: oggm.cfg: PARAMS['temp_bias'] changed from `5.8858625966935065` to `2.900166453135384`.
# 2026-01-19 14:41:34: oggm.cfg: PARAMS['melt_f'] changed from `7.4881886005854605` to `2.571884339305247`.
# 2026-01-19 14:41:34: oggm.cfg: PARAMS['prcp_fac'] changed from `3.8642298634264955` to `7.880995285697988`.
# 2026-01-19 14:41:34: oggm.cfg: PARAMS['temp_bias'] changed from `2.900166453135384` to `-2.849587128445412`.
# 2026-01-19 14:41:35: oggm.cfg: PARAMS['melt_f'] changed from `2.571884339305247` to `8.603387453054754`.
# 2026-01-19 14:41:35: oggm.cfg: PARAMS['prcp_fac'] changed from `7.880995285697988` to `6.8346508897381515`.
# 2026-01-19 14:41:35: oggm.cfg: PARAMS['temp_bias'] changed from `-2.849587128445412` to `0.6697760671680122`.
# 2026-01-19 14:41:36: oggm.cfg: PARAMS['melt_f'] changed from `8.603387453054754` to `2.1613813415016057`.
# 2026-01-19 14:41:36: oggm.cfg: PARAMS['prcp_fac'] changed from `6.8346508897381515` to `6.068885764425273`.
# 2026-01-19 14:41:36: oggm.cfg: PARAMS['temp_bias'] changed from `0.6697760671680122` to `-8.75592349432737`.
# 2026-01-19 14:41:37: oggm.cfg: PARAMS['melt_f'] changed from `2.1613813415016057` to `4.169092997529612`.
# 2026-01-19 14:41:37: oggm.cfg: PARAMS['prcp_fac'] changed from `6.068885764425273` to `7.965896880155551`.
# 2026-01-19 14:41:37: oggm.cfg: PARAMS['temp_bias'] changed from `-8.75592349432737` to `-13.645817032583967`.
# 2026-01-19 14:41:38: oggm.cfg: PARAMS['melt_f'] changed from `4.169092997529612` to `12.987695888696704`.
# 2026-01-19 14:41:38: oggm.cfg: PARAMS['prcp_fac'] changed from `7.965896880155551` to `5.305859787658245`.
# 2026-01-19 14:41:38: oggm.cfg: PARAMS['temp_bias'] changed from `-13.645817032583967` to `12.165139818427559`.
# 2026-01-19 14:41:38: oggm.cfg: PARAMS['melt_f'] changed from `12.987695888696704` to `4.926626594018831`.
# 2026-01-19 14:41:38: oggm.cfg: PARAMS['prcp_fac'] changed from `5.305859787658245` to `3.650638005915494`.
# 2026-01-19 14:41:38: oggm.cfg: PARAMS['temp_bias'] changed from `12.165139818427559` to `-14.17734601953044`.
# 2026-01-19 14:41:39: oggm.cfg: PARAMS['melt_f'] changed from `4.926626594018831` to `16.616877857557633`.
# 2026-01-19 14:41:39: oggm.cfg: PARAMS['prcp_fac'] changed from `3.650638005915494` to `3.968305364744315`.
# 2026-01-19 14:41:39: oggm.cfg: PARAMS['temp_bias'] changed from `-14.17734601953044` to `-4.409791727375914`.
# 2026-01-19 14:41:39: oggm.cfg: PARAMS['melt_f'] changed from `16.616877857557633` to `15.967770705610368`.
# 2026-01-19 14:41:39: oggm.cfg: PARAMS['prcp_fac'] changed from `3.968305364744315` to `5.340450161475286`.
# 2026-01-19 14:41:39: oggm.cfg: PARAMS['temp_bias'] changed from `-4.409791727375914` to `11.376430180736175`.
# 2026-01-19 14:41:40: oggm.cfg: PARAMS['melt_f'] changed from `15.967770705610368` to `13.91980231425663`.
# 2026-01-19 14:41:40: oggm.cfg: PARAMS['prcp_fac'] changed from `5.340450161475286` to `7.4793022461910175`.
# 2026-01-19 14:41:40: oggm.cfg: PARAMS['temp_bias'] changed from `11.376430180736175` to `-8.367636211869051`.
# 2026-01-19 14:41:41: oggm.cfg: PARAMS['melt_f'] changed from `13.91980231425663` to `4.295515142056888`.
# 2026-01-19 14:41:41: oggm.cfg: PARAMS['prcp_fac'] changed from `7.4793022461910175` to `5.928897251206468`.
# 2026-01-19 14:41:41: oggm.cfg: PARAMS['temp_bias'] changed from `-8.367636211869051` to `-11.641932613541588`.
# 2026-01-19 14:41:42: oggm.cfg: PARAMS['melt_f'] changed from `4.295515142056888` to `8.916137510090131`.
# 2026-01-19 14:41:42: oggm.cfg: PARAMS['prcp_fac'] changed from `5.928897251206468` to `2.240445153979307`.
# 2026-01-19 14:41:42: oggm.cfg: PARAMS['temp_bias'] changed from `-11.641932613541588` to `2.6782661118516913`.
# 2026-01-19 14:41:42: oggm.cfg: PARAMS['melt_f'] changed from `8.916137510090131` to `13.829652552543294`.
# 2026-01-19 14:41:42: oggm.cfg: PARAMS['prcp_fac'] changed from `2.240445153979307` to `0.10731251049625466`.
# 2026-01-19 14:41:42: oggm.cfg: PARAMS['temp_bias'] changed from `2.6782661118516913` to `3.33796527604758`.
# 2026-01-19 14:41:43: oggm.cfg: PARAMS['melt_f'] changed from `13.829652552543294` to `2.739929954678545`.
# 2026-01-19 14:41:43: oggm.cfg: PARAMS['prcp_fac'] changed from `0.10731251049625466` to `5.917023663539653`.
# 2026-01-19 14:41:43: oggm.cfg: PARAMS['temp_bias'] changed from `3.33796527604758` to `7.017340247274394`.
# 2026-01-19 14:41:43: oggm.cfg: PARAMS['melt_f'] changed from `2.739929954678545` to `15.831764036713507`.
# 2026-01-19 14:41:43: oggm.cfg: PARAMS['prcp_fac'] changed from `5.917023663539653` to `2.2139426740681256`.
# 2026-01-19 14:41:43: oggm.cfg: PARAMS['temp_bias'] changed from `7.017340247274394` to `6.060536899101166`.
# 2026-01-19 14:41:44: oggm.cfg: PARAMS['melt_f'] changed from `15.831764036713507` to `14.329586925447817`.
# 2026-01-19 14:41:44: oggm.cfg: PARAMS['prcp_fac'] changed from `2.2139426740681256` to `1.1918339841300793`.
# 2026-01-19 14:41:44: oggm.cfg: PARAMS['temp_bias'] changed from `6.060536899101166` to `5.630010333288176`.
# 2026-01-19 14:41:44: oggm.cfg: PARAMS['melt_f'] changed from `14.329586925447817` to `2.192178149432131`.
# 2026-01-19 14:41:44: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1918339841300793` to `1.0063021210031`.
# 2026-01-19 14:41:44: oggm.cfg: PARAMS['temp_bias'] changed from `5.630010333288176` to `-10.90446803881474`.
# 2026-01-19 14:41:45: oggm.cfg: PARAMS['melt_f'] changed from `2.192178149432131` to `13.576089334920933`.
# 2026-01-19 14:41:45: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0063021210031` to `4.75635576433673`.
# 2026-01-19 14:41:45: oggm.cfg: PARAMS['temp_bias'] changed from `-10.90446803881474` to `-8.324680743174635`.
# 2026-01-19 14:41:45: oggm.cfg: PARAMS['melt_f'] changed from `13.576089334920933` to `2.9117819417729045`.
# 2026-01-19 14:41:45: oggm.cfg: PARAMS['prcp_fac'] changed from `4.75635576433673` to `8.121275793795341`.
# 2026-01-19 14:41:45: oggm.cfg: PARAMS['temp_bias'] changed from `-8.324680743174635` to `8.933836916402203`.
# 2026-01-19 14:41:46: oggm.cfg: PARAMS['melt_f'] changed from `2.9117819417729045` to `14.84854232028498`.
# 2026-01-19 14:41:46: oggm.cfg: PARAMS['prcp_fac'] changed from `8.121275793795341` to `1.9363830001410631`.
# 2026-01-19 14:41:46: oggm.cfg: PARAMS['temp_bias'] changed from `8.933836916402203` to `1.7121229856236866`.
# 2026-01-19 14:41:46: oggm.cfg: PARAMS['melt_f'] changed from `14.84854232028498` to `11.909920717233787`.
# 2026-01-19 14:41:46: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9363830001410631` to `2.304768942781842`.
# 2026-01-19 14:41:46: oggm.cfg: PARAMS['temp_bias'] changed from `1.7121229856236866` to `-12.058819837461316`.
# 2026-01-19 14:41:47: oggm.cfg: PARAMS['melt_f'] changed from `11.909920717233787` to `5.78533983711806`.
# 2026-01-19 14:41:47: oggm.cfg: PARAMS['prcp_fac'] changed from `2.304768942781842` to `5.77764174844774`.
# 2026-01-19 14:41:47: oggm.cfg: PARAMS['temp_bias'] changed from `-12.058819837461316` to `-9.084600749255202`.
# 2026-01-19 14:41:48: oggm.cfg: PARAMS['melt_f'] changed from `5.78533983711806` to `7.23041663351253`.
# 2026-01-19 14:41:48: oggm.cfg: PARAMS['prcp_fac'] changed from `5.77764174844774` to `1.0944424808552105`.
# 2026-01-19 14:41:48: oggm.cfg: PARAMS['temp_bias'] changed from `-9.084600749255202` to `-1.4537749051139723`.
# 2026-01-19 14:41:48: oggm.cfg: PARAMS['melt_f'] changed from `7.23041663351253` to `3.5457194271630024`.
# 2026-01-19 14:41:48: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0944424808552105` to `2.5239534808084527`.
# 2026-01-19 14:41:48: oggm.cfg: PARAMS['temp_bias'] changed from `-1.4537749051139723` to `-14.155226561247552`.
# 2026-01-19 14:41:49: oggm.cfg: PARAMS['melt_f'] changed from `3.5457194271630024` to `2.5319375287647548`.
# 2026-01-19 14:41:49: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5239534808084527` to `6.368024923151889`.
# 2026-01-19 14:41:49: oggm.cfg: PARAMS['temp_bias'] changed from `-14.155226561247552` to `3.7064480154177417`.
# 2026-01-19 14:41:49: oggm.cfg: PARAMS['melt_f'] changed from `2.5319375287647548` to `14.943849820686909`.
# 2026-01-19 14:41:49: oggm.cfg: PARAMS['prcp_fac'] changed from `6.368024923151889` to `2.4518152550634693`.
# 2026-01-19 14:41:49: oggm.cfg: PARAMS['temp_bias'] changed from `3.7064480154177417` to `-10.523603947055811`.
# 2026-01-19 14:41:50: oggm.cfg: PARAMS['melt_f'] changed from `14.943849820686909` to `9.670900305417417`.
# 2026-01-19 14:41:50: oggm.cfg: PARAMS['prcp_fac'] changed from `2.4518152550634693` to `1.0309409222353416`.
# 2026-01-19 14:41:50: oggm.cfg: PARAMS['temp_bias'] changed from `-10.523603947055811` to `12.961709551228846`.
# 2026-01-19 14:41:50: oggm.cfg: PARAMS['melt_f'] changed from `9.670900305417417` to `11.173543971507678`.
# 2026-01-19 14:41:50: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0309409222353416` to `0.895468434994871`.
# 2026-01-19 14:41:50: oggm.cfg: PARAMS['temp_bias'] changed from `12.961709551228846` to `-9.591552065971623`.
# 2026-01-19 14:41:51: oggm.cfg: PARAMS['melt_f'] changed from `11.173543971507678` to `3.976021650888709`.
# 2026-01-19 14:41:51: oggm.cfg: PARAMS['prcp_fac'] changed from `0.895468434994871` to `6.636253043450135`.
# 2026-01-19 14:41:51: oggm.cfg: PARAMS['temp_bias'] changed from `-9.591552065971623` to `-14.466011920767073`.
# 2026-01-19 14:41:52: oggm.cfg: PARAMS['melt_f'] changed from `3.976021650888709` to `12.356054671280804`.
# 2026-01-19 14:41:52: oggm.cfg: PARAMS['prcp_fac'] changed from `6.636253043450135` to `1.8401603465804255`.
# 2026-01-19 14:41:52: oggm.cfg: PARAMS['temp_bias'] changed from `-14.466011920767073` to `3.77318714059491`.
# 2026-01-19 14:41:52: oggm.cfg: PARAMS['melt_f'] changed from `12.356054671280804` to `4.052750940816287`.
# 2026-01-19 14:41:52: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8401603465804255` to `0.3642871316204864`.
# 2026-01-19 14:41:52: oggm.cfg: PARAMS['temp_bias'] changed from `3.77318714059491` to `6.850347727620868`.
# 2026-01-19 14:41:53: oggm.cfg: PARAMS['melt_f'] changed from `4.052750940816287` to `9.160282883067957`.
# 2026-01-19 14:41:53: oggm.cfg: PARAMS['prcp_fac'] changed from `0.3642871316204864` to `1.7183141207596848`.
# 2026-01-19 14:41:53: oggm.cfg: PARAMS['temp_bias'] changed from `6.850347727620868` to `12.693798537506034`.
# 2026-01-19 14:41:53: oggm.cfg: PARAMS['melt_f'] changed from `9.160282883067957` to `8.984110678870532`.
# 2026-01-19 14:41:53: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7183141207596848` to `7.2106876604536625`.
# 2026-01-19 14:41:53: oggm.cfg: PARAMS['temp_bias'] changed from `12.693798537506034` to `-0.3368914749659666`.
# 2026-01-19 14:41:54: oggm.cfg: PARAMS['melt_f'] changed from `8.984110678870532` to `15.607166439550126`.
# 2026-01-19 14:41:54: oggm.cfg: PARAMS['prcp_fac'] changed from `7.2106876604536625` to `9.894261521225179`.
# 2026-01-19 14:41:54: oggm.cfg: PARAMS['temp_bias'] changed from `-0.3368914749659666` to `-4.882562614047586`.
# 2026-01-19 14:41:55: oggm.cfg: PARAMS['melt_f'] changed from `15.607166439550126` to `1.8618710212112501`.
# 2026-01-19 14:41:55: oggm.cfg: PARAMS['prcp_fac'] changed from `9.894261521225179` to `6.625518172144819`.
# 2026-01-19 14:41:55: oggm.cfg: PARAMS['temp_bias'] changed from `-4.882562614047586` to `-9.490561672125569`.
# 2026-01-19 14:41:56: oggm.cfg: PARAMS['melt_f'] changed from `1.8618710212112501` to `3.5996538777362135`.
# 2026-01-19 14:41:56: oggm.cfg: PARAMS['prcp_fac'] changed from `6.625518172144819` to `0.8439211211119042`.
# 2026-01-19 14:41:56: oggm.cfg: PARAMS['temp_bias'] changed from `-9.490561672125569` to `3.975352451486149`.
# 2026-01-19 14:41:57: oggm.cfg: PARAMS['melt_f'] changed from `3.5996538777362135` to `8.136759418505413`.
# 2026-01-19 14:41:57: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8439211211119042` to `2.5151580061595076`.
# 2026-01-19 14:41:57: oggm.cfg: PARAMS['temp_bias'] changed from `3.975352451486149` to `-2.3249108826892684`.
# 2026-01-19 14:41:57: oggm.cfg: PARAMS['melt_f'] changed from `8.136759418505413` to `14.276760634273296`.
# 2026-01-19 14:41:57: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5151580061595076` to `1.799875851525152`.
# 2026-01-19 14:41:57: oggm.cfg: PARAMS['temp_bias'] changed from `-2.3249108826892684` to `6.448541417737307`.
# 2026-01-19 14:41:58: oggm.cfg: PARAMS['melt_f'] changed from `14.276760634273296` to `7.92185078352054`.
# 2026-01-19 14:41:58: oggm.cfg: PARAMS['prcp_fac'] changed from `1.799875851525152` to `8.94808588475432`.
# 2026-01-19 14:41:58: oggm.cfg: PARAMS['temp_bias'] changed from `6.448541417737307` to `-2.630957347770652`.
# 2026-01-19 14:41:59: oggm.cfg: PARAMS['melt_f'] changed from `7.92185078352054` to `12.44137905693837`.
# 2026-01-19 14:41:59: oggm.cfg: PARAMS['prcp_fac'] changed from `8.94808588475432` to `7.497146925706868`.
# 2026-01-19 14:41:59: oggm.cfg: PARAMS['temp_bias'] changed from `-2.630957347770652` to `-2.4245358775117936`.
# 2026-01-19 14:41:59: oggm.cfg: PARAMS['melt_f'] changed from `12.44137905693837` to `7.336276987731782`.
# 2026-01-19 14:41:59: oggm.cfg: PARAMS['prcp_fac'] changed from `7.497146925706868` to `6.647921153809414`.
# 2026-01-19 14:41:59: oggm.cfg: PARAMS['temp_bias'] changed from `-2.4245358775117936` to `-6.348884059571972`.
# 2026-01-19 14:42:00: oggm.cfg: PARAMS['melt_f'] changed from `7.336276987731782` to `3.184442474108478`.
# 2026-01-19 14:42:00: oggm.cfg: PARAMS['prcp_fac'] changed from `6.647921153809414` to `1.4239944461943062`.
# 2026-01-19 14:42:00: oggm.cfg: PARAMS['temp_bias'] changed from `-6.348884059571972` to `1.5483479602552954`.
# 2026-01-19 14:42:01: oggm.cfg: PARAMS['melt_f'] changed from `3.184442474108478` to `11.453064345815225`.
# 2026-01-19 14:42:01: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4239944461943062` to `1.2387506292934636`.
# 2026-01-19 14:42:01: oggm.cfg: PARAMS['temp_bias'] changed from `1.5483479602552954` to `14.670397339305012`.
# 2026-01-19 14:42:01: oggm.cfg: PARAMS['melt_f'] changed from `11.453064345815225` to `13.413664354245196`.
# 2026-01-19 14:42:01: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2387506292934636` to `9.865393342448979`.
# 2026-01-19 14:42:01: oggm.cfg: PARAMS['temp_bias'] changed from `14.670397339305012` to `-13.065193198168014`.
# 2026-01-19 14:42:03: oggm.cfg: PARAMS['melt_f'] changed from `13.413664354245196` to `16.333647578100482`.
# 2026-01-19 14:42:03: oggm.cfg: PARAMS['prcp_fac'] changed from `9.865393342448979` to `1.1725310547738281`.
# 2026-01-19 14:42:03: oggm.cfg: PARAMS['temp_bias'] changed from `-13.065193198168014` to `6.801462557466188`.
# 2026-01-19 14:42:03: oggm.cfg: PARAMS['melt_f'] changed from `16.333647578100482` to `6.3049870702784965`.
# 2026-01-19 14:42:03: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1725310547738281` to `2.543569306132552`.
# 2026-01-19 14:42:03: oggm.cfg: PARAMS['temp_bias'] changed from `6.801462557466188` to `-12.723938598726123`.
# 2026-01-19 14:42:04: oggm.cfg: PARAMS['melt_f'] changed from `6.3049870702784965` to `15.052375289484697`.
# 2026-01-19 14:42:04: oggm.cfg: PARAMS['prcp_fac'] changed from `2.543569306132552` to `3.541481965737764`.
# 2026-01-19 14:42:04: oggm.cfg: PARAMS['temp_bias'] changed from `-12.723938598726123` to `8.36891312018895`.
# 2026-01-19 14:42:04: oggm.cfg: PARAMS['melt_f'] changed from `15.052375289484697` to `13.495175271263216`.
# 2026-01-19 14:42:04: oggm.cfg: PARAMS['prcp_fac'] changed from `3.541481965737764` to `4.555113398039557`.
# 2026-01-19 14:42:04: oggm.cfg: PARAMS['temp_bias'] changed from `8.36891312018895` to `-14.493486071025222`.
# 2026-01-19 14:42:05: oggm.cfg: PARAMS['melt_f'] changed from `13.495175271263216` to `8.094165539712582`.
# 2026-01-19 14:42:05: oggm.cfg: PARAMS['prcp_fac'] changed from `4.555113398039557` to `7.923525049381872`.
# 2026-01-19 14:42:05: oggm.cfg: PARAMS['temp_bias'] changed from `-14.493486071025222` to `-3.910856426831355`.
# 2026-01-19 14:42:06: oggm.cfg: PARAMS['melt_f'] changed from `8.094165539712582` to `15.781266602701535`.
# 2026-01-19 14:42:06: oggm.cfg: PARAMS['prcp_fac'] changed from `7.923525049381872` to `5.8741207881259845`.
# 2026-01-19 14:42:06: oggm.cfg: PARAMS['temp_bias'] changed from `-3.910856426831355` to `-0.4912348479301176`.
# 2026-01-19 14:42:07: oggm.cfg: PARAMS['melt_f'] changed from `15.781266602701535` to `13.207307726147363`.
# 2026-01-19 14:42:07: oggm.cfg: PARAMS['prcp_fac'] changed from `5.8741207881259845` to `0.16750624627613586`.
# 2026-01-19 14:42:07: oggm.cfg: PARAMS['temp_bias'] changed from `-0.4912348479301176` to `2.5038880965879535`.
# 2026-01-19 14:42:07: oggm.cfg: PARAMS['melt_f'] changed from `13.207307726147363` to `10.095056147194757`.
# 2026-01-19 14:42:07: oggm.cfg: PARAMS['prcp_fac'] changed from `0.16750624627613586` to `0.4584229816883135`.
# 2026-01-19 14:42:07: oggm.cfg: PARAMS['temp_bias'] changed from `2.5038880965879535` to `-0.059449298442546095`.
# 2026-01-19 14:42:08: oggm.cfg: PARAMS['melt_f'] changed from `10.095056147194757` to `14.495346328058083`.
# 2026-01-19 14:42:08: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4584229816883135` to `1.3276852417478648`.
# 2026-01-19 14:42:08: oggm.cfg: PARAMS['temp_bias'] changed from `-0.059449298442546095` to `-11.018347544131345`.
# 2026-01-19 14:42:08: oggm.cfg: PARAMS['melt_f'] changed from `14.495346328058083` to `10.510985656683557`.
# 2026-01-19 14:42:08: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3276852417478648` to `6.914783754940806`.
# 2026-01-19 14:42:08: oggm.cfg: PARAMS['temp_bias'] changed from `-11.018347544131345` to `14.516197323941661`.
# 2026-01-19 14:42:09: oggm.cfg: PARAMS['melt_f'] changed from `10.510985656683557` to `5.184575308006373`.
# 2026-01-19 14:42:09: oggm.cfg: PARAMS['prcp_fac'] changed from `6.914783754940806` to `7.134249215253653`.
# 2026-01-19 14:42:09: oggm.cfg: PARAMS['temp_bias'] changed from `14.516197323941661` to `-8.958153037878805`.
# 2026-01-19 14:42:10: oggm.cfg: PARAMS['melt_f'] changed from `5.184575308006373` to `6.924325249760912`.
# 2026-01-19 14:42:10: oggm.cfg: PARAMS['prcp_fac'] changed from `7.134249215253653` to `0.5254277740710539`.
# 2026-01-19 14:42:10: oggm.cfg: PARAMS['temp_bias'] changed from `-8.958153037878805` to `-13.044996907424345`.
# 2026-01-19 14:42:10: oggm.cfg: PARAMS['melt_f'] changed from `6.924325249760912` to `9.80430760622496`.
# 2026-01-19 14:42:10: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5254277740710539` to `4.169219997912966`.
# 2026-01-19 14:42:10: oggm.cfg: PARAMS['temp_bias'] changed from `-13.044996907424345` to `11.869960142011784`.
# 2026-01-19 14:42:11: oggm.cfg: PARAMS['melt_f'] changed from `9.80430760622496` to `8.151038724677672`.
# 2026-01-19 14:42:11: oggm.cfg: PARAMS['prcp_fac'] changed from `4.169219997912966` to `7.731572374003843`.
# 2026-01-19 14:42:11: oggm.cfg: PARAMS['temp_bias'] changed from `11.869960142011784` to `-1.5105841675210598`.
# 2026-01-19 14:42:11: oggm.cfg: PARAMS['melt_f'] changed from `8.151038724677672` to `9.578241892923046`.
# 2026-01-19 14:42:11: oggm.cfg: PARAMS['prcp_fac'] changed from `7.731572374003843` to `3.567053136926948`.
# 2026-01-19 14:42:11: oggm.cfg: PARAMS['temp_bias'] changed from `-1.5105841675210598` to `7.217770796159755`.
# 2026-01-19 14:42:12: oggm.cfg: PARAMS['melt_f'] changed from `9.578241892923046` to `5.4226615483106135`.
# 2026-01-19 14:42:12: oggm.cfg: PARAMS['prcp_fac'] changed from `3.567053136926948` to `3.0544399291533537`.
# 2026-01-19 14:42:12: oggm.cfg: PARAMS['temp_bias'] changed from `7.217770796159755` to `10.788877230401763`.
# 2026-01-19 14:42:13: oggm.cfg: PARAMS['melt_f'] changed from `5.4226615483106135` to `4.134866852063345`.
# 2026-01-19 14:42:13: oggm.cfg: PARAMS['prcp_fac'] changed from `3.0544399291533537` to `8.68912381441995`.
# 2026-01-19 14:42:13: oggm.cfg: PARAMS['temp_bias'] changed from `10.788877230401763` to `-3.61326339315138`.
# 2026-01-19 14:42:14: oggm.cfg: PARAMS['melt_f'] changed from `4.134866852063345` to `9.726805522886766`.
# 2026-01-19 14:42:14: oggm.cfg: PARAMS['prcp_fac'] changed from `8.68912381441995` to `3.0966312419793827`.
# 2026-01-19 14:42:14: oggm.cfg: PARAMS['temp_bias'] changed from `-3.61326339315138` to `0.11919826004172762`.
# 2026-01-19 14:42:14: oggm.cfg: PARAMS['melt_f'] changed from `9.726805522886766` to `12.056817206921297`.
# 2026-01-19 14:42:14: oggm.cfg: PARAMS['prcp_fac'] changed from `3.0966312419793827` to `5.470203168014083`.
# 2026-01-19 14:42:14: oggm.cfg: PARAMS['temp_bias'] changed from `0.11919826004172762` to `-6.2249427715770835`.
# 2026-01-19 14:42:15: oggm.cfg: PARAMS['melt_f'] changed from `12.056817206921297` to `14.512802514477197`.
# 2026-01-19 14:42:15: oggm.cfg: PARAMS['prcp_fac'] changed from `5.470203168014083` to `7.2877616116356`.
# 2026-01-19 14:42:15: oggm.cfg: PARAMS['temp_bias'] changed from `-6.2249427715770835` to `-4.447415809998118`.
# 2026-01-19 14:42:16: oggm.cfg: PARAMS['melt_f'] changed from `14.512802514477197` to `12.496715123562709`.
# 2026-01-19 14:42:16: oggm.cfg: PARAMS['prcp_fac'] changed from `7.2877616116356` to `5.350949906352531`.
# 2026-01-19 14:42:16: oggm.cfg: PARAMS['temp_bias'] changed from `-4.447415809998118` to `14.981872079481782`.
# 2026-01-19 14:42:16: oggm.cfg: PARAMS['melt_f'] changed from `12.496715123562709` to `5.699050316055685`.
# 2026-01-19 14:42:16: oggm.cfg: PARAMS['prcp_fac'] changed from `5.350949906352531` to `6.446106743242561`.
# 2026-01-19 14:42:16: oggm.cfg: PARAMS['temp_bias'] changed from `14.981872079481782` to `9.270601795076818`.
# 2026-01-19 14:42:17: oggm.cfg: PARAMS['melt_f'] changed from `5.699050316055685` to `7.410832257257299`.
# 2026-01-19 14:42:17: oggm.cfg: PARAMS['prcp_fac'] changed from `6.446106743242561` to `7.7199753702134215`.
# 2026-01-19 14:42:17: oggm.cfg: PARAMS['temp_bias'] changed from `9.270601795076818` to `4.804767394477729`.
# 2026-01-19 14:42:17: oggm.cfg: PARAMS['melt_f'] changed from `7.410832257257299` to `13.186289056445187`.
# 2026-01-19 14:42:17: oggm.cfg: PARAMS['prcp_fac'] changed from `7.7199753702134215` to `7.459656014182009`.
# 2026-01-19 14:42:17: oggm.cfg: PARAMS['temp_bias'] changed from `4.804767394477729` to `10.337397727440877`.
# 2026-01-19 14:42:18: oggm.cfg: PARAMS['melt_f'] changed from `13.186289056445187` to `14.052435399463917`.
# 2026-01-19 14:42:18: oggm.cfg: PARAMS['prcp_fac'] changed from `7.459656014182009` to `7.599777892310524`.
# 2026-01-19 14:42:18: oggm.cfg: PARAMS['temp_bias'] changed from `10.337397727440877` to `9.362534419609943`.
# 2026-01-19 14:42:18: oggm.cfg: PARAMS['melt_f'] changed from `14.052435399463917` to `2.4705529051935384`.
# 2026-01-19 14:42:18: oggm.cfg: PARAMS['prcp_fac'] changed from `7.599777892310524` to `5.9566407253488185`.
# 2026-01-19 14:42:18: oggm.cfg: PARAMS['temp_bias'] changed from `9.362534419609943` to `7.029499889071197`.
# 2026-01-19 14:42:19: oggm.cfg: PARAMS['melt_f'] changed from `2.4705529051935384` to `3.8897918317052262`.
# 2026-01-19 14:42:19: oggm.cfg: PARAMS['prcp_fac'] changed from `5.9566407253488185` to `1.5250661626263922`.
# 2026-01-19 14:42:19: oggm.cfg: PARAMS['temp_bias'] changed from `7.029499889071197` to `-7.4787386168336045`.
# 2026-01-19 14:42:20: oggm.cfg: PARAMS['melt_f'] changed from `3.8897918317052262` to `6.6535978150436454`.
# 2026-01-19 14:42:20: oggm.cfg: PARAMS['prcp_fac'] changed from `1.5250661626263922` to `2.698142011007697`.
# 2026-01-19 14:42:20: oggm.cfg: PARAMS['temp_bias'] changed from `-7.4787386168336045` to `-3.129322536282535`.
# 2026-01-19 14:42:20: oggm.cfg: PARAMS['melt_f'] changed from `6.6535978150436454` to `4.827087327041728`.
# 2026-01-19 14:42:20: oggm.cfg: PARAMS['prcp_fac'] changed from `2.698142011007697` to `2.397827326650722`.
# 2026-01-19 14:42:20: oggm.cfg: PARAMS['temp_bias'] changed from `-3.129322536282535` to `-14.688794837293353`.
# 2026-01-19 14:42:21: oggm.cfg: PARAMS['melt_f'] changed from `4.827087327041728` to `4.078754269006633`.
# 2026-01-19 14:42:21: oggm.cfg: PARAMS['prcp_fac'] changed from `2.397827326650722` to `5.005352934556222`.
# 2026-01-19 14:42:21: oggm.cfg: PARAMS['temp_bias'] changed from `-14.688794837293353` to `-8.257023114285188`.
# 2026-01-19 14:42:21: oggm.cfg: PARAMS['melt_f'] changed from `4.078754269006633` to `13.303550129555733`.
# 2026-01-19 14:42:21: oggm.cfg: PARAMS['prcp_fac'] changed from `5.005352934556222` to `3.8483239810662004`.
# 2026-01-19 14:42:21: oggm.cfg: PARAMS['temp_bias'] changed from `-8.257023114285188` to `-0.978406189738994`.
# 2026-01-19 14:42:22: oggm.cfg: PARAMS['melt_f'] changed from `13.303550129555733` to `8.84161607153143`.
# 2026-01-19 14:42:22: oggm.cfg: PARAMS['prcp_fac'] changed from `3.8483239810662004` to `8.879388945633174`.
# 2026-01-19 14:42:22: oggm.cfg: PARAMS['temp_bias'] changed from `-0.978406189738994` to `-9.869200838924808`.
# 2026-01-19 14:42:23: oggm.cfg: PARAMS['melt_f'] changed from `8.84161607153143` to `12.898857427647334`.
# 2026-01-19 14:42:23: oggm.cfg: PARAMS['prcp_fac'] changed from `8.879388945633174` to `8.10640826197595`.
# 2026-01-19 14:42:23: oggm.cfg: PARAMS['temp_bias'] changed from `-9.869200838924808` to `4.844285578121632`.
# 2026-01-19 14:42:24: oggm.cfg: PARAMS['melt_f'] changed from `12.898857427647334` to `6.244203667076861`.
# 2026-01-19 14:42:24: oggm.cfg: PARAMS['prcp_fac'] changed from `8.10640826197595` to `6.611203979584624`.
# 2026-01-19 14:42:24: oggm.cfg: PARAMS['temp_bias'] changed from `4.844285578121632` to `11.090671622603232`.
# 2026-01-19 14:42:24: oggm.cfg: PARAMS['melt_f'] changed from `6.244203667076861` to `15.110692201046968`.
# 2026-01-19 14:42:24: oggm.cfg: PARAMS['prcp_fac'] changed from `6.611203979584624` to `1.012519810919602`.
# 2026-01-19 14:42:24: oggm.cfg: PARAMS['temp_bias'] changed from `11.090671622603232` to `14.28432521330684`.
# 2026-01-19 14:42:25: oggm.cfg: PARAMS['melt_f'] changed from `15.110692201046968` to `12.103950044181518`.
# 2026-01-19 14:42:25: oggm.cfg: PARAMS['prcp_fac'] changed from `1.012519810919602` to `8.192040944375421`.
# 2026-01-19 14:42:25: oggm.cfg: PARAMS['temp_bias'] changed from `14.28432521330684` to `1.8053027288143326`.
# 2026-01-19 14:42:25: oggm.cfg: PARAMS['melt_f'] changed from `12.103950044181518` to `1.838615380662576`.
# 2026-01-19 14:42:25: oggm.cfg: PARAMS['prcp_fac'] changed from `8.192040944375421` to `6.742985150772796`.
# 2026-01-19 14:42:25: oggm.cfg: PARAMS['temp_bias'] changed from `1.8053027288143326` to `13.445475706439584`.
# 2026-01-19 14:42:26: oggm.cfg: PARAMS['melt_f'] changed from `1.838615380662576` to `13.992158529096729`.
# 2026-01-19 14:42:26: oggm.cfg: PARAMS['prcp_fac'] changed from `6.742985150772796` to `7.662828761762196`.
# 2026-01-19 14:42:26: oggm.cfg: PARAMS['temp_bias'] changed from `13.445475706439584` to `10.305797183029501`.
# 2026-01-19 14:42:26: oggm.cfg: PARAMS['melt_f'] changed from `13.992158529096729` to `2.557986315054173`.
# 2026-01-19 14:42:26: oggm.cfg: PARAMS['prcp_fac'] changed from `7.662828761762196` to `8.787289627955849`.
# 2026-01-19 14:42:26: oggm.cfg: PARAMS['temp_bias'] changed from `10.305797183029501` to `10.670034426566087`.
# 2026-01-19 14:42:27: oggm.cfg: PARAMS['melt_f'] changed from `2.557986315054173` to `15.621118194313146`.
# 2026-01-19 14:42:27: oggm.cfg: PARAMS['prcp_fac'] changed from `8.787289627955849` to `4.658091426784471`.
# 2026-01-19 14:42:27: oggm.cfg: PARAMS['temp_bias'] changed from `10.670034426566087` to `-1.9837475427687998`.
# 2026-01-19 14:42:27: oggm.cfg: PARAMS['melt_f'] changed from `15.621118194313146` to `10.716272084908601`.
# 2026-01-19 14:42:27: oggm.cfg: PARAMS['prcp_fac'] changed from `4.658091426784471` to `4.633524319559692`.
# 2026-01-19 14:42:27: oggm.cfg: PARAMS['temp_bias'] changed from `-1.9837475427687998` to `11.202343346213926`.
# 2026-01-19 14:42:28: oggm.cfg: PARAMS['melt_f'] changed from `10.716272084908601` to `4.339765229354041`.
# 2026-01-19 14:42:28: oggm.cfg: PARAMS['prcp_fac'] changed from `4.633524319559692` to `2.965973086492691`.
# 2026-01-19 14:42:28: oggm.cfg: PARAMS['temp_bias'] changed from `11.202343346213926` to `-14.075881455473606`.
# 2026-01-19 14:42:29: oggm.cfg: PARAMS['melt_f'] changed from `4.339765229354041` to `13.277425524121467`.
# 2026-01-19 14:42:29: oggm.cfg: PARAMS['prcp_fac'] changed from `2.965973086492691` to `9.83354352319831`.
# 2026-01-19 14:42:29: oggm.cfg: PARAMS['temp_bias'] changed from `-14.075881455473606` to `-13.529438604163712`.
# 2026-01-19 14:42:30: oggm.cfg: PARAMS['melt_f'] changed from `13.277425524121467` to `13.850943450888698`.
# 2026-01-19 14:42:30: oggm.cfg: PARAMS['prcp_fac'] changed from `9.83354352319831` to `9.601756427217087`.
# 2026-01-19 14:42:30: oggm.cfg: PARAMS['temp_bias'] changed from `-13.529438604163712` to `-11.197389179214658`.
# 2026-01-19 14:42:31: oggm.cfg: PARAMS['melt_f'] changed from `13.850943450888698` to `13.551018847593017`.
# 2026-01-19 14:42:31: oggm.cfg: PARAMS['prcp_fac'] changed from `9.601756427217087` to `9.183794195388257`.
# 2026-01-19 14:42:31: oggm.cfg: PARAMS['temp_bias'] changed from `-11.197389179214658` to `2.709576424772763`.
# 2026-01-19 14:42:32: oggm.cfg: PARAMS['melt_f'] changed from `13.551018847593017` to `16.032263495152115`.
# 2026-01-19 14:42:32: oggm.cfg: PARAMS['prcp_fac'] changed from `9.183794195388257` to `3.1718144039397345`.
# 2026-01-19 14:42:32: oggm.cfg: PARAMS['temp_bias'] changed from `2.709576424772763` to `14.70635809449253`.
# 2026-01-19 14:42:32: oggm.cfg: PARAMS['melt_f'] changed from `16.032263495152115` to `15.388774426493223`.
# 2026-01-19 14:42:32: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1718144039397345` to `9.082091361436415`.
# 2026-01-19 14:42:32: oggm.cfg: PARAMS['temp_bias'] changed from `14.70635809449253` to `14.166476145666241`.
# 2026-01-19 14:42:33: oggm.cfg: PARAMS['melt_f'] changed from `15.388774426493223` to `7.8984085776913435`.
# 2026-01-19 14:42:33: oggm.cfg: PARAMS['prcp_fac'] changed from `9.082091361436415` to `1.2723837533169422`.
# 2026-01-19 14:42:33: oggm.cfg: PARAMS['temp_bias'] changed from `14.166476145666241` to `6.975942193858739`.
# 2026-01-19 14:42:33: oggm.cfg: PARAMS['melt_f'] changed from `7.8984085776913435` to `10.252178804479046`.
# 2026-01-19 14:42:33: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2723837533169422` to `4.862049781789339`.
# 2026-01-19 14:42:33: oggm.cfg: PARAMS['temp_bias'] changed from `6.975942193858739` to `-3.1738246157973506`.
# 2026-01-19 14:42:34: oggm.cfg: PARAMS['melt_f'] changed from `10.252178804479046` to `5.209752623374065`.
# 2026-01-19 14:42:34: oggm.cfg: PARAMS['prcp_fac'] changed from `4.862049781789339` to `4.974211090964401`.
# 2026-01-19 14:42:34: oggm.cfg: PARAMS['temp_bias'] changed from `-3.1738246157973506` to `0.2486326422921188`.
# 2026-01-19 14:42:34: oggm.cfg: PARAMS['melt_f'] changed from `5.209752623374065` to `2.9879530488351786`.
# 2026-01-19 14:42:34: oggm.cfg: PARAMS['prcp_fac'] changed from `4.974211090964401` to `8.16287118596705`.
# 2026-01-19 14:42:34: oggm.cfg: PARAMS['temp_bias'] changed from `0.2486326422921188` to `4.699690443995028`.
# 2026-01-19 14:42:35: oggm.cfg: PARAMS['melt_f'] changed from `2.9879530488351786` to `9.437865460666693`.
# 2026-01-19 14:42:35: oggm.cfg: PARAMS['prcp_fac'] changed from `8.16287118596705` to `5.056044887374318`.
# 2026-01-19 14:42:35: oggm.cfg: PARAMS['temp_bias'] changed from `4.699690443995028` to `1.8354090955715847`.
# 2026-01-19 14:42:35: oggm.cfg: PARAMS['melt_f'] changed from `9.437865460666693` to `5.543952632577225`.
# 2026-01-19 14:42:35: oggm.cfg: PARAMS['prcp_fac'] changed from `5.056044887374318` to `6.9601667431908405`.
# 2026-01-19 14:42:35: oggm.cfg: PARAMS['temp_bias'] changed from `1.8354090955715847` to `-10.280262960471031`.
# 2026-01-19 14:42:36: oggm.cfg: PARAMS['melt_f'] changed from `5.543952632577225` to `7.380572277462744`.
# 2026-01-19 14:42:36: oggm.cfg: PARAMS['prcp_fac'] changed from `6.9601667431908405` to `3.3371832387306535`.
# 2026-01-19 14:42:36: oggm.cfg: PARAMS['temp_bias'] changed from `-10.280262960471031` to `13.973723795349471`.
# 2026-01-19 14:42:37: oggm.cfg: PARAMS['melt_f'] changed from `7.380572277462744` to `5.19058881031822`.
# 2026-01-19 14:42:37: oggm.cfg: PARAMS['prcp_fac'] changed from `3.3371832387306535` to `8.902330346442987`.
# 2026-01-19 14:42:37: oggm.cfg: PARAMS['temp_bias'] changed from `13.973723795349471` to `-5.630432367808792`.
# 2026-01-19 14:42:38: oggm.cfg: PARAMS['melt_f'] changed from `5.19058881031822` to `12.588311504166143`.
# 2026-01-19 14:42:38: oggm.cfg: PARAMS['prcp_fac'] changed from `8.902330346442987` to `5.193969505315375`.
# 2026-01-19 14:42:38: oggm.cfg: PARAMS['temp_bias'] changed from `-5.630432367808792` to `-6.165620820214295`.
# 2026-01-19 14:42:39: oggm.cfg: PARAMS['melt_f'] changed from `12.588311504166143` to `5.1454729107075945`.
# ...
# 2026-01-19 14:51:16: oggm.cfg: PARAMS['temp_bias'] changed from `8.741994692925108` to `1.953718568391679`.
# 2026-01-19 14:51:17: oggm.cfg: PARAMS['melt_f'] changed from `6.083514917303066` to `7.65374362305011`.
# 2026-01-19 14:51:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.601949788498679` to `1.289996189668135`.
# 2026-01-19 14:51:17: oggm.cfg: PARAMS['temp_bias'] changed from `1.953718568391679` to `-9.242607945789285`.
# 2026-01-19 14:51:17: oggm.cfg: PARAMS['melt_f'] changed from `7.65374362305011` to `6.5112323729067665`.
# 2026-01-19 14:51:17: oggm.cfg: PARAMS['prcp_fac'] changed from `1.289996189668135` to `4.937128140738188`.
# 2026-01-19 14:51:17: oggm.cfg: PARAMS['temp_bias'] changed from `-9.242607945789285` to `10.439440265318435`.
# 2026-01-19 14:51:18: oggm.cfg: PARAMS['melt_f'] changed from `6.5112323729067665` to `11.930603665706967`.
# 2026-01-19 14:51:18: oggm.cfg: PARAMS['prcp_fac'] changed from `4.937128140738188` to `4.650026979274469`.
# 2026-01-19 14:51:18: oggm.cfg: PARAMS['temp_bias'] changed from `10.439440265318435` to `2.97468336495686`.
# 2026-01-19 14:51:18: oggm.cfg: PARAMS['melt_f'] changed from `11.930603665706967` to `14.206646049776193`.
# 2026-01-19 14:51:18: oggm.cfg: PARAMS['prcp_fac'] changed from `4.650026979274469` to `0.7906072542193682`.
# 2026-01-19 14:51:18: oggm.cfg: PARAMS['temp_bias'] changed from `2.97468336495686` to `-12.624819109498873`.
# 2026-01-19 14:51:19: oggm.cfg: PARAMS['melt_f'] changed from `14.206646049776193` to `9.49695154511541`.
# 2026-01-19 14:51:19: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7906072542193682` to `3.479145262294879`.
# 2026-01-19 14:51:19: oggm.cfg: PARAMS['temp_bias'] changed from `-12.624819109498873` to `0.49509866535955105`.
# 2026-01-19 14:51:19: oggm.cfg: PARAMS['melt_f'] changed from `9.49695154511541` to `7.787882767876394`.
# 2026-01-19 14:51:19: oggm.cfg: PARAMS['prcp_fac'] changed from `3.479145262294879` to `0.7810905540369716`.
# 2026-01-19 14:51:19: oggm.cfg: PARAMS['temp_bias'] changed from `0.49509866535955105` to `-10.034860156431112`.
# 2026-01-19 14:51:20: oggm.cfg: PARAMS['melt_f'] changed from `7.787882767876394` to `5.777012044404288`.
# 2026-01-19 14:51:20: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7810905540369716` to `5.459797493591859`.
# 2026-01-19 14:51:20: oggm.cfg: PARAMS['temp_bias'] changed from `-10.034860156431112` to `0.9707813915812551`.
# 2026-01-19 14:51:20: oggm.cfg: PARAMS['melt_f'] changed from `5.777012044404288` to `8.552205724644786`.
# 2026-01-19 14:51:20: oggm.cfg: PARAMS['prcp_fac'] changed from `5.459797493591859` to `1.2825738659725787`.
# 2026-01-19 14:51:20: oggm.cfg: PARAMS['temp_bias'] changed from `0.9707813915812551` to `-13.259071567525114`.
# 2026-01-19 14:51:21: oggm.cfg: PARAMS['melt_f'] changed from `8.552205724644786` to `3.437089123868687`.
# 2026-01-19 14:51:21: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2825738659725787` to `4.771410359766472`.
# 2026-01-19 14:51:21: oggm.cfg: PARAMS['temp_bias'] changed from `-13.259071567525114` to `-0.14014122216137714`.
# 2026-01-19 14:51:22: oggm.cfg: PARAMS['melt_f'] changed from `3.437089123868687` to `5.158451438974334`.
# 2026-01-19 14:51:22: oggm.cfg: PARAMS['prcp_fac'] changed from `4.771410359766472` to `5.8881509705801705`.
# 2026-01-19 14:51:22: oggm.cfg: PARAMS['temp_bias'] changed from `-0.14014122216137714` to `7.793312440047462`.
# 2026-01-19 14:51:22: oggm.cfg: PARAMS['melt_f'] changed from `5.158451438974334` to `14.633474379125218`.
# 2026-01-19 14:51:22: oggm.cfg: PARAMS['prcp_fac'] changed from `5.8881509705801705` to `3.087508899645508`.
# 2026-01-19 14:51:22: oggm.cfg: PARAMS['temp_bias'] changed from `7.793312440047462` to `14.020708787025658`.
# 2026-01-19 14:51:23: oggm.cfg: PARAMS['melt_f'] changed from `14.633474379125218` to `9.770984183640515`.
# 2026-01-19 14:51:23: oggm.cfg: PARAMS['prcp_fac'] changed from `3.087508899645508` to `1.3741041125802853`.
# 2026-01-19 14:51:23: oggm.cfg: PARAMS['temp_bias'] changed from `14.020708787025658` to `-14.943968034095713`.
# 2026-01-19 14:51:23: oggm.cfg: PARAMS['melt_f'] changed from `9.770984183640515` to `15.141387466321017`.
# 2026-01-19 14:51:23: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3741041125802853` to `5.2376791575990165`.
# 2026-01-19 14:51:23: oggm.cfg: PARAMS['temp_bias'] changed from `-14.943968034095713` to `-14.391595920719414`.
# 2026-01-19 14:51:24: oggm.cfg: PARAMS['melt_f'] changed from `15.141387466321017` to `6.677079885320475`.
# 2026-01-19 14:51:24: oggm.cfg: PARAMS['prcp_fac'] changed from `5.2376791575990165` to `8.516742892766386`.
# 2026-01-19 14:51:24: oggm.cfg: PARAMS['temp_bias'] changed from `-14.391595920719414` to `8.384050243903204`.
# 2026-01-19 14:51:25: oggm.cfg: PARAMS['melt_f'] changed from `6.677079885320475` to `15.359120901242573`.
# 2026-01-19 14:51:25: oggm.cfg: PARAMS['prcp_fac'] changed from `8.516742892766386` to `9.27641756182539`.
# 2026-01-19 14:51:25: oggm.cfg: PARAMS['temp_bias'] changed from `8.384050243903204` to `-12.532627719811883`.
# 2026-01-19 14:51:26: oggm.cfg: PARAMS['melt_f'] changed from `15.359120901242573` to `6.101758075965162`.
# 2026-01-19 14:51:26: oggm.cfg: PARAMS['prcp_fac'] changed from `9.27641756182539` to `7.898217481869287`.
# 2026-01-19 14:51:26: oggm.cfg: PARAMS['temp_bias'] changed from `-12.532627719811883` to `8.971503226431132`.
# 2026-01-19 14:51:27: oggm.cfg: PARAMS['melt_f'] changed from `6.101758075965162` to `16.309924765112807`.
# 2026-01-19 14:51:27: oggm.cfg: PARAMS['prcp_fac'] changed from `7.898217481869287` to `3.8187996172300798`.
# 2026-01-19 14:51:27: oggm.cfg: PARAMS['temp_bias'] changed from `8.971503226431132` to `-6.008195608262799`.
# 2026-01-19 14:51:27: oggm.cfg: PARAMS['melt_f'] changed from `16.309924765112807` to `10.083400790988557`.
# 2026-01-19 14:51:27: oggm.cfg: PARAMS['prcp_fac'] changed from `3.8187996172300798` to `0.9968297035857036`.
# 2026-01-19 14:51:27: oggm.cfg: PARAMS['temp_bias'] changed from `-6.008195608262799` to `-7.852145097663319`.
# 2026-01-19 14:51:28: oggm.cfg: PARAMS['melt_f'] changed from `10.083400790988557` to `8.400499337209839`.
# 2026-01-19 14:51:28: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9968297035857036` to `2.624761934321348`.
# 2026-01-19 14:51:28: oggm.cfg: PARAMS['temp_bias'] changed from `-7.852145097663319` to `12.285276284505418`.
# 2026-01-19 14:51:28: oggm.cfg: PARAMS['melt_f'] changed from `8.400499337209839` to `9.422894608820819`.
# 2026-01-19 14:51:28: oggm.cfg: PARAMS['prcp_fac'] changed from `2.624761934321348` to `9.910065384160912`.
# 2026-01-19 14:51:28: oggm.cfg: PARAMS['temp_bias'] changed from `12.285276284505418` to `-11.80796393904371`.
# 2026-01-19 14:51:30: oggm.cfg: PARAMS['melt_f'] changed from `9.422894608820819` to `8.860333970979461`.
# 2026-01-19 14:51:30: oggm.cfg: PARAMS['prcp_fac'] changed from `9.910065384160912` to `0.6822533325455241`.
# 2026-01-19 14:51:30: oggm.cfg: PARAMS['temp_bias'] changed from `-11.80796393904371` to `2.3163935725303944`.
# 2026-01-19 14:51:30: oggm.cfg: PARAMS['melt_f'] changed from `8.860333970979461` to `7.884127724729832`.
# 2026-01-19 14:51:30: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6822533325455241` to `0.9734281705140515`.
# 2026-01-19 14:51:30: oggm.cfg: PARAMS['temp_bias'] changed from `2.3163935725303944` to `-6.379508163481955`.
# 2026-01-19 14:51:31: oggm.cfg: PARAMS['melt_f'] changed from `7.884127724729832` to `16.78082707428929`.
# 2026-01-19 14:51:31: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9734281705140515` to `7.845676359550832`.
# 2026-01-19 14:51:31: oggm.cfg: PARAMS['temp_bias'] changed from `-6.379508163481955` to `-4.4816295374265245`.
# 2026-01-19 14:51:32: oggm.cfg: PARAMS['melt_f'] changed from `16.78082707428929` to `14.08698798160685`.
# 2026-01-19 14:51:32: oggm.cfg: PARAMS['prcp_fac'] changed from `7.845676359550832` to `3.1178942626805957`.
# 2026-01-19 14:51:32: oggm.cfg: PARAMS['temp_bias'] changed from `-4.4816295374265245` to `14.085495543728541`.
# 2026-01-19 14:51:32: oggm.cfg: PARAMS['melt_f'] changed from `14.08698798160685` to `10.00992233925172`.
# 2026-01-19 14:51:32: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1178942626805957` to `7.246100906756579`.
# 2026-01-19 14:51:32: oggm.cfg: PARAMS['temp_bias'] changed from `14.085495543728541` to `6.298565646452133`.
# 2026-01-19 14:51:33: oggm.cfg: PARAMS['melt_f'] changed from `10.00992233925172` to `5.710605175180126`.
# 2026-01-19 14:51:33: oggm.cfg: PARAMS['prcp_fac'] changed from `7.246100906756579` to `0.2152203589701126`.
# 2026-01-19 14:51:33: oggm.cfg: PARAMS['temp_bias'] changed from `6.298565646452133` to `1.007238193147053`.
# 2026-01-19 14:51:33: oggm.cfg: PARAMS['melt_f'] changed from `5.710605175180126` to `6.870003403157474`.
# 2026-01-19 14:51:33: oggm.cfg: PARAMS['prcp_fac'] changed from `0.2152203589701126` to `2.5453425242249654`.
# 2026-01-19 14:51:33: oggm.cfg: PARAMS['temp_bias'] changed from `1.007238193147053` to `-7.925160314098879`.
# 2026-01-19 14:51:34: oggm.cfg: PARAMS['melt_f'] changed from `6.870003403157474` to `4.945989133597682`.
# 2026-01-19 14:51:34: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5453425242249654` to `5.503151171141733`.
# 2026-01-19 14:51:34: oggm.cfg: PARAMS['temp_bias'] changed from `-7.925160314098879` to `2.053919222979925`.
# 2026-01-19 14:51:34: oggm.cfg: PARAMS['melt_f'] changed from `4.945989133597682` to `8.393333070970499`.
# 2026-01-19 14:51:34: oggm.cfg: PARAMS['prcp_fac'] changed from `5.503151171141733` to `5.216162589765023`.
# 2026-01-19 14:51:34: oggm.cfg: PARAMS['temp_bias'] changed from `2.053919222979925` to `3.865625292967401`.
# 2026-01-19 14:51:35: oggm.cfg: PARAMS['melt_f'] changed from `8.393333070970499` to `3.25424650709658`.
# 2026-01-19 14:51:35: oggm.cfg: PARAMS['prcp_fac'] changed from `5.216162589765023` to `8.562417604861704`.
# 2026-01-19 14:51:35: oggm.cfg: PARAMS['temp_bias'] changed from `3.865625292967401` to `-12.88885485686148`.
# 2026-01-19 14:51:36: oggm.cfg: PARAMS['melt_f'] changed from `3.25424650709658` to `10.395733503014593`.
# 2026-01-19 14:51:36: oggm.cfg: PARAMS['prcp_fac'] changed from `8.562417604861704` to `7.108002082537348`.
# 2026-01-19 14:51:36: oggm.cfg: PARAMS['temp_bias'] changed from `-12.88885485686148` to `-0.8705591691167633`.
# 2026-01-19 14:51:36: oggm.cfg: PARAMS['melt_f'] changed from `10.395733503014593` to `7.3473250347437595`.
# 2026-01-19 14:51:36: oggm.cfg: PARAMS['prcp_fac'] changed from `7.108002082537348` to `2.1067995270514777`.
# 2026-01-19 14:51:36: oggm.cfg: PARAMS['temp_bias'] changed from `-0.8705591691167633` to `6.049915996965929`.
# 2026-01-19 14:51:37: oggm.cfg: PARAMS['melt_f'] changed from `7.3473250347437595` to `4.788652427413851`.
# 2026-01-19 14:51:37: oggm.cfg: PARAMS['prcp_fac'] changed from `2.1067995270514777` to `0.7248862993935259`.
# 2026-01-19 14:51:37: oggm.cfg: PARAMS['temp_bias'] changed from `6.049915996965929` to `3.061596086734081`.
# 2026-01-19 14:51:38: oggm.cfg: PARAMS['melt_f'] changed from `4.788652427413851` to `10.989542699338973`.
# 2026-01-19 14:51:38: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7248862993935259` to `9.007780265330133`.
# 2026-01-19 14:51:38: oggm.cfg: PARAMS['temp_bias'] changed from `3.061596086734081` to `9.948437255300583`.
# 2026-01-19 14:51:38: oggm.cfg: PARAMS['melt_f'] changed from `10.989542699338973` to `3.5633122947348723`.
# 2026-01-19 14:51:38: oggm.cfg: PARAMS['prcp_fac'] changed from `9.007780265330133` to `5.030405184532985`.
# 2026-01-19 14:51:38: oggm.cfg: PARAMS['temp_bias'] changed from `9.948437255300583` to `-8.236153046239385`.
# 2026-01-19 14:51:39: oggm.cfg: PARAMS['melt_f'] changed from `3.5633122947348723` to `2.281332805897545`.
# 2026-01-19 14:51:39: oggm.cfg: PARAMS['prcp_fac'] changed from `5.030405184532985` to `6.904861336870955`.
# 2026-01-19 14:51:39: oggm.cfg: PARAMS['temp_bias'] changed from `-8.236153046239385` to `7.926594967649258`.
# 2026-01-19 14:51:39: oggm.cfg: PARAMS['melt_f'] changed from `2.281332805897545` to `16.089659426811796`.
# 2026-01-19 14:51:39: oggm.cfg: PARAMS['prcp_fac'] changed from `6.904861336870955` to `8.591989922643453`.
# 2026-01-19 14:51:39: oggm.cfg: PARAMS['temp_bias'] changed from `7.926594967649258` to `2.215510320236234`.
# 2026-01-19 14:51:40: oggm.cfg: PARAMS['melt_f'] changed from `16.089659426811796` to `3.440743777332745`.
# 2026-01-19 14:51:40: oggm.cfg: PARAMS['prcp_fac'] changed from `8.591989922643453` to `2.847070589055259`.
# 2026-01-19 14:51:40: oggm.cfg: PARAMS['temp_bias'] changed from `2.215510320236234` to `-7.712248223404054`.
# 2026-01-19 14:51:40: oggm.cfg: PARAMS['melt_f'] changed from `3.440743777332745` to `12.835894420225639`.
# 2026-01-19 14:51:40: oggm.cfg: PARAMS['prcp_fac'] changed from `2.847070589055259` to `5.291978220038656`.
# 2026-01-19 14:51:40: oggm.cfg: PARAMS['temp_bias'] changed from `-7.712248223404054` to `5.506949567207947`.
# 2026-01-19 14:51:41: oggm.cfg: PARAMS['melt_f'] changed from `12.835894420225639` to `7.128952888389759`.
# 2026-01-19 14:51:41: oggm.cfg: PARAMS['prcp_fac'] changed from `5.291978220038656` to `2.26255008984441`.
# 2026-01-19 14:51:41: oggm.cfg: PARAMS['temp_bias'] changed from `5.506949567207947` to `5.227726469284164`.
# 2026-01-19 14:51:42: oggm.cfg: PARAMS['melt_f'] changed from `7.128952888389759` to `9.608049183517387`.
# 2026-01-19 14:51:42: oggm.cfg: PARAMS['prcp_fac'] changed from `2.26255008984441` to `7.00856287030928`.
# 2026-01-19 14:51:42: oggm.cfg: PARAMS['temp_bias'] changed from `5.227726469284164` to `2.3699369721471513`.
# 2026-01-19 14:51:42: oggm.cfg: PARAMS['melt_f'] changed from `9.608049183517387` to `16.36161191737962`.
# 2026-01-19 14:51:42: oggm.cfg: PARAMS['prcp_fac'] changed from `7.00856287030928` to `3.6653241039398146`.
# 2026-01-19 14:51:42: oggm.cfg: PARAMS['temp_bias'] changed from `2.3699369721471513` to `-7.618928698908382`.
# 2026-01-19 14:51:43: oggm.cfg: PARAMS['melt_f'] changed from `16.36161191737962` to `15.94053821306633`.
# 2026-01-19 14:51:43: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6653241039398146` to `3.4064968798443545`.
# 2026-01-19 14:51:43: oggm.cfg: PARAMS['temp_bias'] changed from `-7.618928698908382` to `-9.875916558008994`.
# 2026-01-19 14:51:43: oggm.cfg: PARAMS['melt_f'] changed from `15.94053821306633` to `14.462856377901566`.
# 2026-01-19 14:51:43: oggm.cfg: PARAMS['prcp_fac'] changed from `3.4064968798443545` to `7.3133956109297955`.
# 2026-01-19 14:51:43: oggm.cfg: PARAMS['temp_bias'] changed from `-9.875916558008994` to `10.687662054497782`.
# 2026-01-19 14:51:44: oggm.cfg: PARAMS['melt_f'] changed from `14.462856377901566` to `15.003508366822915`.
# 2026-01-19 14:51:44: oggm.cfg: PARAMS['prcp_fac'] changed from `7.3133956109297955` to `9.945256876348719`.
# 2026-01-19 14:51:44: oggm.cfg: PARAMS['temp_bias'] changed from `10.687662054497782` to `-3.6855586425871927`.
# 2026-01-19 14:51:45: oggm.cfg: PARAMS['melt_f'] changed from `15.003508366822915` to `5.630140315408423`.
# 2026-01-19 14:51:45: oggm.cfg: PARAMS['prcp_fac'] changed from `9.945256876348719` to `1.1409331492449206`.
# 2026-01-19 14:51:45: oggm.cfg: PARAMS['temp_bias'] changed from `-3.6855586425871927` to `0.3687958216463656`.
# 2026-01-19 14:51:45: oggm.cfg: PARAMS['melt_f'] changed from `5.630140315408423` to `9.46933684678828`.
# 2026-01-19 14:51:45: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1409331492449206` to `9.683603013287511`.
# 2026-01-19 14:51:45: oggm.cfg: PARAMS['temp_bias'] changed from `0.3687958216463656` to `-6.3944190101820215`.
# 2026-01-19 14:51:47: oggm.cfg: PARAMS['melt_f'] changed from `9.46933684678828` to `14.355224030864367`.
# 2026-01-19 14:51:47: oggm.cfg: PARAMS['prcp_fac'] changed from `9.683603013287511` to `8.065470434806196`.
# 2026-01-19 14:51:47: oggm.cfg: PARAMS['temp_bias'] changed from `-6.3944190101820215` to `-7.504840429774527`.
# 2026-01-19 14:51:48: oggm.cfg: PARAMS['melt_f'] changed from `14.355224030864367` to `4.198306977448036`.
# 2026-01-19 14:51:48: oggm.cfg: PARAMS['prcp_fac'] changed from `8.065470434806196` to `8.43192472966391`.
# 2026-01-19 14:51:48: oggm.cfg: PARAMS['temp_bias'] changed from `-7.504840429774527` to `-13.85151775135033`.

# %%
# Plot Monte Carlo (MC) simulations results for the Runoff and compare with data:
plt.figure(figsize=[15,5])
plt.plot(mbdf.index.values, np.transpose(runoff), 'k', linewidth = 0.5)
plt.ylabel('Runoff'); plt.xlabel('Years')
plt.legend(['sim'])
plt.title("Number of parameter samples: N = %d" % N, loc='right')
plt.show()

# %%
# Also colour mapping (retrospectively) based on temp_bias values
import matplotlib.pyplot as plt
import numpy as np

temp_bias_index = 2  # Index of temp_bias in X

import matplotlib.pyplot as plt
import numpy as np

# Colormap and normalization
cmap = plt.cm.coolwarm
norm = plt.Normalize(vmin=X[:, temp_bias_index].min(), vmax=X[:, temp_bias_index].max())

fig, ax = plt.subplots(figsize=(15, 5))

# Plot each simulation with color based on temp_bias
for i in range(np.shape(runoff)[0]):  # assuming QQ_runoff is (N, time)
    color = cmap(norm(X[i, temp_bias_index]))
    ax.plot(mbdf.index.values, runoff[i, :], linewidth=0.5, color=color)

ax.set_ylabel('Runoff')
ax.set_xlabel('Years')
ax.set_title(f"Number of parameter samples: N = {N}", loc='right')

# Add colorbar linked to the same colormap
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # required for colorbar
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Temperature Bias')

plt.show()

# %% [markdown]
# ## Distribution of Model Outputs

# %%
Y_lab_runoff_dist = ['Mean Runoff', 'Std of Runoff']

YY_hydro = np.nan * np.ones((N, 2))

for i, x in enumerate(runoff):
    YY_hydro[i,0] = np.mean(x)
    YY_hydro[i,1] = np.std(x)

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_hydro[:,0], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_lab_runoff_dist[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_hydro[:,1], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_lab_runoff_dist[1])

plt.tight_layout()

# %% [markdown]
# ## Sensitivity Analysis

# %%
annual_mean_runoff = np.mean(runoff, axis=1) # Mean annual runoff for each sample
annual_std_runoff = np.std(runoff, axis=1) # Std annual runoff for each sample

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(annual_mean_runoff, annual_std_runoff, s=5), plt.title('Mean runoff vs Std of runoff'), plt.xlabel('Mean runoff'), plt.ylabel('Std of runoff (mm w.e.)'),
plt.gca().locator_params(axis='x', nbins=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here we are plotting the outputs of our runoff model and plotted the mean runoff values vs the standard deviation of the runoff values, this shows us the relationship between the two metrics. It can be seen here that for a lower mean runoff (under 40 (Mt) of runoff per our time period), in general there is a lower variation of runoff as well.
#
# Intuitively this makes sense considering that a lower average runoff would likely skew more towards lower runoff values varying throughout the year, or perhaps will have mostly low runoff with slighly higher runoff (to keep this variation low). However, once we surpass a runoff of 40 (Mt) per our time period, the realtionsip between the mean and std becomes abruptly uncorrelated. This is likely that at higher values, there are either a wider range of runoffs that could cause these higher mean runoffs, or that all runoff values could be sitting around this mean, resulting in a lower variation.

# %%
YY_hydro = np.nan * np.ones((N, 2))

for i, x in enumerate(runoff):
    YY_hydro[i,0] = np.mean(x)
    YY_hydro[i,1] = np.std(x)

Y_Labels = ['Mean Runoff', 'Std of Runoff']

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY_hydro[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %% [markdown]
# ### Now looking at scatter plots for a qualitative view of our sensitivity.
#
# Firstly looking at the mean runoff over the course of a year:
#
# - **The melt_f**: This appears to have a minimal relationship with the mean runoff, this appears almost randomly scattered, with a slight clustering towards a mean runoff of 0, but again this is evenly dispersed across all values of melt_f. Therefore, we can expect that the sensitivity analysis will show the melt_f having a very minimal effect on the mean runoff.
#
# - **The prcp_fac**: This appears to have a slight relationship with the mean runoff, with a clustering of points in a positive linear relationship with the mean runoff. This intuitively is what we might expect, as the prcp_fac increases, this will increase the amount of precipitation on the glacier. If the temperature is above our threshold for solid precipitation, this will then cause the precipitation to contribute directly to the runoff. However, a large number of points is dispersed almost randomly with the prcp_fac, again showing us that perhaps this may not show as particulatly impactful for our sensitivity analysis in relation to the mean runoff. But perhaps slightly more so than that of melt_f?
#
# - **The temp_bias**: This appears to have a very strong correlation with the mean_runoff. With a particularly tight correlation at large negative temperature biases. This makes sense, as this would ensure that the glacier atmospheric temperature is almost always below our threshold that would prevent both melt and liquid precipitation, leading to a very minimal runoff. As the temperature increases, and temp_bias exceeds 0 degrees Celcius, there is a very minimal relationship, with the points becoming more scattered. For our sensitivity analysis, from this, we can expect to see a large sensitivity for temp_bias. However, this is more likely due to the large range that we consider for temp_bias, which by default in the OGGM is [-15,15], if this was reduced to a smaller threshold then we can expect to see this sensitivity towards this parameter decreasing, and perhaps would expect prcp_fac to lead the sensitivity here.
#
# Now looking at the standard deviation of the runoff over the course of a year:
#
# - **The melt_f**: We can now see, that when considering the variation of the runoff over the course of the year, the melt_f now has a slight positive correlation. So that as the melt_f increases (the amount of melt that occurs in melt periods), the variation in the runoff also increases. This makes sense if we consider that when the temperature is above the melt temp threshold, there is very limited melting, however as the temperature increases and melt occurs, the quantity of melt (and therefore runoff) is controlled by the melt_f. Therefore this exaggerates the melting in the melting periods, which will contribute to the variation of the runoff. The melt factor fluctuates with temperatures that occur, some years
#
# - **The prcp_f**: Now, there is very minimal correlation between the precipitation factor and the variation of the runoff across the year, this is likely due to the fact that the temperature bias is dominating here, and that the quantity of precipitation is not affecting the variation due to the fact that if the temperature is below the melting threshold then this does not contribute to the quantity of runoff. The prcp_fac does not dramatically change the rainfall from year to year, hence this will produce a minimal variation in our runoff. Changing the prcp_fac does not introduce new variability, only increases the baseline amount of rainfall.
#
# - **The temp_bias**: This parameter appears relatively similar to before, with a very tight correlation at negative temperature biases. This reduces the temperature, restricting the runoff and thus aligns with our expectations. As the temperature bias exceeds 0 and increases to a positive temperature bias, the correlation becomes a bit less tighly coupled, but there is still a clustering towards a positive correlation, this still affects the variation of runoff, as this raises the temperature uniformly, therefore potentially causing melt when there may not otherwise be. Again, the reason that this is so impactful on the standard deviation is likely due to the large range of temperature bias.

# %% [markdown]
# ## The relationship of temp_bias with the other parameters.
#
# After investigating the scatter plots and the tight correlations of temperature bias, we can assume this will be the dominating factor in our sensitivity analysis. We can investigate the relationship between the temp_bias and the other parameters on our plot with a colour mapping.

# %%
temp_bias_index = 2

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], YY_hydro[:, j], c=X[:, temp_bias_index], cmap='coolwarm', edgecolors='grey')
        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Temp Bias (°C)')
    plt.show()

interact(scatter_function, metric=Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %% [markdown]
# As we would expect, we can see the clustering towards both the mean and std of the runoff being 0 can be attributed to the extreme negative values of the temperature bias as this restricts the precipitation factor or the melt factor from impacting the runoff amount here.

# %% [markdown]
# # Quantitative sensitivity: RSA with bootstrapping
#
# Note: This is currently an abitrary threshold in which we can update if we obtain the desired values. I have put 25, this is the runoff standard deviation and mean value in Megatonnes per year.
#
# The RSA sensitivity analysis may be incorrect due to considering an arbitrary threshold, but this is an example of how the RSA can be used in this notebook with the OGGM runoff output.
#
# If we obtain the correct values we can add this into our code easily.

# %%
Nboot = 50 # Number of resamples used for bootstrapping
# TODO: Currently, I am not sure if we have observed hydro data for the runoff to set targets against?
# For now, we can just set some arbitrary target values to see the sensitivity indices
#  When we know what we are doing this will need to be updated - i.e. glacier we are investigating, questions we want to answer etc.
for i in range(2):
    if i==0:
        Y=YY_hydro[:,0]
        target=25
    if i==1:
        Y=YY_hydro[:,1]
        target=25

    # plot:
    plt.figure(figsize=[7,2])
    mvd, _, _, idx = RSA_tr.RSA_indices_thres(X, Y, target, Nboot=Nboot)
    mvd_m, mvd_lb, mvd_ub = aggregate_boot(mvd) # shape (M,)
    yerr=np.c_[mvd_m-mvd_lb,mvd_ub-mvd_m].T
    plt.bar(range(len(mvd_m)), mvd_m, color='grey',yerr=yerr)
    plt.title(Y_Labels[i], loc='center'), plt.xticks(range(len(mvd_m)), X_labels), plt.ylabel('Sensitivity')
    plt.show()

# %% [markdown]
# Now performing RSA with bootstrapping to quantify the sensitivity of our parameters to our output metrics and using bootstrapping to quantify the uncertainty here.
#
# As we expected, the sensitvity of the melt_f and prcp_fac paramaters is low and have a relatively large uncertainty compared to that of the temp_bias which is significantly the most impactful parameter with very minimal uncertainty.

# %% [markdown]
# It would be interesting here to reduce the range of the temperature bias to see if the sensitivity varies (we would expect the impact of the temp_bias to be reduced), and to try with an array of glaciers, mainly in High Mountain Asia. This glacier is within Austria, and observing an array of glacier could provide us with additional information about other glaciers.

# %% [markdown]
# ## Investigating the relationship between parameters and the runoff

# %% [markdown]
# Here we will be plotting a combination of all the parameters we are investigating sensitivity for in a scatter plot, and colour-mapping the points by the values of the output metrics.
#
# We have investigated sensitivity above, but this will allow us to investigate relationships of pairs of parameters in a bit more detail with the outputs of the runoff (both the mean of the runoff and the standard deviation of the runoff).

# %%
def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], X[:, i-1], 
                         c=YY_hydro[:, j], cmap='coolwarm', edgecolors='grey')
        
        plt.ylabel(X_labels[i-1])    
        plt.xlabel(X_labels[i])      

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Mean Runoff (Mt)')
    plt.show()

interact(scatter_function, metric=Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %% [markdown]
# This shows the relationship between parameters in relation to the runoff output metrics, this is shown through plotting two parameter values against eachother in a scatter plot and colour-coded by the output metrics. We start by investigating by colour-mapping by magnitude of the Mean Runoff.
# - We can see for each combination of parameters there appears to be a trend, in that the higher and lower mean runoff values tend to be cluster. However, for the temp_bias and prcp_fac there is a very strong and clear correlation, where the runoff has a very clear colour-gradient. This shows that the relationship between these two factors most strongly affects the mean runoff magnitude. The other two plots show that the prcp_fac dominates the effect by the melt_f, and similarly, showing the temp_bias dominates the effect by the melt_f.
#
# Next, when colour-mapping by the standard deviation of the runoff.
# - We can see that for the melt_f vs the temp_bias there is a very strong relationship between them and the effect of the standard deviation of the runoff. Here both melt_f and the temp_bias appear to affect this output metric. Looking at the relationship between the melt_f and the prcp_f, there is a weak correlation, however it can be seen that the melt_f slightly dominates the effect on the standard deviation of the runoff. Finally, when looking at the relationship between the temp_bias and the prcp_fac, the temperature bias strongly dominates this relationship.

# %% [markdown]
# ## PAWN Sensitivity Analysis
#
# Above, for the Global Sensitivity Analysis we have used only RSA with bootstapping as our sensitivity analysis technique.
#
# As we have discussed, RSA requires a target value to differentiate between "behavioural" and "non-behaviourable", which will reflect the sensitivities of our parameters. For runoff, as previously stated, we do not have an obvious metric to compare our data to. So we will investigate the use of another method in which we don't need this target value.
#
# We will now move onto the PAWN technique to try another method of Sensitivity Analysis in the SAFE Toolbox that does not require a target value.
