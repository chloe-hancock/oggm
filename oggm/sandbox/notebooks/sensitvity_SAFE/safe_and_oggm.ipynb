# %% [markdown]
# # Investigating parameters effects on Sensitivity of the OGGM Mass Balance and Runoff Models

# %% [markdown]
# In this notebook we will explore the sensitivity of OGGM's mass-balance and runoff models using SAFE. We will focus on the three parameters: melt factor, precipitation factor and temperature bias.
#
# We will start by applying one-at-a-time sensitivity analysis to get a feel for how much each parameter affects the model and output. We will then consider the uncertainty of these sensitivities and work to quantify them.

# %% [markdown]
# ## Sensitivity Analysis with the OGGM Mass Balance Model

# %% [markdown]
# We will apply sensitivity analysis in the following order to investigate our model behaviour:
#
# 1. **One-at-a-time**: We will apply one-at-a-time analysis , in which we change one parameter at a time and see how the mass balance changes in accordance. To show this, we will plot an interactive mass balance time series with toggles, where the parameter values can be changed within their default boundaries.
# 2. **Global sensitivity analysis**: Here we will use AAT sampling to randomly sample a combination of the 3 parameters and investigate the sensitivity in the following ways
#     a. Qualitative - scatter plots
#     b. Quantitative - RSA and bootstrapping
#
# This will be applied first to the mass balance model in the OGGM, and then to the runoff model in the OGGM.

# %% [markdown]
# First we install the packages we require from both OGGM and SAFE.

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import scipy.stats as st

import oggm
from oggm import cfg, utils, workflow
from oggm.core import massbalance
from oggm.utils._funcs import rmsd
from oggm import tasks

# Install python package for interactive visualisation and import required functions:
# %pip install -q ipywidgets
from ipywidgets import interact, fixed

# Install SAFE package and import required functions
# %pip install SAFEpython

import xarray as xr
import safepython.PAWN as PAWN # Module to calculate PAWN sensitivity indices
import safepython.RSA_thres as RSA_tr # Module that implements RSA
from safepython.model_execution import model_execution # Module to execute the model
from safepython.sampling import AAT_sampling # Functions to perform the input sampling
from safepython.util import aggregate_boot # Functions to perform bootstrapping
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: SAFEpython in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: matplotlib>=2.2.3 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (3.10.6)
# Requirement already satisfied: numpy>=1.19.2 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (1.26.4)
# Requirement already satisfied: scipy>=1.3.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (25.0)
# Requirement already satisfied: pillow>=8 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->SAFEpython) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now prepare to load the glacier dierectories from the OGGM.

# %%
cfg.initialize(logging_level='WARNING')
cfg.PATHS['working_dir'] = utils.gettempdir(dirname='OGGM-calib-ro', reset=True)
cfg.PARAMS['border'] = 10
cfg.PARAMS['store_model_geometry'] = True
oggm.cfg.PARAMS['min_ice_thick_for_length'] = 1  # a glacier is when ice thicker than 1m
# Out:
# 2026-01-16 11:21:36: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2026-01-16 11:21:36: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2026-01-16 11:21:36: oggm.cfg: Multiprocessing: using all available processors (N=22)
# 2026-01-16 11:21:37: oggm.cfg: PARAMS['border'] changed from `80` to `10`.
# 2026-01-16 11:21:37: oggm.cfg: PARAMS['store_model_geometry'] changed from `False` to `True`.
# 2026-01-16 11:21:37: oggm.cfg: PARAMS['min_ice_thick_for_length'] changed from `0.0` to `1`.

# %% [markdown]
# We start from a well known glacier in the Austrian Alps, Hintereisferner. But you can choose any other glacier, e.g. from [this list](https://github.com/OGGM/oggm-sample-data/blob/master/wgms/rgi_wgms_links_20220112.csv)

# %%
# Hintereisferner
rgi_id = 'RGI60-11.00897'

# We pick the elevation-bands glaciers because they run a bit faster - but they create more step changes in the area outputs
base_url = 'https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/L3-L5_files/2023.3/elev_bands/W5E5_spinup'
gdir_hef = workflow.init_glacier_directories([rgi_id], from_prepro_level=4, prepro_border=160, prepro_base_url=base_url)[0]
# Out:
# 2026-01-16 11:21:41: oggm.workflow: init_glacier_directories from prepro level 4 on 1 glaciers.
# 2026-01-16 11:21:41: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers

# %%
# Get the observed mass balance and set up dataframe
mbdf = gdir_hef.get_ref_mb_data().loc[2000:2019] # WGMS data for HEF
mbdf['in_situ_mb'] = gdir_hef.get_ref_mb_data().loc[2000:2019]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

# %% [markdown]
# # 1 - One-at-a-time Sensitivity Analysis

# %% [markdown]
# We have loaded all required packages, so now we need to create a runner for the OGGM. To do this, we will set the 3 mass balance parameters to some tentative values, run the model and plot the resulting runoff timeseries. We can then change the parameter values one-at-a-time and look at how this changes the model predictions.
#
# Since we have WGMS observed data here, we will use some fit-to-data metrics to compare the difference in mean, standard deviation and RMSD between the simulated and observed mass balance values.

# %%
def oggm_sim(sample_row, gdir, run_with_hydro=False, years=range(2000,2020)): # set years here for example
    '''
    Reads in the parameters (melt_f, prcp_fac and temp_bias) set in the inputs, and runs the OGGM processes to 
    produce either a time series for the annual specific mass balance, or for the annual runoff.

    Parameters:
    -------------
    sample_row: Tuple
        The parameters we are feeding in (likely from our randomly generated samples). This is a tuple of
        (melt_f, prcp_fac, temp_bias).
    gdir: GlacierDirectory
        The glacier directory.
    run_with_hydro=False: bool
        A flag to indicate if the user wishes to produce a regular mass balance timeseries, or requires to execute the
        OGGM task, run_with_hydro, which produces a timeseries of the runoff.
    years: range(int,int)
        The years we wish to produce a timeseries for.

    Returns:
    -------------
    np.ndarray
        Specific mass balance (units: mm w.e. yr-1).
        OR Runoff (units: Mt w.e. yr-1).

    '''

    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    
    # Set the parameter values
    melt_f, prcp_fac, temp_bias = sample_row
    cfg.PARAMS['melt_f'] = float(melt_f)
    cfg.PARAMS['prcp_fac'] = float(prcp_fac)
    cfg.PARAMS['temp_bias'] = float(temp_bias)

    if run_with_hydro == False:
        # Running the model with the given parameters (without calibration which would alter them again)
        mbmod = massbalance.MonthlyTIModel(gdir, melt_f=melt_f, prcp_fac=prcp_fac, temp_bias=temp_bias)
        fls = gdir.read_pickle('inversion_flowlines') # Read flowlines
        mbdf['mod_mb'] = mbmod.get_specific_mb(fls=fls, year=mbdf.index) # Compute modelled mass balance  

        return np.array(mbdf['mod_mb'])

    else: # If the run_with_hydro flag is set to true, generate the hydrological data and calculate the runoff
        gdir.settings['error_when_glacier_reaches_boundaries'] = False # TODO- When more realistic, I assume we will not need this?
        
        # Setting the parameters in the glacier directory settings, run_with_hydro is a higher level function that reads them from there
        gdir.settings['melt_f'] = float(melt_f) 
        gdir.settings['prcp_fac'] = float(prcp_fac)
        gdir.settings['temp_bias'] = float(temp_bias)
    
        # file identifier where the model output is saved
        # Create unique file identifier based on parameters
        file_id = f'_hydro_mf{melt_f:.2f}_pf{prcp_fac:.2f}_tb{temp_bias:.2f}'
    
        # Delete old file if it exists to force recomputation
        old_file = gdir.get_filepath('model_diagnostics', filesuffix=file_id)
        if os.path.exists(old_file):
            os.remove(old_file)
    
        # TODO: Check relationship between run_With_hydro and mass balance
        # We are using the task run_with_hydro to store hydrological outputs along with the usual glaciological outputs
        tasks.run_with_hydro(gdir,  # Run on the selected glacier
                         run_task=tasks.run_from_climate_data,  # which climate scenario? See following notebook for other examples
                         ys=years[0],  # Period which we will average and constantly repeat
                         init_model_filesuffix='_spinup_historical',  # use the previous run as initial state
                         init_model_yr=years[0],  # Start from spinup year 2000
                         store_monthly_hydro=True,  # Monthly ouptuts provide additional information
                         output_filesuffix=file_id);  # an identifier for the output file, to read it later
    
        with xr.open_dataset(gdir.get_filepath('model_diagnostics', filesuffix=file_id)) as ds:
            # The last step of hydrological output is NaN (we can't compute it for this year)
            ds = ds.isel(time=slice(0, -1)).load()
    
        sel_vars = [v for v in ds.variables if 'month_2d' not in ds[v].dims]
        df_annual = ds[sel_vars].to_dataframe()
    
        # These summed variabels give the total runoff from the glacier
        runoff_vars = ['melt_off_glacier', 'melt_on_glacier','liq_prcp_off_glacier', 'liq_prcp_on_glacier']
    
        # Convert them to megatonnes (instead of kg)
        df_runoff = df_annual[runoff_vars] * 1e-9
    
        runoff = np.array(df_runoff.sum(axis=1))
    
        return runoff

# %%
def output_metric_calculator(sim, gdir, years=range(2000,2020)):
    '''
    Calculates the fit-to-data metrics from the Mass Balance data, on which we can run the sensitivity analysis.
    This is only used for the mass balance, where we can access a sufficient amount of data to calculate these metrics.

    Parameters:
    ------------

    sim: np.array
        The mass balance time series generated from the oggm_sim method, when the output is the mass balance time series.

    gdir: GlacierDirectory
        The glacier directory.

    years: range(int,int)
        The years we are using data from.

    Return:
    ------------

    YY: np.array
        An array containing the values of:
            - The difference in mass balance between the observed and simulated means.
            - The difference in mass balance between the observed and simulated standard deviations.
            - The RMSD between the simulated mass balance and the observed mass balance annual values.
    '''
    
    # Get the observed mass balance and set up dataframe
    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    mbdf['in_situ_mb'] = gdir.get_ref_mb_data().loc[years]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

    # Calculates the goodness-of-fit metrics for all model simulations compared to the in-situ mass balance
    YY = np.zeros((sim.shape[0], 3))

    for i in range(sim.shape[0]):
        # Calculate the goodness-of-fit metrics from the simulated mass balance and the in-situ mass balance
        YY[i, 0] = np.array(sim[i].mean() - mbdf['in_situ_mb'].mean()) # Calculate mean difference
        YY[i, 1] = np.array(sim[i].std() - mbdf['in_situ_mb'].std()) # Calculate standard deviation difference
        YY[i, 2] = np.array(rmsd(sim[i], mbdf['in_situ_mb'])) # Calculate RMSD

    return YY

# %% [markdown]
# We will now plot our results, the parameter values can be changed one-at-a-time via a toggle on the graph below.

# %%
# Define interactive visualisation function to set the parameters to some tentative values, 
# run the model and plot the resulting runoff time series
def oat_function(gdir, years, melt_f = 5.0, prcp_fac = 3.4, temp_bias = 0.0):
    '''  
    Calls the oggm_sim function and plots each mass balance time series with an interactive plot.

    Parameters:
    ------------
    gdir: GlacierDirectory
        The glacier directory.
    years: range
        The years we are investigating.
    melt_f = 5.0: float
        The value of the melt factor you want to use, here the unit
        is kg m-2 day-1 K-1. Defaults to the default value.
    prcp_fac = 3.4: float
        The value of the precipitation factor. Defaults to the
        default value.
    temp_bias : float
        The value of the temperature bias. Defaults to the
        default value.


    Returns:
    ------------
    An interactive plot displaying the mass balance time series of the glacier with the given parameters.
    '''
    # Create parameter array
    param = np.array([melt_f, prcp_fac, temp_bias])
    
    # Get the observed mass balance and set up dataframe
    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    mbdf['in_situ_mb'] = gdir.get_ref_mb_data().loc[years]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

    # Run the model with the given parameters, here we are interested in the modelled mass balance time series
    mb = oggm_sim(param, gdir)

    # Plot the results
    plt.figure(figsize=[15,3])
    plt.plot(mbdf['in_situ_mb'].index, mb, label='sim', color='k')
    mbdf['in_situ_mb'] = gdir_hef.get_ref_mb_data().loc[years]['ANNUAL_BALANCE']
    plt.plot(mbdf['in_situ_mb'], color=[0.7,0.7,0.7], label='obs')
    plt.ylabel('Specific mass balance (mm w.e.)')
    plt.xlabel('Year')
    plt.legend()
    plt.show();

# Create interactive plot, the toggles will change the parameter values 
interact(oat_function,
         gdir = fixed(gdir_hef),
         years = fixed(range(2000,2020)),
         melt_f = (1.5, 17.0, 0.1),
         prcp_fac = (0.1, 10.0, 0.1),
         temp_bias = (-15.0, 15.0, 0.1));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 25
#      22     plt.show();
#      24 # Create interactive plot, the toggles will change the parameter values
# ---> 25 interact(oat_function,
#      26          gdir = fixed(gdir_hef),
#      27          years = fixed(range(2000,2020)),
#      28          melt_f = (1.5, 17.0, 0.1),
#      29          prcp_fac = (0.1, 10.0, 0.1),
#      30          temp_bias = (-15.0, 15.0, 0.1));
#
# NameError: name 'interact' is not defined

# %% [markdown]
# The above graph shows the effects that moving each of the parameters has to the mass balance time series.

# %% [markdown]
# # GSA - Global Sensitvity Analysis

# %% [markdown]
# We will now explore the sensitivity with a global sensitivity analysis. We will create a runner for the OGGM that calculates the mass balance values based off of the parameters sampled. We will be using AAT Sampling from SAFE to perform global sampling.
#
# This method will be creating Monte Carlo Simulations, we will plot the mass balance time series resulting from the Monte Carlo simulations and analyse the results.

# %% [markdown]
# ### Running Monte Carlo Simulations

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)

distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 0.1, -15.0]) # Minimum values for each parameter
x_max = np.array([17.0, 10.0, 15.0]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
    
samp_strat = 'lhs' 

N = 2000 # Number of samples
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

sim = model_execution(oggm_sim, X, gdir_hef, ExtraArgOut=True) # Execute the model for all samples
# Out:
# 2026-01-16 11:25:04: oggm.cfg: PARAMS['melt_f'] changed from
.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['melt_f'] changed from `10.492890566115955` to `6.184862735083633`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['prcp_fac'] changed from `9.227380039697193` to `4.0158644350670505`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['temp_bias'] changed from `3.6298005267765774` to `-3.4130369983680637`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['melt_f'] changed from `6.184862735083633` to `12.548663859693264`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['prcp_fac'] changed from `4.0158644350670505` to `0.2142181696789282`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['temp_bias'] changed from `-3.4130369983680637` to `-6.410695634145327`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['melt_f'] changed from `12.548663859693264` to `3.3538357634189824`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['prcp_fac'] changed from `0.2142181696789282` to `7.175649976160528`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['temp_bias'] changed from `-6.410695634145327` to `-3.2115095081400664`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['melt_f'] changed from `3.3538357634189824` to `3.584006815044508`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['prcp_fac'] changed from `7.175649976160528` to `2.3388858903451895`.
# 2026-01-16 11:26:01: oggm.cfg: PARAMS['temp_bias'] changed from `-3.2115095081400664` to `-7.967833094502512`.

# %%
YY = output_metric_calculator(sim, gdir_hef) # Calculate the output metrics for all simulations

# %% [markdown]
# Plotting the Monte Carlo simulation results and comparison with the observed data.

# %%
# Plot Monte Carlo (MC) simulations results and compare with data:
plt.figure(figsize=[15,5])
plt.plot(mbdf['in_situ_mb'].index.values, np.transpose(sim), 'k', linewidth = 0.5)
plt.plot(mbdf['in_situ_mb'], color=[0.7,0.7,0.7], linewidth=2)
plt.ylabel('Mass Balance'); plt.xlabel('Years')
plt.legend(['sim', 'obs'])
plt.title("Number of parameter samples: N = %d" % N, loc='right')
plt.show()

# %% [markdown]
# We can see from the samples that the mass balance is greatly affected by altering the parameters between their given ranges. The lower mass balances seem to be more sparse, with a more significant clustering towards the higher mass-balances. The observed mass-balance is closer towards the higher mass-balance end of the spectrum, towards 0.

# %% [markdown]
# ### Scatter plot of the fit-to-data metrics

# %% [markdown]
# We will now plot a scatter plot of the fit-to-data metrics, this will show us the relationship between the metrics created from our Monte Carlo simulations.

# %%
plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(YY[:,0], YY[:,1], s=5), plt.title('Mean difference vs Std difference'), plt.xlabel('Mean difference (mm w.e.)'), plt.ylabel('Std difference (mm w.e.)'),
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.subplot(1,3,2), plt.scatter(YY[:,0], YY[:,2], s=5), plt.title('Mean difference vs RMSD'), plt.xlabel('Mean difference (mm w.e.)'), plt.ylabel('RMSD (mm w.e.)')
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.subplot(1,3,3), plt.scatter(YY[:,1], YY[:,2], s=5), plt.title('Std difference vs RMSD'), plt.xlabel('Std difference (mm w.e.)'), plt.ylabel('RMSD (mm w.e.)')
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.tight_layout()
plt.show()

# The red lines show the target of having zero differences in the mean, standard deviation and RMSD.
# TODO: Would absolute differences be better than the raw ones?

# %% [markdown]
# The red lines show the target values of our differences, ideally we would want our differences to be 0 and to match the observations as closely as possible.
#
# It can be seen here that all of our fit-to-data metrics are correlated.

# %% [markdown]
# ## Scatter plot for the parameters against the fit-to-data metrics

# %% [markdown]
# Now we can plot the scatter plots for each parameter against each metric, this will help visualise the sensitivities for the mass balance.

# %%
YY_Labels = ['Mean Difference', 'Std Difference', 'RMSD']

def scatter_function(metric='Mean Difference'):
    if metric == 'Mean Difference':
        j = 0
    elif metric == 'Std Difference':
        j = 1  
    elif metric == 'RMSD':
        j = 2
    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(YY_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = YY_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Difference', 'Std Difference', 'RMSD'), va…

# %% [markdown]
# ### Distribution of the model outputs

# %% [markdown]
# Now looking at the distribution of the model outputs, here this is the goodness-of-fit parameters.

# %%
Y_Labels = ['Mean difference (mm w.e.)', 'Std difference (mm w.e.)', 'RMSD (mm w.e.)', 'Mean & Std difference jointly']

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,0], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,1], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[1])

plt.subplot(1,3,3), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,2], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[2])

plt.tight_layout()

# %% [markdown]
# Looking at our distributions of the output samples, the distributions are as follows:
# 1. Mean difference: Skewed distribition with a long tail (negative skew)
# 2. Std difference: Normal distribution
# 3. RMSD: Skewed distribution with a long tail (positive skew)
#
# TODO: Does this mean we can use RSA vs PAWN?

# %% [markdown]
# # Calculating the Sensitivity Indices
#
# Now we use the input-output samples generated in the previous step to calculate sensitivity indices using **Regional Sensitivity Analysis**. Calculating 3 sets of indices, each measuring the relative importance of the 3 input parameters.

# %%
Nboot = 50 # Number of resamples used for bootstrapping

for i in range(3):
    if i==0:
        Y=YY[:,0]
        target=0
    if i==1:
        Y=YY[:,1]
        target=0
    if i==2:
        Y = YY[:,2]
        target = 500 # RMSD cannot be zero here? Minimum working number is around 550, minimum observed value is around 400.

    # plot:
    plt.figure(figsize=[7,2])
    mvd, _, _, idx = RSA_tr.RSA_indices_thres(X, Y, target, Nboot=Nboot)
    mvd_m, mvd_lb, mvd_ub = aggregate_boot(mvd) # shape (M,)
    yerr=np.c_[mvd_m-mvd_lb,mvd_ub-mvd_m].T
    plt.bar(range(len(mvd_m)), mvd_m, color='grey',yerr=yerr)
    plt.title(Y_Labels[i], loc='center'), plt.xticks(range(len(mvd_m)), X_labels), plt.ylabel('Sensitivity')
    plt.show()

# %% [markdown]
# Now lets discuss the outcome of our sensitivity analysis here with the three fit-to-data metrics:
#
# 1. For the first metric: The difference between the observed and the simulated mass balance mean values. The temperature bias is significantly the most impactful here. This would align with what we might expect, the temperature bias increases or decreases the temperature, which will have an impact on the amount of glacier mass we are either losing or retaining due to melting and whether or not the precipitation is liquid or solid. We are also currently using the OGGM's default range which is between -15 and +15 degrees celcius, this is a very large range and therefore this makes sense this is the most impactful for the differences between the mass balance means between the observed and simulated. The temperature bias will create a uniform shift in temperatures which will then shift the mean values.
#
# 2. For the second metric: The difference between the observed and simulated mass balance standard deviation values. The precipitation factor is the most significant in our study. The precipitation factor controls the amount of precipitation for the glacier, therefore controlling accumulation which strongly affects the variability of the mass balance.
#
# 3. Finally, for the third metric: The RMSD, this penalises larger differences and is dominated by larger deviations. The melt factor is the factor that controls how much ablation occurs, this melt will be amplified in high-melt periods and much lower at lower melt periods. Therefore this will affect the RMSD more, due to the large deviations the melt factor can cause throughout difference period of the year.

# %% [markdown]
# ## Extra Investigation: Relationship with temp_bias and other parameters to the fit-to-data outputs

# %% [markdown]
# Now checking, if the relationship with other parameters has been affected by the temp_bias, this is rather dominant in the differences of the mean. We can plot a colour map to check.

# %%
temp_bias_index = 2  # Index of temp_bias in X

YY_Labels = ['Mean Difference', 'Std Difference', 'RMSD']

def scatter_function(metric='Mean Difference'):
    if metric == 'Mean Difference':
        j = 0
    elif metric == 'Std Difference':
        j = 1  
    elif metric == 'RMSD':
        j = 2

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], YY[:, j], c=X[:, temp_bias_index], cmap='coolwarm', edgecolors='grey')
        
        if i == 0:
            plt.ylabel(YY_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Temp Bias (°C)')
    plt.show()

interact(scatter_function, metric=YY_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Difference', 'Std Difference', 'RMSD'), va…

# %% [markdown]
# # Hydrological Response Metrics - Performance Metrics

# %% [markdown]
# Now looking at the hydrological response metrics we have avaliable in the OGGM, mean of runoff and mean of volume.

# %% [markdown]
# ## One-at-a-time Sensitivity Analysis

# %%
# Define interactive visualisation function to set the parameters to some tentative values, 
# run the model and plot the resulting runoff time series

def oat_hydro_function(gdir, melt_f = 5.0, prcp_fac = 3.4, temp_bias = 0.0):
    # Create parameter array
    param = np.array([melt_f, prcp_fac, temp_bias])
    
    # Run the model with the given parameters, here we are interested in the modelled mass balance time series
    runoff = oggm_sim(param, gdir, True)
    # Plot the results
    plt.figure(figsize=[15,3])
    plt.plot(mbdf.index.values, runoff)
    plt.ylabel('Runoff (Mt)')
    plt.xlabel('Year')
    plt.legend()

# Create interactive plot, the toggles will change the parameter values 
interact(oat_hydro_function,
         gdir = fixed(gdir_hef),
         melt_f = (1.5, 17.0, 0.1),
         prcp_fac = (0.1, 10.0, 0.1),
         temp_bias = (-15.0, 15.0, 0.1));
# Out:
# interactive(children=(FloatSlider(value=5.0, description='melt_f', max=17.0, min=1.5), FloatSlider(value=3.4, …

# %% [markdown]
# # GSA - Global Sensitivity Analysis

# %% [markdown]
# ### Running Monte Carlo Simulations

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)
distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 0.1, -15.0]) # Minimum values for each parameter
x_max = np.array([17.0, 10.0, 15.0]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
samp_strat = 'lhs' 
N = 1000 # Was 2000, TODO- change back to 2000? 1000 takes around 11 mins to run
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

# %%
runoff  = model_execution(oggm_sim, X, gdir_hef, True) # Execute the model for all samples - note: takes around 5-10 mins with N=1000
# Out:
# 2026-01-16 14:10:56: oggm.cfg: PARAMS['melt_f'] changed from `3.584006815044508` to `16.558097152639274`.
# 2026-01-16 14:10:56: oggm.cfg: PARAMS['prcp_fac'] changed from `2.3388858903451895` to `5.258182011735838`.
# 2026-01-16 14:10:56: oggm.cfg: PARAMS['temp_bias'] changed from `-7.967833094502512` to `6.3477760277481075`.
# 2026-01-16 14:10:58: oggm.cfg: PARAMS['melt_f'] changed from `16.558097152639274` to `13.753202242911836`.
# 2026-01-16 14:10:58: oggm.cfg: PARAMS['prcp_fac'] changed from `5.258182011735838` to `4.3564108801453765`.
# 2026-01-16 14:10:58: oggm.cfg: PARAMS['temp_bias'] changed from `6.3477760277481075` to `9.977929714123832`.
# 2026-01-16 14:10:58: oggm.cfg: PARAMS['melt_f'] changed from `13.753202242911836` to `13.763843851368634`.
# 2026-01-16 14:10:58: oggm.cfg: PARAMS['prcp_fac'] changed from `4.3564108801453765` to `1.07402351833011`.
# 2026-01-16 14:10:58: oggm.cfg: PARAMS['temp_bias'] changed from `9.977929714123832` to `10.68654459660161`.
# 2026-01-16 14:10:59: oggm.cfg: PARAMS['melt_f'] changed from `13.763843851368634` to `12.223740237382685`.
# 2026-01-16 14:10:59: oggm.cfg: PARAMS['prcp_fac'] changed from `1.07402351833011` to `3.875104759456427`.
# 2026-01-16 14:10:59: oggm.cfg: PARAMS['temp_bias'] changed from `10.68654459660161` to `8.778199470340219`.
# 2026-01-16 14:10:59: oggm.cfg: PARAMS['melt_f'] changed from `12.223740237382685` to `15.779739598639168`.
# 2026-01-16 14:10:59: oggm.cfg: PARAMS['prcp_fac'] changed from `3.875104759456427` to `8.465372439311057`.
# 2026-01-16 14:10:59: oggm.cfg: PARAMS['temp_bias'] changed from `8.778199470340219` to `-12.919265616804092`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['melt_f'] changed from `15.779739598639168` to `11.021243994756228`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['prcp_fac'] changed from `8.465372439311057` to `5.08504210594349`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['temp_bias'] changed from `-12.919265616804092` to `6.997196923680505`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['melt_f'] changed from `11.021243994756228` to `7.772084285080668`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['prcp_fac'] changed from `5.08504210594349` to `5.050111117465703`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['temp_bias'] changed from `6.997196923680505` to `-10.625613872601036`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['melt_f'] changed from `7.772084285080668` to `14.779461884057838`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['prcp_fac'] changed from `5.050111117465703` to `3.6325937856726025`.
# 2026-01-16 14:11:00: oggm.cfg: PARAMS['temp_bias'] changed from `-10.625613872601036` to `-1.8432356638287608`.
# 2026-01-16 14:11:01: oggm.cfg: PARAMS['melt_f'] changed from `14.779461884057838` to `15.67890534795921`.
# 2026-01-16 14:11:01: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6325937856726025` to `8.281997032786471`.
# 2026-01-16 14:11:01: oggm.cfg: PARAMS['temp_bias'] changed from `-1.8432356638287608` to `-4.615962394161524`.
# 2026-01-16 14:11:01: oggm.cfg: PARAMS['melt_f'] changed from `15.67890534795921` to `9.37617136845648`.
# 2026-01-16 14:11:01: oggm.cfg: PARAMS['prcp_fac'] changed from `8.281997032786471` to `9.503724887277825`.
# 2026-01-16 14:11:01: oggm.cfg: PARAMS['temp_bias'] changed from `-4.615962394161524` to `2.935245914687723`.
# 2026-01-16 14:11:02: oggm.cfg: PARAMS['melt_f'] changed from `9.37617136845648` to `7.183928885093801`.
# 2026-01-16 14:11:02: oggm.cfg: PARAMS['prcp_fac'] changed from `9.503724887277825` to `0.6196572806312384`.
# 2026-01-16 14:11:02: oggm.cfg: PARAMS['temp_bias'] changed from `2.935245914687723` to `5.710996829269391`.
# 2026-01-16 14:11:02: oggm.cfg: PARAMS['melt_f'] changed from `7.183928885093801` to `15.770737742124732`.
# 2026-01-16 14:11:02: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6196572806312384` to `3.6142436779728335`.
# 2026-01-16 14:11:02: oggm.cfg: PARAMS['temp_bias'] changed from `5.710996829269391` to `-7.936654885447115`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['melt_f'] changed from `15.770737742124732` to `16.293415664932507`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6142436779728335` to `9.11955879043921`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['temp_bias'] changed from `-7.936654885447115` to `-2.7692144671714587`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['melt_f'] changed from `16.293415664932507` to `7.536338008813336`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['prcp_fac'] changed from `9.11955879043921` to `9.398059022174175`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['temp_bias'] changed from `-2.7692144671714587` to `5.936075089729933`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['melt_f'] changed from `7.536338008813336` to `4.840027554019468`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['prcp_fac'] changed from `9.398059022174175` to `6.331667109933778`.
# 2026-01-16 14:11:03: oggm.cfg: PARAMS['temp_bias'] changed from `5.936075089729933` to `-11.226220670993367`.
# 2026-01-16 14:11:04: oggm.cfg: PARAMS['melt_f'] changed from `4.840027554019468` to `11.30320530897897`.
# 2026-01-16 14:11:04: oggm.cfg: PARAMS['prcp_fac'] changed from `6.331667109933778` to `6.761849162876087`.
# 2026-01-16 14:11:04: oggm.cfg: PARAMS['temp_bias'] changed from `-11.226220670993367` to `12.210953570284168`.
# 2026-01-16 14:11:04: oggm.cfg: PARAMS['melt_f'] changed from `11.30320530897897` to `16.23358308083038`.
# 2026-01-16 14:11:04: oggm.cfg: PARAMS['prcp_fac'] changed from `6.761849162876087` to `6.61588001407341`.
# 2026-01-16 14:11:04: oggm.cfg: PARAMS['temp_bias'] changed from `12.210953570284168` to `7.530649374240756`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['melt_f'] changed from `16.23358308083038` to `14.401944762750485`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['prcp_fac'] changed from `6.61588001407341` to `4.993597655169001`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['temp_bias'] changed from `7.530649374240756` to `-1.7293663545264408`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['melt_f'] changed from `14.401944762750485` to `5.596951613805911`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['prcp_fac'] changed from `4.993597655169001` to `1.868128671958277`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['temp_bias'] changed from `-1.7293663545264408` to `1.7839966323936558`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['melt_f'] changed from `5.596951613805911` to `9.81413177720881`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['prcp_fac'] changed from `1.868128671958277` to `9.05836871524452`.
# 2026-01-16 14:11:05: oggm.cfg: PARAMS['temp_bias'] changed from `1.7839966323936558` to `-14.5287315240904`.
# 2026-01-16 14:11:06: oggm.cfg: PARAMS['melt_f'] changed from `9.81413177720881` to `10.90966709864708`.
# 2026-01-16 14:11:06: oggm.cfg: PARAMS['prcp_fac'] changed from `9.05836871524452` to `5.426918515827806`.
# 2026-01-16 14:11:06: oggm.cfg: PARAMS['temp_bias'] changed from `-14.5287315240904` to `2.940161863648065`.
# 2026-01-16 14:11:06: oggm.cfg: PARAMS['melt_f'] changed from `10.90966709864708` to `16.669098194440068`.
# 2026-01-16 14:11:06: oggm.cfg: PARAMS['prcp_fac'] changed from `5.426918515827806` to `6.211943548336618`.
# 2026-01-16 14:11:06: oggm.cfg: PARAMS['temp_bias'] changed from `2.940161863648065` to `7.570806430871794`.
# 2026-01-16 14:11:07: oggm.cfg: PARAMS['melt_f'] changed from `16.669098194440068` to `5.105947054309622`.
# 2026-01-16 14:11:07: oggm.cfg: PARAMS['prcp_fac'] changed from `6.211943548336618` to `8.371660687706735`.
# 2026-01-16 14:11:07: oggm.cfg: PARAMS['temp_bias'] changed from `7.570806430871794` to `-8.961553030228972`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['melt_f'] changed from `5.105947054309622` to `14.850830460681273`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['prcp_fac'] changed from `8.371660687706735` to `0.9961403193598545`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['temp_bias'] changed from `-8.961553030228972` to `-13.193169942754405`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['melt_f'] changed from `14.850830460681273` to `7.45605215705753`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9961403193598545` to `1.5408036909110736`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['temp_bias'] changed from `-13.193169942754405` to `-3.81130291300631`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['melt_f'] changed from `7.45605215705753` to `8.393256979730856`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['prcp_fac'] changed from `1.5408036909110736` to `1.8253644542325933`.
# 2026-01-16 14:11:08: oggm.cfg: PARAMS['temp_bias'] changed from `-3.81130291300631` to `6.930458345547635`.
# 2026-01-16 14:11:09: oggm.cfg: PARAMS['melt_f'] changed from `8.393256979730856` to `13.924107526126338`.
# 2026-01-16 14:11:09: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8253644542325933` to `8.524623234454893`.
# 2026-01-16 14:11:09: oggm.cfg: PARAMS['temp_bias'] changed from `6.930458345547635` to `-1.3672346568716556`.
# 2026-01-16 14:11:09: oggm.cfg: PARAMS['melt_f'] changed from `13.924107526126338` to `10.848056237173209`.
# 2026-01-16 14:11:09: oggm.cfg: PARAMS['prcp_fac'] changed from `8.524623234454893` to `7.561557323170985`.
# 2026-01-16 14:11:09: oggm.cfg: PARAMS['temp_bias'] changed from `-1.3672346568716556` to `-9.228062773641799`.
# 2026-01-16 14:11:10: oggm.cfg: PARAMS['melt_f'] changed from `10.848056237173209` to `11.065380990906743`.
# 2026-01-16 14:11:10: oggm.cfg: PARAMS['prcp_fac'] changed from `7.561557323170985` to `8.396597187654605`.
# 2026-01-16 14:11:10: oggm.cfg: PARAMS['temp_bias'] changed from `-9.228062773641799` to `-11.21214338044618`.
# 2026-01-16 14:11:10: oggm.cfg: PARAMS['melt_f'] changed from `11.065380990906743` to `12.384614366949366`.
# 2026-01-16 14:11:10: oggm.cfg: PARAMS['prcp_fac'] changed from `8.396597187654605` to `8.656723753651038`.
# 2026-01-16 14:11:10: oggm.cfg: PARAMS['temp_bias'] changed from `-11.21214338044618` to `13.12480825190121`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['melt_f'] changed from `12.384614366949366` to `9.956884733515512`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['prcp_fac'] changed from `8.656723753651038` to `1.76528992791129`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['temp_bias'] changed from `13.12480825190121` to `-9.369325661877792`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['melt_f'] changed from `9.956884733515512` to `2.088898423006164`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['prcp_fac'] changed from `1.76528992791129` to `5.371373752979963`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['temp_bias'] changed from `-9.369325661877792` to `12.777527056059107`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['melt_f'] changed from `2.088898423006164` to `13.832836155096897`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['prcp_fac'] changed from `5.371373752979963` to `1.5107831588460483`.
# 2026-01-16 14:11:11: oggm.cfg: PARAMS['temp_bias'] changed from `12.777527056059107` to `12.52353465670246`.
# 2026-01-16 14:11:12: oggm.cfg: PARAMS['melt_f'] changed from `13.832836155096897` to `16.03240181964358`.
# 2026-01-16 14:11:12: oggm.cfg: PARAMS['prcp_fac'] changed from `1.5107831588460483` to `1.26710052421368`.
# 2026-01-16 14:11:12: oggm.cfg: PARAMS['temp_bias'] changed from `12.52353465670246` to `-13.313989210539578`.
# 2026-01-16 14:11:12: oggm.cfg: PARAMS['melt_f'] changed from `16.03240181964358` to `6.2973589149889735`.
# 2026-01-16 14:11:12: oggm.cfg: PARAMS['prcp_fac'] changed from `1.26710052421368` to `9.770457314492761`.
# 2026-01-16 14:11:12: oggm.cfg: PARAMS['temp_bias'] changed from `-13.313989210539578` to `1.723562119515801`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['melt_f'] changed from `6.2973589149889735` to `11.033569268817187`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['prcp_fac'] changed from `9.770457314492761` to `4.825391825199649`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['temp_bias'] changed from `1.723562119515801` to `-2.6363140401114737`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['melt_f'] changed from `11.033569268817187` to `3.869561094956964`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['prcp_fac'] changed from `4.825391825199649` to `3.351963576725956`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['temp_bias'] changed from `-2.6363140401114737` to `7.062120200420594`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['melt_f'] changed from `3.869561094956964` to `12.226458848937602`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['prcp_fac'] changed from `3.351963576725956` to `7.191180393278051`.
# 2026-01-16 14:11:13: oggm.cfg: PARAMS['temp_bias'] changed from `7.062120200420594` to `7.141643071115489`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['melt_f'] changed from `12.226458848937602` to `12.258253310068168`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['prcp_fac'] changed from `7.191180393278051` to `5.760214366889763`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['temp_bias'] changed from `7.141643071115489` to `-3.012243121863399`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['melt_f'] changed from `12.258253310068168` to `6.272254076583394`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['prcp_fac'] changed from `5.760214366889763` to `1.3866375247777463`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['temp_bias'] changed from `-3.012243121863399` to `14.844806544063104`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['melt_f'] changed from `6.272254076583394` to `3.831899503099087`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3866375247777463` to `5.735521132419408`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['temp_bias'] changed from `14.844806544063104` to `11.846505044245859`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['melt_f'] changed from `3.831899503099087` to `8.659928674244853`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['prcp_fac'] changed from `5.735521132419408` to `6.251258550597276`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['temp_bias'] changed from `11.846505044245859` to `2.6168233441386697`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['melt_f'] changed from `8.659928674244853` to `13.122519547033606`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['prcp_fac'] changed from `6.251258550597276` to `1.1579917722191342`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['temp_bias'] changed from `2.6168233441386697` to `11.46522368902125`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['melt_f'] changed from `13.122519547033606` to `14.003666618565033`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1579917722191342` to `7.82985672299871`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['temp_bias'] changed from `11.46522368902125` to `-3.172985330348947`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['melt_f'] changed from `14.003666618565033` to `6.379563008255291`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['prcp_fac'] changed from `7.82985672299871` to `6.78611734361189`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['temp_bias'] changed from `-3.172985330348947` to `11.256745992107081`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['melt_f'] changed from `6.379563008255291` to `5.845965045670364`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['prcp_fac'] changed from `6.78611734361189` to `8.043354266269306`.
# 2026-01-16 14:11:14: oggm.cfg: PARAMS['temp_bias'] changed from `11.256745992107081` to `-14.975603574954482`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['melt_f'] changed from `5.845965045670364` to `11.345001468172812`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['prcp_fac'] changed from `8.043354266269306` to `5.1449174359901235`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['temp_bias'] changed from `-14.975603574954482` to `11.31754731091895`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['melt_f'] changed from `11.345001468172812` to `16.585211041522854`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['prcp_fac'] changed from `5.1449174359901235` to `7.306549001186635`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['temp_bias'] changed from `11.31754731091895` to `-0.8692823062604873`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['melt_f'] changed from `16.585211041522854` to `12.977153787134785`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['prcp_fac'] changed from `7.306549001186635` to `7.739563496779671`.
# 2026-01-16 14:11:15: oggm.cfg: PARAMS['temp_bias'] changed from `-0.8692823062604873` to `-3.7203559229386336`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['melt_f'] changed from `12.977153787134785` to `7.866654290089818`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['prcp_fac'] changed from `7.739563496779671` to `7.407488344936839`.
# 2026-01-16 14:11:16: oggm.cfg: PARAMS['temp_bias'] changed from `-3.7203559229386336` to `-5.7739617790715485`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['melt_f'] changed from `7.866654290089818` to `12.48628030712181`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['prcp_fac'] changed from `7.407488344936839` to `2.9939496265703256`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['temp_bias'] changed from `-5.7739617790715485` to `-7.0555084231662635`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['melt_f'] changed from `12.48628030712181` to `8.779363685992852`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.9939496265703256` to `6.374315977175576`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['temp_bias'] changed from `-7.0555084231662635` to `-8.306508314020547`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['melt_f'] changed from `8.779363685992852` to `16.984453657387142`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['prcp_fac'] changed from `6.374315977175576` to `7.146172031576973`.
# 2026-01-16 14:11:17: oggm.cfg: PARAMS['temp_bias'] changed from `-8.306508314020547` to `-14.480236412225263`.
# 2026-01-16 14:11:18: oggm.cfg: PARAMS['melt_f'] changed from `16.984453657387142` to `5.280857826666691`.
# 2026-01-16 14:11:18: oggm.cfg: PARAMS['prcp_fac'] changed from `7.146172031576973` to `3.2204058641564925`.
# 2026-01-16 14:11:18: oggm.cfg: PARAMS['temp_bias'] changed from `-14.480236412225263` to `4.249661933223962`.
# 2026-01-16 14:11:18: oggm.cfg: PARAMS['melt_f'] changed from `5.280857826666691` to `14.790504583497022`.
# 2026-01-16 14:11:18: oggm.cfg: PARAMS['prcp_fac'] changed from `3.2204058641564925` to `0.41860841981612495`.
# 2026-01-16 14:11:18: oggm.cfg: PARAMS['temp_bias'] changed from `4.249661933223962` to `5.899944310874986`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['melt_f'] changed from `14.790504583497022` to `16.71697321520256`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['prcp_fac'] changed from `0.41860841981612495` to `1.2925900153114431`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['temp_bias'] changed from `5.899944310874986` to `-3.1159279681130023`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['melt_f'] changed from `16.71697321520256` to `6.80130071860697`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2925900153114431` to `0.8309403215138322`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['temp_bias'] changed from `-3.1159279681130023` to `12.95165287655771`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['melt_f'] changed from `6.80130071860697` to `10.443397789323768`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8309403215138322` to `7.871714335873106`.
# 2026-01-16 14:11:19: oggm.cfg: PARAMS['temp_bias'] changed from `12.95165287655771` to `-13.127492421277397`.
# 2026-01-16 14:11:20: oggm.cfg: PARAMS['melt_f'] changed from `10.443397789323768` to `1.6740805158845318`.
# 2026-01-16 14:11:20: oggm.cfg: PARAMS['prcp_fac'] changed from `7.871714335873106` to `8.628566473723671`.
# 2026-01-16 14:11:20: oggm.cfg: PARAMS['temp_bias'] changed from `-13.127492421277397` to `8.026864837241835`.
# 2026-01-16 14:11:20: oggm.cfg: PARAMS['melt_f'] changed from `1.6740805158845318` to `16.480509522281096`.
# 2026-01-16 14:11:20: oggm.cfg: PARAMS['prcp_fac'] changed from `8.628566473723671` to `9.904471514526545`.
# 2026-01-16 14:11:20: oggm.cfg: PARAMS['temp_bias'] changed from `8.026864837241835` to `-11.067916116685014`.
# 2026-01-16 14:11:21: oggm.cfg: PARAMS['melt_f'] changed from `16.480509522281096` to `3.893579141590158`.
# 2026-01-16 14:11:21: oggm.cfg: PARAMS['prcp_fac'] changed from `9.904471514526545` to `7.779697750580335`.
# 2026-01-16 14:11:21: oggm.cfg: PARAMS['temp_bias'] changed from `-11.067916116685014` to `14.680702451714602`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['melt_f'] changed from `3.893579141590158` to `4.910226104824881`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['prcp_fac'] changed from `7.779697750580335` to `9.792783048692167`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['temp_bias'] changed from `14.680702451714602` to `12.027743349430661`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['melt_f'] changed from `4.910226104824881` to `11.368865443535105`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['prcp_fac'] changed from `9.792783048692167` to `2.1677424703083186`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['temp_bias'] changed from `12.027743349430661` to `13.395819291732753`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['melt_f'] changed from `11.368865443535105` to `8.006335201239647`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['prcp_fac'] changed from `2.1677424703083186` to `4.943010146539629`.
# 2026-01-16 14:11:22: oggm.cfg: PARAMS['temp_bias'] changed from `13.395819291732753` to `-10.390092434283986`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['melt_f'] changed from `8.006335201239647` to `11.674540242417732`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['prcp_fac'] changed from `4.943010146539629` to `6.877508287810161`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['temp_bias'] changed from `-10.390092434283986` to `-0.5612847127726361`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['melt_f'] changed from `11.674540242417732` to `4.723906873591556`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['prcp_fac'] changed from `6.877508287810161` to `0.39561976666892806`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['temp_bias'] changed from `-0.5612847127726361` to `6.300043195742717`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['melt_f'] changed from `4.723906873591556` to `11.591123384608707`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['prcp_fac'] changed from `0.39561976666892806` to `9.410994024518164`.
# 2026-01-16 14:11:23: oggm.cfg: PARAMS['temp_bias'] changed from `6.300043195742717` to `-14.58513374234548`.
# 2026-01-16 14:11:24: oggm.cfg: PARAMS['melt_f'] changed from `11.591123384608707` to `15.411460127187583`.
# 2026-01-16 14:11:24: oggm.cfg: PARAMS['prcp_fac'] changed from `9.410994024518164` to `7.35270412984966`.
# 2026-01-16 14:11:24: oggm.cfg: PARAMS['temp_bias'] changed from `-14.58513374234548` to `-12.75854708306644`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['melt_f'] changed from `15.411460127187583` to `1.8216487605014022`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['prcp_fac'] changed from `7.35270412984966` to `6.702433099125538`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['temp_bias'] changed from `-12.75854708306644` to `7.880876947288723`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['melt_f'] changed from `1.8216487605014022` to `8.909754725324923`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['prcp_fac'] changed from `6.702433099125538` to `3.3792714854652885`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['temp_bias'] changed from `7.880876947288723` to `3.5284156263788375`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['melt_f'] changed from `8.909754725324923` to `11.525852190076074`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['prcp_fac'] changed from `3.3792714854652885` to `3.06672089069281`.
# 2026-01-16 14:11:25: oggm.cfg: PARAMS['temp_bias'] changed from `3.5284156263788375` to `-6.212652901796998`.
# 2026-01-16 14:11:26: oggm.cfg: PARAMS['melt_f'] changed from `11.525852190076074` to `6.738071409576496`.
# 2026-01-16 14:11:26: oggm.cfg: PARAMS['prcp_fac'] changed from `3.06672089069281` to `6.627053076249121`.
# 2026-01-16 14:11:26: oggm.cfg: PARAMS['temp_bias'] changed from `-6.212652901796998` to `-13.424556771688179`.
# 2026-01-16 14:11:26: oggm.cfg: PARAMS['melt_f'] changed from `6.738071409576496` to `15.129942811022506`.
# 2026-01-16 14:11:26: oggm.cfg: PARAMS['prcp_fac'] changed from `6.627053076249121` to `5.9393609288833735`.
# 2026-01-16 14:11:26: oggm.cfg: PARAMS['temp_bias'] changed from `-13.424556771688179` to `11.809260403721318`.
# 2026-01-16 14:11:27: oggm.cfg: PARAMS['melt_f'] changed from `15.129942811022506` to `4.271302028972998`.
# 2026-01-16 14:11:27: oggm.cfg: PARAMS['prcp_fac'] changed from `5.9393609288833735` to `9.726095287409663`.
# 2026-01-16 14:11:27: oggm.cfg: PARAMS['temp_bias'] changed from `11.809260403721318` to `-6.183473171963019`.
# 2026-01-16 14:11:28: oggm.cfg: PARAMS['melt_f'] changed from `4.271302028972998` to `13.361115544554375`.
# 2026-01-16 14:11:28: oggm.cfg: PARAMS['prcp_fac'] changed from `9.726095287409663` to `0.5257943359917894`.
# 2026-01-16 14:11:28: oggm.cfg: PARAMS['temp_bias'] changed from `-6.183473171963019` to `9.226494760297935`.
# 2026-01-16 14:11:28: oggm.cfg: PARAMS['melt_f'] changed from `13.361115544554375` to `9.312861471923963`.
# 2026-01-16 14:11:28: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5257943359917894` to `6.821656442327296`.
# 2026-01-16 14:11:28: oggm.cfg: PARAMS['temp_bias'] changed from `9.226494760297935` to `-8.851440480418596`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['melt_f'] changed from `9.312861471923963` to `4.554132982586464`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['prcp_fac'] changed from `6.821656442327296` to `4.224311113803053`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['temp_bias'] changed from `-8.851440480418596` to `13.069811663076084`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['melt_f'] changed from `4.554132982586464` to `5.039423607576051`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['prcp_fac'] changed from `4.224311113803053` to `5.479643934410182`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['temp_bias'] changed from `13.069811663076084` to `-2.437955302137789`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['melt_f'] changed from `5.039423607576051` to `3.91601456052042`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['prcp_fac'] changed from `5.479643934410182` to `9.21514821353233`.
# 2026-01-16 14:11:29: oggm.cfg: PARAMS['temp_bias'] changed from `-2.437955302137789` to `4.761862090526119`.
# 2026-01-16 14:11:30: oggm.cfg: PARAMS['melt_f'] changed from `3.91601456052042` to `4.351069247116049`.
# 2026-01-16 14:11:30: oggm.cfg: PARAMS['prcp_fac'] changed from `9.21514821353233` to `7.160114963328192`.
# 2026-01-16 14:11:30: oggm.cfg: PARAMS['temp_bias'] changed from `4.761862090526119` to `8.962890215328677`.
# 2026-01-16 14:11:30: oggm.cfg: PARAMS['melt_f'] changed from `4.351069247116049` to `7.30990231774752`.
# 2026-01-16 14:11:30: oggm.cfg: PARAMS['prcp_fac'] changed from `7.160114963328192` to `8.828416786929743`.
# 2026-01-16 14:11:30: oggm.cfg: PARAMS['temp_bias'] changed from `8.962890215328677` to `-6.5798345099874584`.
# 2026-01-16 14:11:31: oggm.cfg: PARAMS['melt_f'] changed from `7.30990231774752` to `7.837401868089746`.
# 2026-01-16 14:11:31: oggm.cfg: PARAMS['prcp_fac'] changed from `8.828416786929743` to `8.871648847772406`.
# 2026-01-16 14:11:31: oggm.cfg: PARAMS['temp_bias'] changed from `-6.5798345099874584` to `11.118647970223037`.
# 2026-01-16 14:11:31: oggm.cfg: PARAMS['melt_f'] changed from `7.837401868089746` to `4.9678361188514994`.
# 2026-01-16 14:11:31: oggm.cfg: PARAMS['prcp_fac'] changed from `8.871648847772406` to `5.4580010892133926`.
# 2026-01-16 14:11:31: oggm.cfg: PARAMS['temp_bias'] changed from `11.118647970223037` to `10.045201971709957`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['melt_f'] changed from `4.9678361188514994` to `16.260726592935868`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['prcp_fac'] changed from `5.4580010892133926` to `4.745888949302051`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['temp_bias'] changed from `10.045201971709957` to `4.2226124023793155`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['melt_f'] changed from `16.260726592935868` to `5.376402971361907`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['prcp_fac'] changed from `4.745888949302051` to `8.960003999033106`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['temp_bias'] changed from `4.2226124023793155` to `-1.2671505492740014`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['melt_f'] changed from `5.376402971361907` to `6.948592002491104`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['prcp_fac'] changed from `8.960003999033106` to `1.6908300075044547`.
# 2026-01-16 14:11:32: oggm.cfg: PARAMS['temp_bias'] changed from `-1.2671505492740014` to `9.936450358783702`.
# 2026-01-16 14:11:33: oggm.cfg: PARAMS['melt_f'] changed from `6.948592002491104` to `4.164047309050077`.
# 2026-01-16 14:11:33: oggm.cfg: PARAMS['prcp_fac'] changed from `1.6908300075044547` to `2.429768624740386`.
# 2026-01-16 14:11:33: oggm.cfg: PARAMS['temp_bias'] changed from `9.936450358783702` to `3.492629855962729`.
# 2026-01-16 14:11:33: oggm.cfg: PARAMS['melt_f'] changed from `4.164047309050077` to `13.31270008347093`.
# 2026-01-16 14:11:33: oggm.cfg: PARAMS['prcp_fac'] changed from `2.429768624740386` to `4.03427643893497`.
# 2026-01-16 14:11:33: oggm.cfg: PARAMS['temp_bias'] changed from `3.492629855962729` to `4.899728912305321`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['melt_f'] changed from `13.31270008347093` to `7.950361691521911`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['prcp_fac'] changed from `4.03427643893497` to `2.954947338713286`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['temp_bias'] changed from `4.899728912305321` to `14.39276431453953`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['melt_f'] changed from `7.950361691521911` to `15.807581082895688`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['prcp_fac'] changed from `2.954947338713286` to `1.3610881045360244`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['temp_bias'] changed from `14.39276431453953` to `-8.52912123404317`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['melt_f'] changed from `15.807581082895688` to `10.506211614533022`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3610881045360244` to `4.618158795232284`.
# 2026-01-16 14:11:34: oggm.cfg: PARAMS['temp_bias'] changed from `-8.52912123404317` to `7.750255867125425`.
# 2026-01-16 14:11:35: oggm.cfg: PARAMS['melt_f'] changed from `10.506211614533022` to `12.542232597599208`.
# 2026-01-16 14:11:35: oggm.cfg: PARAMS['prcp_fac'] changed from `4.618158795232284` to `0.4483160747016517`.
# 2026-01-16 14:11:35: oggm.cfg: PARAMS['temp_bias'] changed from `7.750255867125425` to `-12.582776400355572`.
# 2026-01-16 14:11:35: oggm.cfg: PARAMS['melt_f'] changed from `12.542232597599208` to `6.859386484322958`.
# 2026-01-16 14:11:35: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4483160747016517` to `5.181974653127667`.
# 2026-01-16 14:11:35: oggm.cfg: PARAMS['temp_bias'] changed from `-12.582776400355572` to `-14.23848495207397`.
# 2026-01-16 14:11:36: oggm.cfg: PARAMS['melt_f'] changed from `6.859386484322958` to `9.089638936229205`.
# 2026-01-16 14:11:36: oggm.cfg: PARAMS['prcp_fac'] changed from `5.181974653127667` to `1.918170925376847`.
# 2026-01-16 14:11:36: oggm.cfg: PARAMS['temp_bias'] changed from `-14.23848495207397` to `9.603848948257482`.
# 2026-01-16 14:11:36: oggm.cfg: PARAMS['melt_f'] changed from `9.089638936229205` to `7.782747864893809`.
# 2026-01-16 14:11:36: oggm.cfg: PARAMS['prcp_fac'] changed from `1.918170925376847` to `2.6625837504808856`.
# 2026-01-16 14:11:36: oggm.cfg: PARAMS['temp_bias'] changed from `9.603848948257482` to `14.353864244440988`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['melt_f'] changed from `7.782747864893809` to `5.1144286112311095`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['prcp_fac'] changed from `2.6625837504808856` to `7.683655308814902`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['temp_bias'] changed from `14.353864244440988` to `12.244692391453459`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['melt_f'] changed from `5.1144286112311095` to `5.56630838759038`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['prcp_fac'] changed from `7.683655308814902` to `9.943890916708567`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['temp_bias'] changed from `12.244692391453459` to `10.245987382689435`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['melt_f'] changed from `5.56630838759038` to `5.665119201966392`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['prcp_fac'] changed from `9.943890916708567` to `9.099558266761141`.
# 2026-01-16 14:11:37: oggm.cfg: PARAMS['temp_bias'] changed from `10.245987382689435` to `-12.466238707910978`.
# 2026-01-16 14:11:38: oggm.cfg: PARAMS['melt_f'] changed from `5.665119201966392` to `2.401413178937119`.
# 2026-01-16 14:11:38: oggm.cfg: PARAMS['prcp_fac'] changed from `9.099558266761141` to `1.969768850909274`.
# 2026-01-16 14:11:38: oggm.cfg: PARAMS['temp_bias'] changed from `-12.466238707910978` to `-4.303708376398747`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['melt_f'] changed from `2.401413178937119` to `11.532836464412924`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['prcp_fac'] changed from `1.969768850909274` to `5.006073820239613`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['temp_bias'] changed from `-4.303708376398747` to `-10.444966217368066`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['melt_f'] changed from `11.532836464412924` to `4.653487103807201`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['prcp_fac'] changed from `5.006073820239613` to `7.011090743792631`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['temp_bias'] changed from `-10.444966217368066` to `11.028255077744713`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['melt_f'] changed from `4.653487103807201` to `9.549098729609655`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['prcp_fac'] changed from `7.011090743792631` to `2.4888707248775095`.
# 2026-01-16 14:11:39: oggm.cfg: PARAMS['temp_bias'] changed from `11.028255077744713` to `4.8682625920002245`.
# 2026-01-16 14:11:40: oggm.cfg: PARAMS['melt_f'] changed from `9.549098729609655` to `7.6573834074309906`.
# 2026-01-16 14:11:40: oggm.cfg: PARAMS['prcp_fac'] changed from `2.4888707248775095` to `9.719769026281973`.
# 2026-01-16 14:11:40: oggm.cfg: PARAMS['temp_bias'] changed from `4.8682625920002245` to `13.170759438140987`.
# 2026-01-16 14:11:40: oggm.cfg: PARAMS['melt_f'] changed from `7.6573834074309906` to `10.844793786163828`.
# 2026-01-16 14:11:40: oggm.cfg: PARAMS['prcp_fac'] changed from `9.719769026281973` to `4.630134966363205`.
# 2026-01-16 14:11:40: oggm.cfg: PARAMS['temp_bias'] changed from `13.170759438140987` to `-6.698761215185243`.
# 2026-01-16 14:11:41: oggm.cfg: PARAMS['melt_f'] changed from `10.844793786163828` to `6.201851724842972`.
# 2026-01-16 14:11:41: oggm.cfg: PARAMS['prcp_fac'] changed from `4.630134966363205` to `0.38111385360923034`.
# 2026-01-16 14:11:41: oggm.cfg: PARAMS['temp_bias'] changed from `-6.698761215185243` to `2.0387425760372366`.
# 2026-01-16 14:11:41: oggm.cfg: PARAMS['melt_f'] changed from `6.201851724842972` to `10.0393852509825`.
# 2026-01-16 14:11:41: oggm.cfg: PARAMS['prcp_fac'] changed from `0.38111385360923034` to `5.920742148939397`.
# 2026-01-16 14:11:41: oggm.cfg: PARAMS['temp_bias'] changed from `2.0387425760372366` to `-9.462867558156088`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['melt_f'] changed from `10.0393852509825` to `4.20046182624073`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['prcp_fac'] changed from `5.920742148939397` to `3.830065350054622`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['temp_bias'] changed from `-9.462867558156088` to `-6.342671903776106`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['melt_f'] changed from `4.20046182624073` to `5.748761540089644`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['prcp_fac'] changed from `3.830065350054622` to `3.6152511295703516`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['temp_bias'] changed from `-6.342671903776106` to `5.866928881996479`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['melt_f'] changed from `5.748761540089644` to `10.117627539717654`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6152511295703516` to `2.085509418061164`.
# 2026-01-16 14:11:42: oggm.cfg: PARAMS['temp_bias'] changed from `5.866928881996479` to `6.39838659700721`.
# 2026-01-16 14:11:43: oggm.cfg: PARAMS['melt_f'] changed from `10.117627539717654` to `6.041569981361716`.
# 2026-01-16 14:11:43: oggm.cfg: PARAMS['prcp_fac'] changed from `2.085509418061164` to `6.6886072495367275`.
# 2026-01-16 14:11:43: oggm.cfg: PARAMS['temp_bias'] changed from `6.39838659700721` to `-7.42927384607385`.
# 2026-01-16 14:11:43: oggm.cfg: PARAMS['melt_f'] changed from `6.041569981361716` to `3.375124252536476`.
# 2026-01-16 14:11:43: oggm.cfg: PARAMS['prcp_fac'] changed from `6.6886072495367275` to `7.486790679513132`.
# 2026-01-16 14:11:43: oggm.cfg: PARAMS['temp_bias'] changed from `-7.42927384607385` to `0.7519119448377793`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['melt_f'] changed from `3.375124252536476` to `8.798772141901747`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['prcp_fac'] changed from `7.486790679513132` to `3.972884173065927`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['temp_bias'] changed from `0.7519119448377793` to `1.0386493733565274`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['melt_f'] changed from `8.798772141901747` to `15.01439302820221`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['prcp_fac'] changed from `3.972884173065927` to `5.832802315777002`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['temp_bias'] changed from `1.0386493733565274` to `12.63980186639763`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['melt_f'] changed from `15.01439302820221` to `4.979701174296029`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['prcp_fac'] changed from `5.832802315777002` to `1.594227377627842`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['temp_bias'] changed from `12.63980186639763` to `-14.513817704382836`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['melt_f'] changed from `4.979701174296029` to `12.88030719957969`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['prcp_fac'] changed from `1.594227377627842` to `2.198696363416214`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['temp_bias'] changed from `-14.513817704382836` to `-8.154855860908103`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['melt_f'] changed from `12.88030719957969` to `16.17200634166564`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['prcp_fac'] changed from `2.198696363416214` to `9.487638674791642`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['temp_bias'] changed from `-8.154855860908103` to `0.9109509705608083`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['melt_f'] changed from `16.17200634166564` to `12.066704273651213`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['prcp_fac'] changed from `9.487638674791642` to `6.575552001948743`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['temp_bias'] changed from `0.9109509705608083` to `3.456512451877508`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['melt_f'] changed from `12.066704273651213` to `4.849761799708548`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['prcp_fac'] changed from `6.575552001948743` to `4.20283476945271`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['temp_bias'] changed from `3.456512451877508` to `14.648891197159148`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['melt_f'] changed from `4.849761799708548` to `1.8752960621406558`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['prcp_fac'] changed from `4.20283476945271` to `4.103606857175329`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['temp_bias'] changed from `14.648891197159148` to `8.987535856400097`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['melt_f'] changed from `1.8752960621406558` to `7.980088667686291`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['prcp_fac'] changed from `4.103606857175329` to `4.065097512423455`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['temp_bias'] changed from `8.987535856400097` to `6.452020778299367`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['melt_f'] changed from `7.980088667686291` to `12.340361204229955`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['prcp_fac'] changed from `4.065097512423455` to `5.796021722689635`.
# 2026-01-16 14:11:44: oggm.cfg: PARAMS['temp_bias'] changed from `6.452020778299367` to `-11.004476330511032`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['melt_f'] changed from `12.340361204229955` to `16.499395398427644`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['prcp_fac'] changed from `5.796021722689635` to `7.08187621615363`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['temp_bias'] changed from `-11.004476330511032` to `5.118401342418537`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['melt_f'] changed from `16.499395398427644` to `9.762960682346764`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['prcp_fac'] changed from `7.08187621615363` to `1.9278614834262433`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['temp_bias'] changed from `5.118401342418537` to `2.7740757732821812`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['melt_f'] changed from `9.762960682346764` to `3.4176838684527118`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9278614834262433` to `0.7008826539773262`.
# 2026-01-16 14:11:45: oggm.cfg: PARAMS['temp_bias'] changed from `2.7740757732821812` to `-8.343993933341714`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['melt_f'] changed from `3.4176838684527118` to `4.631684058718875`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7008826539773262` to `7.427018018984701`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['temp_bias'] changed from `-8.343993933341714` to `-6.132330547627035`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['melt_f'] changed from `4.631684058718875` to `15.300027686276808`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['prcp_fac'] changed from `7.427018018984701` to `0.7411275104646221`.
# 2026-01-16 14:11:46: oggm.cfg: PARAMS['temp_bias'] changed from `-6.132330547627035` to `-8.511730339472201`.
# 2026-01-16 14:11:47: oggm.cfg: PARAMS['melt_f'] changed from `15.300027686276808` to `8.722840790106483`.
# 2026-01-16 14:11:47: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7411275104646221` to `0.7244923947555245`.
# 2026-01-16 14:11:47: oggm.cfg: PARAMS['temp_bias'] changed from `-8.511730339472201` to `-7.177802871551474`.
# 2026-01-16 14:11:47: oggm.cfg: PARAMS['melt_f'] changed from `8.722840790106483` to `10.501734902715755`.
# 2026-01-16 14:11:47: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7244923947555245` to `6.060218581978705`.
# 2026-01-16 14:11:47: oggm.cfg: PARAMS['temp_bias'] changed from `-7.177802871551474` to `14.990093950454263`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['melt_f'] changed from `10.501734902715755` to `8.54816297056892`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['prcp_fac'] changed from `6.060218581978705` to `1.4948130755332432`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['temp_bias'] changed from `14.990093950454263` to `8.923519705940627`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['melt_f'] changed from `8.54816297056892` to `8.215437090585281`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4948130755332432` to `1.815499541843448`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['temp_bias'] changed from `8.923519705940627` to `13.450777356979895`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['melt_f'] changed from `8.215437090585281` to `13.688913321386053`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['prcp_fac'] changed from `1.815499541843448` to `3.6833384049545397`.
# 2026-01-16 14:11:48: oggm.cfg: PARAMS['temp_bias'] changed from `13.450777356979895` to `-12.081207680086592`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['melt_f'] changed from `13.688913321386053` to `14.44691735383846`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6833384049545397` to `1.3389265286163732`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['temp_bias'] changed from `-12.081207680086592` to `-7.5372887091727305`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['melt_f'] changed from `14.44691735383846` to `8.200056535402613`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3389265286163732` to `5.884207546639527`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['temp_bias'] changed from `-7.5372887091727305` to `10.949557511979997`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['melt_f'] changed from `8.200056535402613` to `16.639539374648045`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['prcp_fac'] changed from `5.884207546639527` to `7.658919925491477`.
# 2026-01-16 14:11:49: oggm.cfg: PARAMS['temp_bias'] changed from `10.949557511979997` to `-6.986809688923595`.
# 2026-01-16 14:11:50: oggm.cfg: PARAMS['melt_f'] changed from `16.639539374648045` to `16.326832040791487`.
# 2026-01-16 14:11:50: oggm.cfg: PARAMS['prcp_fac'] changed from `7.658919925491477` to `5.582763729528282`.
# 2026-01-16 14:11:50: oggm.cfg: PARAMS['temp_bias'] changed from `-6.986809688923595` to `-8.607659856618351`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['melt_f'] changed from `16.326832040791487` to `11.865831106834149`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['prcp_fac'] changed from `5.582763729528282` to `2.3701531434789618`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['temp_bias'] changed from `-8.607659856618351` to `12.57921749620316`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['melt_f'] changed from `11.865831106834149` to `13.700681186758201`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['prcp_fac'] changed from `2.3701531434789618` to `6.725183694065561`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['temp_bias'] changed from `12.57921749620316` to `-2.178100107622651`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['melt_f'] changed from `13.700681186758201` to `1.5950966854927668`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['prcp_fac'] changed from `6.725183694065561` to `6.9703106137894055`.
# 2026-01-16 14:11:51: oggm.cfg: PARAMS['temp_bias'] changed from `-2.178100107622651` to `1.560505872682775`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['melt_f'] changed from `1.5950966854927668` to `3.559966194458736`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['prcp_fac'] changed from `6.9703106137894055` to `2.2225516229597915`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['temp_bias'] changed from `1.560505872682775` to `-12.50765358450341`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['melt_f'] changed from `3.559966194458736` to `15.906989316042866`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['prcp_fac'] changed from `2.2225516229597915` to `8.35841971785948`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['temp_bias'] changed from `-12.50765358450341` to `1.4163831690874815`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['melt_f'] changed from `15.906989316042866` to `15.282207924534278`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['prcp_fac'] changed from `8.35841971785948` to `2.3993663368530305`.
# 2026-01-16 14:11:52: oggm.cfg: PARAMS['temp_bias'] changed from `1.4163831690874815` to `-7.153953172534068`.
# 2026-01-16 14:11:53: oggm.cfg: PARAMS['melt_f'] changed from `15.282207924534278` to `8.173690753485886`.
# 2026-01-16 14:11:53: oggm.cfg: PARAMS['prcp_fac'] changed from `2.3993663368530305` to `4.196250507669742`.
# 2026-01-16 14:11:53: oggm.cfg: PARAMS['temp_bias'] changed from `-7.153953172534068` to `9.057640946930793`.
# 2026-01-16 14:11:53: oggm.cfg: PARAMS['melt_f'] changed from `8.173690753485886` to `10.966165506650913`.
# 2026-01-16 14:11:53: oggm.cfg: PARAMS['prcp_fac'] changed from `4.196250507669742` to `6.935267649874097`.
# 2026-01-16 14:11:53: oggm.cfg: PARAMS['temp_bias'] changed from `9.057640946930793` to `-8.978005449626268`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['melt_f'] changed from `10.966165506650913` to `11.628521928876227`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['prcp_fac'] changed from `6.935267649874097` to `7.110767682447216`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['temp_bias'] changed from `-8.978005449626268` to `-2.4150130192597246`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['melt_f'] changed from `11.628521928876227` to `2.6768191464006694`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['prcp_fac'] changed from `7.110767682447216` to `1.597317528496319`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['temp_bias'] changed from `-2.4150130192597246` to `8.848536957871033`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['melt_f'] changed from `2.6768191464006694` to `3.1955181157274852`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['prcp_fac'] changed from `1.597317528496319` to `4.146100124427905`.
# 2026-01-16 14:11:54: oggm.cfg: PARAMS['temp_bias'] changed from `8.848536957871033` to `7.251295307242589`.
# 2026-01-16 14:11:55: oggm.cfg: PARAMS['melt_f'] changed from `3.1955181157274852` to `11.895928093970475`.
# 2026-01-16 14:11:55: oggm.cfg: PARAMS['prcp_fac'] changed from `4.146100124427905` to `4.939944732615939`.
# 2026-01-16 14:11:55: oggm.cfg: PARAMS['temp_bias'] changed from `7.251295307242589` to `-14.453674152281561`.
# 2026-01-16 14:11:55: oggm.cfg: PARAMS['melt_f'] changed from `11.895928093970475` to `13.094902275130178`.
# 2026-01-16 14:11:55: oggm.cfg: PARAMS['prcp_fac'] changed from `4.939944732615939` to `8.158300451492993`.
# 2026-01-16 14:11:55: oggm.cfg: PARAMS['temp_bias'] changed from `-14.453674152281561` to `2.8869630763732275`.
# 2026-01-16 14:11:56: oggm.cfg: PARAMS['melt_f'] changed from `13.094902275130178` to `9.518404467449558`.
# ...
# 2026-01-16 14:17:00: oggm.cfg: PARAMS['temp_bias'] changed from `14.79956121826169` to `-0.1265094064238763`.
# 2026-01-16 14:17:00: oggm.cfg: PARAMS['melt_f'] changed from `8.05484399579423` to `15.023033294841449`.
# 2026-01-16 14:17:00: oggm.cfg: PARAMS['prcp_fac'] changed from `4.151899685962755` to `0.7810058805581179`.
# 2026-01-16 14:17:00: oggm.cfg: PARAMS['temp_bias'] changed from `-0.1265094064238763` to `14.629059414532158`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['melt_f'] changed from `15.023033294841449` to `16.381467692476214`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7810058805581179` to `1.2332974562420818`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['temp_bias'] changed from `14.629059414532158` to `4.695239037197819`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['melt_f'] changed from `16.381467692476214` to `11.466183215106694`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2332974562420818` to `3.210915109985761`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['temp_bias'] changed from `4.695239037197819` to `10.609799815523733`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['melt_f'] changed from `11.466183215106694` to `9.241078170792857`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['prcp_fac'] changed from `3.210915109985761` to `8.565780688535598`.
# 2026-01-16 14:17:01: oggm.cfg: PARAMS['temp_bias'] changed from `10.609799815523733` to `4.07731395529224`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['melt_f'] changed from `9.241078170792857` to `7.142808058384696`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['prcp_fac'] changed from `8.565780688535598` to `0.6577493945316205`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['temp_bias'] changed from `4.07731395529224` to `12.904547312182931`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['melt_f'] changed from `7.142808058384696` to `13.140903091815655`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6577493945316205` to `7.761188119515867`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['temp_bias'] changed from `12.904547312182931` to `8.53397005508419`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['melt_f'] changed from `13.140903091815655` to `1.768966309938812`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['prcp_fac'] changed from `7.761188119515867` to `3.888930106935835`.
# 2026-01-16 14:17:02: oggm.cfg: PARAMS['temp_bias'] changed from `8.53397005508419` to `-7.264596680612552`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['melt_f'] changed from `1.768966309938812` to `11.199560677752343`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['prcp_fac'] changed from `3.888930106935835` to `3.3700989241659656`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['temp_bias'] changed from `-7.264596680612552` to `10.756603150668418`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['melt_f'] changed from `11.199560677752343` to `7.967388215182831`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['prcp_fac'] changed from `3.3700989241659656` to `5.165339512437307`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['temp_bias'] changed from `10.756603150668418` to `14.096766903991835`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['melt_f'] changed from `7.967388215182831` to `7.438272915079784`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['prcp_fac'] changed from `5.165339512437307` to `4.305453346521228`.
# 2026-01-16 14:17:03: oggm.cfg: PARAMS['temp_bias'] changed from `14.096766903991835` to `-7.019029808458618`.
# 2026-01-16 14:17:04: oggm.cfg: PARAMS['melt_f'] changed from `7.438272915079784` to `11.434491647666809`.
# 2026-01-16 14:17:04: oggm.cfg: PARAMS['prcp_fac'] changed from `4.305453346521228` to `0.21264641623279706`.
# 2026-01-16 14:17:04: oggm.cfg: PARAMS['temp_bias'] changed from `-7.019029808458618` to `3.000636030017585`.
# 2026-01-16 14:17:04: oggm.cfg: PARAMS['melt_f'] changed from `11.434491647666809` to `12.941999034830019`.
# 2026-01-16 14:17:04: oggm.cfg: PARAMS['prcp_fac'] changed from `0.21264641623279706` to `8.4838679865747`.
# 2026-01-16 14:17:04: oggm.cfg: PARAMS['temp_bias'] changed from `3.000636030017585` to `-14.127629124948161`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['melt_f'] changed from `12.941999034830019` to `12.11899125091088`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['prcp_fac'] changed from `8.4838679865747` to `3.319247949430163`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['temp_bias'] changed from `-14.127629124948161` to `5.583388329258145`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['melt_f'] changed from `12.11899125091088` to `8.640730391543745`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['prcp_fac'] changed from `3.319247949430163` to `3.0163925101197155`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['temp_bias'] changed from `5.583388329258145` to `3.126379835337488`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['melt_f'] changed from `8.640730391543745` to `12.053241850761605`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['prcp_fac'] changed from `3.0163925101197155` to `6.2887490474986665`.
# 2026-01-16 14:17:05: oggm.cfg: PARAMS['temp_bias'] changed from `3.126379835337488` to `-11.827236017632462`.
# 2026-01-16 14:17:06: oggm.cfg: PARAMS['melt_f'] changed from `12.053241850761605` to `5.337415669510893`.
# 2026-01-16 14:17:06: oggm.cfg: PARAMS['prcp_fac'] changed from `6.2887490474986665` to `4.23676260401778`.
# 2026-01-16 14:17:06: oggm.cfg: PARAMS['temp_bias'] changed from `-11.827236017632462` to `-2.476482138972324`.
# 2026-01-16 14:17:06: oggm.cfg: PARAMS['melt_f'] changed from `5.337415669510893` to `4.290108200713668`.
# 2026-01-16 14:17:06: oggm.cfg: PARAMS['prcp_fac'] changed from `4.23676260401778` to `0.715236303211094`.
# 2026-01-16 14:17:06: oggm.cfg: PARAMS['temp_bias'] changed from `-2.476482138972324` to `5.085206580884577`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['melt_f'] changed from `4.290108200713668` to `8.731224613705372`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['prcp_fac'] changed from `0.715236303211094` to `4.52771931661083`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['temp_bias'] changed from `5.085206580884577` to `11.424691983400667`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['melt_f'] changed from `8.731224613705372` to `4.410784862992323`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['prcp_fac'] changed from `4.52771931661083` to `1.4985087883760326`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['temp_bias'] changed from `11.424691983400667` to `-13.481089935237446`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['melt_f'] changed from `4.410784862992323` to `4.937856003278957`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4985087883760326` to `7.6305357608052375`.
# 2026-01-16 14:17:07: oggm.cfg: PARAMS['temp_bias'] changed from `-13.481089935237446` to `-7.873673735396219`.
# 2026-01-16 14:17:08: oggm.cfg: PARAMS['melt_f'] changed from `4.937856003278957` to `16.879631011371316`.
# 2026-01-16 14:17:08: oggm.cfg: PARAMS['prcp_fac'] changed from `7.6305357608052375` to `3.474043309361228`.
# 2026-01-16 14:17:08: oggm.cfg: PARAMS['temp_bias'] changed from `-7.873673735396219` to `2.28066317354671`.
# 2026-01-16 14:17:08: oggm.cfg: PARAMS['melt_f'] changed from `16.879631011371316` to `7.685034058038896`.
# 2026-01-16 14:17:08: oggm.cfg: PARAMS['prcp_fac'] changed from `3.474043309361228` to `3.6000233611107593`.
# 2026-01-16 14:17:08: oggm.cfg: PARAMS['temp_bias'] changed from `2.28066317354671` to `-2.052164228259482`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['melt_f'] changed from `7.685034058038896` to `8.132665263475452`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6000233611107593` to `0.6097507418995891`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['temp_bias'] changed from `-2.052164228259482` to `0.10597316744184226`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['melt_f'] changed from `8.132665263475452` to `15.848873648816767`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6097507418995891` to `0.7527170105044795`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['temp_bias'] changed from `0.10597316744184226` to `-10.821287703609116`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['melt_f'] changed from `15.848873648816767` to `2.5476921329004574`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7527170105044795` to `3.5047505721612042`.
# 2026-01-16 14:17:09: oggm.cfg: PARAMS['temp_bias'] changed from `-10.821287703609116` to `-10.267211769719788`.
# 2026-01-16 14:17:10: oggm.cfg: PARAMS['melt_f'] changed from `2.5476921329004574` to `4.892052122900106`.
# 2026-01-16 14:17:10: oggm.cfg: PARAMS['prcp_fac'] changed from `3.5047505721612042` to `8.202451632126587`.
# 2026-01-16 14:17:10: oggm.cfg: PARAMS['temp_bias'] changed from `-10.267211769719788` to `-4.837895295637477`.
# 2026-01-16 14:17:10: oggm.cfg: PARAMS['melt_f'] changed from `4.892052122900106` to `9.217532039453676`.
# 2026-01-16 14:17:10: oggm.cfg: PARAMS['prcp_fac'] changed from `8.202451632126587` to `7.797292518022038`.
# 2026-01-16 14:17:10: oggm.cfg: PARAMS['temp_bias'] changed from `-4.837895295637477` to `12.687978152312372`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['melt_f'] changed from `9.217532039453676` to `1.566589124690802`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['prcp_fac'] changed from `7.797292518022038` to `9.876038516718529`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['temp_bias'] changed from `12.687978152312372` to `13.890555636767552`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['melt_f'] changed from `1.566589124690802` to `3.815735000098281`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['prcp_fac'] changed from `9.876038516718529` to `7.360865688386836`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['temp_bias'] changed from `13.890555636767552` to `-0.20854160766225505`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['melt_f'] changed from `3.815735000098281` to `5.447160119678871`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['prcp_fac'] changed from `7.360865688386836` to `4.126947708704268`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['temp_bias'] changed from `-0.20854160766225505` to `-5.745757743371168`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['melt_f'] changed from `5.447160119678871` to `2.5860194552946183`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['prcp_fac'] changed from `4.126947708704268` to `5.641344817457484`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['temp_bias'] changed from `-5.745757743371168` to `10.490188353622653`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['melt_f'] changed from `2.5860194552946183` to `11.770128613809101`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['prcp_fac'] changed from `5.641344817457484` to `2.80345306907854`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['temp_bias'] changed from `10.490188353622653` to `-13.803207480320982`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['melt_f'] changed from `11.770128613809101` to `11.328615248205672`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['prcp_fac'] changed from `2.80345306907854` to `2.482473206599827`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['temp_bias'] changed from `-13.803207480320982` to `-9.651571381820714`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['melt_f'] changed from `11.328615248205672` to `5.938624329141365`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['prcp_fac'] changed from `2.482473206599827` to `7.695272396399813`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['temp_bias'] changed from `-9.651571381820714` to `-13.938941945142902`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['melt_f'] changed from `5.938624329141365` to `2.0101624753027827`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['prcp_fac'] changed from `7.695272396399813` to `6.231295997905958`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['temp_bias'] changed from `-13.938941945142902` to `-11.890076687702708`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['melt_f'] changed from `2.0101624753027827` to `3.530176941757772`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['prcp_fac'] changed from `6.231295997905958` to `0.5968712408870098`.
# 2026-01-16 14:17:11: oggm.cfg: PARAMS['temp_bias'] changed from `-11.890076687702708` to `4.55602939126976`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['melt_f'] changed from `3.530176941757772` to `9.483568520275531`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5968712408870098` to `9.88796448976934`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['temp_bias'] changed from `4.55602939126976` to `-12.020961076052895`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['melt_f'] changed from `9.483568520275531` to `16.240643621669072`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['prcp_fac'] changed from `9.88796448976934` to `3.991918212820644`.
# 2026-01-16 14:17:12: oggm.cfg: PARAMS['temp_bias'] changed from `-12.020961076052895` to `6.158313326595348`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['melt_f'] changed from `16.240643621669072` to `9.701011881242884`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['prcp_fac'] changed from `3.991918212820644` to `0.35164710612755723`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['temp_bias'] changed from `6.158313326595348` to `13.007445883049066`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['melt_f'] changed from `9.701011881242884` to `13.164050187283916`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['prcp_fac'] changed from `0.35164710612755723` to `8.536859502595133`.
# 2026-01-16 14:17:13: oggm.cfg: PARAMS['temp_bias'] changed from `13.007445883049066` to `-6.645298227008649`.
# 2026-01-16 14:17:14: oggm.cfg: PARAMS['melt_f'] changed from `13.164050187283916` to `10.238454480541607`.
# 2026-01-16 14:17:14: oggm.cfg: PARAMS['prcp_fac'] changed from `8.536859502595133` to `8.161894827485517`.
# 2026-01-16 14:17:14: oggm.cfg: PARAMS['temp_bias'] changed from `-6.645298227008649` to `-12.524518187307306`.
# 2026-01-16 14:17:14: oggm.cfg: PARAMS['melt_f'] changed from `10.238454480541607` to `6.423193138928409`.
# 2026-01-16 14:17:14: oggm.cfg: PARAMS['prcp_fac'] changed from `8.161894827485517` to `8.778350814830654`.
# 2026-01-16 14:17:14: oggm.cfg: PARAMS['temp_bias'] changed from `-12.524518187307306` to `-1.6648911450499906`.
# 2026-01-16 14:17:15: oggm.cfg: PARAMS['melt_f'] changed from `6.423193138928409` to `4.5814307074486385`.
# 2026-01-16 14:17:15: oggm.cfg: PARAMS['prcp_fac'] changed from `8.778350814830654` to `2.6808380475545226`.
# 2026-01-16 14:17:15: oggm.cfg: PARAMS['temp_bias'] changed from `-1.6648911450499906` to `7.979064516089899`.
# 2026-01-16 14:17:15: oggm.cfg: PARAMS['melt_f'] changed from `4.5814307074486385` to `6.7841502549356205`.
# 2026-01-16 14:17:15: oggm.cfg: PARAMS['prcp_fac'] changed from `2.6808380475545226` to `0.4576009916178697`.
# 2026-01-16 14:17:15: oggm.cfg: PARAMS['temp_bias'] changed from `7.979064516089899` to `-11.567484924020828`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['melt_f'] changed from `6.7841502549356205` to `14.035119992212472`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4576009916178697` to `3.635342170067922`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['temp_bias'] changed from `-11.567484924020828` to `-3.506035876242416`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['melt_f'] changed from `14.035119992212472` to `16.414735313506455`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['prcp_fac'] changed from `3.635342170067922` to `2.0398490006845984`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['temp_bias'] changed from `-3.506035876242416` to `-12.252005484218312`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['melt_f'] changed from `16.414735313506455` to `13.553696239095858`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0398490006845984` to `4.497959837797522`.
# 2026-01-16 14:17:16: oggm.cfg: PARAMS['temp_bias'] changed from `-12.252005484218312` to `-12.181311794949787`.
# 2026-01-16 14:17:17: oggm.cfg: PARAMS['melt_f'] changed from `13.553696239095858` to `6.593664930099553`.
# 2026-01-16 14:17:17: oggm.cfg: PARAMS['prcp_fac'] changed from `4.497959837797522` to `8.498538305531037`.
# 2026-01-16 14:17:17: oggm.cfg: PARAMS['temp_bias'] changed from `-12.181311794949787` to `12.207169640755996`.
# 2026-01-16 14:17:17: oggm.cfg: PARAMS['melt_f'] changed from `6.593664930099553` to `11.554641706645286`.
# 2026-01-16 14:17:17: oggm.cfg: PARAMS['prcp_fac'] changed from `8.498538305531037` to `5.816179549779523`.
# 2026-01-16 14:17:17: oggm.cfg: PARAMS['temp_bias'] changed from `12.207169640755996` to `-0.3217082795209123`.

# %%
# Plot Monte Carlo (MC) simulations results for the Runoff and compare with data:
plt.figure(figsize=[15,5])
plt.plot(mbdf.index.values, np.transpose(runoff), 'k', linewidth = 0.5)
plt.ylabel('Runoff'); plt.xlabel('Years')
plt.legend(['sim'])
plt.title("Number of parameter samples: N = %d" % N, loc='right')
plt.show()

# %%
# Also colour mapping (retrospectively) based on temp_bias values
import matplotlib.pyplot as plt
import numpy as np

temp_bias_index = 2  # Index of temp_bias in X

import matplotlib.pyplot as plt
import numpy as np

# Colormap and normalization
cmap = plt.cm.coolwarm
norm = plt.Normalize(vmin=X[:, temp_bias_index].min(), vmax=X[:, temp_bias_index].max())

fig, ax = plt.subplots(figsize=(15, 5))

# Plot each simulation with color based on temp_bias
for i in range(np.shape(runoff)[0]):  # assuming QQ_runoff is (N, time)
    color = cmap(norm(X[i, temp_bias_index]))
    ax.plot(mbdf.index.values, runoff[i, :], linewidth=0.5, color=color)

ax.set_ylabel('Runoff')
ax.set_xlabel('Years')
ax.set_title(f"Number of parameter samples: N = {N}", loc='right')

# Add colorbar linked to the same colormap
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # required for colorbar
cbar = fig.colorbar(sm, ax=ax)  # <-- specify ax here
cbar.set_label('Temperature Bias')

plt.show()

# %% [markdown]
# ## Distribution of Model Outputs

# %%
Y_lab_runoff_dist = ['Mean Runoff', 'Std of Runoff']

YY_hydro = np.nan * np.ones((N, 2))

for i, x in enumerate(runoff):
    YY_hydro[i,0] = np.mean(x)
    YY_hydro[i,1] = np.std(x)

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_hydro[:,0], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_lab_runoff_dist[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_hydro[:,1], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_lab_runoff_dist[1])

plt.tight_layout()

# %% [markdown]
# ## Sensitivity Analysis

# %%
annual_mean_runoff = np.mean(runoff, axis=1) # Mean annual runoff for each sample
annual_std_runoff = np.std(runoff, axis=1) # Std annual runoff for each sample

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(annual_mean_runoff, annual_std_runoff, s=5), plt.title('Mean runoff vs Std of runoff'), plt.xlabel('Mean runoff'), plt.ylabel('Std of runoff (mm w.e.)'),
plt.gca().locator_params(axis='x', nbins=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here we are plotting the outputs of our runoff model and plotted the mean runoff values vs the standard deviation of the runoff values, this shows us the relationship between the two metrics. It can be seen here that for a lower mean runoff (under 40 (Mt) of runoff per our time period), in general there is a lower variation of runoff as well.
#
# Intuitively this makes sense considering that a lower average runoff would likely skew more towards lower runoff values varying throughout the year, or perhaps will have mostly low runoff with slighly higher runoff (to keep this variation low). However, once we surpass a runoff of 40 (Mt) per our time period, the realtionsip between the mean and std becomes abruptly uncorrelated. This is likely that at higher values, there are either a wider range of runoffs that could cause these higher mean runoffs, or that all runoff values could be sitting around this mean, resulting in a lower variation.

# %%
YY_hydro = np.nan * np.ones((N, 2))

for i, x in enumerate(runoff):
    YY_hydro[i,0] = np.mean(x)
    YY_hydro[i,1] = np.std(x)

Y_Labels = ['Mean Runoff', 'Std of Runoff']

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY_hydro[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %% [markdown]
# ### Now looking at scatter plots for a qualitative view of our sensitivity.
#
# Firstly looking at the mean runoff over the course of a year:
#
# - **The melt_f**: This appears to have a minimal relationship with the mean runoff, this appears almost randomly scattered, with a slight clustering towards a mean runoff of 0, but again this is evenly dispersed across all values of melt_f. Therefore, we can expect that the sensitivity analysis will show the melt_f having a very minimal effect on the mean runoff.
#
# - **The prcp_fac**: This appears to have a slight relationship with the mean runoff, with a clustering of points in a positive linear relationship with the mean runoff. This intuitively is what we might expect, as the prcp_fac increases, this will increase the amount of precipitation on the glacier. If the temperature is above our threshold for solid precipitation, this will then cause the precipitation to contribute directly to the runoff. However, a large number of points is dispersed almost randomly with the prcp_fac, again showing us that perhaps this may not show as particulatly impactful for our sensitivity analysis in relation to the mean runoff. But perhaps slightly more so than that of melt_f?
#
# - **The temp_bias**: This appears to have a very strong correlation with the mean_runoff. With a particularly tight correlation at large negative temperature biases. This makes sense, as this would ensure that the glacier atmospheric temperature is almost always below our threshold that would prevent both melt and liquid precipitation, leading to a very minimal runoff. As the temperature increases, and temp_bias exceeds 0 degrees Celcius, there is a very minimal relationship, with the points becoming more scattered. For our sensitivity analysis, from this, we can expect to see a large sensitivity for temp_bias. However, this is more likely due to the large range that we consider for temp_bias, which by default in the OGGM is [-15,15], if this was reduced to a smaller threshold then we can expect to see this sensitivity towards this parameter decreasing, and perhaps would expect prcp_fac to lead the sensitivity here.
#
# Now looking at the standard deviation of the runoff over the course of a year:
#
# - **The melt_f**: We can now see, that when considering the variation of the runoff over the course of the year, the melt_f now has a slight positive correlation. So that as the melt_f increases (the amount of melt that occurs in melt periods), the variation in the runoff also increases. This makes sense if we consider that when the temperature is above the melt temp threshold, there is very limited melting, however as the temperature increases and melt occurs, the quantity of melt (and therefore runoff) is controlled by the melt_f. Therefore this exaggerates the melting in the melting periods, which will contribute to the variation of the runoff. The melt factor fluctuates with temperatures that occur, some years
#
# - **The prcp_f**: Now, there is very minimal correlation between the precipitation factor and the variation of the runoff across the year, this is likely due to the fact that the temperature bias is dominating here, and that the quantity of precipitation is not affecting the variation due to the fact that if the temperature is below the melting threshold then this does not contribute to the quantity of runoff. The prcp_fac does not dramatically change the rainfall from year to year, hence this will produce a minimal variation in our runoff. Changing the prcp_fac does not introduce new variability, only increases the baseline amount of rainfall.
#
# - **The temp_bias**: This parameter appears relatively similar to before, with a very tight correlation at negative temperature biases. This reduces the temperature, restricting the runoff and thus aligns with our expectations. As the temperature bias exceeds 0 and increases to a positive temperature bias, the correlation becomes a bit less tighly coupled, but there is still a clustering towards a positive correlation, this still affects the variation of runoff, as this raises the temperature uniformly, therefore potentially causing melt when there may not otherwise be. Again, the reason that this is so impactful on the standard deviation is likely due to the large range of temperature bias.

# %% [markdown]
# ## The relationship of temp_bias with the other parameters.
#
# After investigating the scatter plots and the tight correlations of temperature bias, we can assume this will be the dominating factor in our sensitivity analysis. We can investigate the relationship between the temp_bias and the other parameters on our plot with a colour mapping.

# %%
temp_bias_index = 2

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], YY_hydro[:, j], c=X[:, temp_bias_index], cmap='coolwarm', edgecolors='grey')
        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Temp Bias (°C)')
    plt.show()

interact(scatter_function, metric=Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %% [markdown]
# As we would expect, we can see the clustering towards both the mean and std of the runoff being 0 can be attributed to the extreme negative values of the temperature bias as this restricts the precipitation factor or the melt factor from impacting the runoff amount here.

# %% [markdown]
# # Quantitative sensitivity with bootstrapping

# %%
Nboot = 50 # Number of resamples used for bootstrapping
# Here fails when target is 0 for mean and std runoff, so we set small values instead

for i in range(2):
    if i==0:
        Y=YY_hydro[:,0]
        target=0.1
    if i==1:
        Y=YY_hydro[:,1]
        target=0.1

    # plot:
    plt.figure(figsize=[7,2])
    mvd, _, _, idx = RSA_tr.RSA_indices_thres(X, Y, target, Nboot=Nboot)
    mvd_m, mvd_lb, mvd_ub = aggregate_boot(mvd) # shape (M,)
    yerr=np.c_[mvd_m-mvd_lb,mvd_ub-mvd_m].T
    plt.bar(range(len(mvd_m)), mvd_m, color='grey',yerr=yerr)
    plt.title(Y_Labels[i], loc='center'), plt.xticks(range(len(mvd_m)), X_labels), plt.ylabel('Sensitivity')
    plt.show()

# %% [markdown]
# Now performing RSA with bootstrapping to quantify the sensitivity of our parameters to our output metrics and using bootstrapping to quantify the uncertainty here.
#
# As we expected, the sensitvity of the melt_f and prcp_fac paramaters is low and have a relatively large uncertainty compared to that of the temp_bias which is significantly the most impactful parameter with very minimal uncertainty.

# %% [markdown]
# It would be interesting here to reduce the range of the temperature bias to see if the sensitivity varies (we would expect the impact of the temp_bias to be reduced), and to try with an array of glaciers, mainly in High Mountain Asia. This glacier is within Austria, and observing an array of glacier could provide us with additional information about other glaciers.
