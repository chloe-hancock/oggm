# %% [markdown]
# # Investigating parameters effects on Sensitivity of the OGGM Mass Balance and Runoff Models

# %% [markdown]
# In this notebook we will explore the sensitivity of OGGM's mass-balance and runoff models using SAFE. We will focus on the three parameters: melt factor, precipitation factor and temperature bias.
#
# We will start by applying one-at-a-time sensitivity analysis to get a feel for how much each parameter affects the model and output. We will then consider the uncertainty of these sensitivities and work to quantify them.

# %% [markdown]
# ## Sensitivity Analysis with the OGGM Mass Balance Model

# %% [markdown]
# We will apply sensitivity analysis in the following order to investigate our model behaviour:
#
# 1. **One-at-a-time**: We will apply one-at-a-time analysis , in which we change one parameter at a time and see how the mass balance changes in accordance. To show this, we will plot an interactive mass balance time series with toggles, where the parameter values can be changed within their default boundaries.
# 2. **Global sensitivity analysis**: Here we will use AAT sampling to randomly sample a combination of the 3 parameters and investigate the sensitivity in the following ways
#     a. Qualitative - scatter plots
#     b. Quantitative - RSA and bootstrapping
#
# This will be applied first to the mass balance model in the OGGM, and then to the runoff model in the OGGM.

# %% [markdown]
# First we install the packages we require from both OGGM and SAFE.

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import scipy.stats as st

import oggm
from oggm import cfg, utils, workflow
from oggm.core import massbalance
from oggm.utils._funcs import rmsd
from oggm import tasks

# Install python package for interactive visualisation and import required functions:
# %pip install -q ipywidgets
from ipywidgets import interact, fixed

# Install SAFE package and import required functions
# %pip install SAFEpython

import xarray as xr
import safepython.PAWN as PAWN # Module to calculate PAWN sensitivity indices
import safepython.RSA_thres as RSA_tr # Module that implements RSA
from safepython.model_execution import model_execution # Module to execute the model
from safepython.sampling import AAT_sampling # Functions to perform the input sampling
from safepython.util import aggregate_boot # Functions to perform bootstrapping
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: SAFEpython in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: matplotlib>=2.2.3 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (3.10.6)
# Requirement already satisfied: numpy>=1.19.2 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (1.26.4)
# Requirement already satisfied: scipy>=1.3.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (25.0)
# Requirement already satisfied: pillow>=8 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->SAFEpython) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now prepare to load the glacier dierectories from the OGGM.

# %%
cfg.initialize(logging_level='WARNING')
cfg.PATHS['working_dir'] = utils.gettempdir(dirname='OGGM-calib-ro', reset=True)
cfg.PARAMS['border'] = 10
cfg.PARAMS['store_model_geometry'] = True
oggm.cfg.PARAMS['min_ice_thick_for_length'] = 1  # a glacier is when ice thicker than 1m
# Out:
# 2026-01-15 16:01:27: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2026-01-15 16:01:27: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2026-01-15 16:01:27: oggm.cfg: Multiprocessing: using all available processors (N=22)
# 2026-01-15 16:01:28: oggm.cfg: PARAMS['border'] changed from `80` to `10`.
# 2026-01-15 16:01:28: oggm.cfg: PARAMS['store_model_geometry'] changed from `False` to `True`.
# 2026-01-15 16:01:28: oggm.cfg: PARAMS['min_ice_thick_for_length'] changed from `0.0` to `1`.

# %% [markdown]
# We start from a well known glacier in the Austrian Alps, Hintereisferner. But you can choose any other glacier, e.g. from [this list](https://github.com/OGGM/oggm-sample-data/blob/master/wgms/rgi_wgms_links_20220112.csv)

# %%
# Hintereisferner
rgi_id = 'RGI60-11.00897'

# We pick the elevation-bands glaciers because they run a bit faster - but they create more step changes in the area outputs
base_url = 'https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/L3-L5_files/2023.3/elev_bands/W5E5_spinup'
gdir_hef = workflow.init_glacier_directories([rgi_id], from_prepro_level=4, prepro_border=160, prepro_base_url=base_url)[0]
# Out:
# 2026-01-15 16:01:32: oggm.workflow: init_glacier_directories from prepro level 4 on 1 glaciers.
# 2026-01-15 16:01:33: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers

# %%
# Get the observed mass balance and set up dataframe
mbdf = gdir_hef.get_ref_mb_data().loc[2000:2019] # WGMS data for HEF
mbdf['in_situ_mb'] = gdir_hef.get_ref_mb_data().loc[2000:2019]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

# %% [markdown]
# # 1 - One-at-a-time Sensitivity Analysis

# %% [markdown]
# We have loaded all required packages, so now we need to create a runner for the OGGM. To do this, we will set the 3 mass balance parameters to some tentative values, run the model and plot the resulting runoff timeseries. We can then change the parameter values one-at-a-time and look at how this changes the model predictions.
#
# Since we have WGMS observed data here, we will use some fit-to-data metrics to compare the difference in mean, standard deviation and RMSD between the simulated and observed mass balance values.

# %%
# TODO: Make more generic and add docstring
def oggm_sim(sample_row, gdir, run_with_hydro=False, years=range(2000,2020)): # set years here for example
    
    # Get the observed mass balance and set up dataframe TODO: Edit this, not sure it makes sense to set this up like this here
    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    
    # Set the parameter values
    melt_f, prcp_fac, temp_bias = sample_row
    cfg.PARAMS['melt_f'] = float(melt_f)
    cfg.PARAMS['prcp_fac'] = float(prcp_fac)
    cfg.PARAMS['temp_bias'] = float(temp_bias)

    if run_with_hydro == False:
        # Running the model with the given parameters (without calibration which would alter them again)
        mbmod = massbalance.MonthlyTIModel(gdir, melt_f=melt_f, prcp_fac=prcp_fac, temp_bias=temp_bias)
        fls = gdir.read_pickle('inversion_flowlines') # Read flowlines
        mbdf['mod_mb'] = mbmod.get_specific_mb(fls=fls, year=mbdf.index) # Compute modelled mass balance  

        return np.array(mbdf['mod_mb'])

    else: # If the run_with_hydro flag is set to true, generate the hydrological data and calculate the runoff
        gdir.settings['error_when_glacier_reaches_boundaries'] = False # TODO- When more realistic, I assume we will not need this?
        
        # Setting the parameters in the glacier directory settings, run_with_hydro is a higher level function that reads them from there
        gdir.settings['melt_f'] = float(melt_f) 
        gdir.settings['prcp_fac'] = float(prcp_fac)
        gdir.settings['temp_bias'] = float(temp_bias)
    
        # file identifier where the model output is saved
        # Create unique file identifier based on parameters
        file_id = f'_hydro_mf{melt_f:.2f}_pf{prcp_fac:.2f}_tb{temp_bias:.2f}'
    
        # Delete old file if it exists to force recomputation
        old_file = gdir.get_filepath('model_diagnostics', filesuffix=file_id)
        if os.path.exists(old_file):
            os.remove(old_file)
    
        # TODO: Check relationship between run_With_hydro and mass balance
        # We are using the task run_with_hydro to store hydrological outputs along with the usual glaciological outputs
        tasks.run_with_hydro(gdir,  # Run on the selected glacier
                         run_task=tasks.run_from_climate_data,  # which climate scenario? See following notebook for other examples
                         ys=years[0],  # Period which we will average and constantly repeat
                         init_model_filesuffix='_spinup_historical',  # use the previous run as initial state
                         init_model_yr=years[0],  # Start from spinup year 2000
                         store_monthly_hydro=True,  # Monthly ouptuts provide additional information
                         output_filesuffix=file_id);  # an identifier for the output file, to read it later
    
        with xr.open_dataset(gdir.get_filepath('model_diagnostics', filesuffix=file_id)) as ds:
            # The last step of hydrological output is NaN (we can't compute it for this year)
            ds = ds.isel(time=slice(0, -1)).load()
    
        sel_vars = [v for v in ds.variables if 'month_2d' not in ds[v].dims]
        df_annual = ds[sel_vars].to_dataframe()
    
        # These summed variabels give the total runoff from the glacier
        runoff_vars = ['melt_off_glacier', 'melt_on_glacier','liq_prcp_off_glacier', 'liq_prcp_on_glacier']
    
        # Convert them to megatonnes (instead of kg)
        df_runoff = df_annual[runoff_vars] * 1e-9
    
        runoff = np.array(df_runoff.sum(axis=1))
    
        return runoff

# %%
def output_metric_calculator(sim, gdir, years=range(2000,2020)):
    
    # Get the observed mass balance and set up dataframe
    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    mbdf['in_situ_mb'] = gdir.get_ref_mb_data().loc[years]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

    # Calculates the goodness-of-fit metrics for all model simulations compared to the in-situ mass balance
    YY = np.zeros((sim.shape[0], 3))

    for i in range(sim.shape[0]):
        # Calculate the goodness-of-fit metrics from the simulated mass balance and the in-situ mass balance
        YY[i, 0] = np.array(sim[i].mean() - mbdf['in_situ_mb'].mean()) # Calculate mean difference
        YY[i, 1] = np.array(sim[i].std() - mbdf['in_situ_mb'].std()) # Calculate standard deviation difference
        YY[i, 2] = np.array(rmsd(sim[i], mbdf['in_situ_mb'])) # Calculate RMSD

    return YY

# %% [markdown]
# We will now plot our results, the parameter values can be changed one-at-a-time via a toggle on the graph below.

# %%
# Define interactive visualisation function to set the parameters to some tentative values, 
# run the model and plot the resulting runoff time series
def oat_function(gdir, years, melt_f = 5.0, prcp_fac = 3.4, temp_bias = 0.0):
    # Create parameter array
    param = np.array([melt_f, prcp_fac, temp_bias])
    
    # Get the observed mass balance and set up dataframe
    mbdf = gdir.get_ref_mb_data().loc[years] # WGMS data for HEF
    mbdf['in_situ_mb'] = gdir.get_ref_mb_data().loc[years]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

    # Run the model with the given parameters, here we are interested in the modelled mass balance time series
    mb = oggm_sim(param, gdir)

    # Plot the results
    plt.figure(figsize=[15,3])
    plt.plot(mbdf['in_situ_mb'].index, mb, label='sim', color='k')
    mbdf['in_situ_mb'] = gdir_hef.get_ref_mb_data().loc[years]['ANNUAL_BALANCE']
    plt.plot(mbdf['in_situ_mb'], color=[0.7,0.7,0.7], label='obs')
    plt.ylabel('Specific mass balance (mm w.e.)')
    plt.xlabel('Year')
    plt.legend()
    plt.show();

# Create interactive plot, the toggles will change the parameter values 
interact(oat_function,
         gdir = fixed(gdir_hef),
         years = fixed(range(2000,2020)),
         melt_f = (1.5, 17.0, 0.1),
         prcp_fac = (0.1, 10.0, 0.1),
         temp_bias = (-15.0, 15.0, 0.1));
# Out:
# interactive(children=(FloatSlider(value=5.0, description='melt_f', max=17.0, min=1.5), FloatSlider(value=3.4, …

# %% [markdown]
# The above graph shows the effects that moving each of the parameters has to the mass balance time series.

# %% [markdown]
# # GSA - Global Sensitvity Analysis

# %% [markdown]
# We will now explore the sensitivity with a global sensitivity analysis. We will create a runner for the OGGM that calculates the mass balance values based off of the parameters sampled. We will be using AAT Sampling from SAFE to perform global sampling.
#
# This method will be creating Monte Carlo Simulations, we will plot the mass balance time series resulting from the Monte Carlo simulations and analyse the results.

# %% [markdown]
# ### Running Monte Carlo Simulations

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)

distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 0.1, -15.0]) # Minimum values for each parameter
x_max = np.array([17.0, 10.0, 15.0]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
    
samp_strat = 'lhs' 

N = 2000 # Number of samples
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

sim = model_execution(oggm_sim, X, gdir_hef, ExtraArgOut=True) # Execute the model for all samples
# Out:
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['melt_f'] changed from `10.750805310521052` to `2.854998341137103`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['prcp_fac'] changed from `5.8238951802508545` to `6.25596689167981`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['temp_bias'] changed from `-2.4934203836587017` to `-11.874479471754888`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['melt_f'] changed from `2.854998341137103` to `2.738812080849866`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['prcp_fac'] changed from `6.25596689167981` to `6.032978824530155`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['temp_bias'] changed from `-11.874479471754888` to `5.417559795735375`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['melt_f'] changed from `2.738812080849866` to `10.131395421222386`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['prcp_fac'] changed from `6.032978824530155` to `3.519013866355712`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['temp_bias'] changed from `5.417559795735375` to `-4.185424689449327`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['melt_f'] changed from `10.131395421222386` to `5.8999684029545`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['prcp_fac'] changed from `3.519013866355712` to `1.0346800212667537`.
# 2026-01-15 16:18:14: oggm.cfg: PARAMS['temp_bias'] changed from `-4.185424689449327` to `14.118819210013577`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `5.8999684029545` to `12.062624719365994`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0346800212667537` to `1.9734832293750606`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `14.118819210013577` to `13.36056584898514`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `12.062624719365994` to `14.250981259745407`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9734832293750606` to `9.621895977284614`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `13.36056584898514` to `-0.5710507772113917`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `14.250981259745407` to `8.191165244027655`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `9.621895977284614` to `5.4198649471965785`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `-0.5710507772113917` to `9.953470128961179`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `8.191165244027655` to `16.003692882387124`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `5.4198649471965785` to `3.1275073428697517`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `9.953470128961179` to `14.731467829486824`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `16.003692882387124` to `15.590260835872842`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1275073428697517` to `7.0505779420556784`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `14.731467829486824` to `14.307825617980093`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `15.590260835872842` to `5.166672552062494`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `7.0505779420556784` to `4.3990994203381915`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `14.307825617980093` to `2.8403344560535793`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `5.166672552062494` to `3.2090864090799913`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `4.3990994203381915` to `8.341402113720044`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `2.8403344560535793` to `0.2985108551523439`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `3.2090864090799913` to `3.1180469240984494`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `8.341402113720044` to `1.549473262953916`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `0.2985108551523439` to `-10.46374334283109`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `3.1180469240984494` to `14.7745236148994`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `1.549473262953916` to `2.1457381305426764`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `-10.46374334283109` to `1.6160627004954193`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `14.7745236148994` to `10.538212104773027`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `2.1457381305426764` to `2.5649152807998434`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `1.6160627004954193` to `-9.444048312864027`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `10.538212104773027` to `15.270749791285873`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5649152807998434` to `9.227911797325167`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `-9.444048312864027` to `-3.9687035029239013`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `15.270749791285873` to `6.77828477223401`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `9.227911797325167` to `4.808785937953753`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `-3.9687035029239013` to `5.4592163253818455`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `6.77828477223401` to `11.628537172831669`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `4.808785937953753` to `9.912155652927446`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `5.4592163253818455` to `-9.180312083562395`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `11.628537172831669` to `16.25929848073894`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `9.912155652927446` to `7.464266487613183`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `-9.180312083562395` to `-13.448022279729681`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `16.25929848073894` to `6.309060364197658`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `7.464266487613183` to `0.9068421934473363`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `-13.448022279729681` to `2.6824893978611364`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `6.309060364197658` to `6.296878853987943`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9068421934473363` to `0.5464393161961217`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `2.6824893978611364` to `-7.81291988516683`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `6.296878853987943` to `7.317105996521057`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5464393161961217` to `8.214770783554183`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `-7.81291988516683` to `13.21018584051054`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['melt_f'] changed from `7.317105996521057` to `9.709433991371078`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['prcp_fac'] changed from `8.214770783554183` to `0.479374590905301`.
# 2026-01-15 16:18:15: oggm.cfg: PARAMS['temp_bias'] changed from `13.21018584051054` to `1.3656429450547023`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `9.709433991371078` to `10.026169302325371`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `0.479374590905301` to `6.60789614762154`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `1.3656429450547023` to `-6.625586578173051`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `10.026169302325371` to `15.52115039708073`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `6.60789614762154` to `0.8576846469319761`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-6.625586578173051` to `-13.76145556956427`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `15.52115039708073` to `4.26572897241153`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8576846469319761` to `5.472609939431709`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-13.76145556956427` to `3.159513145417094`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `4.26572897241153` to `15.171299328569543`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `5.472609939431709` to `0.33654324916260103`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `3.159513145417094` to `-0.09882250715952168`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `15.171299328569543` to `14.264026732030608`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `0.33654324916260103` to `8.350708643678916`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-0.09882250715952168` to `9.077109799099443`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `14.264026732030608` to `10.58469399185264`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `8.350708643678916` to `4.593738486496298`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `9.077109799099443` to `-5.500217529226486`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `10.58469399185264` to `1.8316396163571493`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `4.593738486496298` to `4.874742873180084`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-5.500217529226486` to `7.746010586079059`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `1.8316396163571493` to `14.132537720165981`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `4.874742873180084` to `4.962282921847552`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `7.746010586079059` to `-10.034792847168852`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `14.132537720165981` to `8.27242977984191`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `4.962282921847552` to `3.1096704478582775`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-10.034792847168852` to `-9.245516701559769`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `8.27242977984191` to `12.42502134589628`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1096704478582775` to `1.838601226120665`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-9.245516701559769` to `5.805680152782436`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `12.42502134589628` to `8.198419848427328`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `1.838601226120665` to `0.9975845170933236`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `5.805680152782436` to `8.22669240943005`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `8.198419848427328` to `1.698069177066971`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9975845170933236` to `2.0543792382071095`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `8.22669240943005` to `11.954499441378822`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `1.698069177066971` to `14.45182033625038`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0543792382071095` to `6.8712968708354545`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `11.954499441378822` to `0.48722156778482884`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `14.45182033625038` to `5.87816450375251`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `6.8712968708354545` to `3.6799957828501157`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `0.48722156778482884` to `12.350791604577445`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `5.87816450375251` to `9.091334329506576`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6799957828501157` to `9.112087983373577`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `12.350791604577445` to `-0.7669823424400537`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `9.091334329506576` to `8.59137701448729`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `9.112087983373577` to `3.6345225175874583`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-0.7669823424400537` to `-14.27434599251881`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `8.59137701448729` to `14.892745965207173`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6345225175874583` to `6.139144874140782`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-14.27434599251881` to `-13.549706486379037`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `14.892745965207173` to `8.981001513944298`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `6.139144874140782` to `1.8689975181568896`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-13.549706486379037` to `-13.877880150855555`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `8.981001513944298` to `11.63931414868056`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8689975181568896` to `1.8786694360075615`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-13.877880150855555` to `-2.576879468002268`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `11.63931414868056` to `6.91782757011523`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8786694360075615` to `5.813960015711281`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-2.576879468002268` to `-14.477974692011808`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `6.91782757011523` to `11.747909853575598`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `5.813960015711281` to `3.1839679091348305`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-14.477974692011808` to `-7.744542972992202`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `11.747909853575598` to `13.757247326370274`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1839679091348305` to `4.774009024695335`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-7.744542972992202` to `-14.034558144687011`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `13.757247326370274` to `14.153077432058456`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `4.774009024695335` to `8.68943435146603`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `-14.034558144687011` to `2.073881670129097`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['melt_f'] changed from `14.153077432058456` to `11.215339715316604`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['prcp_fac'] changed from `8.68943435146603` to `6.451335134816313`.
# 2026-01-15 16:18:16: oggm.cfg: PARAMS['temp_bias'] changed from `2.073881670129097` to `-2.5965466178233036`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `11.215339715316604` to `15.15408358218478`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `6.451335134816313` to `7.93526656155714`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-2.5965466178233036` to `-14.82419235614962`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `15.15408358218478` to `15.990819424450697`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `7.93526656155714` to `6.851233638416018`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-14.82419235614962` to `4.538869167572091`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `15.990819424450697` to `2.4174616865172904`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `6.851233638416018` to `5.987501099421613`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `4.538869167572091` to `8.804403848231615`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `2.4174616865172904` to `5.179136680186181`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `5.987501099421613` to `3.453368732700543`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `8.804403848231615` to `9.136645846880604`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `5.179136680186181` to `3.9383406881253302`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `3.453368732700543` to `8.377268931817996`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `9.136645846880604` to `3.5870271331456536`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `3.9383406881253302` to `15.008660438371916`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `8.377268931817996` to `6.85818829648247`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `3.5870271331456536` to `-3.9571310805145856`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `15.008660438371916` to `7.251624297506643`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `6.85818829648247` to `3.2846217978709533`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-3.9571310805145856` to `-10.92549435885864`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `7.251624297506643` to `7.544626879513845`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `3.2846217978709533` to `8.4896633129026`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-10.92549435885864` to `-5.730871855330101`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `7.544626879513845` to `8.963369864122857`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `8.4896633129026` to `3.405663498112895`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-5.730871855330101` to `1.10373366632804`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `8.963369864122857` to `9.004900479906873`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `3.405663498112895` to `4.560052010738918`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `1.10373366632804` to `-12.377415172912578`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `9.004900479906873` to `6.845287873554232`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `4.560052010738918` to `4.724070445173017`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-12.377415172912578` to `-2.4466848861657304`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `6.845287873554232` to `16.451760029533453`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `4.724070445173017` to `8.07237383201863`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-2.4466848861657304` to `4.839873424471854`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `16.451760029533453` to `7.609092910536332`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `8.07237383201863` to `1.4399048363659863`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `4.839873424471854` to `13.093112993550868`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `7.609092910536332` to `4.944944742548692`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4399048363659863` to `2.9117639045792254`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `13.093112993550868` to `-2.2799869168703335`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `4.944944742548692` to `10.617337808608736`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.9117639045792254` to `1.460664060890848`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-2.2799869168703335` to `-5.185746344340652`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `10.617337808608736` to `6.939929904489793`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `1.460664060890848` to `2.0045211748831573`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-5.185746344340652` to `-8.848148287715777`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `6.939929904489793` to `9.095249269297014`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0045211748831573` to `2.60866009312233`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-8.848148287715777` to `-10.529581775154483`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `9.095249269297014` to `7.194453181541705`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.60866009312233` to `2.390266635574811`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-10.529581775154483` to `-4.730736395316864`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `7.194453181541705` to `15.552605488787366`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.390266635574811` to `5.1014409135205945`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-4.730736395316864` to `-6.070426948648647`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `15.552605488787366` to `7.399221312962771`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `5.1014409135205945` to `8.866985837710933`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `-6.070426948648647` to `12.789491646636975`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `7.399221312962771` to `5.543866971603725`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `8.866985837710933` to `3.3341327200716435`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `12.789491646636975` to `3.71330818523246`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `5.543866971603725` to `6.894360369777926`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `3.3341327200716435` to `4.064070700746027`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `3.71330818523246` to `13.036569531821069`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['melt_f'] changed from `6.894360369777926` to `2.2963801493249205`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['prcp_fac'] changed from `4.064070700746027` to `2.663146336078077`.
# 2026-01-15 16:18:17: oggm.cfg: PARAMS['temp_bias'] changed from `13.036569531821069` to `8.440984952463108`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `2.2963801493249205` to `2.905171647009877`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `2.663146336078077` to `6.59182736586526`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `8.440984952463108` to `-10.453098324800013`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `2.905171647009877` to `5.608724186406005`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `6.59182736586526` to `1.1065347393650529`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-10.453098324800013` to `7.86263866526107`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `5.608724186406005` to `14.704148164138818`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1065347393650529` to `6.768149842592997`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `7.86263866526107` to `9.103193639098624`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `14.704148164138818` to `6.0359341625561145`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `6.768149842592997` to `8.729564467957275`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `9.103193639098624` to `-1.089683234522159`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `6.0359341625561145` to `6.93029943709914`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `8.729564467957275` to `5.561844533643553`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-1.089683234522159` to `4.378763865437442`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `6.93029943709914` to `12.566374423599536`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `5.561844533643553` to `8.373053712452702`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `4.378763865437442` to `-4.83679585702639`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `12.566374423599536` to `14.079105044655574`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `8.373053712452702` to `0.6497739204604971`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-4.83679585702639` to `-7.319857317218394`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `14.079105044655574` to `3.564341946944726`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6497739204604971` to `9.416073574009912`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-7.319857317218394` to `5.208546940495278`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `3.564341946944726` to `3.3620914509077044`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `9.416073574009912` to `8.805545462296525`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `5.208546940495278` to `7.728059669742748`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `3.3620914509077044` to `10.411573023849936`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `8.805545462296525` to `0.8348994801975891`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `7.728059669742748` to `-4.783186920177048`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `10.411573023849936` to `12.954972896024033`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8348994801975891` to `9.804574770819082`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-4.783186920177048` to `-5.3212855257763625`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `12.954972896024033` to `15.404634569800056`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `9.804574770819082` to `5.094453891837721`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-5.3212855257763625` to `-14.193951252423425`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `15.404634569800056` to `7.964485442062338`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `5.094453891837721` to `0.22205387917262948`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-14.193951252423425` to `-3.561825703246397`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `7.964485442062338` to `4.234215033829397`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `0.22205387917262948` to `4.120543786476041`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-3.561825703246397` to `-14.922006556482424`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `4.234215033829397` to `6.377916905305764`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `4.120543786476041` to `4.1975179301901955`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-14.922006556482424` to `5.072276449933774`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `6.377916905305764` to `16.879156317281925`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `4.1975179301901955` to `6.540667445113364`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `5.072276449933774` to `-3.1175919880533502`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `16.879156317281925` to `11.547813504763559`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `6.540667445113364` to `7.429791973786905`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-3.1175919880533502` to `-12.830320972563886`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `11.547813504763559` to `9.151864574532294`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `7.429791973786905` to `3.391833842534654`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-12.830320972563886` to `-13.263786716022524`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `9.151864574532294` to `4.813576736046665`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `3.391833842534654` to `1.3431697641391827`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-13.263786716022524` to `11.976192290003993`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `4.813576736046665` to `7.685086126809744`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3431697641391827` to `9.340816285905579`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `11.976192290003993` to `6.843035720154841`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `7.685086126809744` to `12.327199652326986`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `9.340816285905579` to `7.765175523549019`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `6.843035720154841` to `10.312557560769452`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `12.327199652326986` to `6.245732125024107`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `7.765175523549019` to `8.127283184463003`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `10.312557560769452` to `-5.385157317817534`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['melt_f'] changed from `6.245732125024107` to `5.290839876509873`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['prcp_fac'] changed from `8.127283184463003` to `8.961657767827985`.
# 2026-01-15 16:18:18: oggm.cfg: PARAMS['temp_bias'] changed from `-5.385157317817534` to `-6.075742273437127`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `5.290839876509873` to `2.218024447756406`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `8.961657767827985` to `7.122021787711209`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-6.075742273437127` to `-9.265827314689071`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `2.218024447756406` to `12.232143412826801`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `7.122021787711209` to `5.437147770992629`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-9.265827314689071` to `5.553408816065826`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `12.232143412826801` to `7.365139502572218`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `5.437147770992629` to `4.270254701924438`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `5.553408816065826` to `-10.403535534720303`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `7.365139502572218` to `8.86046133462634`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `4.270254701924438` to `1.3311494856703776`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-10.403535534720303` to `14.685387852860224`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `8.86046133462634` to `5.125246602257972`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3311494856703776` to `3.228089595817325`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `14.685387852860224` to `-11.65877978061651`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `5.125246602257972` to `8.699588617353974`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `3.228089595817325` to `4.24159571023001`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-11.65877978061651` to `-3.285002776984765`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `8.699588617353974` to `9.436448797432268`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `4.24159571023001` to `7.151709473744458`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-3.285002776984765` to `-6.488550828437155`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `9.436448797432268` to `10.683021670258212`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `7.151709473744458` to `4.766784543785629`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-6.488550828437155` to `-11.226724706502528`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `10.683021670258212` to `6.885752952414529`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `4.766784543785629` to `6.456772188941065`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-11.226724706502528` to `-13.05496105969324`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `6.885752952414529` to `1.5599379068339478`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `6.456772188941065` to `0.17833441378693213`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-13.05496105969324` to `-6.475920462573855`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `1.5599379068339478` to `10.11410051678315`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `0.17833441378693213` to `7.022507571308004`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-6.475920462573855` to `-6.614380962736343`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `10.11410051678315` to `3.981666440482973`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `7.022507571308004` to `6.068304577341956`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-6.614380962736343` to `1.632200558014386`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `3.981666440482973` to `13.974426337454105`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `6.068304577341956` to `3.4590208060556673`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `1.632200558014386` to `-3.0526234150802427`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `13.974426337454105` to `11.86947289545121`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `3.4590208060556673` to `2.289566770354205`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-3.0526234150802427` to `-13.098952453872448`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `11.86947289545121` to `9.164478231328799`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `2.289566770354205` to `2.691322068737513`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-13.098952453872448` to `13.824143027104775`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `9.164478231328799` to `15.077407844041746`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `2.691322068737513` to `0.7712126543340987`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `13.824143027104775` to `11.543149528970666`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `15.077407844041746` to `13.789919494391043`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7712126543340987` to `3.834737674021851`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `11.543149528970666` to `-2.3614005076075326`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `13.789919494391043` to `7.722141465220473`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `3.834737674021851` to `3.465989875208088`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-2.3614005076075326` to `-3.7782868845743636`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `7.722141465220473` to `16.98498198417804`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `3.465989875208088` to `5.16322038483077`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-3.7782868845743636` to `11.837148999570111`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `16.98498198417804` to `16.502564011061835`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `5.16322038483077` to `2.397400801667903`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `11.837148999570111` to `2.740245676408815`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `16.502564011061835` to `2.435675435397667`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `2.397400801667903` to `1.9346676137670173`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `2.740245676408815` to `-2.813355570980132`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['melt_f'] changed from `2.435675435397667` to `15.652874485319938`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9346676137670173` to `8.041986068235925`.
# 2026-01-15 16:18:19: oggm.cfg: PARAMS['temp_bias'] changed from `-2.813355570980132` to `3.3945411381552795`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `15.652874485319938` to `7.489607462345949`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `8.041986068235925` to `1.0548568877851134`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `3.3945411381552795` to `-10.8165064187456`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `7.489607462345949` to `7.291334904515184`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0548568877851134` to `5.868886808435961`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-10.8165064187456` to `5.988072513051591`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `7.291334904515184` to `11.19915408805746`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `5.868886808435961` to `4.539985592573675`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `5.988072513051591` to `5.499901329311424`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `11.19915408805746` to `10.056091571926405`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `4.539985592573675` to `2.830513666526358`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `5.499901329311424` to `12.721284598663889`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `10.056091571926405` to `4.289595015033941`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `2.830513666526358` to `1.2134388632044077`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `12.721284598663889` to `-6.985246822125923`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `4.289595015033941` to `3.514374081900092`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2134388632044077` to `6.331346682212582`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-6.985246822125923` to `13.064309407916596`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `3.514374081900092` to `2.039117949388492`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `6.331346682212582` to `0.41783392577575407`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `13.064309407916596` to `6.459722420108978`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `2.039117949388492` to `3.3090327377338262`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `0.41783392577575407` to `7.710711793504124`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `6.459722420108978` to `6.771013557250956`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `3.3090327377338262` to `12.015512923895526`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `7.710711793504124` to `9.344410114793865`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `6.771013557250956` to `9.915009155243332`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `12.015512923895526` to `5.73577137127027`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `9.344410114793865` to `8.769145113486667`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `9.915009155243332` to `-14.124069935641403`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `5.73577137127027` to `15.589091944119904`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `8.769145113486667` to `9.71867298990035`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-14.124069935641403` to `0.5835928231104646`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `15.589091944119904` to `5.26984859592161`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `9.71867298990035` to `6.010810630561544`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `0.5835928231104646` to `-3.2192714354219607`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `5.26984859592161` to `3.6948064386778565`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `6.010810630561544` to `7.85827925247785`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-3.2192714354219607` to `8.103811579601256`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `3.6948064386778565` to `5.430324999809287`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `7.85827925247785` to `3.4362140921984956`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `8.103811579601256` to `14.54624158069317`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `5.430324999809287` to `5.686662305404152`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `3.4362140921984956` to `4.532028236556817`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `14.54624158069317` to `-0.46303348756315543`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `5.686662305404152` to `4.192143749679671`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `4.532028236556817` to `5.3060512643433695`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-0.46303348756315543` to `-4.950258244917896`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `4.192143749679671` to `11.880459197230564`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `5.3060512643433695` to `9.288521981261336`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-4.950258244917896` to `-3.8875581280916425`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `11.880459197230564` to `15.439585212600997`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `9.288521981261336` to `1.3878761641256474`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-3.8875581280916425` to `-6.648639997251051`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `15.439585212600997` to `14.33845132831563`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3878761641256474` to `9.876800801633882`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-6.648639997251051` to `-1.1081553781401041`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `14.33845132831563` to `14.718600447216666`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `9.876800801633882` to `5.426085750716686`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-1.1081553781401041` to `-5.53956915822674`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `14.718600447216666` to `7.158239340497843`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `5.426085750716686` to `4.813104004306617`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `-5.53956915822674` to `5.120966139151637`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['melt_f'] changed from `7.158239340497843` to `4.4420844375356685`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['prcp_fac'] changed from `4.813104004306617` to `3.9329581640791185`.
# 2026-01-15 16:18:20: oggm.cfg: PARAMS['temp_bias'] changed from `5.120966139151637` to `-12.976187891553982`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `4.4420844375356685` to `16.240894177573008`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `3.9329581640791185` to `1.0414426331450017`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `-12.976187891553982` to `-13.585863867452032`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `16.240894177573008` to `13.54948659551652`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0414426331450017` to `3.15233044786323`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `-13.585863867452032` to `-9.756990803201628`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `13.54948659551652` to `2.968228144261674`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `3.15233044786323` to `2.927028987574742`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `-9.756990803201628` to `1.4355438618656464`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `2.968228144261674` to `12.594963082985807`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `2.927028987574742` to `8.327728260962784`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `1.4355438618656464` to `-2.2074573385874317`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `12.594963082985807` to `14.692075211778329`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `8.327728260962784` to `1.7693622636107038`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `-2.2074573385874317` to `11.877931242226989`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `14.692075211778329` to `8.847860135043184`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7693622636107038` to `8.038327608254448`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `11.877931242226989` to `-3.086767926101299`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `8.847860135043184` to `2.074355524470814`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `8.038327608254448` to `3.0282726832850475`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `-3.086767926101299` to `-6.0229603928266915`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `2.074355524470814` to `13.336658296954463`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `3.0282726832850475` to `2.940682810672824`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `-6.0229603928266915` to `-9.691339608797845`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `13.336658296954463` to `7.107873484763702`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `2.940682810672824` to `4.753363038282836`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `-9.691339608797845` to `4.574201887515443`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `7.107873484763702` to `9.135380325708693`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `4.753363038282836` to `5.745582515987685`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `4.574201887515443` to `-4.298816263144596`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `9.135380325708693` to `11.24163409299843`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `5.745582515987685` to `2.0631240700119697`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `-4.298816263144596` to `12.070788243365953`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `11.24163409299843` to `12.831548788799989`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0631240700119697` to `8.017840748164978`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['temp_bias'] changed from `12.070788243365953` to `-3.6313121680558744`.
# 2026-01-15 16:18:21: oggm.cfg: PARAMS['melt_f'] changed from `12.831548788799989` to `10.601966608861156`.
# ...
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['temp_bias'] changed from `4.4056073143441665` to `-2.6432437096631105`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['melt_f'] changed from `7.617373973840175` to `4.367788057095443`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['prcp_fac'] changed from `6.785517171817463` to `4.6569991366650765`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['temp_bias'] changed from `-2.6432437096631105` to `12.933914388252823`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['melt_f'] changed from `4.367788057095443` to `11.448522733357743`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['prcp_fac'] changed from `4.6569991366650765` to `1.1101936781674941`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['temp_bias'] changed from `12.933914388252823` to `0.13155791104495407`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['melt_f'] changed from `11.448522733357743` to `16.388502247645185`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1101936781674941` to `3.450794733523321`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['temp_bias'] changed from `0.13155791104495407` to `-9.555287050948564`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['melt_f'] changed from `16.388502247645185` to `13.978894858056083`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['prcp_fac'] changed from `3.450794733523321` to `5.078329301864209`.
# 2026-01-15 16:19:47: oggm.cfg: PARAMS['temp_bias'] changed from `-9.555287050948564` to `-8.48270398278142`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `13.978894858056083` to `15.759832758737112`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `5.078329301864209` to `0.5927393814350669`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-8.48270398278142` to `-0.2163805055159571`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `15.759832758737112` to `4.772089022647351`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5927393814350669` to `7.770819243391388`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-0.2163805055159571` to `-1.8965508208902744`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `4.772089022647351` to `3.7883286883560756`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `7.770819243391388` to `6.366990299002257`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-1.8965508208902744` to `-0.7313361541341639`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `3.7883286883560756` to `9.841534256668`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `6.366990299002257` to `0.38669169997769004`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-0.7313361541341639` to `-10.571830407666411`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `9.841534256668` to `4.158886711039732`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `0.38669169997769004` to `6.625009501745373`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-10.571830407666411` to `-6.6796453739100645`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `4.158886711039732` to `6.031487864934973`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `6.625009501745373` to `6.152477050981823`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-6.6796453739100645` to `4.0222825004329685`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `6.031487864934973` to `11.730770489939081`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `6.152477050981823` to `3.3417846596332073`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `4.0222825004329685` to `5.165623006380837`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `11.730770489939081` to `2.691274166123943`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `3.3417846596332073` to `3.088501454694472`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `5.165623006380837` to `6.781073254610561`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `2.691274166123943` to `2.565231789980256`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `3.088501454694472` to `9.115533417055891`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `6.781073254610561` to `11.597224900375412`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `2.565231789980256` to `16.099047203410066`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `9.115533417055891` to `9.559808404502562`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `11.597224900375412` to `13.43638026390403`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `16.099047203410066` to `14.375580339080235`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `9.559808404502562` to `9.042008998957598`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `13.43638026390403` to `-12.096756932904658`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `14.375580339080235` to `12.379205841886861`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `9.042008998957598` to `7.588975338010702`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-12.096756932904658` to `-2.3538399706293998`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `12.379205841886861` to `11.259874499876423`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `7.588975338010702` to `9.144992757658617`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-2.3538399706293998` to `-2.3928491959539056`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `11.259874499876423` to `10.513790219250845`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `9.144992757658617` to `1.125141454086611`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-2.3928491959539056` to `4.592160678361793`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `10.513790219250845` to `7.768707052378569`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `1.125141454086611` to `2.5946531828052453`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `4.592160678361793` to `-0.9425659345852537`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `7.768707052378569` to `12.849625570064081`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5946531828052453` to `6.87639749232495`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-0.9425659345852537` to `-5.797904169075702`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `12.849625570064081` to `5.8551892752723`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `6.87639749232495` to `9.246988421896738`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `-5.797904169075702` to `13.313661762162823`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['melt_f'] changed from `5.8551892752723` to `2.912567645180464`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `9.246988421896738` to `9.364889589640745`.
# 2026-01-15 16:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `13.313661762162823` to `-12.118160138310905`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `2.912567645180464` to `14.858241918930016`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `9.364889589640745` to `4.910118999962918`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-12.118160138310905` to `7.705242205970521`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `14.858241918930016` to `6.399425275074606`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `4.910118999962918` to `7.914481906692621`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `7.705242205970521` to `-2.3738730519839812`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `6.399425275074606` to `8.653632413995908`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `7.914481906692621` to `6.985539899922484`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-2.3738730519839812` to `-3.2558852301790164`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `8.653632413995908` to `2.620066111176593`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `6.985539899922484` to `4.989175838523537`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-3.2558852301790164` to `-3.1035852864439004`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `2.620066111176593` to `1.5955178982553695`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `4.989175838523537` to `1.0571447391720667`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-3.1035852864439004` to `1.5953790462991897`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `1.5955178982553695` to `16.699444230784266`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0571447391720667` to `2.966915615877249`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `1.5953790462991897` to `-14.601703309513631`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `16.699444230784266` to `5.6021605737316875`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `2.966915615877249` to `6.564650284808768`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-14.601703309513631` to `3.6801179051255275`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `5.6021605737316875` to `11.979804368025261`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `6.564650284808768` to `4.190026423745742`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `3.6801179051255275` to `-14.53111300550376`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `11.979804368025261` to `2.7886335407494465`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `4.190026423745742` to `0.9615425148545647`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-14.53111300550376` to `8.384666693277591`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `2.7886335407494465` to `11.05689675769599`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9615425148545647` to `4.617483842246107`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `8.384666693277591` to `13.78135703003058`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `11.05689675769599` to `2.679702730705382`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `4.617483842246107` to `5.69594812970538`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `13.78135703003058` to `-8.10506999884527`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `2.679702730705382` to `9.180716170423175`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `5.69594812970538` to `7.167440216911593`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-8.10506999884527` to `-4.08187882221724`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `9.180716170423175` to `15.127350056620438`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `7.167440216911593` to `0.15853081935253738`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-4.08187882221724` to `13.274000458417213`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `15.127350056620438` to `3.7430528983302933`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `0.15853081935253738` to `6.064302437320294`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `13.274000458417213` to `12.755910802758763`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `3.7430528983302933` to `14.929449162895597`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `6.064302437320294` to `0.4873496604097812`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `12.755910802758763` to `0.9171581129463355`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `14.929449162895597` to `12.664138124375858`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4873496604097812` to `2.9922795230100765`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `0.9171581129463355` to `3.843360717390887`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `12.664138124375858` to `15.372277301022468`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `2.9922795230100765` to `8.13761344229966`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `3.843360717390887` to `8.49266938456665`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `15.372277301022468` to `6.112743948027921`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `8.13761344229966` to `3.4073337286994825`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `8.49266938456665` to `-7.398842815640779`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['melt_f'] changed from `6.112743948027921` to `14.108566968940634`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['prcp_fac'] changed from `3.4073337286994825` to `2.25800755424935`.
# 2026-01-15 16:19:49: oggm.cfg: PARAMS['temp_bias'] changed from `-7.398842815640779` to `-2.125038076936752`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['melt_f'] changed from `14.108566968940634` to `5.057558035348555`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `2.25800755424935` to `5.164202199094581`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `-2.125038076936752` to `-12.580641094538366`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['melt_f'] changed from `5.057558035348555` to `14.948028147702257`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `5.164202199094581` to `4.679336635224673`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `-12.580641094538366` to `-12.137837137224507`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['melt_f'] changed from `14.948028147702257` to `5.746190459202923`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `4.679336635224673` to `2.410171583031184`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `-12.137837137224507` to `-9.335057742762555`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['melt_f'] changed from `5.746190459202923` to `16.90193833402686`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `2.410171583031184` to `1.7166782453183342`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `-9.335057742762555` to `13.147640812513973`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['melt_f'] changed from `16.90193833402686` to `8.415422232676224`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7166782453183342` to `4.829331891012497`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `13.147640812513973` to `-2.4180326449990677`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['melt_f'] changed from `8.415422232676224` to `16.36572418937534`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `4.829331891012497` to `8.323076508497591`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `-2.4180326449990677` to `-1.4092493805375774`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['melt_f'] changed from `16.36572418937534` to `9.408158151337851`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `8.323076508497591` to `8.718434987949596`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `-1.4092493805375774` to `-2.2859807474174723`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['melt_f'] changed from `9.408158151337851` to `10.476108154216591`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `8.718434987949596` to `3.6519728315699775`.
# 2026-01-15 16:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `-2.2859807474174723` to `4.128491060926649`.

# %%
YY = output_metric_calculator(sim, gdir_hef) # Calculate the output metrics for all simulations

# %% [markdown]
# Plotting the Monte Carlo simulation results and comparison with the observed data.

# %%
# Plot Monte Carlo (MC) simulations results and compare with data:
plt.figure(figsize=[15,5])
plt.plot(mbdf['in_situ_mb'].index.values, np.transpose(sim), 'k', linewidth = 0.5)
plt.plot(mbdf['in_situ_mb'], color=[0.7,0.7,0.7], linewidth=2)
plt.ylabel('Mass Balance'); plt.xlabel('Years')
plt.legend(['sim', 'obs'])
plt.title("Number of parameter samples: N = %d" % N, loc='right')
plt.show()

# %% [markdown]
# We can see from the samples that the mass balance is greatly affected by altering the parameters between their given ranges. The lower mass balances seem to be more sparse, with a more significant clustering towards the higher mass-balances. The observed mass-balance is closer towards the higher mass-balance end of the spectrum, towards 0.

# %% [markdown]
# ### Scatter plot of the fit-to-data metrics

# %% [markdown]
# We will now plot a scatter plot of the fit-to-data metrics, this will show us the relationship between the metrics created from our Monte Carlo simulations.

# %%
plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(YY[:,0], YY[:,1], s=5), plt.title('Mean difference vs Std difference'), plt.xlabel('Mean difference (mm w.e.)'), plt.ylabel('Std difference (mm w.e.)'),
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.subplot(1,3,2), plt.scatter(YY[:,0], YY[:,2], s=5), plt.title('Mean difference vs RMSD'), plt.xlabel('Mean difference (mm w.e.)'), plt.ylabel('RMSD (mm w.e.)')
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.subplot(1,3,3), plt.scatter(YY[:,1], YY[:,2], s=5), plt.title('Std difference vs RMSD'), plt.xlabel('Std difference (mm w.e.)'), plt.ylabel('RMSD (mm w.e.)')
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.tight_layout()
plt.show()

# The red lines show the target of having zero differences in the mean, standard deviation and RMSD.
# TODO: Would absolute differences be better than the raw ones?

# %% [markdown]
# The red lines show the target values of our differences, ideally we would want our differences to be 0 and to match the observations as closely as possible.
#
# It can be seen here that all of our fit-to-data metrics are correlated.

# %% [markdown]
# ## Scatter plot for the parameters against the fit-to-data metrics

# %% [markdown]
# Now we can plot the scatter plots for each parameter against each metric, this will help visualise the sensitivities for the mass balance.

# %%
YY_Labels = ['Mean Difference', 'Std Difference', 'RMSD']

def scatter_function(metric='Mean Difference'):
    if metric == 'Mean Difference':
        j = 0
    elif metric == 'Std Difference':
        j = 1  
    elif metric == 'RMSD':
        j = 2
    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(YY_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = YY_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Difference', 'Std Difference', 'RMSD'), va…

# %% [markdown]
# ### Distribution of the model outputs

# %% [markdown]
# Now looking at the distribution of the model outputs, here this is the goodness-of-fit parameters.

# %%
Y_Labels = ['Mean difference (mm w.e.)', 'Std difference (mm w.e.)', 'RMSD (mm w.e.)', 'Mean & Std difference jointly']

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,0], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,1], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[1])

plt.subplot(1,3,3), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,2], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[2])

plt.tight_layout()

# %% [markdown]
# Looking at our distributions of the output samples, the distributions are as follows:
# 1. Mean difference: Skewed distribition with a long tail (negative skew)
# 2. Std difference: Normal distribution
# 3. RMSD: Skewed distribution with a long tail (positive skew)
#
# TODO: Does this mean we can use RSA vs PAWN?

# %% [markdown]
# # Calculating the Sensitivity Indices
#
# Now we use the input-output samples generated in the previous step to calculate sensitivity indices using **Regional Sensitivity Analysis**. Calculating 3 sets of indices, each measuring the relative importance of the 3 input parameters.

# %%
Nboot = 50 # Number of resamples used for bootstrapping

for i in range(3):
    if i==0:
        Y=YY[:,0]
        target=0
    if i==1:
        Y=YY[:,1]
        target=0
    if i==2:
        Y = YY[:,2]
        target = 500 # RMSD cannot be zero here? Minimum working number is around 550, minimum observed value is around 400.

    # plot:
    plt.figure(figsize=[7,2]) # TODO: Explain titles in more detail
    mvd, _, _, idx = RSA_tr.RSA_indices_thres(X, Y, target, Nboot=Nboot)
    mvd_m, mvd_lb, mvd_ub = aggregate_boot(mvd) # shape (M,)
    yerr=np.c_[mvd_m-mvd_lb,mvd_ub-mvd_m].T
    plt.bar(range(len(mvd_m)), mvd_m, color='grey',yerr=yerr)
    plt.title(Y_Labels[i], loc='center'), plt.xticks(range(len(mvd_m)), X_labels), plt.ylabel('Sensitivity')
    plt.show()

# %% [markdown]
# ## Extra Investigation: Relationship with temp_bias and other parameters to the fit-to-data outputs

# %% [markdown]
# Now checking, if the relationship with other parameters has been affected by the temp_bias, this is rather dominant in the differences of the mean. We can plot a colour map to check.

# %%
temp_bias_index = 2  # Index of temp_bias in X

YY_Labels = ['Mean Difference', 'Std Difference', 'RMSD']

def scatter_function(metric='Mean Difference'):
    if metric == 'Mean Difference':
        j = 0
    elif metric == 'Std Difference':
        j = 1  
    elif metric == 'RMSD':
        j = 2

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], YY[:, j], c=X[:, temp_bias_index], cmap='coolwarm', edgecolors='grey')
        
        if i == 0:
            plt.ylabel(YY_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Temp Bias (°C)')
    plt.show()

interact(scatter_function, metric=YY_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Difference', 'Std Difference', 'RMSD'), va…

# %% [markdown]
# # Hydrological Response Metrics - Performance Metrics

# %% [markdown]
# Now looking at the hydrological response metrics we have avaliable in the OGGM, mean of runoff and mean of volume.

# %% [markdown]
# ## One-at-a-time Sensitivity Analysis

# %%
# Define interactive visualisation function to set the parameters to some tentative values, 
# run the model and plot the resulting runoff time series

def oat_hydro_function(gdir, melt_f = 5.0, prcp_fac = 3.4, temp_bias = 0.0):
    # Create parameter array
    param = np.array([melt_f, prcp_fac, temp_bias])
    
    # Run the model with the given parameters, here we are interested in the modelled mass balance time series
    runoff = oggm_sim(param, gdir, True)
    # Plot the results
    plt.figure(figsize=[15,3])
    plt.plot(mbdf.index.values, runoff)
    plt.ylabel('Runoff (Mt)')
    plt.xlabel('Year')
    plt.legend()

# Create interactive plot, the toggles will change the parameter values 
interact(oat_hydro_function,
         gdir = fixed(gdir_hef),
         melt_f = (1.5, 17.0, 0.1),
         prcp_fac = (0.1, 10.0, 0.1),
         temp_bias = (-15.0, 15.0, 0.1));
# Out:
# interactive(children=(FloatSlider(value=5.0, description='melt_f', max=17.0, min=1.5), FloatSlider(value=3.4, …

# %% [markdown]
# # GSA - Global Sensitivity Analysis

# %% [markdown]
# ### Running Monte Carlo Simulations

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)
distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 0.1, -15.0]) # Minimum values for each parameter
x_max = np.array([17.0, 10.0, 15.0]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
samp_strat = 'lhs' 
N = 1000 # Was 2000, TODO- change back to 2000? 1000 takes around 11 mins to run
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

# %%
runoff  = model_execution(oggm_sim, X, gdir_hef, True) # Execute the model for all samples - note: takes around 5-10 mins with N=1000
# Out:
# 2026-01-15 17:18:54: oggm.cfg: PARAMS['melt_f'] changed from `10.365541257457362` to `9.103411924025504`.
# 2026-01-15 17:18:54: oggm.cfg: PARAMS['prcp_fac'] changed from `2.037468812879952` to `8.773045704341051`.
# 2026-01-15 17:18:54: oggm.cfg: PARAMS['temp_bias'] changed from `12.210055612573637` to `-4.881979434400922`.
# 2026-01-15 17:18:57: oggm.cfg: PARAMS['melt_f'] changed from `9.103411924025504` to `9.814844369831295`.
# 2026-01-15 17:18:57: oggm.cfg: PARAMS['prcp_fac'] changed from `8.773045704341051` to `5.302406249226169`.
# 2026-01-15 17:18:57: oggm.cfg: PARAMS['temp_bias'] changed from `-4.881979434400922` to `4.577744222031146`.
# 2026-01-15 17:18:57: oggm.cfg: PARAMS['melt_f'] changed from `9.814844369831295` to `6.4652862436806915`.
# 2026-01-15 17:18:57: oggm.cfg: PARAMS['prcp_fac'] changed from `5.302406249226169` to `0.4894691552474256`.
# 2026-01-15 17:18:57: oggm.cfg: PARAMS['temp_bias'] changed from `4.577744222031146` to `3.8952573100926813`.
# 2026-01-15 17:18:58: oggm.cfg: PARAMS['melt_f'] changed from `6.4652862436806915` to `15.998058027138319`.
# 2026-01-15 17:18:58: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4894691552474256` to `6.052302530293104`.
# 2026-01-15 17:18:58: oggm.cfg: PARAMS['temp_bias'] changed from `3.8952573100926813` to `-3.2610318141102965`.
# 2026-01-15 17:18:58: oggm.cfg: PARAMS['melt_f'] changed from `15.998058027138319` to `8.191273721892367`.
# 2026-01-15 17:18:58: oggm.cfg: PARAMS['prcp_fac'] changed from `6.052302530293104` to `0.8061685623090286`.
# 2026-01-15 17:18:58: oggm.cfg: PARAMS['temp_bias'] changed from `-3.2610318141102965` to `12.901074131427144`.
# 2026-01-15 17:18:59: oggm.cfg: PARAMS['melt_f'] changed from `8.191273721892367` to `1.8670438777954532`.
# 2026-01-15 17:18:59: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8061685623090286` to `9.283378827517199`.
# 2026-01-15 17:18:59: oggm.cfg: PARAMS['temp_bias'] changed from `12.901074131427144` to `1.1666044979514787`.
# 2026-01-15 17:19:00: oggm.cfg: PARAMS['melt_f'] changed from `1.8670438777954532` to `5.989954369273564`.
# 2026-01-15 17:19:00: oggm.cfg: PARAMS['prcp_fac'] changed from `9.283378827517199` to `7.361233223234452`.
# 2026-01-15 17:19:00: oggm.cfg: PARAMS['temp_bias'] changed from `1.1666044979514787` to `-10.73813936778263`.
# 2026-01-15 17:19:01: oggm.cfg: PARAMS['melt_f'] changed from `5.989954369273564` to `7.322623519499535`.
# 2026-01-15 17:19:01: oggm.cfg: PARAMS['prcp_fac'] changed from `7.361233223234452` to `3.0403615138351383`.
# 2026-01-15 17:19:01: oggm.cfg: PARAMS['temp_bias'] changed from `-10.73813936778263` to `8.611297157380104`.
# 2026-01-15 17:19:01: oggm.cfg: PARAMS['melt_f'] changed from `7.322623519499535` to `9.525359814299003`.
# 2026-01-15 17:19:01: oggm.cfg: PARAMS['prcp_fac'] changed from `3.0403615138351383` to `1.1635775995474882`.
# 2026-01-15 17:19:01: oggm.cfg: PARAMS['temp_bias'] changed from `8.611297157380104` to `-5.919723018448522`.
# 2026-01-15 17:19:02: oggm.cfg: PARAMS['melt_f'] changed from `9.525359814299003` to `10.738416735657301`.
# 2026-01-15 17:19:02: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1635775995474882` to `3.249973407271803`.
# 2026-01-15 17:19:02: oggm.cfg: PARAMS['temp_bias'] changed from `-5.919723018448522` to `-3.5560878766541073`.
# 2026-01-15 17:19:02: oggm.cfg: PARAMS['melt_f'] changed from `10.738416735657301` to `14.882790744266229`.
# 2026-01-15 17:19:02: oggm.cfg: PARAMS['prcp_fac'] changed from `3.249973407271803` to `0.34460555633990064`.
# 2026-01-15 17:19:02: oggm.cfg: PARAMS['temp_bias'] changed from `-3.5560878766541073` to `14.014557048794984`.
# 2026-01-15 17:19:03: oggm.cfg: PARAMS['melt_f'] changed from `14.882790744266229` to `2.1753724662114395`.
# 2026-01-15 17:19:03: oggm.cfg: PARAMS['prcp_fac'] changed from `0.34460555633990064` to `6.19334228575979`.
# 2026-01-15 17:19:03: oggm.cfg: PARAMS['temp_bias'] changed from `14.014557048794984` to `-14.217942292819092`.
# 2026-01-15 17:19:04: oggm.cfg: PARAMS['melt_f'] changed from `2.1753724662114395` to `10.954162763537301`.
# 2026-01-15 17:19:04: oggm.cfg: PARAMS['prcp_fac'] changed from `6.19334228575979` to `2.2317520411554486`.
# 2026-01-15 17:19:04: oggm.cfg: PARAMS['temp_bias'] changed from `-14.217942292819092` to `-1.596481676603334`.
# 2026-01-15 17:19:04: oggm.cfg: PARAMS['melt_f'] changed from `10.954162763537301` to `11.920470021283`.
# 2026-01-15 17:19:04: oggm.cfg: PARAMS['prcp_fac'] changed from `2.2317520411554486` to `5.004305928406004`.
# 2026-01-15 17:19:04: oggm.cfg: PARAMS['temp_bias'] changed from `-1.596481676603334` to `-0.9816893947308376`.
# 2026-01-15 17:19:05: oggm.cfg: PARAMS['melt_f'] changed from `11.920470021283` to `11.297983510775127`.
# 2026-01-15 17:19:05: oggm.cfg: PARAMS['prcp_fac'] changed from `5.004305928406004` to `0.21160056044107822`.
# 2026-01-15 17:19:05: oggm.cfg: PARAMS['temp_bias'] changed from `-0.9816893947308376` to `11.2857454498969`.
# 2026-01-15 17:19:06: oggm.cfg: PARAMS['melt_f'] changed from `11.297983510775127` to `2.455241465655562`.
# 2026-01-15 17:19:06: oggm.cfg: PARAMS['prcp_fac'] changed from `0.21160056044107822` to `9.478508382596889`.
# 2026-01-15 17:19:06: oggm.cfg: PARAMS['temp_bias'] changed from `11.2857454498969` to `-13.10674121773683`.
# 2026-01-15 17:19:07: oggm.cfg: PARAMS['melt_f'] changed from `2.455241465655562` to `14.930844043935847`.
# 2026-01-15 17:19:07: oggm.cfg: PARAMS['prcp_fac'] changed from `9.478508382596889` to `0.9721310555933976`.
# 2026-01-15 17:19:07: oggm.cfg: PARAMS['temp_bias'] changed from `-13.10674121773683` to `1.4984007782827256`.
# 2026-01-15 17:19:07: oggm.cfg: PARAMS['melt_f'] changed from `14.930844043935847` to `2.184680820537576`.
# 2026-01-15 17:19:07: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9721310555933976` to `7.653381288543774`.
# 2026-01-15 17:19:07: oggm.cfg: PARAMS['temp_bias'] changed from `1.4984007782827256` to `4.084339928151035`.
# 2026-01-15 17:19:08: oggm.cfg: PARAMS['melt_f'] changed from `2.184680820537576` to `10.196198882983872`.
# 2026-01-15 17:19:08: oggm.cfg: PARAMS['prcp_fac'] changed from `7.653381288543774` to `5.9115873012729505`.
# 2026-01-15 17:19:08: oggm.cfg: PARAMS['temp_bias'] changed from `4.084339928151035` to `-3.0820185545415484`.
# 2026-01-15 17:19:09: oggm.cfg: PARAMS['melt_f'] changed from `10.196198882983872` to `6.7088883407805415`.
# 2026-01-15 17:19:09: oggm.cfg: PARAMS['prcp_fac'] changed from `5.9115873012729505` to `0.4848472045113371`.
# 2026-01-15 17:19:09: oggm.cfg: PARAMS['temp_bias'] changed from `-3.0820185545415484` to `0.867295175872389`.
# 2026-01-15 17:19:09: oggm.cfg: PARAMS['melt_f'] changed from `6.7088883407805415` to `12.186724449405947`.
# 2026-01-15 17:19:09: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4848472045113371` to `0.6902681376127097`.
# 2026-01-15 17:19:09: oggm.cfg: PARAMS['temp_bias'] changed from `0.867295175872389` to `-3.6033518769360846`.
# 2026-01-15 17:19:10: oggm.cfg: PARAMS['melt_f'] changed from `12.186724449405947` to `14.218950325287704`.
# 2026-01-15 17:19:10: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6902681376127097` to `7.666938397082866`.
# 2026-01-15 17:19:10: oggm.cfg: PARAMS['temp_bias'] changed from `-3.6033518769360846` to `-0.9018224614894486`.
# 2026-01-15 17:19:11: oggm.cfg: PARAMS['melt_f'] changed from `14.218950325287704` to `15.066561075760612`.
# 2026-01-15 17:19:11: oggm.cfg: PARAMS['prcp_fac'] changed from `7.666938397082866` to `3.7005546758602788`.
# 2026-01-15 17:19:11: oggm.cfg: PARAMS['temp_bias'] changed from `-0.9018224614894486` to `-14.040680385507876`.
# 2026-01-15 17:19:11: oggm.cfg: PARAMS['melt_f'] changed from `15.066561075760612` to `11.033480658792715`.
# 2026-01-15 17:19:11: oggm.cfg: PARAMS['prcp_fac'] changed from `3.7005546758602788` to `1.9036445772933368`.
# 2026-01-15 17:19:11: oggm.cfg: PARAMS['temp_bias'] changed from `-14.040680385507876` to `10.37646348038938`.
# 2026-01-15 17:19:12: oggm.cfg: PARAMS['melt_f'] changed from `11.033480658792715` to `8.437668560351462`.
# 2026-01-15 17:19:12: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9036445772933368` to `3.1131885504942036`.
# 2026-01-15 17:19:12: oggm.cfg: PARAMS['temp_bias'] changed from `10.37646348038938` to `-7.88168435141183`.
# 2026-01-15 17:19:12: oggm.cfg: PARAMS['melt_f'] changed from `8.437668560351462` to `11.590453771956756`.
# 2026-01-15 17:19:12: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1131885504942036` to `6.714079082494942`.
# 2026-01-15 17:19:12: oggm.cfg: PARAMS['temp_bias'] changed from `-7.88168435141183` to `11.496285317203363`.
# 2026-01-15 17:19:13: oggm.cfg: PARAMS['melt_f'] changed from `11.590453771956756` to `6.91088997842596`.
# 2026-01-15 17:19:13: oggm.cfg: PARAMS['prcp_fac'] changed from `6.714079082494942` to `8.420958225582135`.
# 2026-01-15 17:19:13: oggm.cfg: PARAMS['temp_bias'] changed from `11.496285317203363` to `8.540760373186785`.
# 2026-01-15 17:19:14: oggm.cfg: PARAMS['melt_f'] changed from `6.91088997842596` to `9.64467183137257`.
# 2026-01-15 17:19:14: oggm.cfg: PARAMS['prcp_fac'] changed from `8.420958225582135` to `8.844764623018596`.
# 2026-01-15 17:19:14: oggm.cfg: PARAMS['temp_bias'] changed from `8.540760373186785` to `-4.642975617924135`.
# 2026-01-15 17:19:15: oggm.cfg: PARAMS['melt_f'] changed from `9.64467183137257` to `12.564991745921983`.
# 2026-01-15 17:19:15: oggm.cfg: PARAMS['prcp_fac'] changed from `8.844764623018596` to `3.1324231031542813`.
# 2026-01-15 17:19:15: oggm.cfg: PARAMS['temp_bias'] changed from `-4.642975617924135` to `-9.365495407602111`.
# 2026-01-15 17:19:15: oggm.cfg: PARAMS['melt_f'] changed from `12.564991745921983` to `11.528672964284809`.
# 2026-01-15 17:19:15: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1324231031542813` to `4.738001484198308`.
# 2026-01-15 17:19:15: oggm.cfg: PARAMS['temp_bias'] changed from `-9.365495407602111` to `-7.931767354331485`.
# 2026-01-15 17:19:16: oggm.cfg: PARAMS['melt_f'] changed from `11.528672964284809` to `14.141544255125215`.
# 2026-01-15 17:19:16: oggm.cfg: PARAMS['prcp_fac'] changed from `4.738001484198308` to `2.6458208761086595`.
# 2026-01-15 17:19:16: oggm.cfg: PARAMS['temp_bias'] changed from `-7.931767354331485` to `8.296860818170625`.
# 2026-01-15 17:19:17: oggm.cfg: PARAMS['melt_f'] changed from `14.141544255125215` to `6.8112252347253746`.
# 2026-01-15 17:19:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.6458208761086595` to `6.049743662905621`.
# 2026-01-15 17:19:17: oggm.cfg: PARAMS['temp_bias'] changed from `8.296860818170625` to `6.657914363604004`.
# 2026-01-15 17:19:17: oggm.cfg: PARAMS['melt_f'] changed from `6.8112252347253746` to `14.38182873065821`.
# 2026-01-15 17:19:17: oggm.cfg: PARAMS['prcp_fac'] changed from `6.049743662905621` to `9.6574516260275`.
# 2026-01-15 17:19:17: oggm.cfg: PARAMS['temp_bias'] changed from `6.657914363604004` to `-9.228800506864946`.
# 2026-01-15 17:19:19: oggm.cfg: PARAMS['melt_f'] changed from `14.38182873065821` to `8.528280636367402`.
# 2026-01-15 17:19:19: oggm.cfg: PARAMS['prcp_fac'] changed from `9.6574516260275` to `8.448009629928064`.
# 2026-01-15 17:19:19: oggm.cfg: PARAMS['temp_bias'] changed from `-9.228800506864946` to `7.450147482067177`.
# 2026-01-15 17:19:19: oggm.cfg: PARAMS['melt_f'] changed from `8.528280636367402` to `4.8665455038952485`.
# 2026-01-15 17:19:19: oggm.cfg: PARAMS['prcp_fac'] changed from `8.448009629928064` to `5.441064975224516`.
# 2026-01-15 17:19:19: oggm.cfg: PARAMS['temp_bias'] changed from `7.450147482067177` to `-2.418110575586253`.
# 2026-01-15 17:19:20: oggm.cfg: PARAMS['melt_f'] changed from `4.8665455038952485` to `13.200417435775933`.
# 2026-01-15 17:19:20: oggm.cfg: PARAMS['prcp_fac'] changed from `5.441064975224516` to `5.343091092128028`.
# 2026-01-15 17:19:20: oggm.cfg: PARAMS['temp_bias'] changed from `-2.418110575586253` to `13.528009423528047`.
# 2026-01-15 17:19:20: oggm.cfg: PARAMS['melt_f'] changed from `13.200417435775933` to `6.352652767885236`.
# 2026-01-15 17:19:20: oggm.cfg: PARAMS['prcp_fac'] changed from `5.343091092128028` to `9.94776946411599`.
# 2026-01-15 17:19:20: oggm.cfg: PARAMS['temp_bias'] changed from `13.528009423528047` to `-5.4535280208372985`.
# 2026-01-15 17:19:22: oggm.cfg: PARAMS['melt_f'] changed from `6.352652767885236` to `15.727371158484539`.
# 2026-01-15 17:19:22: oggm.cfg: PARAMS['prcp_fac'] changed from `9.94776946411599` to `5.505058470642309`.
# 2026-01-15 17:19:22: oggm.cfg: PARAMS['temp_bias'] changed from `-5.4535280208372985` to `1.2432442605785283`.
# 2026-01-15 17:19:22: oggm.cfg: PARAMS['melt_f'] changed from `15.727371158484539` to `2.7771707543329276`.
# 2026-01-15 17:19:22: oggm.cfg: PARAMS['prcp_fac'] changed from `5.505058470642309` to `4.620122398029001`.
# 2026-01-15 17:19:22: oggm.cfg: PARAMS['temp_bias'] changed from `1.2432442605785283` to `-14.817793064747926`.
# 2026-01-15 17:19:23: oggm.cfg: PARAMS['melt_f'] changed from `2.7771707543329276` to `7.023624643292628`.
# 2026-01-15 17:19:23: oggm.cfg: PARAMS['prcp_fac'] changed from `4.620122398029001` to `7.138926823430276`.
# 2026-01-15 17:19:23: oggm.cfg: PARAMS['temp_bias'] changed from `-14.817793064747926` to `-13.456031626317907`.
# 2026-01-15 17:19:24: oggm.cfg: PARAMS['melt_f'] changed from `7.023624643292628` to `12.712164311823171`.
# 2026-01-15 17:19:24: oggm.cfg: PARAMS['prcp_fac'] changed from `7.138926823430276` to `1.8779665281541191`.
# 2026-01-15 17:19:24: oggm.cfg: PARAMS['temp_bias'] changed from `-13.456031626317907` to `-0.4856718922992762`.
# 2026-01-15 17:19:24: oggm.cfg: PARAMS['melt_f'] changed from `12.712164311823171` to `2.0923160270235757`.
# 2026-01-15 17:19:24: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8779665281541191` to `8.746930410950307`.
# 2026-01-15 17:19:24: oggm.cfg: PARAMS['temp_bias'] changed from `-0.4856718922992762` to `-13.527986325279572`.
# 2026-01-15 17:19:26: oggm.cfg: PARAMS['melt_f'] changed from `2.0923160270235757` to `5.104240909577266`.
# 2026-01-15 17:19:26: oggm.cfg: PARAMS['prcp_fac'] changed from `8.746930410950307` to `3.5819094084893135`.
# 2026-01-15 17:19:26: oggm.cfg: PARAMS['temp_bias'] changed from `-13.527986325279572` to `-9.906286063078756`.
# 2026-01-15 17:19:26: oggm.cfg: PARAMS['melt_f'] changed from `5.104240909577266` to `7.793326951295914`.
# 2026-01-15 17:19:26: oggm.cfg: PARAMS['prcp_fac'] changed from `3.5819094084893135` to `8.560792432926837`.
# 2026-01-15 17:19:26: oggm.cfg: PARAMS['temp_bias'] changed from `-9.906286063078756` to `-13.4821519782854`.
# 2026-01-15 17:19:27: oggm.cfg: PARAMS['melt_f'] changed from `7.793326951295914` to `8.978229607916413`.
# 2026-01-15 17:19:27: oggm.cfg: PARAMS['prcp_fac'] changed from `8.560792432926837` to `3.956831903474978`.
# 2026-01-15 17:19:27: oggm.cfg: PARAMS['temp_bias'] changed from `-13.4821519782854` to `2.597171266163148`.
# 2026-01-15 17:19:28: oggm.cfg: PARAMS['melt_f'] changed from `8.978229607916413` to `12.934889782470044`.
# 2026-01-15 17:19:28: oggm.cfg: PARAMS['prcp_fac'] changed from `3.956831903474978` to `4.583591855548338`.
# 2026-01-15 17:19:28: oggm.cfg: PARAMS['temp_bias'] changed from `2.597171266163148` to `-5.83012560740371`.
# 2026-01-15 17:19:29: oggm.cfg: PARAMS['melt_f'] changed from `12.934889782470044` to `8.106505358701924`.
# 2026-01-15 17:19:29: oggm.cfg: PARAMS['prcp_fac'] changed from `4.583591855548338` to `7.621463969393278`.
# 2026-01-15 17:19:29: oggm.cfg: PARAMS['temp_bias'] changed from `-5.83012560740371` to `-0.19507777462776943`.
# 2026-01-15 17:19:29: oggm.cfg: PARAMS['melt_f'] changed from `8.106505358701924` to `14.641742027667751`.
# 2026-01-15 17:19:29: oggm.cfg: PARAMS['prcp_fac'] changed from `7.621463969393278` to `1.7358585839855005`.
# 2026-01-15 17:19:29: oggm.cfg: PARAMS['temp_bias'] changed from `-0.19507777462776943` to `10.848931849103032`.
# 2026-01-15 17:19:30: oggm.cfg: PARAMS['melt_f'] changed from `14.641742027667751` to `7.585226414356749`.
# 2026-01-15 17:19:30: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7358585839855005` to `8.171872496650327`.
# 2026-01-15 17:19:30: oggm.cfg: PARAMS['temp_bias'] changed from `10.848931849103032` to `11.703656380808066`.
# 2026-01-15 17:19:30: oggm.cfg: PARAMS['melt_f'] changed from `7.585226414356749` to `2.2561865651801636`.
# 2026-01-15 17:19:30: oggm.cfg: PARAMS['prcp_fac'] changed from `8.171872496650327` to `5.224484982961532`.
# 2026-01-15 17:19:30: oggm.cfg: PARAMS['temp_bias'] changed from `11.703656380808066` to `7.859154689680192`.
# 2026-01-15 17:19:31: oggm.cfg: PARAMS['melt_f'] changed from `2.2561865651801636` to `5.089797231019413`.
# 2026-01-15 17:19:31: oggm.cfg: PARAMS['prcp_fac'] changed from `5.224484982961532` to `2.01558342096647`.
# 2026-01-15 17:19:31: oggm.cfg: PARAMS['temp_bias'] changed from `7.859154689680192` to `7.992169445826505`.
# 2026-01-15 17:19:31: oggm.cfg: PARAMS['melt_f'] changed from `5.089797231019413` to `15.700403188541312`.
# 2026-01-15 17:19:31: oggm.cfg: PARAMS['prcp_fac'] changed from `2.01558342096647` to `6.880765971522914`.
# 2026-01-15 17:19:31: oggm.cfg: PARAMS['temp_bias'] changed from `7.992169445826505` to `-6.415357659820305`.
# 2026-01-15 17:19:32: oggm.cfg: PARAMS['melt_f'] changed from `15.700403188541312` to `12.480968256098855`.
# 2026-01-15 17:19:32: oggm.cfg: PARAMS['prcp_fac'] changed from `6.880765971522914` to `9.330324339654407`.
# 2026-01-15 17:19:32: oggm.cfg: PARAMS['temp_bias'] changed from `-6.415357659820305` to `-4.26406643104893`.
# 2026-01-15 17:19:33: oggm.cfg: PARAMS['melt_f'] changed from `12.480968256098855` to `16.784549141222385`.
# 2026-01-15 17:19:33: oggm.cfg: PARAMS['prcp_fac'] changed from `9.330324339654407` to `1.351629110788514`.
# 2026-01-15 17:19:33: oggm.cfg: PARAMS['temp_bias'] changed from `-4.26406643104893` to `-4.797919457254888`.
# 2026-01-15 17:19:34: oggm.cfg: PARAMS['melt_f'] changed from `16.784549141222385` to `14.818795808607417`.
# 2026-01-15 17:19:34: oggm.cfg: PARAMS['prcp_fac'] changed from `1.351629110788514` to `0.6428981009896199`.
# 2026-01-15 17:19:34: oggm.cfg: PARAMS['temp_bias'] changed from `-4.797919457254888` to `12.931664013406376`.
# 2026-01-15 17:19:34: oggm.cfg: PARAMS['melt_f'] changed from `14.818795808607417` to `14.77749893267303`.
# 2026-01-15 17:19:34: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6428981009896199` to `2.4171598871787867`.
# 2026-01-15 17:19:34: oggm.cfg: PARAMS['temp_bias'] changed from `12.931664013406376` to `9.10198403726367`.
# 2026-01-15 17:19:35: oggm.cfg: PARAMS['melt_f'] changed from `14.77749893267303` to `10.962368151556204`.
# 2026-01-15 17:19:35: oggm.cfg: PARAMS['prcp_fac'] changed from `2.4171598871787867` to `3.833963688397884`.
# 2026-01-15 17:19:35: oggm.cfg: PARAMS['temp_bias'] changed from `9.10198403726367` to `13.83275753572481`.
# 2026-01-15 17:19:36: oggm.cfg: PARAMS['melt_f'] changed from `10.962368151556204` to `13.420815671425833`.
# 2026-01-15 17:19:36: oggm.cfg: PARAMS['prcp_fac'] changed from `3.833963688397884` to `6.144051905432269`.
# 2026-01-15 17:19:36: oggm.cfg: PARAMS['temp_bias'] changed from `13.83275753572481` to `-5.139449001428062`.
# 2026-01-15 17:19:36: oggm.cfg: PARAMS['melt_f'] changed from `13.420815671425833` to `13.937483533403432`.
# 2026-01-15 17:19:36: oggm.cfg: PARAMS['prcp_fac'] changed from `6.144051905432269` to `4.419141608111951`.
# 2026-01-15 17:19:36: oggm.cfg: PARAMS['temp_bias'] changed from `-5.139449001428062` to `-12.886663832816643`.
# 2026-01-15 17:19:37: oggm.cfg: PARAMS['melt_f'] changed from `13.937483533403432` to `9.474695116884034`.
# 2026-01-15 17:19:37: oggm.cfg: PARAMS['prcp_fac'] changed from `4.419141608111951` to `0.3959091528006575`.
# 2026-01-15 17:19:37: oggm.cfg: PARAMS['temp_bias'] changed from `-12.886663832816643` to `-0.05319023642702625`.
# 2026-01-15 17:19:38: oggm.cfg: PARAMS['melt_f'] changed from `9.474695116884034` to `6.095268408286509`.
# 2026-01-15 17:19:38: oggm.cfg: PARAMS['prcp_fac'] changed from `0.3959091528006575` to `6.451039264560034`.
# 2026-01-15 17:19:38: oggm.cfg: PARAMS['temp_bias'] changed from `-0.05319023642702625` to `-0.325804828222763`.
# 2026-01-15 17:19:38: oggm.cfg: PARAMS['melt_f'] changed from `6.095268408286509` to `4.905028652720802`.
# 2026-01-15 17:19:38: oggm.cfg: PARAMS['prcp_fac'] changed from `6.451039264560034` to `1.3612227185964767`.
# 2026-01-15 17:19:38: oggm.cfg: PARAMS['temp_bias'] changed from `-0.325804828222763` to `13.710197318516869`.
# 2026-01-15 17:19:39: oggm.cfg: PARAMS['melt_f'] changed from `4.905028652720802` to `7.272649463992639`.
# 2026-01-15 17:19:39: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3612227185964767` to `7.485285759886982`.
# 2026-01-15 17:19:39: oggm.cfg: PARAMS['temp_bias'] changed from `13.710197318516869` to `1.2168472743056071`.
# 2026-01-15 17:19:39: oggm.cfg: PARAMS['melt_f'] changed from `7.272649463992639` to `10.21116908848399`.
# 2026-01-15 17:19:39: oggm.cfg: PARAMS['prcp_fac'] changed from `7.485285759886982` to `2.145260439868091`.
# 2026-01-15 17:19:39: oggm.cfg: PARAMS['temp_bias'] changed from `1.2168472743056071` to `5.3368157915620635`.
# 2026-01-15 17:19:40: oggm.cfg: PARAMS['melt_f'] changed from `10.21116908848399` to `1.7950875832520259`.
# 2026-01-15 17:19:40: oggm.cfg: PARAMS['prcp_fac'] changed from `2.145260439868091` to `7.379773682519492`.
# 2026-01-15 17:19:40: oggm.cfg: PARAMS['temp_bias'] changed from `5.3368157915620635` to `-1.4076629478091682`.
# 2026-01-15 17:19:41: oggm.cfg: PARAMS['melt_f'] changed from `1.7950875832520259` to `8.615653639115852`.
# 2026-01-15 17:19:41: oggm.cfg: PARAMS['prcp_fac'] changed from `7.379773682519492` to `6.117427206756886`.
# 2026-01-15 17:19:41: oggm.cfg: PARAMS['temp_bias'] changed from `-1.4076629478091682` to `14.117382095826816`.
# 2026-01-15 17:19:41: oggm.cfg: PARAMS['melt_f'] changed from `8.615653639115852` to `15.574340267379474`.
# 2026-01-15 17:19:41: oggm.cfg: PARAMS['prcp_fac'] changed from `6.117427206756886` to `6.644328678034048`.
# 2026-01-15 17:19:41: oggm.cfg: PARAMS['temp_bias'] changed from `14.117382095826816` to `-14.237420423134042`.
# 2026-01-15 17:19:42: oggm.cfg: PARAMS['melt_f'] changed from `15.574340267379474` to `12.396567654180238`.
# 2026-01-15 17:19:42: oggm.cfg: PARAMS['prcp_fac'] changed from `6.644328678034048` to `8.599509785391088`.
# 2026-01-15 17:19:42: oggm.cfg: PARAMS['temp_bias'] changed from `-14.237420423134042` to `0.7507253653489201`.
# 2026-01-15 17:19:43: oggm.cfg: PARAMS['melt_f'] changed from `12.396567654180238` to `12.31445660342392`.
# 2026-01-15 17:19:43: oggm.cfg: PARAMS['prcp_fac'] changed from `8.599509785391088` to `1.6240144441163749`.
# 2026-01-15 17:19:43: oggm.cfg: PARAMS['temp_bias'] changed from `0.7507253653489201` to `-12.093091433320202`.
# 2026-01-15 17:19:43: oggm.cfg: PARAMS['melt_f'] changed from `12.31445660342392` to `12.232566413407014`.
# 2026-01-15 17:19:43: oggm.cfg: PARAMS['prcp_fac'] changed from `1.6240144441163749` to `7.635932373127568`.
# 2026-01-15 17:19:43: oggm.cfg: PARAMS['temp_bias'] changed from `-12.093091433320202` to `-1.6688126843760767`.
# 2026-01-15 17:19:44: oggm.cfg: PARAMS['melt_f'] changed from `12.232566413407014` to `7.158620323078027`.
# 2026-01-15 17:19:44: oggm.cfg: PARAMS['prcp_fac'] changed from `7.635932373127568` to `7.896391756102395`.
# 2026-01-15 17:19:44: oggm.cfg: PARAMS['temp_bias'] changed from `-1.6688126843760767` to `-12.357696720656849`.
# 2026-01-15 17:19:45: oggm.cfg: PARAMS['melt_f'] changed from `7.158620323078027` to `14.093768521276505`.
# 2026-01-15 17:19:45: oggm.cfg: PARAMS['prcp_fac'] changed from `7.896391756102395` to `5.651554186847264`.
# 2026-01-15 17:19:45: oggm.cfg: PARAMS['temp_bias'] changed from `-12.357696720656849` to `12.471603561507031`.
# 2026-01-15 17:19:46: oggm.cfg: PARAMS['melt_f'] changed from `14.093768521276505` to `14.604960289238605`.
# 2026-01-15 17:19:46: oggm.cfg: PARAMS['prcp_fac'] changed from `5.651554186847264` to `4.2936585919529815`.
# 2026-01-15 17:19:46: oggm.cfg: PARAMS['temp_bias'] changed from `12.471603561507031` to `-0.8891786390757961`.
# 2026-01-15 17:19:46: oggm.cfg: PARAMS['melt_f'] changed from `14.604960289238605` to `12.060027309998185`.
# 2026-01-15 17:19:46: oggm.cfg: PARAMS['prcp_fac'] changed from `4.2936585919529815` to `4.351093369205709`.
# 2026-01-15 17:19:46: oggm.cfg: PARAMS['temp_bias'] changed from `-0.8891786390757961` to `-4.977959720115578`.
# 2026-01-15 17:19:47: oggm.cfg: PARAMS['melt_f'] changed from `12.060027309998185` to `8.165938351896873`.
# 2026-01-15 17:19:47: oggm.cfg: PARAMS['prcp_fac'] changed from `4.351093369205709` to `8.57594715629983`.
# 2026-01-15 17:19:47: oggm.cfg: PARAMS['temp_bias'] changed from `-4.977959720115578` to `2.5482941186985784`.
# 2026-01-15 17:19:47: oggm.cfg: PARAMS['melt_f'] changed from `8.165938351896873` to `13.752285079616005`.
# 2026-01-15 17:19:47: oggm.cfg: PARAMS['prcp_fac'] changed from `8.57594715629983` to `4.114306320564441`.
# 2026-01-15 17:19:47: oggm.cfg: PARAMS['temp_bias'] changed from `2.5482941186985784` to `5.811408895960703`.
# 2026-01-15 17:19:48: oggm.cfg: PARAMS['melt_f'] changed from `13.752285079616005` to `1.9289143827155788`.
# 2026-01-15 17:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `4.114306320564441` to `3.1627253538271356`.
# 2026-01-15 17:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `5.811408895960703` to `2.0272561280311905`.
# 2026-01-15 17:19:48: oggm.cfg: PARAMS['melt_f'] changed from `1.9289143827155788` to `1.9642904024152696`.
# 2026-01-15 17:19:48: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1627253538271356` to `9.804781372066719`.
# 2026-01-15 17:19:48: oggm.cfg: PARAMS['temp_bias'] changed from `2.0272561280311905` to `-9.59826104628052`.
# 2026-01-15 17:19:50: oggm.cfg: PARAMS['melt_f'] changed from `1.9642904024152696` to `11.767679164420557`.
# 2026-01-15 17:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `9.804781372066719` to `0.5478994148988712`.
# 2026-01-15 17:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `-9.59826104628052` to `14.227883158801536`.
# 2026-01-15 17:19:50: oggm.cfg: PARAMS['melt_f'] changed from `11.767679164420557` to `5.62662791110255`.
# 2026-01-15 17:19:50: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5478994148988712` to `8.415500302095177`.
# 2026-01-15 17:19:50: oggm.cfg: PARAMS['temp_bias'] changed from `14.227883158801536` to `-6.792971215923288`.
# 2026-01-15 17:19:51: oggm.cfg: PARAMS['melt_f'] changed from `5.62662791110255` to `13.589446033950535`.
# 2026-01-15 17:19:51: oggm.cfg: PARAMS['prcp_fac'] changed from `8.415500302095177` to `5.4354423737309645`.
# 2026-01-15 17:19:51: oggm.cfg: PARAMS['temp_bias'] changed from `-6.792971215923288` to `6.707365253766511`.
# 2026-01-15 17:19:52: oggm.cfg: PARAMS['melt_f'] changed from `13.589446033950535` to `6.728368364454302`.
# 2026-01-15 17:19:52: oggm.cfg: PARAMS['prcp_fac'] changed from `5.4354423737309645` to `2.5286738384502176`.
# 2026-01-15 17:19:52: oggm.cfg: PARAMS['temp_bias'] changed from `6.707365253766511` to `-10.848164373048022`.
# 2026-01-15 17:19:52: oggm.cfg: PARAMS['melt_f'] changed from `6.728368364454302` to `12.494897601306029`.
# 2026-01-15 17:19:52: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5286738384502176` to `1.52720922124869`.
# 2026-01-15 17:19:52: oggm.cfg: PARAMS['temp_bias'] changed from `-10.848164373048022` to `4.038951237239143`.
# 2026-01-15 17:19:53: oggm.cfg: PARAMS['melt_f'] changed from `12.494897601306029` to `1.5806122912273706`.
# 2026-01-15 17:19:53: oggm.cfg: PARAMS['prcp_fac'] changed from `1.52720922124869` to `6.2336769050446055`.
# 2026-01-15 17:19:53: oggm.cfg: PARAMS['temp_bias'] changed from `4.038951237239143` to `-4.45973943964775`.
# 2026-01-15 17:19:54: oggm.cfg: PARAMS['melt_f'] changed from `1.5806122912273706` to `4.058874476789824`.
# 2026-01-15 17:19:54: oggm.cfg: PARAMS['prcp_fac'] changed from `6.2336769050446055` to `2.9675186465770684`.
# 2026-01-15 17:19:54: oggm.cfg: PARAMS['temp_bias'] changed from `-4.45973943964775` to `3.9391224994575573`.
# 2026-01-15 17:19:54: oggm.cfg: PARAMS['melt_f'] changed from `4.058874476789824` to `12.460403748978031`.
# 2026-01-15 17:19:54: oggm.cfg: PARAMS['prcp_fac'] changed from `2.9675186465770684` to `3.515161495312235`.
# 2026-01-15 17:19:54: oggm.cfg: PARAMS['temp_bias'] changed from `3.9391224994575573` to `5.728404508700585`.
# 2026-01-15 17:19:55: oggm.cfg: PARAMS['melt_f'] changed from `12.460403748978031` to `11.877458089649796`.
# 2026-01-15 17:19:55: oggm.cfg: PARAMS['prcp_fac'] changed from `3.515161495312235` to `2.333802358626449`.
# 2026-01-15 17:19:55: oggm.cfg: PARAMS['temp_bias'] changed from `5.728404508700585` to `7.341220074248554`.
# 2026-01-15 17:19:56: oggm.cfg: PARAMS['melt_f'] changed from `11.877458089649796` to `10.888422065048603`.
# 2026-01-15 17:19:56: oggm.cfg: PARAMS['prcp_fac'] changed from `2.333802358626449` to `3.669826807128854`.
# 2026-01-15 17:19:56: oggm.cfg: PARAMS['temp_bias'] changed from `7.341220074248554` to `13.78184307674059`.
# 2026-01-15 17:19:56: oggm.cfg: PARAMS['melt_f'] changed from `10.888422065048603` to `16.43279018979152`.
# 2026-01-15 17:19:56: oggm.cfg: PARAMS['prcp_fac'] changed from `3.669826807128854` to `4.136753611479537`.
# 2026-01-15 17:19:56: oggm.cfg: PARAMS['temp_bias'] changed from `13.78184307674059` to `14.891636310892665`.
# 2026-01-15 17:19:57: oggm.cfg: PARAMS['melt_f'] changed from `16.43279018979152` to `13.671184155700793`.
# 2026-01-15 17:19:57: oggm.cfg: PARAMS['prcp_fac'] changed from `4.136753611479537` to `6.345579246343959`.
# 2026-01-15 17:19:57: oggm.cfg: PARAMS['temp_bias'] changed from `14.891636310892665` to `13.37171176086056`.
# 2026-01-15 17:19:57: oggm.cfg: PARAMS['melt_f'] changed from `13.671184155700793` to `7.48268105373078`.
# 2026-01-15 17:19:57: oggm.cfg: PARAMS['prcp_fac'] changed from `6.345579246343959` to `9.506976660112008`.
# 2026-01-15 17:19:57: oggm.cfg: PARAMS['temp_bias'] changed from `13.37171176086056` to `9.380179797647806`.
# 2026-01-15 17:19:58: oggm.cfg: PARAMS['melt_f'] changed from `7.48268105373078` to `5.423896629194301`.
# 2026-01-15 17:19:58: oggm.cfg: PARAMS['prcp_fac'] changed from `9.506976660112008` to `5.535307091290672`.
# 2026-01-15 17:19:58: oggm.cfg: PARAMS['temp_bias'] changed from `9.380179797647806` to `-0.2911138077594426`.
# 2026-01-15 17:19:58: oggm.cfg: PARAMS['melt_f'] changed from `5.423896629194301` to `6.926227526679342`.
# 2026-01-15 17:19:58: oggm.cfg: PARAMS['prcp_fac'] changed from `5.535307091290672` to `3.586977956426724`.
# 2026-01-15 17:19:58: oggm.cfg: PARAMS['temp_bias'] changed from `-0.2911138077594426` to `1.7268417001767595`.
# 2026-01-15 17:19:59: oggm.cfg: PARAMS['melt_f'] changed from `6.926227526679342` to `10.10432344613456`.
# 2026-01-15 17:19:59: oggm.cfg: PARAMS['prcp_fac'] changed from `3.586977956426724` to `1.341951061894392`.
# 2026-01-15 17:19:59: oggm.cfg: PARAMS['temp_bias'] changed from `1.7268417001767595` to `12.003812489043558`.
# 2026-01-15 17:20:00: oggm.cfg: PARAMS['melt_f'] changed from `10.10432344613456` to `14.406550122225996`.
# 2026-01-15 17:20:00: oggm.cfg: PARAMS['prcp_fac'] changed from `1.341951061894392` to `7.523444797665745`.
# 2026-01-15 17:20:00: oggm.cfg: PARAMS['temp_bias'] changed from `12.003812489043558` to `10.96676020667639`.
# 2026-01-15 17:20:00: oggm.cfg: PARAMS['melt_f'] changed from `14.406550122225996` to `6.0279241758731645`.
# 2026-01-15 17:20:00: oggm.cfg: PARAMS['prcp_fac'] changed from `7.523444797665745` to `7.781101263336598`.
# 2026-01-15 17:20:00: oggm.cfg: PARAMS['temp_bias'] changed from `10.96676020667639` to `-1.484628597197247`.
# 2026-01-15 17:20:01: oggm.cfg: PARAMS['melt_f'] changed from `6.0279241758731645` to `11.084930504912162`.
# 2026-01-15 17:20:01: oggm.cfg: PARAMS['prcp_fac'] changed from `7.781101263336598` to `1.927368482913894`.
# 2026-01-15 17:20:01: oggm.cfg: PARAMS['temp_bias'] changed from `-1.484628597197247` to `-4.147610139595626`.
# 2026-01-15 17:20:01: oggm.cfg: PARAMS['melt_f'] changed from `11.084930504912162` to `2.5893801367532276`.
# 2026-01-15 17:20:01: oggm.cfg: PARAMS['prcp_fac'] changed from `1.927368482913894` to `4.4647308830757275`.
# 2026-01-15 17:20:01: oggm.cfg: PARAMS['temp_bias'] changed from `-4.147610139595626` to `9.291663471733308`.
# 2026-01-15 17:20:02: oggm.cfg: PARAMS['melt_f'] changed from `2.5893801367532276` to `15.270902698714645`.
# 2026-01-15 17:20:02: oggm.cfg: PARAMS['prcp_fac'] changed from `4.4647308830757275` to `6.606683403730226`.
# 2026-01-15 17:20:02: oggm.cfg: PARAMS['temp_bias'] changed from `9.291663471733308` to `-11.13704922147874`.
# 2026-01-15 17:20:03: oggm.cfg: PARAMS['melt_f'] changed from `15.270902698714645` to `3.1636366538479024`.
# 2026-01-15 17:20:03: oggm.cfg: PARAMS['prcp_fac'] changed from `6.606683403730226` to `4.429637912880882`.
# 2026-01-15 17:20:03: oggm.cfg: PARAMS['temp_bias'] changed from `-11.13704922147874` to `12.88905389295536`.
# 2026-01-15 17:20:03: oggm.cfg: PARAMS['melt_f'] changed from `3.1636366538479024` to `4.179234842748314`.
# 2026-01-15 17:20:03: oggm.cfg: PARAMS['prcp_fac'] changed from `4.429637912880882` to `6.1606310828511415`.
# 2026-01-15 17:20:03: oggm.cfg: PARAMS['temp_bias'] changed from `12.88905389295536` to `10.61616548634565`.
# 2026-01-15 17:20:04: oggm.cfg: PARAMS['melt_f'] changed from `4.179234842748314` to `6.154938155449863`.
# 2026-01-15 17:20:04: oggm.cfg: PARAMS['prcp_fac'] changed from `6.1606310828511415` to `6.482170956191603`.
# 2026-01-15 17:20:04: oggm.cfg: PARAMS['temp_bias'] changed from `10.61616548634565` to `5.141911310706419`.
# 2026-01-15 17:20:04: oggm.cfg: PARAMS['melt_f'] changed from `6.154938155449863` to `3.5478858660914554`.
# 2026-01-15 17:20:04: oggm.cfg: PARAMS['prcp_fac'] changed from `6.482170956191603` to `5.275296930351851`.
# 2026-01-15 17:20:04: oggm.cfg: PARAMS['temp_bias'] changed from `5.141911310706419` to `-14.944405076736215`.
# 2026-01-15 17:20:05: oggm.cfg: PARAMS['melt_f'] changed from `3.5478858660914554` to `15.945459052106399`.
# 2026-01-15 17:20:05: oggm.cfg: PARAMS['prcp_fac'] changed from `5.275296930351851` to `0.9347212138317231`.
# 2026-01-15 17:20:05: oggm.cfg: PARAMS['temp_bias'] changed from `-14.944405076736215` to `11.095924797602493`.
# 2026-01-15 17:20:06: oggm.cfg: PARAMS['melt_f'] changed from `15.945459052106399` to `9.894134083217194`.
# 2026-01-15 17:20:06: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9347212138317231` to `8.709740339276628`.
# 2026-01-15 17:20:06: oggm.cfg: PARAMS['temp_bias'] changed from `11.095924797602493` to `10.146023461327147`.
# 2026-01-15 17:20:06: oggm.cfg: PARAMS['melt_f'] changed from `9.894134083217194` to `12.996609898471018`.
# 2026-01-15 17:20:06: oggm.cfg: PARAMS['prcp_fac'] changed from `8.709740339276628` to `8.539385009027287`.
# 2026-01-15 17:20:06: oggm.cfg: PARAMS['temp_bias'] changed from `10.146023461327147` to `5.065886791989506`.
# 2026-01-15 17:20:07: oggm.cfg: PARAMS['melt_f'] changed from `12.996609898471018` to `12.58912259845355`.
# 2026-01-15 17:20:07: oggm.cfg: PARAMS['prcp_fac'] changed from `8.539385009027287` to `1.8294560339820243`.
# 2026-01-15 17:20:07: oggm.cfg: PARAMS['temp_bias'] changed from `5.065886791989506` to `-5.194539998340126`.
# 2026-01-15 17:20:08: oggm.cfg: PARAMS['melt_f'] changed from `12.58912259845355` to `4.165086508163025`.
# 2026-01-15 17:20:08: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8294560339820243` to `3.8942426082113433`.
# 2026-01-15 17:20:08: oggm.cfg: PARAMS['temp_bias'] changed from `-5.194539998340126` to `-2.254662257863899`.
# 2026-01-15 17:20:08: oggm.cfg: PARAMS['melt_f'] changed from `4.165086508163025` to `13.767099891951151`.
# 2026-01-15 17:20:08: oggm.cfg: PARAMS['prcp_fac'] changed from `3.8942426082113433` to `7.417023560721008`.
# 2026-01-15 17:20:08: oggm.cfg: PARAMS['temp_bias'] changed from `-2.254662257863899` to `13.757859377460736`.
# 2026-01-15 17:20:09: oggm.cfg: PARAMS['melt_f'] changed from `13.767099891951151` to `10.657550447954371`.
# 2026-01-15 17:20:09: oggm.cfg: PARAMS['prcp_fac'] changed from `7.417023560721008` to `5.900245027787066`.
# 2026-01-15 17:20:09: oggm.cfg: PARAMS['temp_bias'] changed from `13.757859377460736` to `-2.6473693696889207`.
# 2026-01-15 17:20:09: oggm.cfg: PARAMS['melt_f'] changed from `10.657550447954371` to `2.6081243150115783`.
# 2026-01-15 17:20:09: oggm.cfg: PARAMS['prcp_fac'] changed from `5.900245027787066` to `3.9699385672343874`.
# 2026-01-15 17:20:09: oggm.cfg: PARAMS['temp_bias'] changed from `-2.6473693696889207` to `9.79317891009412`.
# 2026-01-15 17:20:10: oggm.cfg: PARAMS['melt_f'] changed from `2.6081243150115783` to `2.019005653602622`.
# 2026-01-15 17:20:10: oggm.cfg: PARAMS['prcp_fac'] changed from `3.9699385672343874` to `5.077918142077248`.
# 2026-01-15 17:20:10: oggm.cfg: PARAMS['temp_bias'] changed from `9.79317891009412` to `-4.2477526663184495`.
# 2026-01-15 17:20:11: oggm.cfg: PARAMS['melt_f'] changed from `2.019005653602622` to `2.6640517908095784`.
# 2026-01-15 17:20:11: oggm.cfg: PARAMS['prcp_fac'] changed from `5.077918142077248` to `6.185659415368337`.
# 2026-01-15 17:20:11: oggm.cfg: PARAMS['temp_bias'] changed from `-4.2477526663184495` to `8.160079324480854`.
# 2026-01-15 17:20:11: oggm.cfg: PARAMS['melt_f'] changed from `2.6640517908095784` to `3.261911007550805`.
# 2026-01-15 17:20:11: oggm.cfg: PARAMS['prcp_fac'] changed from `6.185659415368337` to `7.492954003174028`.
# 2026-01-15 17:20:11: oggm.cfg: PARAMS['temp_bias'] changed from `8.160079324480854` to `-0.44374697228358073`.
# 2026-01-15 17:20:13: oggm.cfg: PARAMS['melt_f'] changed from `3.261911007550805` to `2.4337389449273723`.
# 2026-01-15 17:20:13: oggm.cfg: PARAMS['prcp_fac'] changed from `7.492954003174028` to `9.97013595901698`.
# 2026-01-15 17:20:13: oggm.cfg: PARAMS['temp_bias'] changed from `-0.44374697228358073` to `-6.335278221122916`.
# 2026-01-15 17:20:15: oggm.cfg: PARAMS['melt_f'] changed from `2.4337389449273723` to `2.4905226179667093`.
# 2026-01-15 17:20:15: oggm.cfg: PARAMS['prcp_fac'] changed from `9.97013595901698` to `5.033017089748763`.
# 2026-01-15 17:20:15: oggm.cfg: PARAMS['temp_bias'] changed from `-6.335278221122916` to `-2.980961589830377`.
# 2026-01-15 17:20:15: oggm.cfg: PARAMS['melt_f'] changed from `2.4905226179667093` to `1.836875695022404`.
# 2026-01-15 17:20:15: oggm.cfg: PARAMS['prcp_fac'] changed from `5.033017089748763` to `3.794292557805229`.
# 2026-01-15 17:20:15: oggm.cfg: PARAMS['temp_bias'] changed from `-2.980961589830377` to `12.641438635758394`.
# 2026-01-15 17:20:16: oggm.cfg: PARAMS['melt_f'] changed from `1.836875695022404` to `4.918549213240603`.
# 2026-01-15 17:20:16: oggm.cfg: PARAMS['prcp_fac'] changed from `3.794292557805229` to `0.7358708230699962`.
# 2026-01-15 17:20:16: oggm.cfg: PARAMS['temp_bias'] changed from `12.641438635758394` to `7.366205604959138`.
# 2026-01-15 17:20:16: oggm.cfg: PARAMS['melt_f'] changed from `4.918549213240603` to `13.527933914601402`.
# 2026-01-15 17:20:16: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7358708230699962` to `7.6539618729509655`.
# 2026-01-15 17:20:16: oggm.cfg: PARAMS['temp_bias'] changed from `7.366205604959138` to `14.919783399201261`.
# 2026-01-15 17:20:17: oggm.cfg: PARAMS['melt_f'] changed from `13.527933914601402` to `13.918886416319802`.
# 2026-01-15 17:20:17: oggm.cfg: PARAMS['prcp_fac'] changed from `7.6539618729509655` to `9.293802362189037`.
# 2026-01-15 17:20:17: oggm.cfg: PARAMS['temp_bias'] changed from `14.919783399201261` to `9.31815925156532`.
# 2026-01-15 17:20:18: oggm.cfg: PARAMS['melt_f'] changed from `13.918886416319802` to `12.866393770225663`.
# 2026-01-15 17:20:18: oggm.cfg: PARAMS['prcp_fac'] changed from `9.293802362189037` to `2.1287422744959508`.
# 2026-01-15 17:20:18: oggm.cfg: PARAMS['temp_bias'] changed from `9.31815925156532` to `-14.726592709511957`.
# 2026-01-15 17:20:18: oggm.cfg: PARAMS['melt_f'] changed from `12.866393770225663` to `2.2372405741349515`.
# 2026-01-15 17:20:18: oggm.cfg: PARAMS['prcp_fac'] changed from `2.1287422744959508` to `1.000887384249809`.
# 2026-01-15 17:20:18: oggm.cfg: PARAMS['temp_bias'] changed from `-14.726592709511957` to `9.667877201094527`.
# 2026-01-15 17:20:19: oggm.cfg: PARAMS['melt_f'] changed from `2.2372405741349515` to `8.797319033443962`.
# 2026-01-15 17:20:19: oggm.cfg: PARAMS['prcp_fac'] changed from `1.000887384249809` to `3.7297133389532857`.
# 2026-01-15 17:20:19: oggm.cfg: PARAMS['temp_bias'] changed from `9.667877201094527` to `13.027697431251823`.
# 2026-01-15 17:20:19: oggm.cfg: PARAMS['melt_f'] changed from `8.797319033443962` to `11.319427791459258`.
# 2026-01-15 17:20:19: oggm.cfg: PARAMS['prcp_fac'] changed from `3.7297133389532857` to `7.203184040835122`.
# 2026-01-15 17:20:19: oggm.cfg: PARAMS['temp_bias'] changed from `13.027697431251823` to `1.316516274656987`.
# 2026-01-15 17:20:20: oggm.cfg: PARAMS['melt_f'] changed from `11.319427791459258` to `14.865418631660956`.
# 2026-01-15 17:20:20: oggm.cfg: PARAMS['prcp_fac'] changed from `7.203184040835122` to `2.2965380857713877`.
# 2026-01-15 17:20:20: oggm.cfg: PARAMS['temp_bias'] changed from `1.316516274656987` to `12.48014400190797`.
# 2026-01-15 17:20:20: oggm.cfg: PARAMS['melt_f'] changed from `14.865418631660956` to `3.4650241460280995`.
# 2026-01-15 17:20:20: oggm.cfg: PARAMS['prcp_fac'] changed from `2.2965380857713877` to `2.766619370382015`.
# 2026-01-15 17:20:20: oggm.cfg: PARAMS['temp_bias'] changed from `12.48014400190797` to `-11.55959228751423`.
# 2026-01-15 17:20:21: oggm.cfg: PARAMS['melt_f'] changed from `3.4650241460280995` to `3.3875101310871223`.
# 2026-01-15 17:20:21: oggm.cfg: PARAMS['prcp_fac'] changed from `2.766619370382015` to `5.514233618617057`.
# 2026-01-15 17:20:21: oggm.cfg: PARAMS['temp_bias'] changed from `-11.55959228751423` to `-11.7268274487849`.
# 2026-01-15 17:20:22: oggm.cfg: PARAMS['melt_f'] changed from `3.3875101310871223` to `4.814624814420084`.
# 2026-01-15 17:20:22: oggm.cfg: PARAMS['prcp_fac'] changed from `5.514233618617057` to `6.540534864545308`.
# 2026-01-15 17:20:22: oggm.cfg: PARAMS['temp_bias'] changed from `-11.7268274487849` to `-5.16064574994923`.
# 2026-01-15 17:20:23: oggm.cfg: PARAMS['melt_f'] changed from `4.814624814420084` to `14.080493923671092`.
# 2026-01-15 17:20:23: oggm.cfg: PARAMS['prcp_fac'] changed from `6.540534864545308` to `9.030450808429704`.
# 2026-01-15 17:20:23: oggm.cfg: PARAMS['temp_bias'] changed from `-5.16064574994923` to `11.133974984081341`.
# 2026-01-15 17:20:23: oggm.cfg: PARAMS['melt_f'] changed from `14.080493923671092` to `10.847526519971543`.
# 2026-01-15 17:20:23: oggm.cfg: PARAMS['prcp_fac'] changed from `9.030450808429704` to `6.361918910335045`.
# 2026-01-15 17:20:23: oggm.cfg: PARAMS['temp_bias'] changed from `11.133974984081341` to `0.6385963853942549`.
# 2026-01-15 17:20:24: oggm.cfg: PARAMS['melt_f'] changed from `10.847526519971543` to `13.465434322780341`.
# 2026-01-15 17:20:24: oggm.cfg: PARAMS['prcp_fac'] changed from `6.361918910335045` to `0.6592864039712609`.
# 2026-01-15 17:20:24: oggm.cfg: PARAMS['temp_bias'] changed from `0.6385963853942549` to `-2.7034216420880046`.
# 2026-01-15 17:20:24: oggm.cfg: PARAMS['melt_f'] changed from `13.465434322780341` to `3.0469777855536595`.
# 2026-01-15 17:20:24: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6592864039712609` to `7.253978668923191`.
# 2026-01-15 17:20:24: oggm.cfg: PARAMS['temp_bias'] changed from `-2.7034216420880046` to `-5.364330073046254`.
# 2026-01-15 17:20:25: oggm.cfg: PARAMS['melt_f'] changed from `3.0469777855536595` to `9.200218858735518`.
# 2026-01-15 17:20:25: oggm.cfg: PARAMS['prcp_fac'] changed from `7.253978668923191` to `6.423474189435579`.
# 2026-01-15 17:20:25: oggm.cfg: PARAMS['temp_bias'] changed from `-5.364330073046254` to `14.219569297054964`.
# 2026-01-15 17:20:26: oggm.cfg: PARAMS['melt_f'] changed from `9.200218858735518` to `11.485249015049373`.
# 2026-01-15 17:20:26: oggm.cfg: PARAMS['prcp_fac'] changed from `6.423474189435579` to `1.4373925549101418`.
# 2026-01-15 17:20:26: oggm.cfg: PARAMS['temp_bias'] changed from `14.219569297054964` to `0.5760007691203608`.
# 2026-01-15 17:20:26: oggm.cfg: PARAMS['melt_f'] changed from `11.485249015049373` to `16.072106239460354`.
# 2026-01-15 17:20:26: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4373925549101418` to `6.5612935183505465`.
# 2026-01-15 17:20:26: oggm.cfg: PARAMS['temp_bias'] changed from `0.5760007691203608` to `-8.925420278836416`.
# 2026-01-15 17:20:27: oggm.cfg: PARAMS['melt_f'] changed from `16.072106239460354` to `14.107227414412355`.
# 2026-01-15 17:20:27: oggm.cfg: PARAMS['prcp_fac'] changed from `6.5612935183505465` to `2.105980071236529`.
# 2026-01-15 17:20:27: oggm.cfg: PARAMS['temp_bias'] changed from `-8.925420278836416` to `-6.420766393915706`.
# 2026-01-15 17:20:28: oggm.cfg: PARAMS['melt_f'] changed from `14.107227414412355` to `8.843279107514038`.
# 2026-01-15 17:20:28: oggm.cfg: PARAMS['prcp_fac'] changed from `2.105980071236529` to `8.098957382549102`.
# 2026-01-15 17:20:28: oggm.cfg: PARAMS['temp_bias'] changed from `-6.420766393915706` to `11.625715382399154`.
# 2026-01-15 17:20:29: oggm.cfg: PARAMS['melt_f'] changed from `8.843279107514038` to `8.351272274104018`.
# 2026-01-15 17:20:29: oggm.cfg: PARAMS['prcp_fac'] changed from `8.098957382549102` to `9.162556670274446`.
# 2026-01-15 17:20:29: oggm.cfg: PARAMS['temp_bias'] changed from `11.625715382399154` to `9.62376878097001`.
# 2026-01-15 17:20:29: oggm.cfg: PARAMS['melt_f'] changed from `8.351272274104018` to `7.206890132099486`.
# 2026-01-15 17:20:29: oggm.cfg: PARAMS['prcp_fac'] changed from `9.162556670274446` to `1.4364432449772202`.
# 2026-01-15 17:20:29: oggm.cfg: PARAMS['temp_bias'] changed from `9.62376878097001` to `3.9930127775049407`.
# 2026-01-15 17:20:30: oggm.cfg: PARAMS['melt_f'] changed from `7.206890132099486` to `7.5741274424258185`.
# 2026-01-15 17:20:30: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4364432449772202` to `6.10219618110858`.
# 2026-01-15 17:20:30: oggm.cfg: PARAMS['temp_bias'] changed from `3.9930127775049407` to `10.796333813519787`.
# 2026-01-15 17:20:30: oggm.cfg: PARAMS['melt_f'] changed from `7.5741274424258185` to `16.343303183494992`.
# 2026-01-15 17:20:30: oggm.cfg: PARAMS['prcp_fac'] changed from `6.10219618110858` to `4.878767916921835`.
# 2026-01-15 17:20:30: oggm.cfg: PARAMS['temp_bias'] changed from `10.796333813519787` to `-14.87378493040835`.
# 2026-01-15 17:20:31: oggm.cfg: PARAMS['melt_f'] changed from `16.343303183494992` to `1.6886728478936062`.
# 2026-01-15 17:20:31: oggm.cfg: PARAMS['prcp_fac'] changed from `4.878767916921835` to `9.046647982217946`.
# 2026-01-15 17:20:31: oggm.cfg: PARAMS['temp_bias'] changed from `-14.87378493040835` to `1.5655498857593315`.
# 2026-01-15 17:20:32: oggm.cfg: PARAMS['melt_f'] changed from `1.6886728478936062` to `10.45261023707246`.
# 2026-01-15 17:20:32: oggm.cfg: PARAMS['prcp_fac'] changed from `9.046647982217946` to `0.195941246151356`.
# 2026-01-15 17:20:32: oggm.cfg: PARAMS['temp_bias'] changed from `1.5655498857593315` to `11.902911368816326`.
# 2026-01-15 17:20:32: oggm.cfg: PARAMS['melt_f'] changed from `10.45261023707246` to `10.862714568150494`.
# 2026-01-15 17:20:32: oggm.cfg: PARAMS['prcp_fac'] changed from `0.195941246151356` to `5.751823494001198`.
# 2026-01-15 17:20:32: oggm.cfg: PARAMS['temp_bias'] changed from `11.902911368816326` to `-12.96860027715373`.
# 2026-01-15 17:20:33: oggm.cfg: PARAMS['melt_f'] changed from `10.862714568150494` to `7.869021082792756`.
# 2026-01-15 17:20:33: oggm.cfg: PARAMS['prcp_fac'] changed from `5.751823494001198` to `7.809942970409507`.
# 2026-01-15 17:20:33: oggm.cfg: PARAMS['temp_bias'] changed from `-12.96860027715373` to `2.331664707605917`.
# 2026-01-15 17:20:34: oggm.cfg: PARAMS['melt_f'] changed from `7.869021082792756` to `9.73744730759128`.
# 2026-01-15 17:20:34: oggm.cfg: PARAMS['prcp_fac'] changed from `7.809942970409507` to `4.318657650305759`.
# 2026-01-15 17:20:34: oggm.cfg: PARAMS['temp_bias'] changed from `2.331664707605917` to `-12.161301550167865`.
# 2026-01-15 17:20:35: oggm.cfg: PARAMS['melt_f'] changed from `9.73744730759128` to `5.0082655709942365`.
# 2026-01-15 17:20:35: oggm.cfg: PARAMS['prcp_fac'] changed from `4.318657650305759` to `1.083394199905207`.
# 2026-01-15 17:20:35: oggm.cfg: PARAMS['temp_bias'] changed from `-12.161301550167865` to `9.913001058167648`.
# 2026-01-15 17:20:35: oggm.cfg: PARAMS['melt_f'] changed from `5.0082655709942365` to `15.205810980233315`.
# 2026-01-15 17:20:35: oggm.cfg: PARAMS['prcp_fac'] changed from `1.083394199905207` to `2.0237658242475973`.
# 2026-01-15 17:20:35: oggm.cfg: PARAMS['temp_bias'] changed from `9.913001058167648` to `-2.8988654018182416`.
# 2026-01-15 17:20:36: oggm.cfg: PARAMS['melt_f'] changed from `15.205810980233315` to `8.877055760628814`.
# ...
# 2026-01-15 17:29:35: oggm.cfg: PARAMS['temp_bias'] changed from `1.8264496610958645` to `4.538546918997579`.
# 2026-01-15 17:29:35: oggm.cfg: PARAMS['melt_f'] changed from `3.1223433864836565` to `14.689560549462131`.
# 2026-01-15 17:29:35: oggm.cfg: PARAMS['prcp_fac'] changed from `4.856929823210468` to `9.381435770390555`.
# 2026-01-15 17:29:35: oggm.cfg: PARAMS['temp_bias'] changed from `4.538546918997579` to `5.093772670859618`.
# 2026-01-15 17:29:36: oggm.cfg: PARAMS['melt_f'] changed from `14.689560549462131` to `7.101573194925505`.
# 2026-01-15 17:29:36: oggm.cfg: PARAMS['prcp_fac'] changed from `9.381435770390555` to `4.0578440356482375`.
# 2026-01-15 17:29:36: oggm.cfg: PARAMS['temp_bias'] changed from `5.093772670859618` to `2.8966215782830176`.
# 2026-01-15 17:29:36: oggm.cfg: PARAMS['melt_f'] changed from `7.101573194925505` to `15.464997559424447`.
# 2026-01-15 17:29:36: oggm.cfg: PARAMS['prcp_fac'] changed from `4.0578440356482375` to `5.175929841963539`.
# 2026-01-15 17:29:36: oggm.cfg: PARAMS['temp_bias'] changed from `2.8966215782830176` to `-12.934493311434771`.
# 2026-01-15 17:29:37: oggm.cfg: PARAMS['melt_f'] changed from `15.464997559424447` to `13.906028652575165`.
# 2026-01-15 17:29:37: oggm.cfg: PARAMS['prcp_fac'] changed from `5.175929841963539` to `2.9827510993262294`.
# 2026-01-15 17:29:37: oggm.cfg: PARAMS['temp_bias'] changed from `-12.934493311434771` to `-11.001131658809253`.
# 2026-01-15 17:29:38: oggm.cfg: PARAMS['melt_f'] changed from `13.906028652575165` to `8.773765463679403`.
# 2026-01-15 17:29:38: oggm.cfg: PARAMS['prcp_fac'] changed from `2.9827510993262294` to `7.218517119566695`.
# 2026-01-15 17:29:38: oggm.cfg: PARAMS['temp_bias'] changed from `-11.001131658809253` to `9.408492082879732`.
# 2026-01-15 17:29:38: oggm.cfg: PARAMS['melt_f'] changed from `8.773765463679403` to `9.546018405217875`.
# 2026-01-15 17:29:38: oggm.cfg: PARAMS['prcp_fac'] changed from `7.218517119566695` to `4.481287649040999`.
# 2026-01-15 17:29:38: oggm.cfg: PARAMS['temp_bias'] changed from `9.408492082879732` to `-14.68627185493202`.
# 2026-01-15 17:29:39: oggm.cfg: PARAMS['melt_f'] changed from `9.546018405217875` to `9.98295246024133`.
# 2026-01-15 17:29:39: oggm.cfg: PARAMS['prcp_fac'] changed from `4.481287649040999` to `3.406168935487454`.
# 2026-01-15 17:29:39: oggm.cfg: PARAMS['temp_bias'] changed from `-14.68627185493202` to `7.127415924165252`.
# 2026-01-15 17:29:39: oggm.cfg: PARAMS['melt_f'] changed from `9.98295246024133` to `2.7104305595755838`.
# 2026-01-15 17:29:39: oggm.cfg: PARAMS['prcp_fac'] changed from `3.406168935487454` to `5.13007028756072`.
# 2026-01-15 17:29:39: oggm.cfg: PARAMS['temp_bias'] changed from `7.127415924165252` to `-11.751577859522985`.
# 2026-01-15 17:29:40: oggm.cfg: PARAMS['melt_f'] changed from `2.7104305595755838` to `4.285521611842464`.
# 2026-01-15 17:29:40: oggm.cfg: PARAMS['prcp_fac'] changed from `5.13007028756072` to `1.3338226123298265`.
# 2026-01-15 17:29:40: oggm.cfg: PARAMS['temp_bias'] changed from `-11.751577859522985` to `-10.089987445376002`.
# 2026-01-15 17:29:41: oggm.cfg: PARAMS['melt_f'] changed from `4.285521611842464` to `1.849166346142093`.
# 2026-01-15 17:29:41: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3338226123298265` to `4.029187974836047`.
# 2026-01-15 17:29:41: oggm.cfg: PARAMS['temp_bias'] changed from `-10.089987445376002` to `2.056110621643086`.
# 2026-01-15 17:29:41: oggm.cfg: PARAMS['melt_f'] changed from `1.849166346142093` to `1.7250871151124616`.
# 2026-01-15 17:29:41: oggm.cfg: PARAMS['prcp_fac'] changed from `4.029187974836047` to `1.7210822811435018`.
# 2026-01-15 17:29:41: oggm.cfg: PARAMS['temp_bias'] changed from `2.056110621643086` to `0.47358322996775293`.
# 2026-01-15 17:29:42: oggm.cfg: PARAMS['melt_f'] changed from `1.7250871151124616` to `12.545545372633317`.
# 2026-01-15 17:29:42: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7210822811435018` to `9.389426497611646`.
# 2026-01-15 17:29:42: oggm.cfg: PARAMS['temp_bias'] changed from `0.47358322996775293` to `1.450078148409986`.
# 2026-01-15 17:29:42: oggm.cfg: PARAMS['melt_f'] changed from `12.545545372633317` to `2.5471164426636483`.
# 2026-01-15 17:29:42: oggm.cfg: PARAMS['prcp_fac'] changed from `9.389426497611646` to `9.88480533452502`.
# 2026-01-15 17:29:42: oggm.cfg: PARAMS['temp_bias'] changed from `1.450078148409986` to `-5.091228582395754`.
# 2026-01-15 17:29:44: oggm.cfg: PARAMS['melt_f'] changed from `2.5471164426636483` to `3.3031884206588398`.
# 2026-01-15 17:29:44: oggm.cfg: PARAMS['prcp_fac'] changed from `9.88480533452502` to `4.076680572366483`.
# 2026-01-15 17:29:44: oggm.cfg: PARAMS['temp_bias'] changed from `-5.091228582395754` to `8.993935004623342`.
# 2026-01-15 17:29:44: oggm.cfg: PARAMS['melt_f'] changed from `3.3031884206588398` to `9.09490377901312`.
# 2026-01-15 17:29:44: oggm.cfg: PARAMS['prcp_fac'] changed from `4.076680572366483` to `6.00764589002935`.
# 2026-01-15 17:29:44: oggm.cfg: PARAMS['temp_bias'] changed from `8.993935004623342` to `-13.885312226636257`.
# 2026-01-15 17:29:45: oggm.cfg: PARAMS['melt_f'] changed from `9.09490377901312` to `1.9006196704582474`.
# 2026-01-15 17:29:45: oggm.cfg: PARAMS['prcp_fac'] changed from `6.00764589002935` to `5.598975939845365`.
# 2026-01-15 17:29:45: oggm.cfg: PARAMS['temp_bias'] changed from `-13.885312226636257` to `-14.893662273902626`.
# 2026-01-15 17:29:46: oggm.cfg: PARAMS['melt_f'] changed from `1.9006196704582474` to `10.257140099702578`.
# 2026-01-15 17:29:46: oggm.cfg: PARAMS['prcp_fac'] changed from `5.598975939845365` to `2.6709052082228433`.
# 2026-01-15 17:29:46: oggm.cfg: PARAMS['temp_bias'] changed from `-14.893662273902626` to `6.855137871079528`.
# 2026-01-15 17:29:46: oggm.cfg: PARAMS['melt_f'] changed from `10.257140099702578` to `10.974056557407044`.
# 2026-01-15 17:29:46: oggm.cfg: PARAMS['prcp_fac'] changed from `2.6709052082228433` to `8.626883158363677`.
# 2026-01-15 17:29:46: oggm.cfg: PARAMS['temp_bias'] changed from `6.855137871079528` to `5.008029815433147`.
# 2026-01-15 17:29:47: oggm.cfg: PARAMS['melt_f'] changed from `10.974056557407044` to `7.825453208144736`.
# 2026-01-15 17:29:47: oggm.cfg: PARAMS['prcp_fac'] changed from `8.626883158363677` to `1.4686281876205765`.
# 2026-01-15 17:29:47: oggm.cfg: PARAMS['temp_bias'] changed from `5.008029815433147` to `5.850001960834383`.
# 2026-01-15 17:29:47: oggm.cfg: PARAMS['melt_f'] changed from `7.825453208144736` to `9.128982089057459`.
# 2026-01-15 17:29:47: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4686281876205765` to `6.567339863015887`.
# 2026-01-15 17:29:47: oggm.cfg: PARAMS['temp_bias'] changed from `5.850001960834383` to `2.410840511151612`.
# 2026-01-15 17:29:48: oggm.cfg: PARAMS['melt_f'] changed from `9.128982089057459` to `4.053846034529897`.
# 2026-01-15 17:29:48: oggm.cfg: PARAMS['prcp_fac'] changed from `6.567339863015887` to `1.8042970671236371`.
# 2026-01-15 17:29:48: oggm.cfg: PARAMS['temp_bias'] changed from `2.410840511151612` to `-9.267507352020015`.
# 2026-01-15 17:29:49: oggm.cfg: PARAMS['melt_f'] changed from `4.053846034529897` to `7.925977154469769`.
# 2026-01-15 17:29:49: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8042970671236371` to `6.790313338511778`.
# 2026-01-15 17:29:49: oggm.cfg: PARAMS['temp_bias'] changed from `-9.267507352020015` to `7.826401123500645`.
# 2026-01-15 17:29:49: oggm.cfg: PARAMS['melt_f'] changed from `7.925977154469769` to `15.31121561194439`.
# 2026-01-15 17:29:49: oggm.cfg: PARAMS['prcp_fac'] changed from `6.790313338511778` to `1.2852983607739117`.
# 2026-01-15 17:29:49: oggm.cfg: PARAMS['temp_bias'] changed from `7.826401123500645` to `-2.8652025886568957`.
# 2026-01-15 17:29:50: oggm.cfg: PARAMS['melt_f'] changed from `15.31121561194439` to `1.9063543715244176`.
# 2026-01-15 17:29:50: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2852983607739117` to `2.704644842969127`.
# 2026-01-15 17:29:50: oggm.cfg: PARAMS['temp_bias'] changed from `-2.8652025886568957` to `-4.0049522176722245`.
# 2026-01-15 17:29:50: oggm.cfg: PARAMS['melt_f'] changed from `1.9063543715244176` to `15.429664153318704`.
# 2026-01-15 17:29:50: oggm.cfg: PARAMS['prcp_fac'] changed from `2.704644842969127` to `4.305229115203027`.
# 2026-01-15 17:29:50: oggm.cfg: PARAMS['temp_bias'] changed from `-4.0049522176722245` to `5.495283175848687`.
# 2026-01-15 17:29:51: oggm.cfg: PARAMS['melt_f'] changed from `15.429664153318704` to `11.146773475795381`.
# 2026-01-15 17:29:51: oggm.cfg: PARAMS['prcp_fac'] changed from `4.305229115203027` to `5.0003776242293085`.
# 2026-01-15 17:29:51: oggm.cfg: PARAMS['temp_bias'] changed from `5.495283175848687` to `-10.279022795634535`.
# 2026-01-15 17:29:52: oggm.cfg: PARAMS['melt_f'] changed from `11.146773475795381` to `5.971652943912787`.
# 2026-01-15 17:29:52: oggm.cfg: PARAMS['prcp_fac'] changed from `5.0003776242293085` to `8.232846393888025`.
# 2026-01-15 17:29:52: oggm.cfg: PARAMS['temp_bias'] changed from `-10.279022795634535` to `4.4019644369281`.
# 2026-01-15 17:29:52: oggm.cfg: PARAMS['melt_f'] changed from `5.971652943912787` to `3.8963380445260727`.
# 2026-01-15 17:29:52: oggm.cfg: PARAMS['prcp_fac'] changed from `8.232846393888025` to `6.011867902438946`.
# 2026-01-15 17:29:52: oggm.cfg: PARAMS['temp_bias'] changed from `4.4019644369281` to `-11.433597225529052`.
# 2026-01-15 17:29:53: oggm.cfg: PARAMS['melt_f'] changed from `3.8963380445260727` to `3.5039222234635883`.
# 2026-01-15 17:29:53: oggm.cfg: PARAMS['prcp_fac'] changed from `6.011867902438946` to `6.331760793300643`.
# 2026-01-15 17:29:53: oggm.cfg: PARAMS['temp_bias'] changed from `-11.433597225529052` to `2.151445620380528`.
# 2026-01-15 17:29:53: oggm.cfg: PARAMS['melt_f'] changed from `3.5039222234635883` to `16.052195118419114`.
# 2026-01-15 17:29:53: oggm.cfg: PARAMS['prcp_fac'] changed from `6.331760793300643` to `6.438642163383113`.
# 2026-01-15 17:29:53: oggm.cfg: PARAMS['temp_bias'] changed from `2.151445620380528` to `-1.2530965073899871`.
# 2026-01-15 17:29:54: oggm.cfg: PARAMS['melt_f'] changed from `16.052195118419114` to `15.885084103893744`.
# 2026-01-15 17:29:54: oggm.cfg: PARAMS['prcp_fac'] changed from `6.438642163383113` to `5.882968443307817`.
# 2026-01-15 17:29:54: oggm.cfg: PARAMS['temp_bias'] changed from `-1.2530965073899871` to `-6.572243234709315`.
# 2026-01-15 17:29:55: oggm.cfg: PARAMS['melt_f'] changed from `15.885084103893744` to `2.750937775109221`.
# 2026-01-15 17:29:55: oggm.cfg: PARAMS['prcp_fac'] changed from `5.882968443307817` to `1.3114075202279785`.
# 2026-01-15 17:29:55: oggm.cfg: PARAMS['temp_bias'] changed from `-6.572243234709315` to `-14.303504883083926`.
# 2026-01-15 17:29:55: oggm.cfg: PARAMS['melt_f'] changed from `2.750937775109221` to `10.581487217714571`.
# 2026-01-15 17:29:55: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3114075202279785` to `5.639256753595563`.
# 2026-01-15 17:29:55: oggm.cfg: PARAMS['temp_bias'] changed from `-14.303504883083926` to `-0.399153902452662`.
# 2026-01-15 17:29:56: oggm.cfg: PARAMS['melt_f'] changed from `10.581487217714571` to `11.638508112482926`.
# 2026-01-15 17:29:56: oggm.cfg: PARAMS['prcp_fac'] changed from `5.639256753595563` to `1.414173228067997`.
# 2026-01-15 17:29:56: oggm.cfg: PARAMS['temp_bias'] changed from `-0.399153902452662` to `9.457411664541144`.
# 2026-01-15 17:29:56: oggm.cfg: PARAMS['melt_f'] changed from `11.638508112482926` to `9.483364212740678`.
# 2026-01-15 17:29:56: oggm.cfg: PARAMS['prcp_fac'] changed from `1.414173228067997` to `3.530137594385236`.
# 2026-01-15 17:29:56: oggm.cfg: PARAMS['temp_bias'] changed from `9.457411664541144` to `9.357579542389058`.
# 2026-01-15 17:29:57: oggm.cfg: PARAMS['melt_f'] changed from `9.483364212740678` to `8.933489450079009`.
# 2026-01-15 17:29:57: oggm.cfg: PARAMS['prcp_fac'] changed from `3.530137594385236` to `1.8663172281818836`.
# 2026-01-15 17:29:57: oggm.cfg: PARAMS['temp_bias'] changed from `9.357579542389058` to `8.478267704442704`.
# 2026-01-15 17:29:57: oggm.cfg: PARAMS['melt_f'] changed from `8.933489450079009` to `7.050567314648041`.
# 2026-01-15 17:29:57: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8663172281818836` to `8.264450534820915`.
# 2026-01-15 17:29:57: oggm.cfg: PARAMS['temp_bias'] changed from `8.478267704442704` to `0.7841822564455896`.
# 2026-01-15 17:29:58: oggm.cfg: PARAMS['melt_f'] changed from `7.050567314648041` to `2.4049137178034856`.
# 2026-01-15 17:29:58: oggm.cfg: PARAMS['prcp_fac'] changed from `8.264450534820915` to `1.0366251678616156`.
# 2026-01-15 17:29:58: oggm.cfg: PARAMS['temp_bias'] changed from `0.7841822564455896` to `1.745491578625053`.
# 2026-01-15 17:29:59: oggm.cfg: PARAMS['melt_f'] changed from `2.4049137178034856` to `5.835052816744579`.
# 2026-01-15 17:29:59: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0366251678616156` to `7.848300987316111`.
# 2026-01-15 17:29:59: oggm.cfg: PARAMS['temp_bias'] changed from `1.745491578625053` to `2.2835652474530725`.
# 2026-01-15 17:29:59: oggm.cfg: PARAMS['melt_f'] changed from `5.835052816744579` to `8.644636700355075`.
# 2026-01-15 17:29:59: oggm.cfg: PARAMS['prcp_fac'] changed from `7.848300987316111` to `6.582486443606388`.
# 2026-01-15 17:29:59: oggm.cfg: PARAMS['temp_bias'] changed from `2.2835652474530725` to `13.20959891275347`.
# 2026-01-15 17:30:00: oggm.cfg: PARAMS['melt_f'] changed from `8.644636700355075` to `14.787050291116865`.
# 2026-01-15 17:30:00: oggm.cfg: PARAMS['prcp_fac'] changed from `6.582486443606388` to `7.450550080888014`.
# 2026-01-15 17:30:00: oggm.cfg: PARAMS['temp_bias'] changed from `13.20959891275347` to `14.392767547742348`.
# 2026-01-15 17:30:00: oggm.cfg: PARAMS['melt_f'] changed from `14.787050291116865` to `8.459439531195642`.
# 2026-01-15 17:30:00: oggm.cfg: PARAMS['prcp_fac'] changed from `7.450550080888014` to `0.4983420187346834`.
# 2026-01-15 17:30:00: oggm.cfg: PARAMS['temp_bias'] changed from `14.392767547742348` to `-6.933809752734316`.
# 2026-01-15 17:30:01: oggm.cfg: PARAMS['melt_f'] changed from `8.459439531195642` to `11.412050606051954`.
# 2026-01-15 17:30:01: oggm.cfg: PARAMS['prcp_fac'] changed from `0.4983420187346834` to `5.972486914208027`.
# 2026-01-15 17:30:01: oggm.cfg: PARAMS['temp_bias'] changed from `-6.933809752734316` to `5.307893987192507`.
# 2026-01-15 17:30:01: oggm.cfg: PARAMS['melt_f'] changed from `11.412050606051954` to `14.94797345206214`.
# 2026-01-15 17:30:01: oggm.cfg: PARAMS['prcp_fac'] changed from `5.972486914208027` to `4.179154332747559`.
# 2026-01-15 17:30:01: oggm.cfg: PARAMS['temp_bias'] changed from `5.307893987192507` to `-2.6134736910394274`.
# 2026-01-15 17:30:02: oggm.cfg: PARAMS['melt_f'] changed from `14.94797345206214` to `14.357422202226642`.
# 2026-01-15 17:30:02: oggm.cfg: PARAMS['prcp_fac'] changed from `4.179154332747559` to `6.349404335479368`.
# 2026-01-15 17:30:02: oggm.cfg: PARAMS['temp_bias'] changed from `-2.6134736910394274` to `10.104315763770803`.
# 2026-01-15 17:30:03: oggm.cfg: PARAMS['melt_f'] changed from `14.357422202226642` to `4.471362830704113`.
# 2026-01-15 17:30:03: oggm.cfg: PARAMS['prcp_fac'] changed from `6.349404335479368` to `4.216646010786789`.
# 2026-01-15 17:30:03: oggm.cfg: PARAMS['temp_bias'] changed from `10.104315763770803` to `-6.704578690815431`.
# 2026-01-15 17:30:03: oggm.cfg: PARAMS['melt_f'] changed from `4.471362830704113` to `11.892288831629791`.
# 2026-01-15 17:30:03: oggm.cfg: PARAMS['prcp_fac'] changed from `4.216646010786789` to `5.961853558708865`.
# 2026-01-15 17:30:03: oggm.cfg: PARAMS['temp_bias'] changed from `-6.704578690815431` to `8.405397272589628`.
# 2026-01-15 17:30:04: oggm.cfg: PARAMS['melt_f'] changed from `11.892288831629791` to `8.467403648800689`.
# 2026-01-15 17:30:04: oggm.cfg: PARAMS['prcp_fac'] changed from `5.961853558708865` to `7.8261920794481865`.
# 2026-01-15 17:30:04: oggm.cfg: PARAMS['temp_bias'] changed from `8.405397272589628` to `-9.198984166953636`.
# 2026-01-15 17:30:05: oggm.cfg: PARAMS['melt_f'] changed from `8.467403648800689` to `11.837827783954788`.
# 2026-01-15 17:30:05: oggm.cfg: PARAMS['prcp_fac'] changed from `7.8261920794481865` to `8.713743255564825`.
# 2026-01-15 17:30:05: oggm.cfg: PARAMS['temp_bias'] changed from `-9.198984166953636` to `6.613281354566446`.

# %%
# Plot Monte Carlo (MC) simulations results for the Runoff and compare with data:
plt.figure(figsize=[15,5])
plt.plot(mbdf.index.values, np.transpose(runoff), 'k', linewidth = 0.5)
plt.ylabel('Runoff'); plt.xlabel('Years')
plt.legend(['sim'])
plt.title("Number of parameter samples: N = %d" % N, loc='right')
plt.show()

# %%
# Also colour mapping (retrospectively) based on temp_bias values
import matplotlib.pyplot as plt
import numpy as np

temp_bias_index = 2  # Index of temp_bias in X


import matplotlib.pyplot as plt
import numpy as np

# Colormap and normalization
cmap = plt.cm.coolwarm
norm = plt.Normalize(vmin=X[:, temp_bias_index].min(), vmax=X[:, temp_bias_index].max())

fig, ax = plt.subplots(figsize=(15, 5))

# Plot each simulation with color based on temp_bias
for i in range(np.shape(runoff)[0]):  # assuming QQ_runoff is (N, time)
    color = cmap(norm(X[i, temp_bias_index]))
    ax.plot(mbdf.index.values, runoff[i, :], linewidth=0.5, color=color)

ax.set_ylabel('Runoff')
ax.set_xlabel('Years')
ax.set_title(f"Number of parameter samples: N = {N}", loc='right')

# Add colorbar linked to the same colormap
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # required for colorbar
cbar = fig.colorbar(sm, ax=ax)  # <-- specify ax here
cbar.set_label('Temperature Bias')

plt.show()

# %% [markdown]
# ## Distribution of Model Outputs

# %%
Y_lab_runoff_dist = ['Mean Runoff', 'Std of Runoff']

YY_hydro = np.nan * np.ones((N, 2))

for i, x in enumerate(runoff):
    YY_hydro[i,0] = np.mean(x)
    YY_hydro[i,1] = np.std(x)

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_hydro[:,0], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_lab_runoff_dist[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_hydro[:,1], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_lab_runoff_dist[1])

plt.tight_layout()

# %% [markdown]
# ## Sensitivity Analysis

# %%
annual_mean_runoff = np.mean(runoff, axis=1) # Mean annual runoff for each sample
annual_std_runoff = np.std(runoff, axis=1) # Std annual runoff for each sample

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(annual_mean_runoff, annual_std_runoff, s=5), plt.title('Mean runoff vs Std of runoff'), plt.xlabel('Mean runoff'), plt.ylabel('Std of runoff (mm w.e.)'),
# plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.tight_layout()
plt.show()

# %%
YY_hydro = np.nan * np.ones((N, 2))

for i, x in enumerate(runoff):
    YY_hydro[i,0] = np.mean(x)
    YY_hydro[i,1] = np.std(x)

Y_Labels = ['Mean Runoff', 'Std of Runoff']

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY_hydro[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %%
temp_bias_index = 2

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], YY_hydro[:, j], c=X[:, temp_bias_index], cmap='coolwarm', edgecolors='grey')
        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Temp Bias (°C)')
    plt.show()

interact(scatter_function, metric=Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %%
Nboot = 50 # Number of resamples used for bootstrapping
# Here fails when target is 0 for mean and std runoff, so we set small values instead

for i in range(2):
    if i==0:
        Y=YY_hydro[:,0]
        target=0.1
    if i==1:
        Y=YY_hydro[:,1]
        target=0.1

    # plot:
    plt.figure(figsize=[7,2])
    mvd, _, _, idx = RSA_tr.RSA_indices_thres(X, Y, target, Nboot=Nboot)
    mvd_m, mvd_lb, mvd_ub = aggregate_boot(mvd) # shape (M,)
    yerr=np.c_[mvd_m-mvd_lb,mvd_ub-mvd_m].T
    plt.bar(range(len(mvd_m)), mvd_m, color='grey',yerr=yerr)
    plt.title(Y_Labels[i], loc='center'), plt.xticks(range(len(mvd_m)), X_labels), plt.ylabel('Sensitivity')
    plt.show()
