# %% [markdown]
# # Investigating parameters effects on Sensitivity of the OGGM Mass Balance and Runoff Models

# %% [markdown]
# In this notebook we will explore the sensitivity of OGGM's mass-balance and runoff models using SAFE. We will focus on the three parameters: melt factor, precipitation factor and temperature bias.
#
# We will start by applying one-at-a-time sensitivity analysis to get a feel for how much each parameter affects the model and output. We will then consider the uncertainty of these sensitivities and work to quantify them.

# %% [markdown]
# ## Sensitivity Analysis with the OGGM Mass Balance Model

# %% [markdown]
# We will apply sensitivity analysis in the following order to investigate our model behaviour:
#
# 1. **One-at-a-time**: We will apply one-at-a-time analysis , in which we change one parameter at a time and see how the mass balance changes in accordance. To show this, we will plot an interactive mass balance time series with toggles, where the parameter values can be changed within their default boundaries.
# 2. **Global sensitivity analysis**: Here we will use AAT sampling to randomly sample a combination of the 3 parameters and investigate the sensitivity in the following ways
#     a. Qualitative - scatter plots
#     b. Quantitative - RSA and bootstrapping
#
# This will be applied first to the mass balance model in the OGGM, and then to the runoff model in the OGGM.

# %% [markdown]
# First we install the packages we require from both OGGM and SAFE.

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import scipy.stats as st

import oggm
from oggm import cfg, utils, workflow
from oggm.core import massbalance
from oggm.utils._funcs import rmsd
from oggm import tasks

# Install python package for interactive visualisation and import required functions:
# %pip install -q ipywidgets
from ipywidgets import interact

# Install SAFE package and import required functions
# %pip install SAFEpython

import xarray as xr
import safepython.PAWN as PAWN # Module to calculate PAWN sensitivity indices
import safepython.RSA_thres as RSA_tr # Module that implements RSA
from safepython.model_execution import model_execution # Module to execute the model
from safepython.sampling import AAT_sampling # Functions to perform the input sampling
from safepython.util import aggregate_boot # Functions to perform bootstrapping
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: SAFEpython in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: matplotlib>=2.2.3 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (3.10.6)
# Requirement already satisfied: numpy>=1.19.2 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (1.26.4)
# Requirement already satisfied: scipy>=1.3.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from SAFEpython) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (25.0)
# Requirement already satisfied: pillow>=8 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from matplotlib>=2.2.3->SAFEpython) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/chloe/micromamba/envs/oggm_env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->SAFEpython) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now prepare to load the glacier dierectories from the OGGM.

# %%
cfg.initialize(logging_level='WARNING')
cfg.PATHS['working_dir'] = utils.gettempdir(dirname='OGGM-calib-ro', reset=True)
cfg.PARAMS['border'] = 10
cfg.PARAMS['store_model_geometry'] = True
oggm.cfg.PARAMS['min_ice_thick_for_length'] = 1  # a glacier is when ice thicker than 1m
# Out:
# 2026-01-15 10:25:57: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2026-01-15 10:25:57: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2026-01-15 10:25:57: oggm.cfg: Multiprocessing: using all available processors (N=22)
# 2026-01-15 10:25:57: oggm.cfg: PARAMS['border'] changed from `80` to `10`.
# 2026-01-15 10:25:57: oggm.cfg: PARAMS['store_model_geometry'] changed from `False` to `True`.
# 2026-01-15 10:25:57: oggm.cfg: PARAMS['min_ice_thick_for_length'] changed from `0.0` to `1`.

# %% [markdown]
# We start from a well known glacier in the Austrian Alps, Hintereisferner. But you can choose any other glacier, e.g. from [this list](https://github.com/OGGM/oggm-sample-data/blob/master/wgms/rgi_wgms_links_20220112.csv)

# %%
# Hintereisferner
rgi_id = 'RGI60-11.00897'

# We pick the elevation-bands glaciers because they run a bit faster - but they create more step changes in the area outputs
base_url = 'https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/L3-L5_files/2023.3/elev_bands/W5E5_spinup'
gdir_hef = workflow.init_glacier_directories([rgi_id], from_prepro_level=4, prepro_border=160, prepro_base_url=base_url)[0]
# Out:
# 2026-01-15 10:25:59: oggm.workflow: init_glacier_directories from prepro level 4 on 1 glaciers.
# 2026-01-15 10:25:59: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers

# %% [markdown]
# # 1 - One-at-a-time Sensitivity Analysis

# %% [markdown]
# We have loaded all required packages, so now we need to create a runner for the OGGM. To do this, we will set the 3 mass balance parameters to some tentative values, run the model and plot the resulting runoff timeseries. We can then change the parameter values one-at-a-time and look at how this changes the model predictions.
#
# Since we have WGMS observed data here, we will use some fit-to-data metrics to compare the difference in mean, standard deviation and RMSD between the simulated and observed mass balance values.

# %%
mbdf = gdir_hef.get_ref_mb_data().loc[2000:2019] # WGMS data for HEF

def oggm_sim(sample_row, gdir, run_with_hydro=False):

    # Set the parameter values
    melt_f, prcp_fac, temp_bias = sample_row
    cfg.PARAMS['melt_f'] = float(melt_f)
    cfg.PARAMS['prcp_fac'] = float(prcp_fac)
    cfg.PARAMS['temp_bias'] = float(temp_bias)
    
    # Running the model with the given parameters (without calibration which would alter them again)
    mbmod = massbalance.MonthlyTIModel(gdir, melt_f=melt_f, prcp_fac=prcp_fac, temp_bias=temp_bias)
    fls = gdir.read_pickle('inversion_flowlines') # Read flowlines
    mbdf['mod_mb'] = mbmod.get_specific_mb(fls=fls, year=mbdf.index) # Compute modelled mass balance  

    return np.array(mbdf['mod_mb'])

def oggm_hydro_sim(sample_row, gdir):
    # Set the parameter values
    melt_f, prcp_fac, temp_bias = sample_row
    cfg.PARAMS['melt_f'] = float(melt_f)
    cfg.PARAMS['prcp_fac'] = float(prcp_fac)
    cfg.PARAMS['temp_bias'] = float(temp_bias)
    
    # Run the hydrological model here if flagged required
    gdir.settings['error_when_glacier_reaches_boundaries'] = False # TODO- When more realistic, I assume we will not need this?
    
    # Setting the parameters in the glacier directory settings, run_with_hydro is a higher level function that reads them from there
    gdir.settings['melt_f'] = float(melt_f) 
    gdir.settings['prcp_fac'] = float(prcp_fac)
    gdir.settings['temp_bias'] = float(temp_bias)

    # file identifier where the model output is saved
    # Create unique file identifier based on parameters
    file_id = f'_hydro_mf{melt_f:.2f}_pf{prcp_fac:.2f}_tb{temp_bias:.2f}'

    # Delete old file if it exists to force recomputation
    old_file = gdir.get_filepath('model_diagnostics', filesuffix=file_id)
    if os.path.exists(old_file):
        os.remove(old_file)

    # TODO: Check relationship between run_With_hydro and mass balance
    # We are using the task run_with_hydro to store hydrological outputs along with the usual glaciological outputs
    tasks.run_with_hydro(gdir,  # Run on the selected glacier
                     run_task=tasks.run_from_climate_data,  # which climate scenario? See following notebook for other examples
                     ys=2000,  # Period which we will average and constantly repeat
                     init_model_filesuffix='_spinup_historical',  # use the previous run as initial state
                     init_model_yr=2000,  # Start from spinup year 2000
                     store_monthly_hydro=True,  # Monthly ouptuts provide additional information
                     output_filesuffix=file_id);  # an identifier for the output file, to read it later

    with xr.open_dataset(gdir.get_filepath('model_diagnostics', filesuffix=file_id)) as ds:
        # The last step of hydrological output is NaN (we can't compute it for this year)
        ds = ds.isel(time=slice(0, -1)).load()

    sel_vars = [v for v in ds.variables if 'month_2d' not in ds[v].dims]
    df_annual = ds[sel_vars].to_dataframe()

    # These summed variabels give the total runoff from the glacier
    runoff_vars = ['melt_off_glacier', 'melt_on_glacier','liq_prcp_off_glacier', 'liq_prcp_on_glacier']

    # Convert them to megatonnes (instead of kg)
    df_runoff = df_annual[runoff_vars] * 1e-9

    runoff = np.array(df_runoff.sum(axis=1))

    return runoff

# %%
mbdf['in_situ_mb'] = gdir_hef.get_ref_mb_data().loc[2000:2019]['ANNUAL_BALANCE'] # In-situ mass balance for comparison

def output_metric_calculator(sim):
    # Calculates the goodness-of-fit metrics for all model simulations compared to the in-situ mass balance
    YY = np.zeros((sim.shape[0], 3))

    for i in range(sim.shape[0]):
        # Calculate the goodness-of-fit metrics from the simulated mass balance and the in-situ mass balance
        YY[i, 0] = np.array(sim[i].mean() - mbdf['in_situ_mb'].mean()) # Calculate mean difference
        YY[i, 1] = np.array(sim[i].std() - mbdf['in_situ_mb'].std()) # Calculate standard deviation difference
        YY[i, 2] = np.array(rmsd(sim[i], mbdf['in_situ_mb'])) # Calculate RMSD

    return YY

# %% [markdown]
# We will now plot our results, the parameter values can be changed one-at-a-time via a toggle on the graph below.

# %%
# Define interactive visualisation function to set the parameters to some tentative values, 
# run the model and plot the resulting runoff time series

def oat_function(melt_f = 5.0, prcp_fac = 3.4, temp_bias = 0.0):
    # Create parameter array
    param = np.array([melt_f, prcp_fac, temp_bias])
    
    # Run the model with the given parameters, here we are interested in the modelled mass balance time series
    mb = oggm_sim(param, gdir_hef)

    # Plot the results
    plt.figure(figsize=[15,3])
    plt.plot(mbdf['in_situ_mb'].index, mb, label='sim', color='k')
    mbdf['in_situ_mb'] = gdir_hef.get_ref_mb_data().loc[2000:2019]['ANNUAL_BALANCE']
    plt.plot(mbdf['in_situ_mb'], color=[0.7,0.7,0.7], label='obs')
    plt.ylabel('Specific mass balance (mm w.e.)')
    plt.xlabel('Year')
    plt.legend()
    plt.show();

# Create interactive plot, the toggles will change the parameter values 
interact(oat_function,
         melt_f = (1.5, 17.0, 0.1),
         prcp_fac = (0.1, 10.0, 0.1),
         temp_bias = (-15.0, 15.0, 0.1));
# Out:
# interactive(children=(FloatSlider(value=5.0, description='melt_f', max=17.0, min=1.5), FloatSlider(value=3.4, …

# %% [markdown]
# The above graph shows the effects that moving each of the parameters has to the mass balance time series.

# %% [markdown]
# # GSA - Global Sensitvity Analysis

# %% [markdown]
# We will now explore the sensitivity with a global sensitivity analysis. We will create a runner for the OGGM that calculates the mass balance values based off of the parameters sampled. We will be using AAT Sampling from SAFE to perform global sampling.
#
# This method will be creating Monte Carlo Simulations, we will plot the mass balance time series resulting from the Monte Carlo simulations and analyse the results.

# %% [markdown]
# ### Running Monte Carlo Simulations

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)

distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 0.1, -15.0]) # Minimum values for each parameter
x_max = np.array([17.0, 10.0, 15.0]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
    
samp_strat = 'lhs' 

N = 1000 # Number of samples
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

sim = model_execution(oggm_sim, X, gdir_hef, ExtraArgOut=True) # Execute the model for all samples
YY = output_metric_calculator(sim) # Calculate the output metrics for all simulations
# Out:
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `9.8` to `13.776782104846584`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `3.400000000000001` to `4.585588556830747`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `0.0` to `-8.69380547499863`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `13.776782104846584` to `4.414587861658032`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `4.585588556830747` to `4.269765179401558`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-8.69380547499863` to `3.8209913312134667`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `4.414587861658032` to `7.8119020865693125`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `4.269765179401558` to `5.855658915326809`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `3.8209913312134667` to `3.2824811048350107`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `7.8119020865693125` to `5.797529127367084`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `5.855658915326809` to `6.293757602689766`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `3.2824811048350107` to `-8.87175235032646`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `5.797529127367084` to `11.683323437446736`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `6.293757602689766` to `1.3075339779141761`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-8.87175235032646` to `-4.479839475237656`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `11.683323437446736` to `7.591927061131127`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `1.3075339779141761` to `8.853760379090241`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-4.479839475237656` to `-12.105444331284335`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `7.591927061131127` to `15.261520011245963`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `8.853760379090241` to `2.907760752106504`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-12.105444331284335` to `1.1135220152083782`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `15.261520011245963` to `11.22123162787892`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `2.907760752106504` to `0.11065616114657353`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `1.1135220152083782` to `8.863803164314305`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `11.22123162787892` to `9.384694713673587`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `0.11065616114657353` to `8.071491495820975`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `8.863803164314305` to `-0.7291972166542742`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `9.384694713673587` to `16.115065616019102`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `8.071491495820975` to `2.188629236900671`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-0.7291972166542742` to `-3.286230415808438`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `16.115065616019102` to `11.163688211445333`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `2.188629236900671` to `9.333166285774396`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-3.286230415808438` to `-0.2838869732744822`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `11.163688211445333` to `14.664630033984535`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `9.333166285774396` to `1.7690031732349698`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-0.2838869732744822` to `-2.011441187761985`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `14.664630033984535` to `11.524950433607614`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7690031732349698` to `5.6364116031346345`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-2.011441187761985` to `14.108373263024909`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `11.524950433607614` to `16.055939717798573`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `5.6364116031346345` to `4.29701144336032`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `14.108373263024909` to `-14.680851589012082`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `16.055939717798573` to `4.282117460485059`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `4.29701144336032` to `2.4940070671585124`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-14.680851589012082` to `-7.820223928065341`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `4.282117460485059` to `14.445005705163238`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `2.4940070671585124` to `1.4523057089027336`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-7.820223928065341` to `0.5257913057273829`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `14.445005705163238` to `8.692320284567497`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4523057089027336` to `5.174277294102921`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `0.5257913057273829` to `6.31094635615128`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `8.692320284567497` to `16.989869312991562`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `5.174277294102921` to `8.782003625710077`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `6.31094635615128` to `-14.51842203156352`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `16.989869312991562` to `8.431072741549533`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `8.782003625710077` to `7.541549501914059`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-14.51842203156352` to `-11.364484042013409`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `8.431072741549533` to `1.9376457549629562`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from `7.541549501914059` to `3.826053155450708`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['temp_bias'] changed from `-11.364484042013409` to `7.985462214356637`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['melt_f'] changed from `1.9376457549629562` to `11.579180661001395`.
# 2026-01-15 14:03:18: oggm.cfg: PARAMS['prcp_fac'] changed from
.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['temp_bias'] changed from `12.954249489111792` to `6.463092737205937`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['melt_f'] changed from `6.404712656419531` to `12.086121098962721`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['prcp_fac'] changed from `7.365131451281057` to `1.9103410875946054`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['temp_bias'] changed from `6.463092737205937` to `4.436135291416186`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['melt_f'] changed from `12.086121098962721` to `7.42508997728571`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9103410875946054` to `4.668065612891934`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['temp_bias'] changed from `4.436135291416186` to `-8.779781519225159`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['melt_f'] changed from `7.42508997728571` to `2.9948550100074867`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['prcp_fac'] changed from `4.668065612891934` to `8.335474133939124`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['temp_bias'] changed from `-8.779781519225159` to `12.615810827417029`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['melt_f'] changed from `2.9948550100074867` to `8.169332677306581`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['prcp_fac'] changed from `8.335474133939124` to `2.864339097392566`.
# 2026-01-15 14:03:42: oggm.cfg: PARAMS['temp_bias'] changed from `12.615810827417029` to `1.9535088316115576`.

# %% [markdown]
# Plotting the Monte Carlo simulation results and comparison with the observed data.

# %%
# Plot Monte Carlo (MC) simulations results and compare with data:
plt.figure(figsize=[15,5])
plt.plot(mbdf['in_situ_mb'].index.values, np.transpose(sim), 'k', linewidth = 0.5)
plt.plot(mbdf['in_situ_mb'], color=[0.7,0.7,0.7], linewidth=2)
plt.ylabel('Mass Balance'); plt.xlabel('Years')
plt.legend(['sim', 'obs'])
plt.title("Number of parameter samples: N = %d" % N, loc='right')
plt.show()

# %% [markdown]
# We can see from the samples that the mass balance is greatly affected by altering the parameters between their given ranges. The lower mass balances seem to be more sparse, with a more significant clustering towards the higher mass-balances. The observed mass-balance is closer towards the higher mass-balance end of the spectrum, towards 0.

# %% [markdown]
# ### Scatter plot of the fit-to-data metrics

# %% [markdown]
# We will now plot a scatter plot of the fit-to-data metrics, this will show us the relationship between the metrics created from our Monte Carlo simulations.

# %%
plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(YY[:,0], YY[:,1], s=5), plt.title('Mean difference vs Std difference'), plt.xlabel('Mean difference (mm w.e.)'), plt.ylabel('Std difference (mm w.e.)'),
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.subplot(1,3,2), plt.scatter(YY[:,0], YY[:,2], s=5), plt.title('Mean difference vs RMSD'), plt.xlabel('Mean difference (mm w.e.)'), plt.ylabel('RMSD (mm w.e.)')
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.subplot(1,3,3), plt.scatter(YY[:,1], YY[:,2], s=5), plt.title('Std difference vs RMSD'), plt.xlabel('Std difference (mm w.e.)'), plt.ylabel('RMSD (mm w.e.)')
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.tight_layout()
plt.show()

# The red lines show the target of having zero differences in the mean, standard deviation and RMSD.
# TODO: Would absolute differences be better than the raw ones?

# %% [markdown]
# The red lines show the target values of our differences, ideally we would want our differences to be 0 and to match the observations as closely as possible.
#
# It can be seen here that all of our fit-to-data metrics are correlated.

# %% [markdown]
# ## Scatter plot for the parameters against the fit-to-data metrics

# %% [markdown]
# Now we can plot the scatter plots for each parameter against each metric, this will help visualise the sensitivities for the mass balance.

# %%
Y_Labels = ['Mean Difference', 'Std Difference', 'RMSD']

def scatter_function(metric='Mean Difference'):
    if metric == 'Mean Difference':
        j = 0
    elif metric == 'Std Difference':
        j = 1  
    elif metric == 'RMSD':
        j = 2
    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Difference', 'Std Difference', 'RMSD'), va…

# %% [markdown]
# ### Distribution of the model outputs

# %% [markdown]
# Now looking at the distribution of the model outputs, here this is the goodness-of-fit parameters.

# %%
Y_Labels = ['Mean difference (mm w.e.)', 'Std difference (mm w.e.)', 'RMSD (mm w.e.)', 'Mean & Std difference jointly']

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,0], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,1], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[1])

plt.subplot(1,3,3), plt.title('Distribution of output samples', loc='left'), plt.hist(YY[:,2], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_Labels[2])

plt.tight_layout()

# %% [markdown]
# Looking at our distributions of the output samples, the distributions are as follows:
# 1. Mean difference: Skewed distribition with a long tail (negative skew)
# 2. Std difference: Normal distribution
# 3. RMSD: Skewed distribution with a long tail (positive skew)
#
# TODO: Does this mean we can use RSA vs PAWN?

# %% [markdown]
# # Calculating the Sensitivity Indices
#
# Now we use the input-output samples generated in the previous step to calculate sensitivity indices using **Regional Sensitivity Analysis**. Calculating 3 sets of indices, each measuring the relative importance of the 3 input parameters.

# %%
Nboot = 50 # Number of resamples used for bootstrapping

for i in range(3):
    if i==0:
        Y=YY[:,0]
        target=0
    if i==1:
        Y=YY[:,1]
        target=0
    if i==2:
        Y = YY[:,2]
        target = 500 # RMSD cannot be zero here? Minimum working number is around 500, minimum observed value is around 400.

    # plot:
    plt.figure(figsize=[7,2]) # TODO: Explain titles in more detail
    mvd, _, _, idx = RSA_tr.RSA_indices_thres(X, Y, target, Nboot=Nboot)
    mvd_m, mvd_lb, mvd_ub = aggregate_boot(mvd) # shape (M,)
    yerr=np.c_[mvd_m-mvd_lb,mvd_ub-mvd_m].T
    plt.bar(range(len(mvd_m)), mvd_m, color='grey',yerr=yerr)
    plt.title(Y_Labels[i], loc='center'), plt.xticks(range(len(mvd_m)), X_labels), plt.ylabel('Sensitivity')
    plt.show()

# %% [markdown]
# ## Extra Investigation: Relationship with temp_bias and other parameters to the fit-to-data outputs

# %% [markdown]
# Now checking, if the relationship with other parameters has been affected by the temp_bias, this is rather dominant in the differences of the mean. We can plot a colour map to check.

# %%
temp_bias_index = 2  # Index of temp_bias in X

YY_Labels = ['Mean Difference', 'Std Difference', 'RMSD']

def scatter_function(metric='Mean Difference'):
    if metric == 'Mean Difference':
        j = 0
    elif metric == 'Std Difference':
        j = 1  
    elif metric == 'RMSD':
        j = 2

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], YY[:, j], c=X[:, temp_bias_index], cmap='coolwarm', edgecolors='grey')
        
        if i == 0:
            plt.ylabel(YY_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Temp Bias (°C)')
    plt.show()

interact(scatter_function, metric=YY_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Difference', 'Std Difference', 'RMSD'), va…

# %% [markdown]
# # Hydrological Response Metrics - Performance Metrics

# %% [markdown]
# Now looking at the hydrological response metrics we have avaliable in the OGGM, mean of runoff and mean of volume.

# %% [markdown]
# ## One-at-a-time Sensitivity Analysis

# %%
# Define interactive visualisation function to set the parameters to some tentative values, 
# run the model and plot the resulting runoff time series
from ipywidgets import fixed, interact

def oat_hydro_function(gdir, melt_f = 5.0, prcp_fac = 3.4, temp_bias = 0.0):
    # Create parameter array
    param = np.array([melt_f, prcp_fac, temp_bias])
    
    # Run the model with the given parameters, here we are interested in the modelled mass balance time series
    runoff = oggm_hydro_sim(param, gdir)

    # Plot the results
    plt.figure(figsize=[15,3])
    plt.plot(runoff)
    plt.ylabel('Runoff (Mt)')
    plt.xlabel('Year')
    plt.legend()

# Create interactive plot, the toggles will change the parameter values 
interact(oat_hydro_function,
         gdir = fixed(gdir_hef),
         melt_f = (1.5, 17.0, 0.1),
         prcp_fac = (0.1, 10.0, 0.1),
         temp_bias = (-15.0, 15.0, 0.1));
# Out:
# interactive(children=(FloatSlider(value=5.0, description='melt_f', max=17.0, min=1.5), FloatSlider(value=3.4, …

# %% [markdown]
# # GSA - Global Sensitivity Analysis

# %% [markdown]
# ### Running Monte Carlo Simulations

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)
distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 0.1, -15.0]) # Minimum values for each parameter
x_max = np.array([17.0, 10.0, 15.0]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
samp_strat = 'lhs' 
N = 1000 # Was 2000, TODO- change back to 2000? 1000 takes around 11 mins to run
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

# %%
runoff  = model_execution(oggm_hydro_sim, X, gdir_hef) # Execute the model for all samples - note: takes around 5-10 mins with N=1000
# Out:
# 2026-01-15 14:10:02: oggm.cfg: PARAMS['melt_f'] changed from `10.96383495535463` to `14.749621594124815`.
# 2026-01-15 14:10:02: oggm.cfg: PARAMS['prcp_fac'] changed from `4.7025367278926025` to `6.001053465129696`.
# 2026-01-15 14:10:02: oggm.cfg: PARAMS['temp_bias'] changed from `4.434330626012894` to `8.617507258994749`.
# 2026-01-15 14:10:03: oggm.cfg: PARAMS['melt_f'] changed from `14.749621594124815` to `16.941432975092276`.
# 2026-01-15 14:10:03: oggm.cfg: PARAMS['prcp_fac'] changed from `6.001053465129696` to `4.305352527584153`.
# 2026-01-15 14:10:03: oggm.cfg: PARAMS['temp_bias'] changed from `8.617507258994749` to `2.837573982769282`.
# 2026-01-15 14:10:03: oggm.cfg: PARAMS['melt_f'] changed from `16.941432975092276` to `6.627027710848978`.
# 2026-01-15 14:10:03: oggm.cfg: PARAMS['prcp_fac'] changed from `4.305352527584153` to `9.903939399955435`.
# 2026-01-15 14:10:03: oggm.cfg: PARAMS['temp_bias'] changed from `2.837573982769282` to `-0.646522286311173`.
# 2026-01-15 14:10:04: oggm.cfg: PARAMS['melt_f'] changed from `6.627027710848978` to `13.08840334594871`.
# 2026-01-15 14:10:04: oggm.cfg: PARAMS['prcp_fac'] changed from `9.903939399955435` to `4.074548803378284`.
# 2026-01-15 14:10:04: oggm.cfg: PARAMS['temp_bias'] changed from `-0.646522286311173` to `8.265096868014673`.
# 2026-01-15 14:10:04: oggm.cfg: PARAMS['melt_f'] changed from `13.08840334594871` to `7.503050805805048`.
# 2026-01-15 14:10:04: oggm.cfg: PARAMS['prcp_fac'] changed from `4.074548803378284` to `3.560782802480203`.
# 2026-01-15 14:10:04: oggm.cfg: PARAMS['temp_bias'] changed from `8.265096868014673` to `-11.219603051315087`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['melt_f'] changed from `7.503050805805048` to `12.931786514515734`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['prcp_fac'] changed from `3.560782802480203` to `2.0256056345467788`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['temp_bias'] changed from `-11.219603051315087` to `-3.1424367880351074`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['melt_f'] changed from `12.931786514515734` to `15.475971629286287`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0256056345467788` to `0.5213219790701089`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['temp_bias'] changed from `-3.1424367880351074` to `-12.689029982187083`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['melt_f'] changed from `15.475971629286287` to `2.5755842827969486`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5213219790701089` to `2.5695090815117347`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['temp_bias'] changed from `-12.689029982187083` to `-2.89676471600443`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['melt_f'] changed from `2.5755842827969486` to `5.27134839333864`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5695090815117347` to `3.3450363359244224`.
# 2026-01-15 14:10:05: oggm.cfg: PARAMS['temp_bias'] changed from `-2.89676471600443` to `-14.814241067829728`.
# 2026-01-15 14:10:06: oggm.cfg: PARAMS['melt_f'] changed from `5.27134839333864` to `15.205328772389638`.
# 2026-01-15 14:10:06: oggm.cfg: PARAMS['prcp_fac'] changed from `3.3450363359244224` to `8.279238119351994`.
# 2026-01-15 14:10:06: oggm.cfg: PARAMS['temp_bias'] changed from `-14.814241067829728` to `-12.701756489001832`.
# 2026-01-15 14:10:06: oggm.cfg: PARAMS['melt_f'] changed from `15.205328772389638` to `16.922932655651827`.
# 2026-01-15 14:10:06: oggm.cfg: PARAMS['prcp_fac'] changed from `8.279238119351994` to `7.528313731149202`.
# 2026-01-15 14:10:06: oggm.cfg: PARAMS['temp_bias'] changed from `-12.701756489001832` to `-2.9748833540684334`.
# 2026-01-15 14:10:07: oggm.cfg: PARAMS['melt_f'] changed from `16.922932655651827` to `3.184341515538441`.
# 2026-01-15 14:10:07: oggm.cfg: PARAMS['prcp_fac'] changed from `7.528313731149202` to `7.19699954399613`.
# 2026-01-15 14:10:07: oggm.cfg: PARAMS['temp_bias'] changed from `-2.9748833540684334` to `8.516441339618368`.
# 2026-01-15 14:10:07: oggm.cfg: PARAMS['melt_f'] changed from `3.184341515538441` to `4.477367009400134`.
# 2026-01-15 14:10:07: oggm.cfg: PARAMS['prcp_fac'] changed from `7.19699954399613` to `0.6707102604975098`.
# 2026-01-15 14:10:07: oggm.cfg: PARAMS['temp_bias'] changed from `8.516441339618368` to `1.4658438102019815`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['melt_f'] changed from `4.477367009400134` to `1.9048193535731233`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['prcp_fac'] changed from `0.6707102604975098` to `2.365826825508013`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['temp_bias'] changed from `1.4658438102019815` to `-14.054682050541336`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['melt_f'] changed from `1.9048193535731233` to `3.2428067344053284`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['prcp_fac'] changed from `2.365826825508013` to `1.4170394506277137`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['temp_bias'] changed from `-14.054682050541336` to `10.881994469085111`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['melt_f'] changed from `3.2428067344053284` to `5.012870614883626`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4170394506277137` to `1.7573239718210658`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['temp_bias'] changed from `10.881994469085111` to `-0.83843608828297`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['melt_f'] changed from `5.012870614883626` to `13.245142827638494`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7573239718210658` to `4.5056628396753196`.
# 2026-01-15 14:10:08: oggm.cfg: PARAMS['temp_bias'] changed from `-0.83843608828297` to `-7.8437525304243`.
# 2026-01-15 14:10:09: oggm.cfg: PARAMS['melt_f'] changed from `13.245142827638494` to `5.653447844287265`.
# 2026-01-15 14:10:09: oggm.cfg: PARAMS['prcp_fac'] changed from `4.5056628396753196` to `9.345286183615844`.
# 2026-01-15 14:10:09: oggm.cfg: PARAMS['temp_bias'] changed from `-7.8437525304243` to `-9.894088538192367`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['melt_f'] changed from `5.653447844287265` to `15.027483901300922`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['prcp_fac'] changed from `9.345286183615844` to `1.4822777559213085`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['temp_bias'] changed from `-9.894088538192367` to `-4.798996775373242`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['melt_f'] changed from `15.027483901300922` to `14.580415014304034`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['prcp_fac'] changed from `1.4822777559213085` to `6.411850735589898`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['temp_bias'] changed from `-4.798996775373242` to `5.126671793241481`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['melt_f'] changed from `14.580415014304034` to `9.904286621280104`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['prcp_fac'] changed from `6.411850735589898` to `9.731101616357314`.
# 2026-01-15 14:10:10: oggm.cfg: PARAMS['temp_bias'] changed from `5.126671793241481` to `7.912232761371893`.
# 2026-01-15 14:10:11: oggm.cfg: PARAMS['melt_f'] changed from `9.904286621280104` to `8.321573719634017`.
# 2026-01-15 14:10:11: oggm.cfg: PARAMS['prcp_fac'] changed from `9.731101616357314` to `9.108605069206147`.
# 2026-01-15 14:10:11: oggm.cfg: PARAMS['temp_bias'] changed from `7.912232761371893` to `-9.690509474903532`.
# 2026-01-15 14:10:11: oggm.cfg: PARAMS['melt_f'] changed from `8.321573719634017` to `15.98535370187465`.
# 2026-01-15 14:10:11: oggm.cfg: PARAMS['prcp_fac'] changed from `9.108605069206147` to `0.8272804872092004`.
# 2026-01-15 14:10:11: oggm.cfg: PARAMS['temp_bias'] changed from `-9.690509474903532` to `6.223036952971622`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['melt_f'] changed from `15.98535370187465` to `10.632543638599183`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8272804872092004` to `9.61546685350465`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['temp_bias'] changed from `6.223036952971622` to `12.253294211983963`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['melt_f'] changed from `10.632543638599183` to `5.892272320409234`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['prcp_fac'] changed from `9.61546685350465` to `4.009400318718846`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['temp_bias'] changed from `12.253294211983963` to `7.304088978069753`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['melt_f'] changed from `5.892272320409234` to `15.34509024427367`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['prcp_fac'] changed from `4.009400318718846` to `6.490270584117171`.
# 2026-01-15 14:10:12: oggm.cfg: PARAMS['temp_bias'] changed from `7.304088978069753` to `-12.252823819786103`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['melt_f'] changed from `15.34509024427367` to `14.79501874831685`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['prcp_fac'] changed from `6.490270584117171` to `1.8374829119172011`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['temp_bias'] changed from `-12.252823819786103` to `-4.942390583491866`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['melt_f'] changed from `14.79501874831685` to `15.95520617805785`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['prcp_fac'] changed from `1.8374829119172011` to `4.038235872128012`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['temp_bias'] changed from `-4.942390583491866` to `12.55432959019496`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['melt_f'] changed from `15.95520617805785` to `9.015179681153182`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['prcp_fac'] changed from `4.038235872128012` to `1.0899137711962446`.
# 2026-01-15 14:10:13: oggm.cfg: PARAMS['temp_bias'] changed from `12.55432959019496` to `-12.340142678991683`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['melt_f'] changed from `9.015179681153182` to `8.97832691392308`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['prcp_fac'] changed from `1.0899137711962446` to `3.1759743016056494`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['temp_bias'] changed from `-12.340142678991683` to `7.338443463785399`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['melt_f'] changed from `8.97832691392308` to `12.872077993451711`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1759743016056494` to `4.384944647688694`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['temp_bias'] changed from `7.338443463785399` to `-7.7970379278531246`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['melt_f'] changed from `12.872077993451711` to `12.670790851992237`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['prcp_fac'] changed from `4.384944647688694` to `8.807294739754926`.
# 2026-01-15 14:10:14: oggm.cfg: PARAMS['temp_bias'] changed from `-7.7970379278531246` to `9.397628345676939`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['melt_f'] changed from `12.670790851992237` to `8.46062849821561`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['prcp_fac'] changed from `8.807294739754926` to `7.32518571160851`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['temp_bias'] changed from `9.397628345676939` to `4.644811349489778`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['melt_f'] changed from `8.46062849821561` to `8.884779303766887`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['prcp_fac'] changed from `7.32518571160851` to `6.556617559943741`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['temp_bias'] changed from `4.644811349489778` to `-0.9545576141193415`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['melt_f'] changed from `8.884779303766887` to `10.659372494809134`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['prcp_fac'] changed from `6.556617559943741` to `7.287977147972025`.
# 2026-01-15 14:10:15: oggm.cfg: PARAMS['temp_bias'] changed from `-0.9545576141193415` to `-12.861010094558422`.
# 2026-01-15 14:10:16: oggm.cfg: PARAMS['melt_f'] changed from `10.659372494809134` to `14.389126859246847`.
# 2026-01-15 14:10:16: oggm.cfg: PARAMS['prcp_fac'] changed from `7.287977147972025` to `5.850918435813556`.
# 2026-01-15 14:10:16: oggm.cfg: PARAMS['temp_bias'] changed from `-12.861010094558422` to `-9.995218352833273`.
# 2026-01-15 14:10:16: oggm.cfg: PARAMS['melt_f'] changed from `14.389126859246847` to `7.933912001094696`.
# 2026-01-15 14:10:16: oggm.cfg: PARAMS['prcp_fac'] changed from `5.850918435813556` to `9.845188948888298`.
# 2026-01-15 14:10:16: oggm.cfg: PARAMS['temp_bias'] changed from `-9.995218352833273` to `-10.902346530262786`.
# 2026-01-15 14:10:17: oggm.cfg: PARAMS['melt_f'] changed from `7.933912001094696` to `6.912272182007903`.
# 2026-01-15 14:10:17: oggm.cfg: PARAMS['prcp_fac'] changed from `9.845188948888298` to `5.796786932570709`.
# 2026-01-15 14:10:17: oggm.cfg: PARAMS['temp_bias'] changed from `-10.902346530262786` to `-9.639491455553156`.
# 2026-01-15 14:10:17: oggm.cfg: PARAMS['melt_f'] changed from `6.912272182007903` to `5.673334052169713`.
# 2026-01-15 14:10:17: oggm.cfg: PARAMS['prcp_fac'] changed from `5.796786932570709` to `9.382600366709148`.
# 2026-01-15 14:10:17: oggm.cfg: PARAMS['temp_bias'] changed from `-9.639491455553156` to `-3.8094869521158294`.
# 2026-01-15 14:10:18: oggm.cfg: PARAMS['melt_f'] changed from `5.673334052169713` to `8.24264246979409`.
# 2026-01-15 14:10:18: oggm.cfg: PARAMS['prcp_fac'] changed from `9.382600366709148` to `0.5545112904265223`.
# 2026-01-15 14:10:18: oggm.cfg: PARAMS['temp_bias'] changed from `-3.8094869521158294` to `11.899063793993164`.
# 2026-01-15 14:10:18: oggm.cfg: PARAMS['melt_f'] changed from `8.24264246979409` to `11.463130547762812`.
# 2026-01-15 14:10:18: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5545112904265223` to `1.2617605637176117`.
# 2026-01-15 14:10:18: oggm.cfg: PARAMS['temp_bias'] changed from `11.899063793993164` to `1.614757694973747`.
# 2026-01-15 14:10:19: oggm.cfg: PARAMS['melt_f'] changed from `11.463130547762812` to `3.6300544498177447`.
# 2026-01-15 14:10:19: oggm.cfg: PARAMS['prcp_fac'] changed from `1.2617605637176117` to `7.945732481153229`.
# 2026-01-15 14:10:19: oggm.cfg: PARAMS['temp_bias'] changed from `1.614757694973747` to `-5.066377285657682`.
# 2026-01-15 14:10:19: oggm.cfg: PARAMS['melt_f'] changed from `3.6300544498177447` to `13.561098301559532`.
# 2026-01-15 14:10:19: oggm.cfg: PARAMS['prcp_fac'] changed from `7.945732481153229` to `7.519360931179459`.
# 2026-01-15 14:10:19: oggm.cfg: PARAMS['temp_bias'] changed from `-5.066377285657682` to `11.867335741289374`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['melt_f'] changed from `13.561098301559532` to `5.515457423274411`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['prcp_fac'] changed from `7.519360931179459` to `6.307832158163193`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['temp_bias'] changed from `11.867335741289374` to `1.5195495718230738`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['melt_f'] changed from `5.515457423274411` to `10.49305537980634`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['prcp_fac'] changed from `6.307832158163193` to `8.26991279692621`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['temp_bias'] changed from `1.5195495718230738` to `3.7667203105481235`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['melt_f'] changed from `10.49305537980634` to `1.5127240845972771`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['prcp_fac'] changed from `8.26991279692621` to `4.391969739073094`.
# 2026-01-15 14:10:20: oggm.cfg: PARAMS['temp_bias'] changed from `3.7667203105481235` to `-9.495126969178326`.
# 2026-01-15 14:10:21: oggm.cfg: PARAMS['melt_f'] changed from `1.5127240845972771` to `9.368757103190822`.
# 2026-01-15 14:10:21: oggm.cfg: PARAMS['prcp_fac'] changed from `4.391969739073094` to `7.079917520473781`.
# 2026-01-15 14:10:21: oggm.cfg: PARAMS['temp_bias'] changed from `-9.495126969178326` to `-9.684078630256089`.
# 2026-01-15 14:10:21: oggm.cfg: PARAMS['melt_f'] changed from `9.368757103190822` to `3.080593404826949`.
# 2026-01-15 14:10:21: oggm.cfg: PARAMS['prcp_fac'] changed from `7.079917520473781` to `4.339547842019587`.
# 2026-01-15 14:10:21: oggm.cfg: PARAMS['temp_bias'] changed from `-9.684078630256089` to `-12.22017982022653`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['melt_f'] changed from `3.080593404826949` to `5.117908602949735`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['prcp_fac'] changed from `4.339547842019587` to `4.533438946231199`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['temp_bias'] changed from `-12.22017982022653` to `-13.818938575795823`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['melt_f'] changed from `5.117908602949735` to `16.322992460045306`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['prcp_fac'] changed from `4.533438946231199` to `5.972026917603546`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['temp_bias'] changed from `-13.818938575795823` to `-13.950950846484323`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['melt_f'] changed from `16.322992460045306` to `16.555871498876208`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['prcp_fac'] changed from `5.972026917603546` to `7.1164389690546646`.
# 2026-01-15 14:10:22: oggm.cfg: PARAMS['temp_bias'] changed from `-13.950950846484323` to `13.750305180304597`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['melt_f'] changed from `16.555871498876208` to `5.559292373363107`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['prcp_fac'] changed from `7.1164389690546646` to `2.554665124519153`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['temp_bias'] changed from `13.750305180304597` to `4.228986137648953`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['melt_f'] changed from `5.559292373363107` to `10.428204135145439`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['prcp_fac'] changed from `2.554665124519153` to `4.550492982330647`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['temp_bias'] changed from `4.228986137648953` to `10.664535324788599`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['melt_f'] changed from `10.428204135145439` to `6.557253215652281`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['prcp_fac'] changed from `4.550492982330647` to `3.1405824388734023`.
# 2026-01-15 14:10:23: oggm.cfg: PARAMS['temp_bias'] changed from `10.664535324788599` to `-3.872499180119444`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['melt_f'] changed from `6.557253215652281` to `5.078383894532869`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['prcp_fac'] changed from `3.1405824388734023` to `2.5561022191030807`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['temp_bias'] changed from `-3.872499180119444` to `-5.373771788143534`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['melt_f'] changed from `5.078383894532869` to `1.8064842197125934`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['prcp_fac'] changed from `2.5561022191030807` to `6.623691537660061`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['temp_bias'] changed from `-5.373771788143534` to `12.188729422146352`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['melt_f'] changed from `1.8064842197125934` to `13.414707596203169`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['prcp_fac'] changed from `6.623691537660061` to `5.458833596685635`.
# 2026-01-15 14:10:24: oggm.cfg: PARAMS['temp_bias'] changed from `12.188729422146352` to `-12.55162251993887`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['melt_f'] changed from `13.414707596203169` to `13.521178792665545`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['prcp_fac'] changed from `5.458833596685635` to `2.820386908731093`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['temp_bias'] changed from `-12.55162251993887` to `-5.94997846427596`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['melt_f'] changed from `13.521178792665545` to `5.420301651951879`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['prcp_fac'] changed from `2.820386908731093` to `6.47973502645218`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['temp_bias'] changed from `-5.94997846427596` to `1.9294885628485723`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['melt_f'] changed from `5.420301651951879` to `4.854933522222923`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['prcp_fac'] changed from `6.47973502645218` to `7.782572324408471`.
# 2026-01-15 14:10:25: oggm.cfg: PARAMS['temp_bias'] changed from `1.9294885628485723` to `-14.730565116708739`.
# 2026-01-15 14:10:26: oggm.cfg: PARAMS['melt_f'] changed from `4.854933522222923` to `6.108960334013603`.
# 2026-01-15 14:10:26: oggm.cfg: PARAMS['prcp_fac'] changed from `7.782572324408471` to `4.676688106802605`.
# 2026-01-15 14:10:26: oggm.cfg: PARAMS['temp_bias'] changed from `-14.730565116708739` to `13.260720310660268`.
# 2026-01-15 14:10:26: oggm.cfg: PARAMS['melt_f'] changed from `6.108960334013603` to `10.809389493861081`.
# 2026-01-15 14:10:26: oggm.cfg: PARAMS['prcp_fac'] changed from `4.676688106802605` to `5.873435438633623`.
# 2026-01-15 14:10:26: oggm.cfg: PARAMS['temp_bias'] changed from `13.260720310660268` to `2.247603366350006`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['melt_f'] changed from `10.809389493861081` to `11.14296054462532`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['prcp_fac'] changed from `5.873435438633623` to `0.9586868190518634`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['temp_bias'] changed from `2.247603366350006` to `14.245047715625763`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['melt_f'] changed from `11.14296054462532` to `8.377917808452441`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9586868190518634` to `1.9702725011178341`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['temp_bias'] changed from `14.245047715625763` to `-0.8071214930538986`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['melt_f'] changed from `8.377917808452441` to `15.44497001286164`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['prcp_fac'] changed from `1.9702725011178341` to `7.107811922577665`.
# 2026-01-15 14:10:27: oggm.cfg: PARAMS['temp_bias'] changed from `-0.8071214930538986` to `12.583840448078845`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['melt_f'] changed from `15.44497001286164` to `13.223964257792655`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['prcp_fac'] changed from `7.107811922577665` to `0.5343448611964828`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['temp_bias'] changed from `12.583840448078845` to `7.432641891409066`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['melt_f'] changed from `13.223964257792655` to `13.42243958367076`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5343448611964828` to `7.907759798220824`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['temp_bias'] changed from `7.432641891409066` to `4.491175775549845`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['melt_f'] changed from `13.42243958367076` to `14.435516563275483`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['prcp_fac'] changed from `7.907759798220824` to `8.000868470976878`.
# 2026-01-15 14:10:28: oggm.cfg: PARAMS['temp_bias'] changed from `4.491175775549845` to `-6.033469511123442`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['melt_f'] changed from `14.435516563275483` to `11.097422163805296`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['prcp_fac'] changed from `8.000868470976878` to `5.146900259973518`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['temp_bias'] changed from `-6.033469511123442` to `-0.7047213329003466`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['melt_f'] changed from `11.097422163805296` to `13.978060989038383`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['prcp_fac'] changed from `5.146900259973518` to `5.601524503376155`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['temp_bias'] changed from `-0.7047213329003466` to `1.9094367531413816`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['melt_f'] changed from `13.978060989038383` to `4.334946062166068`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['prcp_fac'] changed from `5.601524503376155` to `5.087292813304215`.
# 2026-01-15 14:10:29: oggm.cfg: PARAMS['temp_bias'] changed from `1.9094367531413816` to `3.74019001403785`.
# 2026-01-15 14:10:30: oggm.cfg: PARAMS['melt_f'] changed from `4.334946062166068` to `16.451593411562524`.
# 2026-01-15 14:10:30: oggm.cfg: PARAMS['prcp_fac'] changed from `5.087292813304215` to `6.872893564241119`.
# 2026-01-15 14:10:30: oggm.cfg: PARAMS['temp_bias'] changed from `3.74019001403785` to `-6.281512800723249`.
# 2026-01-15 14:10:30: oggm.cfg: PARAMS['melt_f'] changed from `16.451593411562524` to `1.5983986065471751`.
# 2026-01-15 14:10:30: oggm.cfg: PARAMS['prcp_fac'] changed from `6.872893564241119` to `3.4510673301929162`.
# 2026-01-15 14:10:30: oggm.cfg: PARAMS['temp_bias'] changed from `-6.281512800723249` to `-14.510023233086129`.
# 2026-01-15 14:10:31: oggm.cfg: PARAMS['melt_f'] changed from `1.5983986065471751` to `2.4958509084291314`.
# 2026-01-15 14:10:31: oggm.cfg: PARAMS['prcp_fac'] changed from `3.4510673301929162` to `5.944807215739708`.
# 2026-01-15 14:10:31: oggm.cfg: PARAMS['temp_bias'] changed from `-14.510023233086129` to `-7.801262053015219`.
# 2026-01-15 14:10:31: oggm.cfg: PARAMS['melt_f'] changed from `2.4958509084291314` to `10.39029434134536`.
# 2026-01-15 14:10:31: oggm.cfg: PARAMS['prcp_fac'] changed from `5.944807215739708` to `6.209021178861712`.
# 2026-01-15 14:10:31: oggm.cfg: PARAMS['temp_bias'] changed from `-7.801262053015219` to `-12.092808320526357`.
# 2026-01-15 14:10:32: oggm.cfg: PARAMS['melt_f'] changed from `10.39029434134536` to `16.310155903587138`.
# 2026-01-15 14:10:32: oggm.cfg: PARAMS['prcp_fac'] changed from `6.209021178861712` to `6.933588718707134`.
# 2026-01-15 14:10:32: oggm.cfg: PARAMS['temp_bias'] changed from `-12.092808320526357` to `4.937923268215137`.
# 2026-01-15 14:10:32: oggm.cfg: PARAMS['melt_f'] changed from `16.310155903587138` to `13.957244413021714`.
# 2026-01-15 14:10:32: oggm.cfg: PARAMS['prcp_fac'] changed from `6.933588718707134` to `9.277319851167862`.
# 2026-01-15 14:10:32: oggm.cfg: PARAMS['temp_bias'] changed from `4.937923268215137` to `-13.081874054690694`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['melt_f'] changed from `13.957244413021714` to `16.835916475686034`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['prcp_fac'] changed from `9.277319851167862` to `8.561974672170969`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['temp_bias'] changed from `-13.081874054690694` to `9.796339265734979`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['melt_f'] changed from `16.835916475686034` to `15.334950849998178`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['prcp_fac'] changed from `8.561974672170969` to `3.8379016908874917`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['temp_bias'] changed from `9.796339265734979` to `3.972006576137037`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['melt_f'] changed from `15.334950849998178` to `3.7528749501842182`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['prcp_fac'] changed from `3.8379016908874917` to `2.978178959912635`.
# 2026-01-15 14:10:33: oggm.cfg: PARAMS['temp_bias'] changed from `3.972006576137037` to `-2.290824400006205`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['melt_f'] changed from `3.7528749501842182` to `8.809609559741968`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['prcp_fac'] changed from `2.978178959912635` to `2.0164101495726987`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['temp_bias'] changed from `-2.290824400006205` to `7.452365565162715`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['melt_f'] changed from `8.809609559741968` to `9.087058248727342`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0164101495726987` to `8.822157561453958`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['temp_bias'] changed from `7.452365565162715` to `11.499445679311158`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['melt_f'] changed from `9.087058248727342` to `2.895557520972842`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['prcp_fac'] changed from `8.822157561453958` to `3.860066051351915`.
# 2026-01-15 14:10:34: oggm.cfg: PARAMS['temp_bias'] changed from `11.499445679311158` to `8.1315100007718`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['melt_f'] changed from `2.895557520972842` to `7.957711139046908`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['prcp_fac'] changed from `3.860066051351915` to `5.323088442234267`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['temp_bias'] changed from `8.1315100007718` to `3.177870278868319`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['melt_f'] changed from `7.957711139046908` to `1.691209509244703`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['prcp_fac'] changed from `5.323088442234267` to `4.127625894498229`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['temp_bias'] changed from `3.177870278868319` to `5.412996421463415`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['melt_f'] changed from `1.691209509244703` to `7.225539555451061`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['prcp_fac'] changed from `4.127625894498229` to `8.891622926649848`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['temp_bias'] changed from `5.412996421463415` to `1.3215758700928077`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['melt_f'] changed from `7.225539555451061` to `6.893848874444114`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['prcp_fac'] changed from `8.891622926649848` to `6.384551771293647`.
# 2026-01-15 14:10:35: oggm.cfg: PARAMS['temp_bias'] changed from `1.3215758700928077` to `-12.486930625744101`.
# 2026-01-15 14:10:36: oggm.cfg: PARAMS['melt_f'] changed from `6.893848874444114` to `14.699209426095287`.
# 2026-01-15 14:10:36: oggm.cfg: PARAMS['prcp_fac'] changed from `6.384551771293647` to `9.712643065155364`.
# 2026-01-15 14:10:36: oggm.cfg: PARAMS['temp_bias'] changed from `-12.486930625744101` to `3.8467320764445248`.
# 2026-01-15 14:10:36: oggm.cfg: PARAMS['melt_f'] changed from `14.699209426095287` to `14.982720033807535`.
# 2026-01-15 14:10:36: oggm.cfg: PARAMS['prcp_fac'] changed from `9.712643065155364` to `6.7559124302355045`.
# 2026-01-15 14:10:36: oggm.cfg: PARAMS['temp_bias'] changed from `3.8467320764445248` to `-12.207591169996235`.
# 2026-01-15 14:10:37: oggm.cfg: PARAMS['melt_f'] changed from `14.982720033807535` to `6.459381027257317`.
# 2026-01-15 14:10:37: oggm.cfg: PARAMS['prcp_fac'] changed from `6.7559124302355045` to `3.752197610367264`.
# 2026-01-15 14:10:37: oggm.cfg: PARAMS['temp_bias'] changed from `-12.207591169996235` to `1.6475984596329702`.
# 2026-01-15 14:10:37: oggm.cfg: PARAMS['melt_f'] changed from `6.459381027257317` to `7.4155523982673115`.
# 2026-01-15 14:10:37: oggm.cfg: PARAMS['prcp_fac'] changed from `3.752197610367264` to `5.753112928475414`.
# 2026-01-15 14:10:37: oggm.cfg: PARAMS['temp_bias'] changed from `1.6475984596329702` to `-4.280989124648732`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['melt_f'] changed from `7.4155523982673115` to `11.261964498791821`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['prcp_fac'] changed from `5.753112928475414` to `9.629667100545253`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['temp_bias'] changed from `-4.280989124648732` to `2.3881081375706614`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['melt_f'] changed from `11.261964498791821` to `14.942973028492032`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['prcp_fac'] changed from `9.629667100545253` to `0.28804921164190356`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['temp_bias'] changed from `2.3881081375706614` to `2.4954133629704707`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['melt_f'] changed from `14.942973028492032` to `1.6790851265021802`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['prcp_fac'] changed from `0.28804921164190356` to `8.84130733165753`.
# 2026-01-15 14:10:38: oggm.cfg: PARAMS['temp_bias'] changed from `2.4954133629704707` to `-6.092338701416933`.
# 2026-01-15 14:10:39: oggm.cfg: PARAMS['melt_f'] changed from `1.6790851265021802` to `3.3585800781316486`.
# 2026-01-15 14:10:39: oggm.cfg: PARAMS['prcp_fac'] changed from `8.84130733165753` to `1.5925317932642677`.
# 2026-01-15 14:10:39: oggm.cfg: PARAMS['temp_bias'] changed from `-6.092338701416933` to `14.152612018611517`.
# 2026-01-15 14:10:39: oggm.cfg: PARAMS['melt_f'] changed from `3.3585800781316486` to `5.579686058732669`.
# 2026-01-15 14:10:39: oggm.cfg: PARAMS['prcp_fac'] changed from `1.5925317932642677` to `7.198493284679304`.
# 2026-01-15 14:10:39: oggm.cfg: PARAMS['temp_bias'] changed from `14.152612018611517` to `-7.567111239144084`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['melt_f'] changed from `5.579686058732669` to `9.181988359224642`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['prcp_fac'] changed from `7.198493284679304` to `7.03642985202769`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['temp_bias'] changed from `-7.567111239144084` to `11.589382198262388`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['melt_f'] changed from `9.181988359224642` to `8.51449432101062`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['prcp_fac'] changed from `7.03642985202769` to `9.26228898569405`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['temp_bias'] changed from `11.589382198262388` to `4.867210494223986`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['melt_f'] changed from `8.51449432101062` to `2.1137560623381972`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['prcp_fac'] changed from `9.26228898569405` to `2.7396318992331294`.
# 2026-01-15 14:10:40: oggm.cfg: PARAMS['temp_bias'] changed from `4.867210494223986` to `11.980863944901206`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['melt_f'] changed from `2.1137560623381972` to `15.877047676881249`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['prcp_fac'] changed from `2.7396318992331294` to `4.878596752303146`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['temp_bias'] changed from `11.980863944901206` to `0.2719541070610809`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['melt_f'] changed from `15.877047676881249` to `2.0864549166440765`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['prcp_fac'] changed from `4.878596752303146` to `2.3378983098198263`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['temp_bias'] changed from `0.2719541070610809` to `10.58484112147401`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['melt_f'] changed from `2.0864549166440765` to `4.99841817469081`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['prcp_fac'] changed from `2.3378983098198263` to `6.526529122775902`.
# 2026-01-15 14:10:41: oggm.cfg: PARAMS['temp_bias'] changed from `10.58484112147401` to `5.058075150947673`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['melt_f'] changed from `4.99841817469081` to `1.6104178123744735`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['prcp_fac'] changed from `6.526529122775902` to `9.507346106742778`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['temp_bias'] changed from `5.058075150947673` to `4.045745182495203`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['melt_f'] changed from `1.6104178123744735` to `5.594797773679054`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['prcp_fac'] changed from `9.507346106742778` to `7.76731260762714`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['temp_bias'] changed from `4.045745182495203` to `4.39830157078212`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['melt_f'] changed from `5.594797773679054` to `8.394453304042884`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['prcp_fac'] changed from `7.76731260762714` to `7.593559584666163`.
# 2026-01-15 14:10:42: oggm.cfg: PARAMS['temp_bias'] changed from `4.39830157078212` to `-4.705921667928003`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['melt_f'] changed from `8.394453304042884` to `16.677612336734843`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['prcp_fac'] changed from `7.593559584666163` to `6.813353879186117`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['temp_bias'] changed from `-4.705921667928003` to `12.096044569693817`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['melt_f'] changed from `16.677612336734843` to `10.37099499968584`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['prcp_fac'] changed from `6.813353879186117` to `8.672586873585086`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['temp_bias'] changed from `12.096044569693817` to `3.464630651059334`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['melt_f'] changed from `10.37099499968584` to `8.645923225969476`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['prcp_fac'] changed from `8.672586873585086` to `9.973388907648795`.
# 2026-01-15 14:10:43: oggm.cfg: PARAMS['temp_bias'] changed from `3.464630651059334` to `-6.502658490251632`.
# 2026-01-15 14:10:44: oggm.cfg: PARAMS['melt_f'] changed from `8.645923225969476` to `12.6760180437695`.
# 2026-01-15 14:10:44: oggm.cfg: PARAMS['prcp_fac'] changed from `9.973388907648795` to `0.8224815308680908`.
# 2026-01-15 14:10:44: oggm.cfg: PARAMS['temp_bias'] changed from `-6.502658490251632` to `-1.115199566812585`.
# 2026-01-15 14:10:44: oggm.cfg: PARAMS['melt_f'] changed from `12.6760180437695` to `14.373743748173533`.
# 2026-01-15 14:10:44: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8224815308680908` to `6.5837374041805115`.
# 2026-01-15 14:10:44: oggm.cfg: PARAMS['temp_bias'] changed from `-1.115199566812585` to `-0.08299537346341523`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['melt_f'] changed from `14.373743748173533` to `16.77253052442837`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['prcp_fac'] changed from `6.5837374041805115` to `7.69979630962929`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['temp_bias'] changed from `-0.08299537346341523` to `9.876341579511195`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['melt_f'] changed from `16.77253052442837` to `16.986110657350828`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['prcp_fac'] changed from `7.69979630962929` to `9.248290981416897`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['temp_bias'] changed from `9.876341579511195` to `12.828749611627916`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['melt_f'] changed from `16.986110657350828` to `14.896674490732059`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['prcp_fac'] changed from `9.248290981416897` to `9.570535805005711`.
# 2026-01-15 14:10:45: oggm.cfg: PARAMS['temp_bias'] changed from `12.828749611627916` to `0.8432431185504417`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['melt_f'] changed from `14.896674490732059` to `5.287938464534458`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['prcp_fac'] changed from `9.570535805005711` to `4.919872496857672`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['temp_bias'] changed from `0.8432431185504417` to `-4.178496136050324`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['melt_f'] changed from `5.287938464534458` to `6.207028564038329`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['prcp_fac'] changed from `4.919872496857672` to `5.469434144692371`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['temp_bias'] changed from `-4.178496136050324` to `11.750368206596306`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['melt_f'] changed from `6.207028564038329` to `12.163318421549008`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['prcp_fac'] changed from `5.469434144692371` to `7.7558113473606465`.
# 2026-01-15 14:10:46: oggm.cfg: PARAMS['temp_bias'] changed from `11.750368206596306` to `-13.532565613227838`.
# 2026-01-15 14:10:47: oggm.cfg: PARAMS['melt_f'] changed from `12.163318421549008` to `4.933958539993673`.
# 2026-01-15 14:10:47: oggm.cfg: PARAMS['prcp_fac'] changed from `7.7558113473606465` to `7.723908512447051`.
# 2026-01-15 14:10:47: oggm.cfg: PARAMS['temp_bias'] changed from `-13.532565613227838` to `-4.67676870982428`.
# 2026-01-15 14:10:47: oggm.cfg: PARAMS['melt_f'] changed from `4.933958539993673` to `2.122246414529873`.
# 2026-01-15 14:10:47: oggm.cfg: PARAMS['prcp_fac'] changed from `7.723908512447051` to `2.6476166414820788`.
# 2026-01-15 14:10:47: oggm.cfg: PARAMS['temp_bias'] changed from `-4.67676870982428` to `10.18231614692603`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['melt_f'] changed from `2.122246414529873` to `11.736831432445163`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['prcp_fac'] changed from `2.6476166414820788` to `2.1003801380569764`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['temp_bias'] changed from `10.18231614692603` to `-12.43324480834911`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['melt_f'] changed from `11.736831432445163` to `9.972636864420869`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['prcp_fac'] changed from `2.1003801380569764` to `7.580502538678098`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['temp_bias'] changed from `-12.43324480834911` to `9.378385686777904`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['melt_f'] changed from `9.972636864420869` to `6.607897388767568`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['prcp_fac'] changed from `7.580502538678098` to `0.9786636224615326`.
# 2026-01-15 14:10:48: oggm.cfg: PARAMS['temp_bias'] changed from `9.378385686777904` to `-5.645683848799385`.
# 2026-01-15 14:10:49: oggm.cfg: PARAMS['melt_f'] changed from `6.607897388767568` to `8.24130238134947`.
# 2026-01-15 14:10:49: oggm.cfg: PARAMS['prcp_fac'] changed from `0.9786636224615326` to `9.563625308675899`.
# 2026-01-15 14:10:49: oggm.cfg: PARAMS['temp_bias'] changed from `-5.645683848799385` to `-11.13795743909403`.
# 2026-01-15 14:10:49: oggm.cfg: PARAMS['melt_f'] changed from `8.24130238134947` to `15.582007719414053`.
# 2026-01-15 14:10:49: oggm.cfg: PARAMS['prcp_fac'] changed from `9.563625308675899` to `0.8718084297051594`.
# 2026-01-15 14:10:49: oggm.cfg: PARAMS['temp_bias'] changed from `-11.13795743909403` to `13.151113866160543`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['melt_f'] changed from `15.582007719414053` to `6.370325789105209`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['prcp_fac'] changed from `0.8718084297051594` to `5.020197974332792`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['temp_bias'] changed from `13.151113866160543` to `11.134784375945532`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['melt_f'] changed from `6.370325789105209` to `5.244581248368211`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['prcp_fac'] changed from `5.020197974332792` to `0.414467546159634`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['temp_bias'] changed from `11.134784375945532` to `5.346612140367753`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['melt_f'] changed from `5.244581248368211` to `16.42778801701698`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['prcp_fac'] changed from `0.414467546159634` to `3.816936587247811`.
# 2026-01-15 14:10:50: oggm.cfg: PARAMS['temp_bias'] changed from `5.346612140367753` to `-7.299990415141287`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['melt_f'] changed from `16.42778801701698` to `5.0389085117089625`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['prcp_fac'] changed from `3.816936587247811` to `2.309772285529845`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['temp_bias'] changed from `-7.299990415141287` to `11.189846969521692`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['melt_f'] changed from `5.0389085117089625` to `14.638182271668798`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['prcp_fac'] changed from `2.309772285529845` to `1.1804920672138703`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['temp_bias'] changed from `11.189846969521692` to `9.528647947382083`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['melt_f'] changed from `14.638182271668798` to `15.717757238706673`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['prcp_fac'] changed from `1.1804920672138703` to `6.915159993316291`.
# 2026-01-15 14:10:51: oggm.cfg: PARAMS['temp_bias'] changed from `9.528647947382083` to `-9.038800364740926`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['melt_f'] changed from `15.717757238706673` to `16.661673409777055`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['prcp_fac'] changed from `6.915159993316291` to `5.82624781948158`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['temp_bias'] changed from `-9.038800364740926` to `7.070816949189627`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['melt_f'] changed from `16.661673409777055` to `7.402399463635296`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['prcp_fac'] changed from `5.82624781948158` to `5.953968435834854`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['temp_bias'] changed from `7.070816949189627` to `7.887909957638218`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['melt_f'] changed from `7.402399463635296` to `1.8411234589522283`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['prcp_fac'] changed from `5.953968435834854` to `8.043390407409477`.
# 2026-01-15 14:10:52: oggm.cfg: PARAMS['temp_bias'] changed from `7.887909957638218` to `-6.739001396371432`.
# 2026-01-15 14:10:53: oggm.cfg: PARAMS['melt_f'] changed from `1.8411234589522283` to `5.031990174898841`.
# 2026-01-15 14:10:53: oggm.cfg: PARAMS['prcp_fac'] changed from `8.043390407409477` to `5.617598741686132`.
# 2026-01-15 14:10:53: oggm.cfg: PARAMS['temp_bias'] changed from `-6.739001396371432` to `3.558167272283132`.
# 2026-01-15 14:10:53: oggm.cfg: PARAMS['melt_f'] changed from `5.031990174898841` to `6.469051726569001`.
# 2026-01-15 14:10:53: oggm.cfg: PARAMS['prcp_fac'] changed from `5.617598741686132` to `8.635452497992574`.
# 2026-01-15 14:10:53: oggm.cfg: PARAMS['temp_bias'] changed from `3.558167272283132` to `-10.686514952407354`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['melt_f'] changed from `6.469051726569001` to `10.567470900135515`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['prcp_fac'] changed from `8.635452497992574` to `9.897209956057916`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['temp_bias'] changed from `-10.686514952407354` to `9.197797177847285`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['melt_f'] changed from `10.567470900135515` to `8.440639958227045`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['prcp_fac'] changed from `9.897209956057916` to `8.426348628853264`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['temp_bias'] changed from `9.197797177847285` to `1.1770733348251845`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['melt_f'] changed from `8.440639958227045` to `4.946544183491505`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['prcp_fac'] changed from `8.426348628853264` to `4.355792313051859`.
# 2026-01-15 14:10:54: oggm.cfg: PARAMS['temp_bias'] changed from `1.1770733348251845` to `1.8472880103632257`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['melt_f'] changed from `4.946544183491505` to `5.724880180503551`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['prcp_fac'] changed from `4.355792313051859` to `6.551557803693019`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['temp_bias'] changed from `1.8472880103632257` to `10.977263913374806`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['melt_f'] changed from `5.724880180503551` to `15.27969270201674`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['prcp_fac'] changed from `6.551557803693019` to `9.784524685178795`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['temp_bias'] changed from `10.977263913374806` to `-0.895368567423855`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['melt_f'] changed from `15.27969270201674` to `3.6896552050246183`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['prcp_fac'] changed from `9.784524685178795` to `2.0924395677372507`.
# 2026-01-15 14:10:55: oggm.cfg: PARAMS['temp_bias'] changed from `-0.895368567423855` to `-2.181909170781392`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['melt_f'] changed from `3.6896552050246183` to `16.397015671148637`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['prcp_fac'] changed from `2.0924395677372507` to `9.145435855494998`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['temp_bias'] changed from `-2.181909170781392` to `2.6497344359341177`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['melt_f'] changed from `16.397015671148637` to `9.671694370717693`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['prcp_fac'] changed from `9.145435855494998` to `2.4117047548945036`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['temp_bias'] changed from `2.6497344359341177` to `-5.3368368033315186`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['melt_f'] changed from `9.671694370717693` to `16.224292420940216`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['prcp_fac'] changed from `2.4117047548945036` to `1.223011913756084`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['temp_bias'] changed from `-5.3368368033315186` to `1.5797674797317143`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['melt_f'] changed from `16.224292420940216` to `14.491972878728042`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['prcp_fac'] changed from `1.223011913756084` to `9.088781934310013`.
# 2026-01-15 14:10:56: oggm.cfg: PARAMS['temp_bias'] changed from `1.5797674797317143` to `2.7472774936749857`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['melt_f'] changed from `14.491972878728042` to `3.9709187596597433`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['prcp_fac'] changed from `9.088781934310013` to `7.625730978655922`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['temp_bias'] changed from `2.7472774936749857` to `3.490141917742509`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['melt_f'] changed from `3.9709187596597433` to `3.951719080074186`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['prcp_fac'] changed from `7.625730978655922` to `0.10477519308696759`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['temp_bias'] changed from `3.490141917742509` to `-7.156445732411007`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['melt_f'] changed from `3.951719080074186` to `16.566291730961396`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['prcp_fac'] changed from `0.10477519308696759` to `5.389863261345783`.
# 2026-01-15 14:10:57: oggm.cfg: PARAMS['temp_bias'] changed from `-7.156445732411007` to `13.253610174138192`.
# 2026-01-15 14:10:58: oggm.cfg: PARAMS['melt_f'] changed from `16.566291730961396` to `2.759796040171855`.
# 2026-01-15 14:10:58: oggm.cfg: PARAMS['prcp_fac'] changed from `5.389863261345783` to `8.02535006034106`.
# 2026-01-15 14:10:58: oggm.cfg: PARAMS['temp_bias'] changed from `13.253610174138192` to `7.178458161393408`.
# 2026-01-15 14:10:58: oggm.cfg: PARAMS['melt_f'] changed from `2.759796040171855` to `14.194039088448434`.
# ...
# 2026-01-15 14:16:09: oggm.cfg: PARAMS['temp_bias'] changed from `-11.90697447249498` to `-13.886860485945302`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['melt_f'] changed from `9.139743246658984` to `13.347749778187044`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['prcp_fac'] changed from `7.004307304218504` to `5.06375170841022`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['temp_bias'] changed from `-13.886860485945302` to `9.647705217114428`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['melt_f'] changed from `13.347749778187044` to `4.359850355799798`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['prcp_fac'] changed from `5.06375170841022` to `0.7739112294966454`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['temp_bias'] changed from `9.647705217114428` to `-7.479408856762648`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['melt_f'] changed from `4.359850355799798` to `13.13069430685758`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7739112294966454` to `6.228122299431248`.
# 2026-01-15 14:16:10: oggm.cfg: PARAMS['temp_bias'] changed from `-7.479408856762648` to `-14.65667353822664`.
# 2026-01-15 14:16:11: oggm.cfg: PARAMS['melt_f'] changed from `13.13069430685758` to `10.867179179509359`.
# 2026-01-15 14:16:11: oggm.cfg: PARAMS['prcp_fac'] changed from `6.228122299431248` to `3.325575710438785`.
# 2026-01-15 14:16:11: oggm.cfg: PARAMS['temp_bias'] changed from `-14.65667353822664` to `10.826339930689809`.
# 2026-01-15 14:16:11: oggm.cfg: PARAMS['melt_f'] changed from `10.867179179509359` to `13.861182993269876`.
# 2026-01-15 14:16:11: oggm.cfg: PARAMS['prcp_fac'] changed from `3.325575710438785` to `0.12010584238783759`.
# 2026-01-15 14:16:11: oggm.cfg: PARAMS['temp_bias'] changed from `10.826339930689809` to `-7.193012281153137`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['melt_f'] changed from `13.861182993269876` to `15.159880221075094`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['prcp_fac'] changed from `0.12010584238783759` to `2.460508960620448`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['temp_bias'] changed from `-7.193012281153137` to `-1.4239952006494185`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['melt_f'] changed from `15.159880221075094` to `3.2330397937620146`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['prcp_fac'] changed from `2.460508960620448` to `0.18661964699300676`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['temp_bias'] changed from `-1.4239952006494185` to `6.304218065932247`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['melt_f'] changed from `3.2330397937620146` to `10.523559568139682`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['prcp_fac'] changed from `0.18661964699300676` to `8.425386533121442`.
# 2026-01-15 14:16:12: oggm.cfg: PARAMS['temp_bias'] changed from `6.304218065932247` to `10.506023268179959`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['melt_f'] changed from `10.523559568139682` to `13.480315886209894`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['prcp_fac'] changed from `8.425386533121442` to `4.319170518022832`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['temp_bias'] changed from `10.506023268179959` to `6.832284467416432`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['melt_f'] changed from `13.480315886209894` to `10.245142873436071`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['prcp_fac'] changed from `4.319170518022832` to `6.695309325206573`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['temp_bias'] changed from `6.832284467416432` to `12.348277670953575`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['melt_f'] changed from `10.245142873436071` to `15.315486456935743`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['prcp_fac'] changed from `6.695309325206573` to `1.7698866020160977`.
# 2026-01-15 14:16:13: oggm.cfg: PARAMS['temp_bias'] changed from `12.348277670953575` to `14.929385746767661`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['melt_f'] changed from `15.315486456935743` to `12.004433837368252`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['prcp_fac'] changed from `1.7698866020160977` to `0.5625123961168416`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['temp_bias'] changed from `14.929385746767661` to `-4.471576873392106`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['melt_f'] changed from `12.004433837368252` to `5.184089957326794`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['prcp_fac'] changed from `0.5625123961168416` to `4.744989477977852`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['temp_bias'] changed from `-4.471576873392106` to `-11.550658198166987`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['melt_f'] changed from `5.184089957326794` to `3.8569481150769627`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['prcp_fac'] changed from `4.744989477977852` to `4.846143307302801`.
# 2026-01-15 14:16:14: oggm.cfg: PARAMS['temp_bias'] changed from `-11.550658198166987` to `8.384605229687978`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['melt_f'] changed from `3.8569481150769627` to `9.99379649850128`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['prcp_fac'] changed from `4.846143307302801` to `2.908657063768193`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['temp_bias'] changed from `8.384605229687978` to `-2.2391510626696256`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['melt_f'] changed from `9.99379649850128` to `14.292342554385957`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['prcp_fac'] changed from `2.908657063768193` to `4.360380185034912`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['temp_bias'] changed from `-2.2391510626696256` to `0.36795368958421726`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['melt_f'] changed from `14.292342554385957` to `9.042752326882344`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['prcp_fac'] changed from `4.360380185034912` to `0.7967785656778046`.
# 2026-01-15 14:16:15: oggm.cfg: PARAMS['temp_bias'] changed from `0.36795368958421726` to `-8.532287246520989`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['melt_f'] changed from `9.042752326882344` to `9.556493610731536`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['prcp_fac'] changed from `0.7967785656778046` to `7.917539834850731`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['temp_bias'] changed from `-8.532287246520989` to `13.544605714540687`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['melt_f'] changed from `9.556493610731536` to `16.38749007117057`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['prcp_fac'] changed from `7.917539834850731` to `9.668155780414782`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['temp_bias'] changed from `13.544605714540687` to `-1.6597942471196578`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['melt_f'] changed from `16.38749007117057` to `2.510746065356569`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['prcp_fac'] changed from `9.668155780414782` to `6.519470543355028`.
# 2026-01-15 14:16:16: oggm.cfg: PARAMS['temp_bias'] changed from `-1.6597942471196578` to `-1.3648393352904566`.
# 2026-01-15 14:16:17: oggm.cfg: PARAMS['melt_f'] changed from `2.510746065356569` to `10.226871846874827`.
# 2026-01-15 14:16:17: oggm.cfg: PARAMS['prcp_fac'] changed from `6.519470543355028` to `2.1260325115751195`.
# 2026-01-15 14:16:17: oggm.cfg: PARAMS['temp_bias'] changed from `-1.3648393352904566` to `-4.5137455735525975`.
# 2026-01-15 14:16:17: oggm.cfg: PARAMS['melt_f'] changed from `10.226871846874827` to `6.00123702243136`.
# 2026-01-15 14:16:17: oggm.cfg: PARAMS['prcp_fac'] changed from `2.1260325115751195` to `9.747044167739197`.
# 2026-01-15 14:16:17: oggm.cfg: PARAMS['temp_bias'] changed from `-4.5137455735525975` to `3.3035573662311464`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['melt_f'] changed from `6.00123702243136` to `2.6648334153664464`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['prcp_fac'] changed from `9.747044167739197` to `4.109704036129523`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['temp_bias'] changed from `3.3035573662311464` to `13.05146196354547`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['melt_f'] changed from `2.6648334153664464` to `14.753606717650493`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['prcp_fac'] changed from `4.109704036129523` to `3.6475240287865107`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['temp_bias'] changed from `13.05146196354547` to `11.191577010158742`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['melt_f'] changed from `14.753606717650493` to `8.289492653445585`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['prcp_fac'] changed from `3.6475240287865107` to `7.357147892268509`.
# 2026-01-15 14:16:18: oggm.cfg: PARAMS['temp_bias'] changed from `11.191577010158742` to `1.159703514349804`.
# 2026-01-15 14:16:19: oggm.cfg: PARAMS['melt_f'] changed from `8.289492653445585` to `14.523042657241088`.
# 2026-01-15 14:16:19: oggm.cfg: PARAMS['prcp_fac'] changed from `7.357147892268509` to `8.031294489499889`.
# 2026-01-15 14:16:19: oggm.cfg: PARAMS['temp_bias'] changed from `1.159703514349804` to `-13.361602191658863`.
# 2026-01-15 14:16:19: oggm.cfg: PARAMS['melt_f'] changed from `14.523042657241088` to `10.158613566227507`.
# 2026-01-15 14:16:19: oggm.cfg: PARAMS['prcp_fac'] changed from `8.031294489499889` to `9.683241043748914`.
# 2026-01-15 14:16:19: oggm.cfg: PARAMS['temp_bias'] changed from `-13.361602191658863` to `-14.781787831567994`.
# 2026-01-15 14:16:20: oggm.cfg: PARAMS['melt_f'] changed from `10.158613566227507` to `1.8874355191927237`.
# 2026-01-15 14:16:20: oggm.cfg: PARAMS['prcp_fac'] changed from `9.683241043748914` to `8.7674786818902`.
# 2026-01-15 14:16:20: oggm.cfg: PARAMS['temp_bias'] changed from `-14.781787831567994` to `8.298880199580008`.
# 2026-01-15 14:16:20: oggm.cfg: PARAMS['melt_f'] changed from `1.8874355191927237` to `8.749347946024315`.
# 2026-01-15 14:16:20: oggm.cfg: PARAMS['prcp_fac'] changed from `8.7674786818902` to `0.3616791221664183`.
# 2026-01-15 14:16:20: oggm.cfg: PARAMS['temp_bias'] changed from `8.298880199580008` to `3.2650622834910052`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['melt_f'] changed from `8.749347946024315` to `2.0315958522994837`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['prcp_fac'] changed from `0.3616791221664183` to `9.42810339136206`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['temp_bias'] changed from `3.2650622834910052` to `4.127381599092441`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['melt_f'] changed from `2.0315958522994837` to `5.763008677383022`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['prcp_fac'] changed from `9.42810339136206` to `8.310084297533969`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['temp_bias'] changed from `4.127381599092441` to `5.6443948630865215`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['melt_f'] changed from `5.763008677383022` to `15.22264236353952`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['prcp_fac'] changed from `8.310084297533969` to `6.294010781844072`.
# 2026-01-15 14:16:21: oggm.cfg: PARAMS['temp_bias'] changed from `5.6443948630865215` to `-2.9436370178759024`.
# 2026-01-15 14:16:22: oggm.cfg: PARAMS['melt_f'] changed from `15.22264236353952` to `3.730368700845547`.
# 2026-01-15 14:16:22: oggm.cfg: PARAMS['prcp_fac'] changed from `6.294010781844072` to `4.8965002923996925`.
# 2026-01-15 14:16:22: oggm.cfg: PARAMS['temp_bias'] changed from `-2.9436370178759024` to `-10.192652191469437`.
# 2026-01-15 14:16:22: oggm.cfg: PARAMS['melt_f'] changed from `3.730368700845547` to `10.972145819002053`.
# 2026-01-15 14:16:22: oggm.cfg: PARAMS['prcp_fac'] changed from `4.8965002923996925` to `4.989219865232736`.
# 2026-01-15 14:16:22: oggm.cfg: PARAMS['temp_bias'] changed from `-10.192652191469437` to `12.30890405360595`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['melt_f'] changed from `10.972145819002053` to `12.09184630258409`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['prcp_fac'] changed from `4.989219865232736` to `5.854393290304888`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['temp_bias'] changed from `12.30890405360595` to `6.93899726129586`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['melt_f'] changed from `12.09184630258409` to `9.72798780387665`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['prcp_fac'] changed from `5.854393290304888` to `9.347855299406545`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['temp_bias'] changed from `6.93899726129586` to `5.58923219737952`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['melt_f'] changed from `9.72798780387665` to `6.8010045579711`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['prcp_fac'] changed from `9.347855299406545` to `4.2933595230890615`.
# 2026-01-15 14:16:23: oggm.cfg: PARAMS['temp_bias'] changed from `5.58923219737952` to `-11.626987139335032`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['melt_f'] changed from `6.8010045579711` to `5.444613305506197`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['prcp_fac'] changed from `4.2933595230890615` to `6.898559245050044`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['temp_bias'] changed from `-11.626987139335032` to `4.441244208023466`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['melt_f'] changed from `5.444613305506197` to `4.083468791179932`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['prcp_fac'] changed from `6.898559245050044` to `5.629253388285851`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['temp_bias'] changed from `4.441244208023466` to `-4.322593841421639`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['melt_f'] changed from `4.083468791179932` to `2.4353588154076165`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['prcp_fac'] changed from `5.629253388285851` to `4.212050440199152`.
# 2026-01-15 14:16:24: oggm.cfg: PARAMS['temp_bias'] changed from `-4.322593841421639` to `-11.739491320243529`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['melt_f'] changed from `2.4353588154076165` to `8.066102193106257`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['prcp_fac'] changed from `4.212050440199152` to `8.542579125601987`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['temp_bias'] changed from `-11.739491320243529` to `4.183329471151808`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['melt_f'] changed from `8.066102193106257` to `15.390957672775048`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['prcp_fac'] changed from `8.542579125601987` to `9.694332776637353`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['temp_bias'] changed from `4.183329471151808` to `4.3218843128236415`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['melt_f'] changed from `15.390957672775048` to `11.130199606418111`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['prcp_fac'] changed from `9.694332776637353` to `3.2137514672473326`.
# 2026-01-15 14:16:25: oggm.cfg: PARAMS['temp_bias'] changed from `4.3218843128236415` to `-9.952525767643612`.
# 2026-01-15 14:16:26: oggm.cfg: PARAMS['melt_f'] changed from `11.130199606418111` to `14.84858973580257`.
# 2026-01-15 14:16:26: oggm.cfg: PARAMS['prcp_fac'] changed from `3.2137514672473326` to `9.403818185141155`.
# 2026-01-15 14:16:26: oggm.cfg: PARAMS['temp_bias'] changed from `-9.952525767643612` to `14.802097286398784`.
# 2026-01-15 14:16:26: oggm.cfg: PARAMS['melt_f'] changed from `14.84858973580257` to `12.645925485772842`.
# 2026-01-15 14:16:26: oggm.cfg: PARAMS['prcp_fac'] changed from `9.403818185141155` to `3.8773398671465276`.
# 2026-01-15 14:16:26: oggm.cfg: PARAMS['temp_bias'] changed from `14.802097286398784` to `-10.740893124111768`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['melt_f'] changed from `12.645925485772842` to `8.876650097717231`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['prcp_fac'] changed from `3.8773398671465276` to `8.189967282889018`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['temp_bias'] changed from `-10.740893124111768` to `14.756768092256134`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['melt_f'] changed from `8.876650097717231` to `16.341635120658218`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['prcp_fac'] changed from `8.189967282889018` to `5.732983170207817`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['temp_bias'] changed from `14.756768092256134` to `-12.535240175692145`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['melt_f'] changed from `16.341635120658218` to `2.742893626350754`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['prcp_fac'] changed from `5.732983170207817` to `1.6551934329680265`.
# 2026-01-15 14:16:27: oggm.cfg: PARAMS['temp_bias'] changed from `-12.535240175692145` to `-4.119082541493848`.
# 2026-01-15 14:16:28: oggm.cfg: PARAMS['melt_f'] changed from `2.742893626350754` to `13.706928755060698`.
# 2026-01-15 14:16:28: oggm.cfg: PARAMS['prcp_fac'] changed from `1.6551934329680265` to `4.946498691024554`.
# 2026-01-15 14:16:28: oggm.cfg: PARAMS['temp_bias'] changed from `-4.119082541493848` to `0.3264269339488042`.

# %%
# Plot Monte Carlo (MC) simulations results for the Runoff and compare with data:
plt.figure(figsize=[15,5])
plt.plot(mbdf.index.values, np.transpose(runoff), 'k', linewidth = 0.5)
plt.ylabel('Runoff'); plt.xlabel('Years')
plt.legend(['sim'])
plt.title("Number of parameter samples: N = %d" % N, loc='right')
plt.show()

# %%
# Also colour mapping (retrospectively) based on temp_bias values
import matplotlib.pyplot as plt
import numpy as np

temp_bias_index = 2  # Index of temp_bias in X


import matplotlib.pyplot as plt
import numpy as np

# Colormap and normalization
cmap = plt.cm.coolwarm
norm = plt.Normalize(vmin=X[:, temp_bias_index].min(), vmax=X[:, temp_bias_index].max())

fig, ax = plt.subplots(figsize=(15, 5))

# Plot each simulation with color based on temp_bias
for i in range(np.shape(runoff)[0]):  # assuming QQ_runoff is (N, time)
    color = cmap(norm(X[i, temp_bias_index]))
    ax.plot(mbdf.index.values, runoff[i, :], linewidth=0.5, color=color)

ax.set_ylabel('Runoff')
ax.set_xlabel('Years')
ax.set_title(f"Number of parameter samples: N = {N}", loc='right')

# Add colorbar linked to the same colormap
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # required for colorbar
cbar = fig.colorbar(sm, ax=ax)  # <-- specify ax here
cbar.set_label('Temperature Bias')

plt.show()

# %% [markdown]
# ## Distribution of Model Outputs

# %%
Y_lab_runoff_dist = ['Mean Runoff', 'Std of Runoff']

YY_hydro = np.nan * np.ones((N, 2))

for i, x in enumerate(runoff):
    YY_hydro[i,0] = np.mean(x)
    YY_hydro[i,1] = np.std(x)

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_hydro[:,0], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_lab_runoff_dist[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_hydro[:,1], bins=20, color='grey');
plt.axvline(x=0, color='r'), plt.ylim((0,N)), plt.ylabel('number of samples'), plt.xlabel(Y_lab_runoff_dist[1])

plt.tight_layout()

# %% [markdown]
# ## Sensitivity Analysis

# %%
annual_mean_runoff = np.mean(runoff, axis=1) # Mean annual runoff for each sample
annual_std_runoff = np.std(runoff, axis=1) # Std annual runoff for each sample

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(annual_mean_runoff, annual_std_runoff, s=5), plt.title('Mean runoff vs Std of runoff'), plt.xlabel('Mean runoff'), plt.ylabel('Std of runoff (mm w.e.)'),
plt.axvline(x=0, color='r'), plt.axhline(y=0, color='r')
plt.gca().locator_params(axis='x', nbins=6)

plt.tight_layout()
plt.show()

# %%
YY_hydro = np.nan * np.ones((N, 2))

for i, x in enumerate(runoff):
    YY_hydro[i,0] = np.mean(x)
    YY_hydro[i,1] = np.std(x)

Y_Labels = ['Mean Runoff', 'Std of Runoff']

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY_hydro[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %%
temp_bias_index = 2

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X[:, i], YY_hydro[:, j], c=X[:, temp_bias_index], cmap='coolwarm', edgecolors='grey')
        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label('Temp Bias (°C)')
    plt.show()

interact(scatter_function, metric=Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %%
Nboot = 50 # Number of resamples used for bootstrapping
# Here fails when target is 0 for mean and std runoff, so we set small values instead

for i in range(2):
    if i==0:
        Y=YY_hydro[:,0]
        target=0.1
    if i==1:
        Y=YY_hydro[:,1]
        target=0.1

    # plot:
    plt.figure(figsize=[7,2])
    mvd, _, _, idx = RSA_tr.RSA_indices_thres(X, Y, target, Nboot=Nboot)
    mvd_m, mvd_lb, mvd_ub = aggregate_boot(mvd) # shape (M,)
    yerr=np.c_[mvd_m-mvd_lb,mvd_ub-mvd_m].T
    plt.bar(range(len(mvd_m)), mvd_m, color='grey',yerr=yerr)
    plt.title(Y_Labels[i], loc='center'), plt.xticks(range(len(mvd_m)), X_labels), plt.ylabel('Sensitivity')
    plt.show()
