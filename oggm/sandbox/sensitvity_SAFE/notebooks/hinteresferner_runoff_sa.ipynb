# %% [markdown]
# # Investigating parameters effects on Sensitivity of the OGGM Mass Balance and Runoff Models

# %% [markdown]
# In this notebook we will explore the sensitivity of OGGM's mass-balance and runoff models using SAFE. We will focus on the three parameters: melt factor, precipitation factor and temperature bias.
#
# We will start by applying one-at-a-time sensitivity analysis to get a feel for how much each parameter affects the model and output. We will then consider the uncertainty of these sensitivities and work to quantify them.

# %% [markdown]
# ## Sensitivity Analysis with the OGGM Mass Balance Model

# %% [markdown]
# We will apply sensitivity analysis in the following order to investigate our model behaviour:
#
# 1. **One-at-a-time**: We will apply one-at-a-time analysis , in which we change one parameter at a time and see how the mass balance changes in accordance. To show this, we will plot an interactive mass balance time series with toggles, where the parameter values can be changed within their default boundaries.
# 2. **Global sensitivity analysis**: Here we will use AAT sampling to randomly sample a combination of the 3 parameters and investigate the sensitivity in the following ways
#     a. Qualitative - scatter plots
#     b. Quantitative - RSA and bootstrapping
#
# This will be applied first to the mass balance model in the OGGM, and then to the runoff model in the OGGM.

# %% [markdown]
# First we install the packages we require from both OGGM and SAFE.

# %%
# %pip install -q matplotlib
# %pip install -q oggm

import matplotlib.pyplot as plt
import os
import numpy as np
import scipy.stats as st
import pandas as pd

from oggm import cfg, workflow, utils
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We start from a well known glacier in the Austrian Alps, Hintereisferner. But you can choose any other glacier, e.g. from [this list](https://github.com/OGGM/oggm-sample-data/blob/master/wgms/rgi_wgms_links_20220112.csv). We will load in the glacier directories and ensure our configuration is as required for our runs.

# %%
# Hintereisferner
rgi_id = ['RGI60-06.00377', 'RGI60-11.00897', 'RGI60-13.53223']

cfg.initialize(logging_level='CRITICAL') # To suppress OGGM logging output during the runs
cfg.PATHS['working_dir'] = "~/testing"
cfg.PARAMS['store_model_geometry'] = True
cfg.PARAMS['min_ice_thick_for_length'] = 1

cfg.PARAMS['use_multiprocessing'] = True  # To speed up sensitivity analysis run
# We pick the elevation-bands glaciers
base_url = 'https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/L3-L5_files/2023.3/elev_bands/W5E5_spinup
gdir = workflow.init_glacier_directories(rgi_id, from_prepro_level=4, prepro_border=160, prepro_base_url=base_url)[0]
# Out:
# 2026-06-10 12:38:38: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2026-06-10 12:38:38: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2026-06-10 12:38:38: oggm.cfg: Multiprocessing: using all available processors (N=32)
# 2026-06-10 12:38:38: oggm.cfg: PARAMS['border'] changed from `80` to `10`.
# 2026-06-10 12:38:38: oggm.cfg: PARAMS['store_model_geometry'] changed from `False` to `True`.
# 2026-06-10 12:38:38: oggm.cfg: PARAMS['min_ice_thick_for_length'] changed from `0.0` to `1`.
# 2026-06-10 12:38:38: oggm.workflow: init_glacier_directories from prepro level 4 on 1 glaciers.
# 2026-06-10 12:38:38: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 12
#       8 rgi_id = ['RGI60-06.00377', 'RGI60-11.00897', 'RGI60-13.53223']
#       9
#      10 # We pick the elevation-bands glaciers because they run a bit faster - but they create more step changes in the area outputs
#      11 base_url = 'https://cluster.klima.uni-bremen.de/~oggm/gdirs/oggm_v1.6/L3-L5_files/2023.3/elev_bands/W5E5_spinup'
# ---> 12 gdirs = workflow.init_glacier_directories([rgi_id[0]], from_prepro_level=4, prepro_border=160, prepro_base_url=base_url)[0]
#      13
#      14 geodf = gdirs[0].get_geodf()
#      15 print(geodf[['RGIId', 'Area', 'Area_km2']])
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/workflow.py:428, in init_glacier_directories(rgidf, reset, force, from_prepro_level, prepro_border, prepro_rgi_version, prepro_base_url, from_tar, delete_tar)
#     424 if from_prepro_level is not None:
#     425     log.workflow('init_glacier_directories from prepro level {} on '
#     426                  '{} glaciers.'.format(from_prepro_level,
#     427                                        len(entities)))
# --> 428     gdirs = execute_entity_task(gdir_from_prepro, entities,
#     429                                 from_prepro_level=from_prepro_level,
#     430                                 prepro_border=prepro_border,
#     431                                 prepro_rgi_version=prepro_rgi_version,
#     432                                 base_url=prepro_base_url)
#     433 else:
#     434     # We can set the intersects file automatically here
#     435     if (cfg.PARAMS['use_intersects'] and
#     436             len(cfg.PARAMS['intersects_gdf']) == 0 and
#     437             not from_tar):
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/workflow.py:192, in execute_entity_task(task, gdirs, **kwargs)
#     188     if ng > 3:
#     189         log.workflow('WARNING: you are trying to run an entity task on '
#     190                      '%d glaciers with multiprocessing turned off. OGGM '
#     191                      'will run faster with multiprocessing turned on.', ng)
# --> 192     out = [pc(gdir) for gdir in gdirs]
#     194 return out
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/workflow.py:109, in _pickle_copier.__call__(self, arg)
#     107 for func in self.call_func:
#     108     func, kwargs = func
# --> 109     res = self._call_internal(func, arg, kwargs)
#     110 return res
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/workflow.py:103, in _pickle_copier._call_internal(self, call_func, gdir, kwargs)
#     100     gdir, gdir_kwargs = gdir
#     101     kwargs.update(gdir_kwargs)
# --> 103 return call_func(gdir, **kwargs)
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/workflow.py:256, in gdir_from_prepro(entity, from_prepro_level, prepro_border, prepro_rgi_version, base_url)
#     253 tar_base = utils.get_prepro_gdir(prepro_rgi_version, rid, prepro_border,
#     254                                  from_prepro_level, base_url=base_url)
#     255 from_tar = os.path.join(tar_base.replace('.tar', ''), rid + '.tar.gz')
# --> 256 return oggm.GlacierDirectory(entity, from_tar=from_tar)
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/utils/_workflow.py:2752, in GlacierDirectory.__init__(self, rgi_entity, base_dir, reset, from_tar, delete_tar)
#    2750 if from_tar is True:
#    2751     from_tar = _dir + '.tar.gz'
# -> 2752 robust_tar_extract(from_tar, _dir, delete_tar=delete_tar)
#    2753 from_tar = False  # to not re-unpack later below
#    2754 _shp = os.path.join(_dir, 'outlines.shp')
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/utils/_workflow.py:2637, in robust_tar_extract(from_tar, to_dir, delete_tar)
#    2634             with tf.extractfile(i_from_tar) as fileobj:
#    2635                 _robust_extract(to_dir, fileobj=fileobj)
# -> 2637     _back_up_retry(func, RuntimeError)
#    2639 if delete_tar:
#    2640     os.remove(from_tar)
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/utils/_workflow.py:2592, in _back_up_retry(func, exceptions, max_count)
#    2590     if count > 0:
#    2591         time.sleep(random.uniform(0.05, 0.1))
# -> 2592     return func()
#    2593 except exceptions:
#    2594     count += 1
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/utils/_workflow.py:2635, in robust_tar_extract.<locals>.func()
#    2633 i_from_tar = tf.getmember(os.path.join(dirbname, bname))
#    2634 with tf.extractfile(i_from_tar) as fileobj:
# -> 2635     _robust_extract(to_dir, fileobj=fileobj)
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/utils/_workflow.py:2611, in _robust_extract(to_dir, *args, **kwargs)
#    2608             raise RuntimeError("Empty tarfile")
#    2609         tf.extractall(os.path.dirname(to_dir))
# -> 2611 _back_up_retry(func, FileExistsError)
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/utils/_workflow.py:2592, in _back_up_retry(func, exceptions, max_count)
#    2590     if count > 0:
#    2591         time.sleep(random.uniform(0.05, 0.1))
# -> 2592     return func()
#    2593 except exceptions:
#    2594     count += 1
#
# File ~/OGGM_repo/.venv/lib/python3.14/site-packages/oggm/utils/_workflow.py:2609, in _robust_extract.<locals>.func()
#    2607 if not len(tf.getnames()):
#    2608     raise RuntimeError("Empty tarfile")
# -> 2609 tf.extractall(os.path.dirname(to_dir))
#
# File /usr/lib/python3.14/tarfile.py:2439, in TarFile.extractall(self, path, members, numeric_owner, filter)
#    2434     if tarinfo.isdir():
#    2435         # For directories, delay setting attributes until later,
#    2436         # since permissions can interfere with extraction and
#    2437         # extracting contents can reset mtime.
#    2438         directories.append(unfiltered)
# -> 2439     self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2440                       numeric_owner=numeric_owner,
#    2441                       filter_function=filter_function)
#    2443 # Reverse sort directories.
#    2444 directories.sort(key=lambda a: a.name, reverse=True)
#
# File /usr/lib/python3.14/tarfile.py:2548, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner, filter_function)
#    2542     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2543                          set_attrs=set_attrs,
#    2544                          numeric_owner=numeric_owner,
#    2545                          filter_function=filter_function,
#    2546                          extraction_root=path)
#    2547 except (OSError, UnicodeEncodeError) as e:
# -> 2548     self._handle_fatal_error(e)
#    2549 except ExtractError as e:
#    2550     self._handle_nonfatal_error(e)
#
# File /usr/lib/python3.14/tarfile.py:2542, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner, filter_function)
#    2539 self._check("r")
#    2541 try:
# -> 2542     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2543                          set_attrs=set_attrs,
#    2544                          numeric_owner=numeric_owner,
#    2545                          filter_function=filter_function,
#    2546                          extraction_root=path)
#    2547 except (OSError, UnicodeEncodeError) as e:
#    2548     self._handle_fatal_error(e)
#
# File /usr/lib/python3.14/tarfile.py:2623, in TarFile._extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner, filter_function, extraction_root)
#    2619 upperdirs = os.path.dirname(targetpath)
#    2620 if upperdirs and not os.path.exists(upperdirs):
#    2621     # Create directories that are not part of the archive with
#    2622     # default permissions.
# -> 2623     os.makedirs(upperdirs, exist_ok=True)
#    2625 if tarinfo.islnk() or tarinfo.issym():
#    2626     self._dbg(1, "%s -> %s" % (tarinfo.name, tarinfo.linkname))
#
# File <frozen os>:226, in makedirs(name, mode, exist_ok)
#     224 if head and tail and not path.exists(head):
#     225     try:
# --> 226         makedirs(head, exist_ok=exist_ok)
#     227     except FileExistsError:
#     228         # Defeats race condition when another thread created the path
#     229         pass
#
# File <frozen os>:226, in makedirs(name, mode, exist_ok)
#     224 if head and tail and not path.exists(head):
#     225     try:
# --> 226         makedirs(head, exist_ok=exist_ok)
#     227     except FileExistsError:
#     228         # Defeats race condition when another thread created the path
#     229         pass
#
#     [... skipping similar frames: makedirs at line 226 (4 times)]
#
# File <frozen os>:226, in makedirs(name, mode, exist_ok)
#     224 if head and tail and not path.exists(head):
#     225     try:
# --> 226         makedirs(head, exist_ok=exist_ok)
#     227     except FileExistsError:
#     228         # Defeats race condition when another thread created the path
#     229         pass
#
# File <frozen os>:236, in makedirs(name, mode, exist_ok)
#     234         return
#     235 try:
# --> 236     mkdir(name, mode)
#     237 except OSError:
#     238     # Cannot rely on checking for EEXIST, since the operating system
#     239     # could give priority to other errors like EACCES or EROFS
#     240     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/mnt/c'

# %% [markdown]
# # Step 1 - The OGGM Runner, to produce runoff simulations
#
# We have loaded all required packages, so now we need to create a runner for the OGGM. To do this, we will set the 3 mass balance parameters to some tentative values, run the model and plot the resulting runoff timeseries. We can then change the parameter values one-at-a-time and look at how this changes the model predictions.
#
# This runner will produce a timeseries for the runoff.
#
# The method will use run_with_hydro to create the hydrological data required to calculate the runoff in the OGGM.

# %% [markdown]
# The below method calculates the output metrics we will be using to understand the output of our hydrological simulations and our runoff timeseries. We currently do not have any observed data and so we are unsure of the values to expect, but we can still look into the mean and standard deviation, and use these in our sensitivity analysis.
#
# Using the mean and standard deviation can give us a good picture of the data we have generated.

# %%
gdir_hef.rgi_area_km2 # plus or minus 10 percent here
gdir_hef.rgi_date # At this date specifically
# Out:
# 2003

# %%
# And match the Hugonnet
geo_df = utils.get_geodetic_mb_dataframe()
geo_df.loc[gdir_hef.rgi_id]
# Out:
#                                period       area  dmdtda  err_dmdtda  reg  \
# rgiid
# RGI60-11.00897  2000-01-01_2010-01-01  8036000.0 -1.0425      0.2610   11
# RGI60-11.00897  2000-01-01_2020-01-01  8036000.0 -1.1003      0.1718   11
# RGI60-11.00897  2010-01-01_2020-01-01  8036000.0 -1.1580      0.2427   11
#
#                 is_cor
# rgiid
# RGI60-11.00897   False
# RGI60-11.00897   False
# RGI60-11.00897   False

# %% [markdown]
# ## Taking samples and producing the runoff in the OGGM

# %%
X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)

# gdir_hef.settings['error_when_glacier_reaches_boundaries'] = False # TODO- When more realistic, I assume we will not need this? 
distr_fun = st.uniform # Uniform distribution for all parameters
x_min = np.array([1.5, 1.0, -3]) # Minimum values for each parameter
x_max = np.array([7.0, 5.0, 3]) # Maximum values for each parameter

distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
    
samp_strat = 'lhs' 

N = 2 # Number of samples

# %% [markdown]
#     Note: Will only need to run this once! Once it has run, the CSVs with the outputs will be saved

# %%
X = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

YY = runoff_execution(fun_test = run_with_runoff_for_sa, 
                 X = X, # All samples
                 gdir = gdir_hef, # Hinteresfirner Glacier directory
                 years =range(1979, 2020), # years
                 init_model_yr = 1901, # Simulation start year - needs to be early enough to allow for spinup before the period we are interested in
                 ys =1901, # Start of the simulation
                 min_ys = 1901, # Minimum start year
                 ref_area_yr = 2004, # Reference area year - needs to be a year for which we have observed area data for the glacier, so we can use this to constrain the modelled glacier area during the spinup period
                 spinup_period = 21, # Spinup period in years (we are cutting this off, once the glacier has reached an equilibrium state, but this can be changed to a different period if desired)
                 csv_filepath = 'hinteresfirner_runoff_output.csv',
                 params_csv_filepath='hinteresfirner_params.csv',
                 run_task = tasks.run_from_climate_data,
                 mb_model_method = MultipleFlowlineMassBalance)
# Out:
# 2026-03-09 14:04:28: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2026-03-09 14:04:28: oggm.workflow: Execute entity tasks [run_with_runoff_for_sa] on 2 glaciers
# 2026-03-09 14:04:32: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-09 14:04:32: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-09 14:04:43: oggm.cfg: PARAMS['continue_on_error'] changed from `True` to `False`.
# <class 'list'> 2

# %% [markdown]
# ## Parameter Space Study
#
# The OGGM uses extremely large default parameter ranges, that for specific glaciers are completely unrealistic. Here we perform some studies on the parameter space to understand which ranges are feasible, if there are any trends we can take into account for our data and if we can optimise our sampling approach. The outline of the methodology is as follows:
# 1. Sampling the parameter space uniformly with large ranges and an initial, qualitative investigation if any patterns emerge.
# 2. Comparison with the observed data we have avaliable: area and mass balance, we can investigate the combinations of parameters that cause a large deivation from the observed values.
#     a. Here we can start with an AAT investigation, as our inputs are not independent.
# 3. From this initial study, it may become apparent that our ranges can be reduced. If this is obvious, we can reduce the ranges and resample with the updated parameter ranges.
# 4. Running the simulations again, we can now investigate the sampling strategy and distributions. From here some more complex techniques can be investigated and we can compare which behaves the best.

# %% [markdown]
# ## Experiment #1: A uniform sampling of the OGGM's default sample space.
#
# We start off simply with the OGGM's default sample space, which has large ranges for the melt_f, prcp_fac and temp_bias. We have used a uniform distribution to sample these in a LHS technique using AAT.

# %% [markdown]
# Firstly, lets plot the mass balance alongside the observed mass balance value to understand how much our outputs are currently varying from the parameters we are sampling and if there is a large difference between our simulated and observed values.

# %%
# compile CSVs to plot timeseries and plot to view the mass balance time series for each of the 50 samples, to see how they are looking and check that they make sense before we calculate the sensitivity indices
mass_balance_samples = []
years = []
runoff_samples = []
area_samples = []
volume_samples = []
params = []

for i in range(N):
    df = pd.read_csv(cfg.PATHS['working_dir'] + '/' + str(i) + '_hinteresfirner_runoff_output.csv')
    mass_balance_samples.append(df['mass_balance'].values)
    years.append(df['years'].values)
    runoff_samples.append(df['runoff_Mt'].values)
    area_samples.append(df['area_km2'].values)
    volume_samples.append(df['volume_km3'].values)

    mb_param_df = pd.read_csv(cfg.PATHS['working_dir'] + '/' + str(i) + '_hinteresfirner_params.csv') 
    params.append(mb_param_df['params'])

try:
    X
except NameError:
    X = np.vstack([p.values for p in params])

try:
    YY
except NameError:
    YY = hydro_output_metric_calculator(runoff_samples)

# %%
mass_balance_samples
# Out:
# [array([-1266.19130656, -1643.80294459,  -806.00303076, -3234.880309  ,
#         -1955.41141587, -2300.88718863, -2724.80108304, -1731.99702485,
#         -1325.96865941, -2301.45855164, -1177.4838647 , -2709.02444752,
#         -2290.04480122, -1680.67895309, -1383.24173313, -2566.93280227,
#         -2046.36944452, -2350.25768091, -2996.67845586, -1873.48343475]),
#  array([2093.18432866, 1514.72328081, 1923.04373725,  589.64905903,
#         1327.46524692, 1398.87967475,  891.50258431, 1538.983884  ,
#         1849.62065896, 1222.41027096, 1567.05151833, 1340.09234616,
#         1417.18229807, 1394.24772001, 1850.92214685,  796.56357575,
#         1352.52845629, 1224.80986324, 1172.2089782 , 1584.83934375])]

# %% [markdown]
# ## Plotting our output timeseries

# %% [markdown]
# ## Mass Balance

# %%
# compile csvs to plot timeseries and plot to view the mass balance time series for each of the 50 samples, to see how they are looking and check that they make sense before we calculate the sensitivity indices
plt.figure(figsize=(15,5))

for i in range(N):
    plt.plot(years[i], mass_balance_samples[i], label='sim', color='k', linewidth=0.5)

plt.title('Mass balance time series for each parameter sample, N = %d' % N)
plt.xlabel('Year'), plt.ylabel('Mass Balance kg m$^-2$')
plt.plot(range(2000,2020), mbdf['in_situ_mb'].loc[2000:2019], label='obs', color='r', linewidth=2)

# %% [markdown]
# ## Area

# %%
plt.figure(figsize=(15,5))

# Check the area from the observed, why is it so low compared to the simulation?

for i in range(N):
    area_km2 = area_samples[i]
    plt.plot(years[i], area_km2, label='sim', color='k', linewidth=0.5)
    
plt.scatter(gdir_hef.rgi_date, gdir_hef.rgi_area_km2, color='r', s=20, zorder=999)
plt.title('Area time series for each parameter sample, N = %d' % N)
plt.ylabel('Glacier area (km$^2$)')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ## Volume

# %%
# Update this to continue for the entire period
plt.figure(figsize=(15,5))

for i in range(N):
    volume_km3 = volume_samples[i]
    plt.plot(years[i], volume_km3, label='sim', color='k', linewidth=0.5)
    plt.title('Volume time series for each parameter sample, N = %d' % N)

plt.ylabel('Glacier volume (km$^3$)')
plt.xlabel('Year')

plt.show()

# %% [markdown]
# ## Runoff

# %%
# compile csvs to plot timeseries and plot to view the runoff time series for each of the 50 samples, to see how they are looking and check that they make sense before we calculate the sensitivity indices
plt.figure(figsize=(15,5))

for i in range(N):
    plt.plot(years[i], runoff_samples[i], label='sim', color='k', linewidth=0.5)
    plt.title('Runoff time series for each parameter sample, N = %d' % N)

plt.ylabel('Runoff (Mt/yr)')
plt.xlabel('Year')

plt.show()

# %% [markdown]
# ## Inputs
#
# Investigating the distribution of the input parameters compared to the output parameters. In our study, initially we are using a uniform sampling distribution. As we would expect, the distributions here are of uniform distribution, as we had specified. Firstly, if we restart our notebook we can use our variables! We have stored everything we need in a CSV, so if required we can recover these without running a lengthy set of simulations again.

# %%
try:
    X
except NameError:
    X = np.vstack([p.values for p in params])

try:
    YY
except NameError:
    YY = hydro_output_metric_calculator(runoff_samples)

# %% [markdown]
# Investigating the distribution of our inputs, checking ther are as we would expect:

# %%
import numpy as np
import matplotlib.pyplot as plt

melt_low, melt_high = x_min[0], x_max[0]
precip_low, precip_high = x_min[1], x_max[1]
tbias_low, tbias_high = x_min[2], x_max[2]
nbins = 50

bins_melt   = np.linspace(melt_low,   melt_high,   nbins+1)
bins_precip = np.linspace(precip_low, precip_high, nbins+1)
bins_tbias  = np.linspace(tbias_low,  tbias_high,  nbins+1)

plt.figure(figsize=(13, 4))

plt.subplot(1,3,1)
plt.title('Distribution of melt factor', loc='left')
plt.hist(X[:,0], bins=bins_melt, range=(melt_low, melt_high),
         color='grey', edgecolor='white')
plt.ylabel('Frequency of samples'); plt.xlabel('Melt Factor')

plt.subplot(1,3,2)
plt.title('Distribution of precipitation factor', loc='left')
plt.hist(X[:,1], bins=bins_precip, range=(precip_low, precip_high),
         color='grey', edgecolor='white')
plt.ylabel('Frequency of samples'); plt.xlabel('Precipitation Factor')

plt.subplot(1,3,3)
plt.title('Distribution of temperature bias', loc='left')
plt.hist(X[:,2], bins=bins_tbias, range=(tbias_low, tbias_high),
         color='grey', edgecolor='white')
plt.ylabel('Frequency of samples'); plt.xlabel('Temperature Bias')

plt.tight_layout()
plt.show()

# %% [markdown]
# These inputs are as we would expect, we required a uniform sampling and this is what we can seee in the three graphs above.

# %%
from oggm.utils import rmsd

mass_balances = []
mean_mass_balances = []
std_mass_balances = []
rmsds = []

for i in range(N):
    mean_mass_balances.append(mass_balance_samples[i].mean())
    std_mass_balances.append(mass_balance_samples[i].std())
    rmsds.append(rmsd(mass_balance_samples[i], mbdf['in_situ_mb'].loc[2000:2019]))

# %%
plt.figure(figsize=[13,4])

min_means, max_means = np.min(mean_mass_balances), np.max(mean_mass_balances)
min_stds, max_stds = np.min(std_mass_balances), np.max(std_mass_balances)
min_rmsds, max_rmsds = np.min(rmsds), np.max(rmsds)

nbins = 50

bins_means = np.linspace(min_means, max_means, nbins+1)
bins_stds = np.linspace(min_stds, max_stds, nbins+1)
bins_rmsds  = np.linspace(min_rmsds, max_rmsds,  nbins+1)

plt.subplot(1,3,1), plt.title('Distribution of Mean Mass Balance', loc='left'), plt.hist(mean_mass_balances, bins='auto', 
                                                                                         range=(min_means, max_means), color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel('Mean')

plt.subplot(1,3,2), plt.title('Distribution of Std of Mass Balance', loc='left'), plt.hist(std_mass_balances, bins='auto', 
                                                                                         range=(min_stds, max_stds), color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel('Std')

plt.subplot(1,3,3), plt.title('Distribution of RMSD Mass Balance', loc='left'), plt.hist(rmsds, bins='auto', 
                                                                                         range=(min_rmsds, max_rmsds), color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel('RMSDs')

plt.tight_layout()

# %% [markdown]
# We can see that the mean mass balance and the standard deviation of the mass balance are both normally distributed. And we can see that the RMSD is heavily skewed towards lower values.
#
# This indicates that there are likely other influences on the model that would drive this output behaviour, and the nature of the inputs do not wholly control the nature of the outputs.

# %% [markdown]
# Now, lets plot our two output metrics together the mean and standard deviation of the runoff.

# %%
plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(YY[:,0], YY[:,1], s=5), plt.title('Mean runoff vs Std of runoff'), plt.xlabel('Mean runoff Mt/yr'), plt.ylabel('Std of runoff Mt/yr'),

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=[13,4])


min_mean_ro, max_mean_ro = np.min(YY[:,0]), np.max(YY[:,0])
min_std_ro, max_std_ro = np.min(YY[:,1]), np.max(YY[:,1])

nbins = 30

bins_mean_ro = np.linspace(min_mean_ro, max_mean_ro, nbins+1)
bins_std_ro = np.linspace(min_std_ro, max_std_ro, nbins+1)

plt.subplot(1,3,1), plt.title('Distribution of Runoff Mean', loc='left'), 
plt.hist(YY[:,0], bins=bins_mean_ro, color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel('Mean')

plt.subplot(1,3,2), plt.title('Distribution of Runoff Std', loc='left'), 
plt.hist(YY[:,1], bins=bins_std_ro, color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel('Std')
plt.tight_layout()

# %% [markdown]
# ## Qualitative sensitivity

# %%
Y_Labels = ['Mean Runoff', 'Std of Runoff']

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X[:, i], YY[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %% [markdown]
# From this we can already see qualitatively that we would expect, for the runoff mean that the precipitation would be the most significant in sensitivity. We can see for the std of the runoff that the temperature bias would be likely the most significant for sensitivity. This is confirmed by our PAWN sensitivity analysis that we performed above.

# %% [markdown]
# We can investigate how the sensitivity looks right now, where we know our parameter ranges are not correct and are infact too large. this to before to understand how reducing our parameter ranges has affected the sensitivity. This can help us understand if any parameters are currently dominating and we will use this to compare later.

# %% [markdown]
# ## Quantitative Sensitivity
#
# ## PAWN Sensitivity

# %%
# Define interactive visualisation function to calculate and visualise sensitivity indices
# for the chosen output metric and different choices of the PAWN tuning parameters (n,Nboot,aggr)

def runoff_pawn_function(metric='Mean Runoff', n = 5, aggr = 'median', Nboot = 500):
    # Extract output metric:
    if metric == 'Mean Runoff':
        i = 0
    elif metric == 'Std of Runoff':
        i = 1   
    Y = YY[:, i]; 

    X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
    
    # Apply PAWN
    # Tuning parameters:
    # n = number of conditioning intervals
    # aggr = statistic to aggregate KS values
    # Nboot = number of bootstrapping resamples used to derive confidence bounds of sensitivity indices   

    # Compute sensitivity indices for Nboot bootstrap resamples
    KS_median, KS_mean, KS_max = PAWN.pawn_indices(X, Y, n, Nboot=Nboot)
    # KS_median and KS_mean and KS_max have shape (Nboot, M)
        
    # Compute mean and confidence intervals of the sensitivity indices across the bootstrap resamples:
    KS_median_m, KS_median_lb, KS_median_ub = aggregate_boot(KS_median) # shape (M,)
    KS_mean_m, KS_mean_lb, KS_mean_ub = aggregate_boot(KS_mean) # shape (M,)
    KS_max_m, KS_max_lb, KS_max_ub = aggregate_boot(KS_max) # shape (M,)

    # Plot sensitivity indices:
    plt.figure()
    plt.title("Output Metric for the Runoff = %s" % metric)
    if aggr == 'median':
        pf.boxplot1(KS_median_m, S_lb=KS_median_lb, S_ub=KS_median_ub, X_Labels=X_labels, Y_Label='sensitivity (median KS)')
    if aggr == 'mean':
        pf.boxplot1(KS_mean_m, S_lb=KS_mean_lb, S_ub=KS_mean_ub, X_Labels=X_labels, Y_Label='sensitivity (mean KS)')
    if aggr == 'max':
        pf.boxplot1(KS_max_m, S_lb=KS_max_lb, S_ub=KS_max_ub, X_Labels=X_labels, Y_Label='sensitivity (max KS)')
    plt.show()

interact(runoff_pawn_function, metric = ['Mean Runoff','Std of Runoff'], n = (2, 20, 1), aggr = ['median', 'mean','max'], Nboot = (0, 500, 10));
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %% [markdown]
# We can see that for sensitivity, with the parameter bounds that we have chosen, that for the mean of the runoff, `prcp_fac` is significantly the most impactful parameter, and also appears to have (perhaps) the largest uncertainty.
#
# And for the standard deviation of the runoff, that the `temp_bias` parameter appears to be both the most significant and the most uncertain, with `prcp_fac` following closely behind.

# %% [markdown]
# ## Investigation to reduce range

# %% [markdown]
# Sensitivity analysis is highly reliant on the parameter space chosen in the inputs we are investigating. If they are too large or too small this could seriously throw off our sensitivity results. We know that our parameter ranges are a bit too large for our first try, but we don't necessarily know what the appropriate, more "realistic" ranges of parameters could be here. We do however have the mean annual mass balance value. We can try and reduce the mean bias as much as possible to gather a more realistic range of parameter values to make our sensitvity analysis more appropriate.
#
# Let's investigate the mean bias to investigate the overall fit of our simulations to the observed data. From this analysis, we can derive a set of parameters that are within a specific tolerance to attempt to tune our parameter ranges a bit more closely.

# %% [markdown]
# Firstly, let's investigate that we can actually apply linear regression here to be able to constrain our values.

# %% [markdown]
# Now colour mapping the mean bias to the mass balance timeseries.

# %% [markdown]
# Let's see if this affects the runoff time series in the same way!

# %% [markdown]
# This does affect the runoff similarly! The relationship is perhaps not quite as clean as it is with the mass balance timeseries, but there is still a very clear gradient of the mean bias.

# %% [markdown]
# We can see there are some very large mean bias values here. Now let's investigate these by colour coding our parameters. Due to the very large range of temp_bias it's relationship with the other parameters, lets investigate the behaviour of the samples taken of temp_bias and see if we can reduce the range at all.

# %% [markdown]
# Let's perhaps choose the values with the Mean Bias below a specific threshold and see if this reduces our parameter ranges.

# %% [markdown]
# Now we investigate these points against the Mean MB Bias to see if the values towards the end of the scale do infact cause the Mean MB Bias to be excessively large.

# %% [markdown]
# The above confirms that the high Mean MB Bias confirms with extreme values of the parametes, the Mean MB Bias is maximised, hence verifying that these parameter ranges are unrealistic. We can now work to minimise the parameter ranges within a smaller boundary of the RMSD.
#
# Since we have plotted these points together, we can determine some relationships to provide constraints for our samples for a more realistic parameter space.D
#
# We can see in the above graph for:
# 1. Relationship between the melt factor and the temperature bias, that there is almost a linear relationship split between the feasible and not-feasible combinations of these parameters. This equation can take the form as $ y = -\frac{1}{3}x + 1 $, we can bound the parameters in this way, where $y$ is the temp_bias and $x$ is the melt_f. So that $temp_b \geq -\frac{1}{3}melt_f +1$
#
# 2. For the relationship between the precipitation factor we have a rather clear linear distinction between a larger and smaller Mean MB Bias split around the function $prcp_f = 3$. The smaller Mean MB Bias region here is $prcp_f \leq 3$. The melt factor seems relatively inconsequential here and is dominated by the behaviour of the precipitation factor.
#
# 3. Now looking at the relationship between the precipitation factor and the temperature bias, there is a very clear relationship where there is a significantly larger Mean MB Bias towards significantly smaller temperature biases and larger precipitation factors. This also appears to be a linear relationship around the function $y = 0.8x + 3.5$. So we can bound the parameters so that $prcp_f \leq 0.8temp_b + 3.5$

# %% [markdown]
# Doing this manually would be a slow and iterative technique, with a big chance at human error. So we will attempt to automate this process instead. We will start by using a very simple ML technique, Linear Regression.

# %% [markdown]
# ## ML Linear Regression
#
# We will try out linear regression to find a linear distinction between different metrics in the dataset to be able to determine the best collection of metrics that we can map to find a more feasible parameter range.

# %% [markdown]
# We want to use the mass balance as our results here so we will calculate the mass balance from the output so we can take this from the CSV file from the initial run that we have done.

# %% [markdown]
# First we must verify whether or not our parameters have a linear relationship with the outputs (we will investigate the mean mass balance to investigate whether or not the relationships between the inputs and outputs are linear in our model)

# %% [markdown]
# When looking into other glaciers, we will likely only have access to the Huggonet data, which will be a singular mass balance value over a period of years. To prepare for this, we will focus on using the mean bias to reduce the parameter ranges.

# %% [markdown]
# We can investigate which of these metrics can perform better to constrain the parameters, we will use the metrics of the mass balance between the observed and simulated values: the mean bias.

# %%
index = np.where(years[0] == 2003)[0][0]

area_in_rgi_year = []
for area_sample in area_samples:
    area_in_rgi_year.append(area_sample[index])

area_mean_bias = []

for i in range(len(area_in_rgi_year)):
    area_mean_bias.append((area_in_rgi_year[i] - gdir_hef.rgi_area_km2))

# %%
# compute the 90th percentile (best of abs mean bias 10%)

abs_means = np.abs(area_mean_bias)
thr = np.percentile(abs_means, 10)   # 10% closest to zero

plt.hist(area_mean_bias, bins=30, color='grey', edgecolor='white')

# Shade the region corresponding to the best 10%
plt.axvspan(-thr, thr, color='teal', alpha=0.25, label='Top 10% closest to zero')

# plot vertical lines for clarity
plt.axvline(-thr, color='teal', linestyle='--')
plt.axvline(+thr, color='teal', linestyle='--')

# labels + title
plt.xlabel("Area Bias")
plt.ylabel("Frequency")
plt.title("Distribution of Area Bias at the RGI Year")
plt.legend()

plt.show()

# %%
# compile csvs to plot timeseries and plot to view the mass balance time series for each of the 50 samples, to see how they are looking and check that they make sense before we calculate the sensitivity indices
# Colormap and normalization
cmap = plt.cm.coolwarm

vmin_mean_area = min(area_mean_bias)
vmax_mean_area = max(area_mean_bias)
norm_mean_area = plt.Normalize(vmin=vmin_mean_area, vmax=vmax_mean_area)

# %%
plt.figure(figsize=(15,5))
fig, ax = plt.subplots(figsize=(15, 5))

for i in range(N):
    df = pd.read_csv(cfg.PATHS['working_dir'] + '/' + str(i) + '_hinteresfirner_runoff_output.csv')
    color = cmap(norm_mean_area(area_mean_bias[i]))
    plt.plot(df['years'], df['mass_balance'], label='sim', color=color, linewidth=0.5)
    plt.title('Mass balance time series for each parameter sample, N = %d' % N)

# Add colorbar linked to the same colormap
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm_mean_area)
sm.set_array([])  # required for colorbar
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Area Bias at RGI Year')

plt.xlabel('Years')
plt.ylabel('Mass Balance')
plt.plot(range(2000,2020), mbdf['in_situ_mb'].loc[2000:2019], label='obs', color='r', linewidth=2)

# %%
plt.figure(figsize=(15,5))
fig, ax = plt.subplots(figsize=(15, 5))

for i in range(N):
    df = pd.read_csv(cfg.PATHS['working_dir'] + '/' + str(i) + '_hinteresfirner_runoff_output.csv')
    color = cmap(norm_mean_area(area_mean_bias[i]))
    plt.plot(df['years'], df['runoff_Mt'], label='sim', color=color, linewidth=0.5)
    plt.title('Runoff time series for each parameter sample, N = %d' % N)

# Add colorbar linked to the same colormap
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm_mean_area)
sm.set_array([])  # required for colorbar
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Area Bias at RGI Year')

plt.xlabel('Years')
plt.ylabel('Runoff')
plt.show()
# Out:
# Text(0, 0.5, 'Runoff')

# %%
M = X.shape[1]

import numpy as np
import matplotlib.pyplot as plt

success_index = np.asarray(area_mean_bias)
cmap = plt.cm.coolwarm
norm = plt.Normalize(vmin=success_index.min(), vmax=success_index.max())

j = (i - 1) % X.shape[1]  # previous column (wraps around)
plt.figure(figsize=[15,4])

for i in range(M):
    plt.subplot(1,3,i+1)
    sc = plt.scatter(
        X[:, i], X[:, i-1],
        c=success_index, cmap=cmap, norm=norm, s=20, edgecolors="none"
        )
    if i == 0:   
        
        xmin, xmax = plt.xlim()
        x = np.array([xmin, xmax])
        y = -(1/3)*x + 1

        plt.plot(x, y, color='black', linewidth=1)
        plt.xlabel(X_labels[i]); plt.ylabel(X_labels[i-1])
    if i == 1:
        ymin, ymax = plt.ylim()
        y = np.array([ymin, ymax])
        x = 3 * np.ones_like(y)

        plt.plot(x, y, color='black', linewidth=1)
        plt.xlabel(X_labels[i]); plt.ylabel(X_labels[i-1])
    if i == 2:
        plt.xlim((-3.5, 3.5))
        plt.ylim((0.5, 5.5))
        xmin, xmax = plt.xlim()
        x = np.array([xmin, xmax])
        y = 0.8*x + 3.5

        plt.plot(x, y, color='black', linewidth=1)
        plt.xlabel(X_labels[i]); plt.ylabel(X_labels[i-1])

cbar = plt.colorbar(sc)
cbar.set_label("Area Bias at RGI Year")
ax = plt.gca()

plt.tight_layout(); plt.show()

# %% [markdown]
# From these diagnostics, we can see that our full parameter space is extremely well suited for linear predictability, the top 10% of values less so, but there is still a moderate linear predictability here. This shows that the values still meaningfully map to the bias.
#
# We can also see in the new proposed boundary region, that the melt factor and temperature bias have a strong negative effect on the bias and that the precipitation factor has a strong positive effect on the bias.

# %% [markdown]
# From our linear regression method, choosing the best 10% of mean bias (the 10% smallest abs mean bias values), and their corresponding parameters we get the following as the new reduced ranges:

# %% [markdown]
# ## Now lets look into bounding with the Hugonnet geodetic data

# %%
geo_df = utils.get_geodetic_mb_dataframe()
geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000
# Out:
# /tmp/ipykernel_1236/591556853.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000
# -1100.3

# %% [markdown]
# Hugonnet et al error:

# %%
geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000
# Out:
# /tmp/ipykernel_1236/3900375199.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000
# 171.8

# %%
mb_in_rgi_year = []

for mb_sample in mass_balance_samples:
    mb_in_rgi_year.append(mb_sample[index])

# %%
# compute the 90th percentile (best of abs mean bias 10%)

abs_hugonnet_means = np.abs(mb_in_rgi_year)

plt.hist(mb_in_rgi_year, bins=30, color='grey', edgecolor='white')

hugonnet = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 
upper_error = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 + geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000
lower_error = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 - geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000

# # Shade the region corresponding to the values within the error region
# plot vertical lines for clarity
plt.axvline(upper_error, color='teal', linestyle='--')
plt.axvline(lower_error, color='teal', linestyle='--')
plt.axvline(hugonnet, color='teal')

# Shade the region corresponding to the best 10%
plt.axvspan(lower_error, upper_error, color='teal', alpha=0.25, label='Hugonnet data with 1-sigma uncertainty')

# labels + title
plt.xlabel("Mean mass balance over observation period")
plt.ylabel("Frequency")
plt.title("Simulated Mean Mass Balance in the Observation Period with Hugonnet Obervations and Uncertainty Marked")
plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_1236/3229534486.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hugonnet = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000
# /tmp/ipykernel_1236/3229534486.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   upper_error = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 + geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000
# /tmp/ipykernel_1236/3229534486.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lower_error = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 - geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000

# %%
new_lower_bounds, new_upper_bounds = parameter_bounding(X, y_area = area_mean_bias, y_hugonnet=mb_in_rgi_year, percentile=10, hugonnet_bounding_flag= True, lower_error=lower_error, upper_error=upper_error)

print("New lower bounds", new_lower_bounds)
print("New upper bounds", new_upper_bounds)
# Out:
# New lower bounds [1.68143596 1.03247605 0.18999555]
# New upper bounds [3.30457875 2.64806448 2.98221939]

# %% [markdown]
# These ranges are reduced compared to before. With the main reduction being the lower end of the temperature bias. Let's now generate the new outputs with these reduced parameter ranges and see how the model performs. Here we can validate that our metrics are actually now improved from before.

# %%
# Generate a fresh set of samples with no constraints

X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
M = len(X_labels)

# gdir_hef.settings['error_when_glacier_reaches_boundaries'] = False # TODO- When more realistic, I assume we will not need this? 
distr_fun = st.uniform # Uniform distribution for all parameters
x_min = new_lower_bounds # Minimum values for each parameter
x_max = new_upper_bounds # Maximum values for each parameter
# The default ranges error with the dynamic spinup, we need to reduce these ranges - ideally to something closer to the Hinteresfirner glacier to be able to complete a dynamic spinup
# Some of these output values are 0 for runoff, 
distr_par = [np.nan] * M
for i in range(M):
    distr_par[i] = [x_min[i], x_max[i] - x_min[i]]
    
samp_strat = 'lhs' 

N = 1000 # Number of samples
X_new = AAT_sampling(samp_strat, M, distr_fun, distr_par, N) # Generate the samples

YY_new = runoff_execution(fun_test = run_with_runoff_for_sa, 
                 X = X_new, #All samples
                 gdir = gdir_hef, # Hinteresfirner Glacier directory
                 years =range(1979, 2020), # years
                 init_model_yr = 1901, # Simulation start year - needs to be early enough to allow for spinup before the period we are interested in
                 ys =1901, # Was 1979
                 min_ys = 1901, # Was 1979
                 ref_area_yr = 2004, # Reference area year - needs to be a year for which we have observed area data for the glacier, so we can use this to constrain the modelled glacier area during the spinup period
                 spinup_period = 21, # Spinup period in years (we are cutting this off, once the glacier has reached an equilibrium state, but this can be changed to a different period if desired)
                 csv_filepath = 'new_runoff_output.csv',
                 params_csv_filepath = 'new_params.csv',
                 run_task = tasks.run_from_climate_data,
                 mb_model_method = MultipleFlowlineMassBalance)
# Out:
# 2026-03-05 11:02:42: oggm.workflow: Execute entity tasks [run_with_runoff_for_sa] on 1000 glaciers
# 2026-03-05 11:02:45: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:45: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:45: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:45: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:45: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:45: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:45: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:45: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:46: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:46: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:47: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:49: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:49: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:49: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:50: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:50: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:50: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:50: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:51: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:51: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:51: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:52: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:52: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:52: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:52: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:53: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:53: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:53: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:54: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:54: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:54: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:54: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:54: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:56: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:59: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:59: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:02:59: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:00: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:00: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:00: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:01: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:01: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:01: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:01: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:02: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:02: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:02: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:02: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:03: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:04: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:04: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:06: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:06: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:06: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:08: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:08: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:08: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:09: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:09: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:09: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:10: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:11: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:11: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:11: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:11: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:12: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:13: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:13: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:13: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:14: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:14: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:14: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:14: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:15: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:15: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:15: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:15: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:16: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:16: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:16: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:17: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:17: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:17: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:17: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:18: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:19: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:19: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:19: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:20: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:20: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:21: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:21: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:22: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:22: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:22: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:22: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:22: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:22: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:23: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:23: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:23: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:23: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:23: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:24: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:24: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:24: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:25: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:25: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:25: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:26: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:26: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:27: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:27: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:28: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:28: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:28: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:28: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:29: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:29: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:29: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:29: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:29: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:30: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:30: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:30: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:31: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:31: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:31: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:31: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:31: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:32: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:32: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:32: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:34: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:34: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:35: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:35: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:35: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:36: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:37: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:37: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:38: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:38: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:38: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:38: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:40: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:41: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:41: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:42: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:42: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:42: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:42: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:42: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:43: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:43: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:43: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:43: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:43: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:44: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:44: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:44: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:44: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:44: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:44: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:03:44: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# ...
# 2026-03-05 11:07:50: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:50: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:51: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:51: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:51: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:52: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:52: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:52: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:53: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:53: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:53: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:55: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:56: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:57: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:58: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:59: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:07:59: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:00: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:00: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:01: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:03: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:04: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:04: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:04: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:04: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:05: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:06: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:06: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:07: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:08: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:08: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:09: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:11: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:11: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:11: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:11: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:12: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:12: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:12: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:12: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:12: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:12: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:12: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:13: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:13: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# 2026-03-05 11:08:13: oggm.core.flowline: You are attempting to run_with_climate_data at dates prior to the RGI inventory date. This may indicate some problem in your workflow. Consider using `fixed_geometry_spinup_yr` for example.
# <class 'list'> 1000

# %% [markdown]
# Now lets explore the new behaviour of the outputs. We will start by investigating the difference between the mass balance performance metrics since we have some oberved values to compare to. This can validate the success of our parameter bounding here.

# %% [markdown]
# Firstly, reading the new metrics from the CSVs for our analysis.

# %%
from oggm.utils import rmsd

new_mass_balance_samples = []
new_years = []
new_runoff_samples = []
new_area_samples = []
new_params = []

for i in range(N):
    new_df = pd.read_csv(cfg.PATHS['working_dir'] + '/' + str(i) + '_new_runoff_output.csv')
    new_mass_balance_samples.append(new_df['mass_balance'].values)
    new_years.append(new_df['years'].values)
    new_runoff_samples.append(new_df['runoff_Mt'].values)
    new_area_samples.append(new_df['area_km2'].values)

    new_param_df = pd.read_csv(cfg.PATHS['working_dir'] + '/' + str(i) + '_new_params.csv')
    new_params.append(new_param_df)

new_means = []
new_stds = []
new_rmsds = []  

# Calculating our fit-to-data metrics

for i in range(len(new_mass_balance_samples)):
    new_means.append(new_mass_balance_samples[i].mean() - mbdf['in_situ_mb'].loc[2000:2019].mean())
    new_stds.append(new_mass_balance_samples[i].std() - mbdf['in_situ_mb'].loc[2000:2019].std())
    new_rmsds.append(rmsd(new_mass_balance_samples[i], mbdf['in_situ_mb'].loc[2000:2019].values))

# %%
try:
    X_new
except NameError:
    X_new = np.vstack([p.values for p in new_params])

try:
    YY_new
except NameError:
    YY_new = hydro_output_metric_calculator(new_runoff_samples)

# %%
Y_lab_runoff_dist = ['Mean Runoff', 'Std of Runoff']

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(new_means, bins=50, color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel('Mean MB Bias')

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(new_stds, bins=50, color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel('Std MB Bias')

plt.subplot(1,3,3), plt.title('Distribution of output samples', loc='left'), plt.hist(new_rmsds, bins=50, color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel('MB RMSDs')

plt.tight_layout()

# %%
plt.figure(figsize=(15,5))

# Check the area from the observed, why is it so low compared to the simulation?

for i in range(N):
    area_km2 = new_area_samples[i]
    plt.plot(new_years[i], area_km2, label='sim', color='k', linewidth=0.5)
    
plt.scatter(gdir_hef.rgi_date, gdir_hef.rgi_area_km2, color='r', s=20, zorder=999)
plt.title('Area time series for each parameter sample, N = %d' % N)
plt.ylabel('Glacier area (km$^2$)')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# We can see above that the mean bias of the mass balance and the standard deviation are still normally distributed, and both of which are now reduced in range than the values we were seeing before constraining the parameters, suggesting that the new parameter range is more realistic than before. We can also see that the RMSD also now has a similar skewed behaviour as before (due to the functions behaviour limiting it to only positive values), the range here is also much smaller than before.

# %%
index = np.where(years[0] == 2003)[0][0]

new_area_in_rgi_year = []
for new_area_sample in new_area_samples:
    new_area_in_rgi_year.append(new_area_sample[index])

new_area_mean_bias = []

for i in range(len(new_area_in_rgi_year)):
    new_area_mean_bias.append((new_area_in_rgi_year[i] - gdir_hef.rgi_area_km2))

# %%
# compile csvs to plot timeseries and plot to view the mass balance time series for each of the 50 samples, to see how they are looking and check that they make sense before we calculate the sensitivity indices
# Colormap and normalization
cmap = plt.cm.coolwarm

vmin_mean_area = min(new_area_mean_bias)
vmax_mean_area = max(new_area_mean_bias)
new_norm_mean_area = plt.Normalize(vmin=vmin_mean_area, vmax=vmax_mean_area)

# %%
# compute the 90th percentile (best of abs mean bias 10%)

abs_means = np.abs(new_area_mean_bias)
# thr = np.percentile(abs_means, 10)   # 10% closest to zero

plt.hist(new_area_mean_bias, bins=30, color='grey', edgecolor='white')

# labels + title
plt.xlabel("Area Bias")
plt.ylabel("Frequency")
plt.title("Distribution of Area Bias at the RGI Year")
plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_1236/1624913450.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(15,5))
fig, ax = plt.subplots(figsize=(15, 5))

for i in range(N):
    new_df = pd.read_csv(cfg.PATHS['working_dir'] + '/' + str(i) + '_new_runoff_output.csv')
    color = cmap(new_norm_mean_area(new_area_mean_bias[i]))
    plt.plot(new_df['years'], new_df['mass_balance'], label='sim', color=color, linewidth=0.5)
    plt.title('Mass balance time series for each parameter sample, N = %d' % N)

# Add colorbar linked to the same colormap
sm = plt.cm.ScalarMappable(cmap=cmap, norm=new_norm_mean_area)
sm.set_array([])  # required for colorbar
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Area Bias at RGI Year')

plt.xlabel('Years')
plt.ylabel('Mass Balance')
plt.plot(range(2000,2020), mbdf['in_situ_mb'].loc[2000:2019], label='obs', color='r', linewidth=2)

# %%
plt.figure(figsize=(15,5))
fig, ax = plt.subplots(figsize=(15, 5))

for i in range(N):
    new_df = pd.read_csv(cfg.PATHS['working_dir'] + '/' + str(i) + '_new_runoff_output.csv')
    color = cmap(new_norm_mean_area(new_area_mean_bias[i]))
    plt.plot(new_df['years'], new_df['runoff_Mt'], label='sim', color=color, linewidth=0.5)
    plt.title('Runoff time series for each parameter sample, N = %d' % N)

# Add colorbar linked to the same colormap
sm = plt.cm.ScalarMappable(cmap=cmap, norm=new_norm_mean_area)
sm.set_array([])  # required for colorbar
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Area Bias at RGI Year')

plt.xlabel('Years')
plt.ylabel('Runoff')
plt.show()

# %%
new_mb_in_rgi_year = []

for mb_sample in new_mass_balance_samples:
    new_mb_in_rgi_year.append(mb_sample[index])

# %%
# compute the 90th percentile (best of abs mean bias 10%)

abs_hugonnet_means = np.abs(new_mb_in_rgi_year)
plt.hist(new_mb_in_rgi_year, bins=30, color='grey', edgecolor='white')

hugonnet = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 
upper_error = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 + geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000
lower_error = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 - geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000

# # Shade the region corresponding to the corresponding values within the error region
# plot vertical lines for clarity
plt.axvline(upper_error, color='teal', linestyle='--')
plt.axvline(lower_error, color='teal', linestyle='--')
plt.axvline(hugonnet, color='teal')

# Shade the region corresponding to the best 10%
plt.axvspan(lower_error, upper_error, color='teal', alpha=0.25, label='Hugonnet data with 1-sigma uncertainty')

# labels + title
plt.xlabel("Mean mass balance over observation period")
plt.ylabel("Frequency")
plt.title("Simulated Mean Mass Balance in the Observation Period with Hugonnet Obervations and Uncertainty Marked")
plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_1236/1179611335.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hugonnet = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000
# /tmp/ipykernel_1236/1179611335.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   upper_error = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 + geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000
# /tmp/ipykernel_1236/1179611335.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lower_error = geo_df.loc[gdir_hef.rgi_id]['dmdtda'][1] * 1000 - geo_df.loc[gdir_hef.rgi_id]['err_dmdtda'][1] * 1000

# %%
plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.scatter(YY_new[:,0], YY_new[:,1], s=5), plt.title('Mean runoff vs Std of runoff'), plt.xlabel('Mean runoff'), plt.ylabel('Std of runoff (mm w.e.)'),

plt.tight_layout()
plt.show()

# %% [markdown]
# Now investigating the runoff output behaviour, we can see that the mean runoff and std of runoff are now both smaller in magnitude, with a slightly tighter positive correlation than before.

# %%
Y_lab_runoff_dist = ['Mean Runoff', 'Std of Runoff']

plt.figure(figsize=[13,4])
plt.subplot(1,3,1), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_new[:,0], bins=50, color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel(Y_lab_runoff_dist[0])

plt.subplot(1,3,2), plt.title('Distribution of output samples', loc='left'), plt.hist(YY_new[:,1], bins=50, color='grey');
plt.ylabel('Frequency of samples'), plt.xlabel(Y_lab_runoff_dist[1])

plt.tight_layout()

# %%
# Now let's investigate these simulations by plotting the parameters against the RMSD values, to see if we can identify any relationships between the parameters and the performance of the simulations in terms of matching the observed mass balance time series.
Y_Labels = ['Mean Runoff', 'Std of Runoff']
# Read the parameters for each simulation

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])

    for i in range(M):
        plt.subplot(1,M,i+1)
        # Use scatter with color mapped to temp_bias
        sc = plt.scatter(X_new[:, i], X_new[:, i-1], 
                         c=YY_new[:,j], cmap='coolwarm', edgecolors='grey')
        
        plt.ylabel(X_labels[i-1])    
        plt.xlabel(X_labels[i])      

        # Add colorbar only once
        if i == M-1:
            cbar = plt.colorbar(sc)
            cbar.set_label(metric +'(Mt)')

    plt.show()

interact(scatter_function, metric=Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %%
M = X.shape[1]

import numpy as np
import matplotlib.pyplot as plt

new_success_index = np.asarray(new_area_mean_bias)
cmap = plt.cm.coolwarm
norm = plt.Normalize(vmin=new_success_index.min(), vmax=new_success_index.max())

j = (i - 1) % X.shape[1]  # previous column (wraps around)
plt.figure(figsize=[15,4])

for i in range(M):
    plt.subplot(1,3,i+1)
    sc = plt.scatter(
        X_new[:, i], X_new[:, i-1],
        c=new_success_index, cmap=cmap, norm=norm, s=20, edgecolors="none"
        )
    if i == 0:   
        plt.xlabel(X_labels[i]); plt.ylabel(X_labels[i-1])
    if i == 1:
        ymin, ymax = plt.ylim()
        plt.xlabel(X_labels[i]); plt.ylabel(X_labels[i-1])
    if i == 2:
        plt.xlabel(X_labels[i]); plt.ylabel(X_labels[i-1])

cbar = plt.colorbar(sc)
cbar.set_label("Mean MB Bias")
ax = plt.gca()

plt.tight_layout(); plt.show()

# %% [markdown]
# ## Qualitative Sensitivity

# %%
Y_Labels = ['Mean Runoff', 'Std of Runoff']

def scatter_function(metric='Mean Runoff'):
    if metric == 'Mean Runoff':
        j = 0
    elif metric == 'Std of Runoff':
        j = 1  

    plt.figure(figsize=[18,3])
    for i in range(M):
        plt.subplot(1,M,i+1)
        plt.plot(X_new[:, i], YY_new[:,j], '.', markerfacecolor="white", markeredgecolor="grey")        
        if i == 0:
            plt.ylabel(Y_Labels[j])
        else:
            plt.yticks([])       
        plt.xlabel(X_labels[i])       
    plt.show()

interact(scatter_function,  metric = Y_Labels);
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…

# %% [markdown]
# ## PAWN Sensitivity

# %%
# Define interactive visualisation function to calculate and visualise sensitivity indices
# for the chosen output metric and different choices of the PAWN tuning parameters (n,Nboot,aggr)

def runoff_pawn_function(metric='Mean Runoff', n = 5, aggr = 'median', Nboot = 500):
    # Extract output metric:
    if metric == 'Mean Runoff':
        i = 0
    elif metric == 'Std of Runoff':
        i = 1   
    Y = YY_new[:, i]; 

    X_labels = ['melt_f', 'prcp_fac', 'temp_bias']
    
    # Apply PAWN
    # Tuning parameters:
    # n = number of conditioning intervals
    # aggr = statistic to aggregate KS values
    # Nboot = number of bootstrapping resamples used to derive confidence bounds of sensitivity indices   

    # Compute sensitivity indices for Nboot bootstrap resamples
    KS_median, KS_mean, KS_max = PAWN.pawn_indices(X_new, Y, n, Nboot=Nboot)
    # KS_median and KS_mean and KS_max have shape (Nboot, M)
        
    # Compute mean and confidence intervals of the sensitivity indices across the bootstrap resamples:
    KS_median_m, KS_median_lb, KS_median_ub = aggregate_boot(KS_median) # shape (M,)
    KS_mean_m, KS_mean_lb, KS_mean_ub = aggregate_boot(KS_mean) # shape (M,)
    KS_max_m, KS_max_lb, KS_max_ub = aggregate_boot(KS_max) # shape (M,)

    # Plot sensitivity indices:
    plt.figure()
    plt.title("Output Metric for the Runoff = %s" % metric)
    if aggr == 'median':
        pf.boxplot1(KS_median_m, S_lb=KS_median_lb, S_ub=KS_median_ub, X_Labels=X_labels, Y_Label='sensitivity (median KS)')
    if aggr == 'mean':
        pf.boxplot1(KS_mean_m, S_lb=KS_mean_lb, S_ub=KS_mean_ub, X_Labels=X_labels, Y_Label='sensitivity (mean KS)')
    if aggr == 'max':
        pf.boxplot1(KS_max_m, S_lb=KS_max_lb, S_ub=KS_max_ub, X_Labels=X_labels, Y_Label='sensitivity (max KS)')
    plt.show()

interact(runoff_pawn_function, metric = ['Mean Runoff','Std of Runoff'], n = (2, 20, 1), aggr = ['median', 'mean','max'], Nboot = (0, 500, 10));
# Out:
# interactive(children=(Dropdown(description='metric', options=('Mean Runoff', 'Std of Runoff'), value='Mean Run…
